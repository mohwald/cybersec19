# %%
# %matplotlib inline

import numpy as np
import pandas as pd

import math
import scipy.stats as st
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib
import seaborn as sns

import copy
import os
import pprint
import time

from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics

# %% [markdown]
# # Starter functions

# %% [markdown]
# # Load data

# %%
df_train = pd.read_json(os.path.join('dataset', 'train.json'), lines=True)

# %%
df_test = pd.read_json(os.path.join('dataset', 'test.json'), lines=True)

# %%
df_train
# Out:
#           device_class                             device_id  \
# 0             IP_PHONE  5347ada9-925c-400e-8a7c-9aedd3c142f6
# 1            MEDIA_BOX  2717684b-3937-4644-a33a-33f4226c43ec
# 2                AUDIO  f1fc42f4-c794-4cc5-ac13-a5097d722d92
# 3         GAME_CONSOLE  74ab1b5b-3cb6-4aee-8362-f3b2f016574c
# 4          GENERIC_IOT  1fe43d89-329d-40fe-b948-d1cbe0fe6c96
# 5      VOICE_ASSISTANT  8bb8971c-5983-4baa-9753-f0ac21faf162
# 6                AUDIO  0acd15a9-c52a-4980-bf30-a8c8f5042412
# 7      VOICE_ASSISTANT  6d559ddb-84ac-4e47-83bb-e3bff6e53afe
# 8             IP_PHONE  c69cc92a-a813-4312-9993-7816994bc04d
# 9             IP_PHONE  db9bdc04-0322-424a-a3d1-57432f1c7326
# 10        SURVEILLANCE  9c4d7661-fc06-4c60-bb21-90fc1ebef24f
# 11           MEDIA_BOX  05812c2f-91f3-4623-a4a0-c6b3f9bd738d
# 12                  TV  79df3990-f059-4afc-924b-e242ef33ec81
# 13     HOME_AUTOMATION  b51c7109-22c1-4c32-8d8a-cbb8cf0d768c
# 14                  TV  4f3da75c-f6a7-4a19-b5bb-dcb8db930103
# 15            IP_PHONE  5f31e08e-43ba-48cf-bd2f-28e99db89210
# 16             PRINTER  e4b31f3b-35cb-499f-a7b2-b5bc93201a1a
# 17     VOICE_ASSISTANT  1b6a283c-00cd-4ac0-b539-499eb25fa346
# 18        SURVEILLANCE  c8f5d594-8586-4bba-8639-d47977a08925
# 19               AUDIO  4bcaf7f6-a373-4ab7-862c-830b8c452306
# 20                  PC  55ee0395-8818-4751-b7bd-ad39d21aad14
# 21     HOME_AUTOMATION  57c61eb8-32ac-44f3-b539-699a78429567
# 22            IP_PHONE  57d31527-2223-4288-9577-0cf33155200b
# 23     VOICE_ASSISTANT  8a35a985-6376-4a78-8f04-d11f5d73e76a
# 24     VOICE_ASSISTANT  8f3836a5-b199-468b-a190-d98d9aa5cf54
# 25           MEDIA_BOX  6bb435ba-fff0-4463-8da9-c16a06d7e713
# 26           MEDIA_BOX  01a8f47b-ef71-4d9c-9109-745b9ac01963
# 27                  PC  074dccdc-f9e0-4cb4-9753-e47d254d3058
# 28               AUDIO  f9386aed-6967-434b-a47a-4328a89bc610
# 29               AUDIO  89511b47-c1ee-4ad9-90b5-73c43ee84b02
# ...                ...                                   ...
# 57876     SURVEILLANCE  316cfcfb-3f48-4e47-87fd-7def2a37036d
# 57877               TV  558a0f9d-c3f2-4e5e-a772-df6d639f7f1b
# 57878     GAME_CONSOLE  d57a9982-f26a-402f-9e3c-9d4825e10abd
# 57879        MEDIA_BOX  1d6ba5e4-92ae-4ae0-a2d8-620865996dcd
# 57880  HOME_AUTOMATION  e10f34d0-9093-462f-8c9d-0a921b3675d6
# 57881     GAME_CONSOLE  b3fe41d3-9ffb-4f05-b4e3-b9ccbeb9384c
# 57882            AUDIO  9b7eb0fe-9950-407b-a4eb-efe0469d5752
# 57883            AUDIO  c9610125-ead6-4441-a317-f05de7d3bbf4
# 57884  HOME_AUTOMATION  e34bb1dc-d3f7-4c25-ab11-3a5f05479b9f
# 57885          PRINTER  847b6464-2639-4e98-8b0b-27fa5521d8a9
# 57886         IP_PHONE  86945718-f7e6-4601-b513-2d3e8b965fb5
# 57887      GENERIC_IOT  7b86aadd-07a2-446b-bc22-aeff50ec9747
# 57888     SURVEILLANCE  e67b8049-c787-4974-b54e-5fbe18d64db6
# 57889            AUDIO  9819b562-48d1-4b7b-b1de-634adb5ab2fd
# 57890  HOME_AUTOMATION  cee590dc-ce49-422f-bfc8-fb331b1fac27
# 57891      GENERIC_IOT  e8a3540d-3f40-4ec9-bbd6-22f280b8d610
# 57892      GENERIC_IOT  cd545576-9234-43bc-9487-2834a201878c
# 57893               PC  d57786cc-fca1-42a1-ade3-97a4ce72c699
# 57894            AUDIO  2259e011-91b2-4fe2-9ecb-42df9fade6ee
# 57895        MEDIA_BOX  67d5e9c6-6996-4d26-b53d-df35a82f90ed
# 57896  HOME_AUTOMATION  96944b2a-fcf8-476b-9956-f7bc01e2777e
# 57897               TV  1b8ba593-bc19-4539-a21f-20e7fdba923c
# 57898  HOME_AUTOMATION  33fef0fe-2528-41e2-91db-844bb2f93c8f
# 57899         IP_PHONE  fae14115-7db4-44cf-a2ad-bf298c5a0c49
# 57900  HOME_AUTOMATION  35ea1129-f161-4b0e-b82a-d3531fe3eeec
# 57901        MEDIA_BOX  c61bf8f6-7cc2-4ed9-b9cf-80e3d02aa92b
# 57902        MEDIA_BOX  4180e4bc-5b80-40d7-9943-079fb33113db
# 57903        MEDIA_BOX  dea61f2a-d750-4b1a-9d01-3c089ca14bc7
# 57904               TV  4dbc81a5-166d-4430-b72d-565f7c18dd60
# 57905  HOME_AUTOMATION  94b23284-1611-4c7c-b91b-27d016c3127e
#
#                                                     dhcp              ip  \
# 0                                                    NaN   192.168.0.147
# 1                                                    NaN   192.168.1.109
# 2                                                    NaN   192.168.1.121
# 3                                                    NaN     192.168.0.7
# 4      [{'paramlist': '1,28,2,3,15,6,119,12,44,47,26,...   192.168.15.26
# 5                                                    NaN    192.168.1.80
# 6                                                    NaN  192.168.254.24
# 7                                                    NaN  192.168.178.29
# 8                                                    NaN   172.26.17.234
# 9                                                    NaN   172.26.17.238
# 10                                                   NaN    192.168.1.64
# 11                                                   NaN    192.168.0.49
# 12     [{'paramlist': '252,3,42,15,6,1,12', 'classid'...   192.168.0.120
# 13                                                   NaN    192.168.1.62
# 14                                                   NaN    192.168.0.12
# 15                                                   NaN   192.168.1.123
# 16                                                   NaN   192.168.1.132
# 17                                                   NaN       10.1.2.83
# 18                                                   NaN   192.168.1.209
# 19                                                   NaN    192.168.2.11
# 20     [{'paramlist': '1,3,6,15,31,33,43,44,46,47,119...
# 21                                                   NaN    192.168.1.71
# 22                                                   NaN   192.168.0.105
# 23                                                   NaN    192.168.1.10
# 24                                                   NaN  192.168.178.58
# 25                                                   NaN     192.168.1.6
# 26                                                   NaN   192.168.1.131
# 27     [{'paramlist': '1,15,3,6,44,46,47,31,33,121,24...    192.168.1.54
# 28                                                   NaN   192.168.1.250
# 29                                                   NaN  192.168.178.52
# ...                                                  ...             ...
# 57876                                                NaN   192.168.1.213
# 57877                                                NaN  192.168.178.24
# 57878                        [{'paramlist': '1,3,15,6'}]      10.0.0.206
# 57879                                                NaN    192.168.0.13
# 57880                                                NaN   192.168.66.13
# 57881                                                NaN    192.168.0.10
# 57882                                                NaN    192.168.0.49
# 57883                                                NaN    192.168.0.10
# 57884                                                NaN    192.168.0.14
# 57885                                                NaN  192.168.178.21
# 57886                                                NaN   192.168.1.213
# 57887  [{'paramlist': '1,28,2,3,15,6,119,12,44,47,26,...   192.168.1.195
# 57888                                                NaN  192.168.62.104
# 57889                                                NaN    192.168.1.91
# 57890                                                NaN  192.168.178.22
# 57891  [{'paramlist': '1,3,28,6,15,44,46,47,31,33,121...   192.168.1.136
# 57892  [{'paramlist': '1,3,28,6,15,44,46,47,31,33,121...  192.168.178.38
# 57893                                                NaN     192.168.1.5
# 57894                                                NaN    192.168.1.10
# 57895                                                NaN     192.168.0.7
# 57896                                                NaN   192.168.0.154
# 57897                        [{'paramlist': '1,3,15,6'}]   192.168.1.136
# 57898                                                NaN    192.168.1.69
# 57899                                                NaN      10.50.1.78
# 57900                      [{'paramlist': '1,2,3,6,69'}]    192.168.1.11
# 57901                                                NaN    192.168.1.95
# 57902  [{'paramlist': '1,33,3,6,15,28,51,58,59', 'cla...
# 57903                                                NaN    192.168.1.14
# 57904                                                NaN     192.168.1.2
# 57905                                                NaN    192.168.1.47
#
#                      mac                                      mdns_services  \
# 0      80:5e:c0:41:ad:39                                                NaN
# 1      44:e1:37:a2:ec:c1                                                NaN
# 2      00:00:00:00:00:00  [_airplay._tcp.local., _spotify-connect._tcp.l...
# 3      40:99:22:41:ac:a6                     [_spotify-connect._tcp.local.]
# 4      00:07:25:15:3a:fb                                                NaN
# 5      ac:63:be:a5:50:43  [_workstation._tcp.local., _ssh._tcp.local., _...
# 6      00:0e:58:fc:40:60                     [_spotify-connect._tcp.local.]
# 7      40:b4:cd:41:f0:cc  [_workstation._tcp.local., _ssh._tcp.local., _...
# 8      00:08:5d:22:fd:c5                                                NaN
# 9      00:08:5d:22:fd:d2                                                NaN
# 10     70:ee:50:29:b3:dc                                 [_hap._tcp.local.]
# 11     00:24:d4:79:dd:5f              [_raop._tcp.local., _hid._udp.local.]
# 12     c4:36:6c:84:47:fc                                                NaN
# 13     70:ee:50:0a:3a:d3                                 [_hap._tcp.local.]
# 14     78:bd:bc:30:83:67                                                NaN
# 15     80:5e:c0:03:ce:08                                                NaN
# 16     5c:ea:1d:32:5d:88                                                NaN
# 17     68:54:fd:9c:17:2c  [_workstation._tcp.local., _ssh._tcp.local., _...
# 18     64:db:8b:39:e4:42  [_psia._tcp.local., _CGI._tcp.local., _http._t...
# 19     00:05:cd:55:eb:86                     [_spotify-connect._tcp.local.]
# 20     b0:6e:bf:30:26:aa                        [_nvstream_dbd._tcp.local.]
# 21     00:d0:2d:93:18:d0               [_hap._tcp.local., _iri._tcp.local.]
# 22     80:5e:c0:0d:23:60                                                NaN
# 23     48:d6:d5:5b:be:f9  [_googlecast._tcp.local., _googlezone._tcp.loc...
# 24     44:07:0b:d8:05:97  [_googlecast._tcp.local., _googlezone._tcp.loc...
# 25     9c:80:df:ed:19:0b  [_googlecast._tcp.local., _androidtvremote._tc...
# 26     00:00:00:00:00:00                                                NaN
# 27     74:d4:35:04:84:f2                                                NaN
# 28     b8:bb:af:e4:5b:0c                     [_spotify-connect._tcp.local.]
# 29     00:05:cd:9f:de:76                                                NaN
# ...                  ...                                                ...
# 57876  00:1b:fe:05:2b:75                                [_http._tcp.local.]
# 57877  04:4e:af:1a:d0:f5                                                NaN
# 57878  d4:4b:5e:ae:08:14                                                NaN
# 57879  00:24:d4:a8:35:47              [_raop._tcp.local., _hid._udp.local.]
# 57880  b8:d7:af:2b:e4:75              [_hap._tcp.local., _coap._udp.local.]
# 57881  00:00:00:00:00:00                          [_googlecast._tcp.local.]
# 57882  00:05:cd:62:6f:b1                                                NaN
# 57883  00:05:cd:f1:9d:ff  [_airplay._tcp.local., _spotify-connect._tcp.l...
# 57884  70:ee:50:1b:ec:39                                 [_hap._tcp.local.]
# 57885  30:cd:a7:a7:b4:2a  [_ipp._tcp.local., _printer._tcp.local., _pdl-...
# 57886  00:08:5d:97:4e:71                                                NaN
# 57887  00:07:25:16:6b:e3                                                NaN
# 57888  b2:c5:54:45:e7:90                                [_http._tcp.local.]
# 57889  00:0e:58:b6:e3:4c                     [_spotify-connect._tcp.local.]
# 57890  a0:c9:a0:d6:b8:bc              [_hap._tcp.local., _coap._udp.local.]
# 57891  60:01:94:1d:ec:93                                                NaN
# 57892  ec:fa:bc:8c:e3:0d                                                NaN
# 57893  00:25:4b:a7:f7:81  [_afpovertcp._tcp.local., _smb._tcp.local., _s...
# 57894  74:5e:1c:ae:30:3d  [_airplay._tcp.local., _spotify-connect._tcp.l...
# 57895  34:27:92:80:72:3c  [_spotify-connect._tcp.local., _raop._tcp.loca...
# 57896  44:61:32:e7:35:38                                 [_hap._tcp.local.]
# 57897  a8:23:fe:1e:9e:9f                                                NaN
# 57898  d0:73:d5:23:2e:cc                                 [_hap._tcp.local.]
# 57899  00:15:65:e6:9d:fa                                                NaN
# 57900  d0:73:d5:29:72:2a                                 [_hap._tcp.local.]
# 57901  a8:d3:f7:f7:4e:5f  [_androidtvremote._tcp.local., _spotify-connec...
# 57902  f4:f5:d8:54:e8:39  [_googlecast._tcp.local., _googlezone._tcp.loc...
# 57903  7c:03:d8:3e:38:94                                                NaN
# 57904  84:9c:a6:d3:a8:55                                                NaN
# 57905  70:ee:50:30:a5:af                                 [_hap._tcp.local.]
#
#                                                 services  \
# 0      [{'port': 80, 'protocol': 'tcp'}, {'port': 443...
# 1      [{'port': 80, 'protocol': 'tcp'}, {'port': 443...
# 2      [{'port': 80, 'protocol': 'tcp'}, {'port': 80,...
# 3      [{'port': 5353, 'protocol': 'udp'}, {'port': 4...
# 4                                                    NaN
# 5      [{'port': 22, 'protocol': 'tcp'}, {'port': 407...
# 6      [{'port': 1400, 'protocol': 'tcp'}, {'port': 1...
# 7      [{'port': 22, 'protocol': 'tcp'}, {'port': 407...
# 8      [{'port': 80, 'protocol': 'tcp'}, {'port': 443...
# 9      [{'port': 80, 'protocol': 'tcp'}, {'port': 443...
# 10     [{'port': 80, 'protocol': 'tcp'}, {'port': 500...
# 11     [{'port': 80, 'protocol': 'tcp'}, {'port': 554...
# 12                                                    []
# 13     [{'port': 5001, 'protocol': 'tcp'}, {'port': 5...
# 14     [{'port': 68, 'protocol': 'udp'}, {'port': 190...
# 15     [{'port': 80, 'protocol': 'tcp'}, {'port': 443...
# 16     [{'port': 80, 'protocol': 'tcp'}, {'port': 443...
# 17     [{'port': 22, 'protocol': 'tcp'}, {'port': 407...
# 18                                                    []
# 19     [{'port': 80, 'protocol': 'tcp'}, {'port': 80,...
# 20     [{'port': 5353, 'protocol': 'udp'}, {'port': 4...
# 21     [{'port': 80, 'protocol': 'tcp'}, {'port': 535...
# 22     [{'port': 80, 'protocol': 'tcp'}, {'port': 443...
# 23     [{'port': 427, 'protocol': 'udp'}, {'port': 44...
# 24     [{'port': 53, 'protocol': 'udp'}, {'port': 123...
# 25     [{'port': 5000, 'protocol': 'tcp'}, {'port': 5...
# 26     [{'port': 80, 'protocol': 'tcp'}, {'port': 190...
# 27     [{'port': 135, 'protocol': 'tcp'}, {'port': 19...
# 28     [{'port': 1900, 'protocol': 'udp'}, {'port': 5...
# 29     [{'port': 80, 'protocol': 'tcp'}, {'port': 111...
# ...                                                  ...
# 57876  [{'port': 67, 'protocol': 'udp'}, {'port': 80,...
# 57877  [{'port': 1062, 'protocol': 'tcp'}, {'port': 9...
# 57878                                                NaN
# 57879  [{'port': 80, 'protocol': 'tcp'}, {'port': 554...
# 57880  [{'port': 80, 'protocol': 'tcp'}, {'port': 535...
# 57881  [{'port': 139, 'protocol': 'tcp'}, {'port': 44...
# 57882                                                 []
# 57883                                                 []
# 57884  [{'port': 5001, 'protocol': 'tcp'}, {'port': 5...
# 57885  [{'port': 80, 'protocol': 'tcp'}, {'port': 515...
# 57886  [{'port': 21, 'protocol': 'tcp'}, {'port': 80,...
# 57887  [{'port': 68, 'protocol': 'udp'}, {'port': 535...
# 57888                                                 []
# 57889  [{'port': 1400, 'protocol': 'tcp'}, {'port': 1...
# 57890  [{'port': 68, 'protocol': 'udp'}, {'port': 80,...
# 57891                                                NaN
# 57892                                                NaN
# 57893  [{'port': 22, 'protocol': 'tcp'}, {'port': 80,...
# 57894  [{'port': 80, 'protocol': 'tcp'}, {'port': 80,...
# 57895  [{'port': 80, 'protocol': 'tcp'}, {'port': 554...
# 57896  [{'port': 161, 'protocol': 'udp'}, {'port': 42...
# 57897  [{'port': 1392, 'protocol': 'tcp'}, {'port': 1...
# 57898  [{'port': 80, 'protocol': 'tcp'}, {'port': 535...
# 57899  [{'port': 80, 'protocol': 'tcp'}, {'port': 443...
# 57900  [{'port': 80, 'protocol': 'tcp'}, {'port': 535...
# 57901  [{'port': 138, 'protocol': 'udp'}, {'port': 19...
# 57902                                                 []
# 57903                                                 []
# 57904  [{'port': 1900, 'protocol': 'udp'}, {'port': 1...
# 57905  [{'port': 5001, 'protocol': 'tcp'}, {'port': 5...
#
#                                                     ssdp  \
# 0                                                    NaN
# 1      [{'st': '', 'nt': 'upnp:rootdevice', 'location...
# 2      [{'st': '', 'nt': 'urn:schemas-upnp-org:servic...
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6      [{'st': '', 'nt': 'uuid:RINCON_000E58FC4084014...
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12     [{'st': '', 'nt': 'upnp:rootdevice', 'location...
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18     [{'st': '', 'nt': 'upnp:rootdevice', 'location...
# 19     [{'st': '', 'nt': 'urn:schemas-denon-com:servi...
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25     [{'st': '', 'nt': 'upnp:rootdevice', 'location...
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29     [{'st': '', 'nt': 'urn:schemas-upnp-org:servic...
# ...                                                  ...
# 57876  [{'st': '', 'nt': 'urn:schemas-upnp-org:device...
# 57877  [{'st': '', 'nt': 'upnp:rootdevice', 'location...
# 57878  [{'st': 'urn:schemas-upnp-org:device:InternetG...
# 57879                                                NaN
# 57880                                                NaN
# 57881  [{'st': '', 'nt': 'upnp:rootdevice', 'location...
# 57882  [{'st': 'urn:schemas-upnp-org:service:ContentD...
# 57883  [{'st': '', 'nt': 'urn:schemas-upnp-org:servic...
# 57884                                                NaN
# 57885                                                NaN
# 57886                                                NaN
# 57887                                                NaN
# 57888  [{'st': '', 'nt': 'uuid:ae67e622-7a66-465e-bab...
# 57889  [{'st': '', 'nt': 'uuid:RINCON_000E58B6E3BF014...
# 57890                                                NaN
# 57891                                                NaN
# 57892                                                NaN
# 57893                                                NaN
# 57894  [{'st': '', 'nt': 'upnp:rootdevice', 'location...
# 57895                                                NaN
# 57896                                                NaN
# 57897  [{'st': '', 'nt': 'upnp:rootdevice', 'location...
# 57898                                                NaN
# 57899                                                NaN
# 57900                                                NaN
# 57901  [{'st': '', 'nt': 'uuid:a8d3f7f7-4eb2-00f6-7bd...
# 57902                                                NaN
# 57903  [{'st': '', 'nt': 'urn:schemas-orange-com:serv...
# 57904  [{'st': 'upnp:rootdevice', 'nt': 'M-SEARCH', '...
# 57905                                                NaN
#
#                                                     upnp
# 0                                                    NaN
# 1      [{'model_name': 'Verizon Media Server', 'model...
# 2      [{'model_name': 'Denon AVR-X2400H', 'manufactu...
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6      [{'model_name': 'Sonos Play:3', 'model_descrip...
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12     [{'model_name': 'LG Smart TV', 'manufacturer':...
# 13                                                   NaN
# 14     [{'model_name': 'UE40JU6000', 'model_descripti...
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18     [{'model_name': 'HIKVISION DS-2CD2120F-IS', 'm...
# 19     [{'model_name': 'HEOS HomeCinema', 'manufactur...
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25     [{'model_name': 'BouygtelTV', 'model_descripti...
# 26     [{'model_name': 'IPC1100P2', 'model_descriptio...
# 27     [{'model_name': 'Windows Media Player Sharing'...
# 28     [{'model_name': 'SPK-WAM1500', 'model_descript...
# 29     [{'model_name': 'Denon AVR-X1400H', 'manufactu...
# ...                                                  ...
# 57876  [{'model_name': 'H.264 720P Wired D/N Indoor D...
# 57877  [{'model_name': 'LG Smart TV', 'manufacturer':...
# 57878                                                NaN
# 57879                                                NaN
# 57880                                                NaN
# 57881  [{'model_name': 'Plex Media Server', 'model_de...
# 57882  [{'model_name': '*AVR-X3200W', 'model_descript...
# 57883  [{'model_name': 'Denon AVR-X1400H', 'manufactu...
# 57884                                                NaN
# 57885                                                NaN
# 57886                                                NaN
# 57887                                                NaN
# 57888  [{'model_name': 'DCS-5000L', 'model_descriptio...
# 57889  [{'model_name': 'Sonos Playbar', 'model_descri...
# 57890                                                NaN
# 57891                                                NaN
# 57892                                                NaN
# 57893                                                NaN
# 57894  [{'model_name': 'VSX-1130/CUXESM', 'model_desc...
# 57895                                                NaN
# 57896                                                NaN
# 57897  [{'model_name': 'LG TV', 'model_description': ...
# 57898                                                NaN
# 57899                                                NaN
# 57900                                                NaN
# 57901  [{'model_name': 'BouygtelTV', 'model_descripti...
# 57902  [{'model_name': 'Eureka Dongle', 'manufacturer...
# 57903  [{'model_name': 'IHD92', 'manufacturer': 'SAGE...
# 57904  [{'model_name': 'LG TV', 'model_description': ...
# 57905                                                NaN
#
# [57906 rows x 9 columns]

# %% [markdown]
# # Feature lookup
#
# Interesting features:
# - services: list of used ports & protocols
# - upnp: dict of device info --> names, types, manufactuer, ...
# - mdns_services: can directly point on device type
#
# Examples:

# %%
df_train['ssdp'][2]
# Out:
# [{'st': '',
#   'nt': 'urn:schemas-upnp-org:service:RenderingControl:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-upnp-org:service:AVTransport:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'uuid:cf2583ce-f896-14cc-0080-0005cde2625e',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-denon-com:device:AiosDevice:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'uuid:5cdaa5bc-2db2-1022-0080-0005cde2625e',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'upnp:rootdevice',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-upnp-org:device:MediaRenderer:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-upnp-org:service:ConnectionManager:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-upnp-org:service:ContentDirectory:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-upnp-org:device:MediaServer:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'uuid:e35f8c97-7b71-8ed9-e786-05f4c18e25ee',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-denon-com:service:ACT:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-denon-com:device:ACT-Denon:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'uuid:792faf7f-b97a-979e-dbf7-24ff3b5dada5',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-denon-com:service:GroupControl:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-denon-com:service:ZoneControl:2',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-denon-com:service:ErrorHandler:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-denon-com:device:AiosServices:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'uuid:bf87348f-27aa-1691-0080-0005cde2625e',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'uuid:5cdaa5bc-2db2-1022-0080-0005cde2625e',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-upnp-org:service:AVTransport:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-upnp-org:device:MediaRenderer:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'uuid:cf2583ce-f896-14cc-0080-0005cde2625e',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-denon-com:device:AiosDevice:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'upnp:rootdevice',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-denon-com:service:ZoneControl:2',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-denon-com:service:ErrorHandler:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-denon-com:device:AiosServices:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'uuid:bf87348f-27aa-1691-0080-0005cde2625e',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-upnp-org:service:RenderingControl:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-upnp-org:device:MediaServer:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'uuid:e35f8c97-7b71-8ed9-e786-05f4c18e25ee',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-denon-com:service:ACT:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-denon-com:device:ACT-Denon:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'uuid:792faf7f-b97a-979e-dbf7-24ff3b5dada5',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-denon-com:service:GroupControl:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-upnp-org:service:ConnectionManager:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-upnp-org:service:ContentDirectory:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'uuid:bf87348f-27aa-1691-0080-0005cde2625e',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-denon-com:device:AiosServices:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-denon-com:service:ErrorHandler:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-denon-com:service:ZoneControl:2',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-denon-com:service:GroupControl:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'uuid:792faf7f-b97a-979e-dbf7-24ff3b5dada5',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-denon-com:device:ACT-Denon:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-denon-com:service:ACT:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'uuid:e35f8c97-7b71-8ed9-e786-05f4c18e25ee',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-upnp-org:device:MediaServer:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-upnp-org:service:ContentDirectory:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-upnp-org:service:ConnectionManager:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-upnp-org:device:MediaRenderer:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'upnp:rootdevice',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'uuid:5cdaa5bc-2db2-1022-0080-0005cde2625e',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-denon-com:device:AiosDevice:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'uuid:cf2583ce-f896-14cc-0080-0005cde2625e',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-upnp-org:service:AVTransport:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''},
#  {'st': '',
#   'nt': 'urn:schemas-upnp-org:service:RenderingControl:1',
#   'location': 'http://192.168.1.121:60006/upnp/desc/aios_device/aios_device.xml',
#   'server': 'LINUX UPnP/1.0 Denon-Heos/139046',
#   'user_agent': '',
#   'method': ''}]

# %% [markdown]
# ## services col
#
# Just make cols for each port and protocol.

# %%
ports = []
for _, row in pd.concat([df_train, df_test], axis=0, sort=False).iterrows():
    if not isinstance(row['services'], list): continue
    for d in row['services']:
        if d['port'] not in ports:
            ports.append(d['port'])
ports.sort()
print(len(ports))  # Count of unique ports
print(ports)  # Unique port list
# Out:
# 13379
# [3, 7, 9, 13, 16, 17, 19, 20, 21, 22, 23, 24, 25, 30, 32, 44, 45, 49, 50, 51, 53, 67, 68, 69, 70, 71, 80, 81, 82, 83, 84, 85, 86, 88, 89, 90, 91, 92, 94, 96, 99, 100, 101, 102, 110, 111, 114, 123, 125, 127, 134, 135, 137, 138, 139, 161, 162, 182, 199, 200, 201, 202, 209, 230, 245, 256, 311, 319, 333, 389, 427, 440, 441, 443, 444, 445, 465, 500, 501, 514, 515, 520, 546, 548, 554, 555, 559, 591, 594, 623, 625, 631, 660, 666, 777, 800, 801, 802, 806, 807, 808, 809, 811, 812, 815, 819, 832, 843, 873, 885, 960, 964, 990, 993, 1000, 1004, 1005, 1020, 1021, 1024, 1025, 1026, 1027, 1028, 1029, 1030, 1031, 1032, 1033, 1034, 1035, 1036, 1037, 1038, 1039, 1040, 1041, 1042, 1043, 1044, 1045, 1046, 1047, 1048, 1049, 1050, 1051, 1052, 1053, 1054, 1055, 1056, 1057, 1058, 1059, 1060, 1061, 1062, 1063, 1064, 1065, 1066, 1067, 1068, 1069, 1070, 1071, 1072, 1073, 1074, 1075, 1076, 1077, 1078, 1079, 1080, 1081, 1082, 1083, 1084, 1085, 1086, 1087, 1088, 1089, 1090, 1091, 1092, 1093, 1094, 1095, 1096, 1097, 1098, 1099, 1100, 1101, 1102, 1103, 1104, 1105, 1106, 1107, 1108, 1109, 1110, 1111, 1112, 1113, 1114, 1115, 1116, 1117, 1118, 1119, 1120, 1121, 1122, 1123, 1124, 1125, 1126, 1127, 1128, 1129, 1130, 1131, 1132, 1133, 1134, 1135, 1136, 1137, 1138, 1139, 1140, 1141, 1142, 1143, 1144, 1145, 1146, 1147, 1148, 1149, 1150, 1151, 1152, 1153, 1154, 1155, 1156, 1157, 1158, 1159, 1160, 1161, 1162, 1163, 1164, 1165, 1166, 1167, 1168, 1169, 1170, 1171, 1172, 1173, 1174, 1175, 1176, 1177, 1178, 1179, 1180, 1181, 1182, 1183, 1184, 1185, 1186, 1187, 1188, 1189, 1190, 1191, 1192, 1193, 1194, 1195, 1196, 1197, 1198, 1199, 1200, 1201, 1202, 1203, 1204, 1205, 1206, 1207, 1208, 1209, 1210, 1211, 1212, 1213, 1214, 1215, 1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1234, 1235, 1236, 1237, 1238, 1239, 1240, 1241, 1242, 1243, 1244, 1245, 1246, 1247, 1248, 1249, 1250, 1251, 1252, 1253, 1254, 1255, 1256, 1257, 1258, 1259, 1260, 1261, 1262, 1263, 1264, 1265, 1266, 1267, 1268, 1269, 1270, 1271, 1272, 1273, 1274, 1275, 1276, 1277, 1278, 1279, 1280, 1281, 1282, 1283, 1284, 1285, 1286, 1287, 1288, 1289, 1290, 1291, 1292, 1293, 1294, 1295, 1296, 1297, 1298, 1299, 1300, 1301, 1302, 1303, 1304, 1305, 1306, 1307, 1308, 1309, 1310, 1311, 1312, 1313, 1314, 1315, 1316, 1317, 1318, 1319, 1320, 1321, 1322, 1323, 1324, 1325, 1326, 1327, 1328, 1329, 1330, 1331, 1332, 1333, 1334, 1335, 1336, 1337, 1338, 1339, 1340, 1341, 1342, 1343, 1344, 1345, 1346, 1347, 1348, 1349, 1350, 1351, 1352, 1353, 1354, 1355, 1356, 1357, 1358, 1359, 1360, 1361, 1362, 1363, 1364, 1365, 1366, 1367, 1368, 1369, 1370, 1371, 1372, 1373, 1374, 1375, 1376, 1377, 1378, 1379, 1380, 1381, 1382, 1383, 1384, 1385, 1386, 1387, 1388, 1389, 1390, 1391, 1392, 1393, 1394, 1395, 1396, 1397, 1398, 1399, 1400, 1401, 1402, 1403, 1404, 1405, 1406, 1407, 1408, 1409, 1410, 1411, 1412, 1413, 1414, 1415, 1416, 1417, 1418, 1419, 1420, 1421, 1422, 1423, 1424, 1425, 1426, 1427, 1428, 1429, 1430, 1431, 1432, 1433, 1434, 1435, 1436, 1437, 1438, 1439, 1440, 1441, 1442, 1443, 1444, 1445, 1446, 1447, 1448, 1449, 1450, 1451, 1452, 1453, 1454, 1455, 1456, 1457, 1458, 1459, 1460, 1461, 1462, 1463, 1464, 1465, 1466, 1467, 1468, 1469, 1470, 1471, 1472, 1473, 1474, 1475, 1476, 1477, 1478, 1479, 1480, 1481, 1482, 1483, 1484, 1485, 1486, 1487, 1488, 1489, 1490, 1491, 1492, 1493, 1494, 1495, 1496, 1497, 1498, 1499, 1500, 1501, 1502, 1503, 1504, 1505, 1506, 1507, 1508, 1509, 1510, 1511, 1512, 1513, 1514, 1515, 1516, 1517, 1518, 1519, 1520, 1521, 1522, 1523, 1524, 1525, 1526, 1527, 1528, 1529, 1530, 1531, 1532, 1533, 1534, 1535, 1536, 1537, 1538, 1539, 1540, 1541, 1542, 1543, 1544, 1545, 1546, 1547, 1548, 1549, 1550, 1551, 1552, 1553, 1554, 1555, 1556, 1557, 1558, 1559, 1560, 1561, 1562, 1563, 1564, 1565, 1566, 1567, 1568, 1569, 1570, 1571, 1572, 1573, 1574, 1575, 1576, 1577, 1578, 1579, 1580, 1581, 1582, 1583, 1584, 1585, 1586, 1587, 1588, 1589, 1590, 1591, 1592, 1593, 1594, 1595, 1596, 1597, ...

# %% [markdown]
# In the port cell:
# 0 = no port,
# 1 = tcp protocol,
# 2 = udp protocol

# %% [markdown]
# ## upnp col
#
# Get manufactuer, if possible.

# %%
df_train['upnp'][1]
# Out:
# [{'model_name': 'Verizon Media Server',
#   'model_description': 'Media Server',
#   'manufacturer': 'ARRIS',
#   'device_type': 'urn:schemas-upnp-org:device:MediaServer:1',
#   'services': ['urn:upnp-org:serviceId:ContentDirectory',
#    'urn:upnp-org:serviceId:ConnectionManager']},
#  {'model_name': 'VMS1100',
#   'model_description': 'Device Management',
#   'manufacturer': 'ARRIS',
#   'device_type': 'urn:schemas-upnp-org:device:ManageableDevice:2',
#   'services': ['urn:upnp-org:serviceId:BasicManagement',
#    'urn:upnp-org:serviceId:ConfigurationManagement',
#    'urn:upnp-org:serviceId:DeviceProtection']},
#  {'model_name': 'VMS1100',
#   'model_description': 'DIAL Server',
#   'manufacturer': 'ARRIS',
#   'device_type': 'urn:schemas-upnp-org:device:dial:1',
#   'services': ['urn:upnp-org:serviceId:dial']}]

# %%
def get_manufacturer(upnp):
    return upnp[0]['manufacturer'] if isinstance(upnp, list) and 'manufacturer' in upnp[0].keys() else "Unknown"

manufacturers = []
for _, row in pd.concat([df_train, df_test], axis=0, sort=False).iterrows():
    m = get_manufacturer(row['upnp'])
    if m not in manufacturers:
        manufacturers.append(m)
manufacturers.sort()
print(len(manufacturers))
pprint.pprint(manufacturers)
# Out:
# 237
# [' ',
#  '     ',
#  ' DUAL ',
#  'ABUS Security-Center',
#  'ACCESS CO., LTD.',
#  'ARCAM',
#  'ARRIS',
#  'ASUS Corporation',
#  'AUNA',
#  'AVTECH Corporation.',
#  'AXIS',
#  'Aastra Telecom Inc',
#  'AirBeamTV BV',
#  'Amazon',
#  'Amlogic Corporation',
#  'Arcadyan',
#  'Argon Audio',
#  'Arris Inc.',
#  'Atlantis',
#  'Audioblock GmbH',
#  'Azureus Software, Inc.',
#  'Belkin International Inc.',
#  'Belkin International, Inc.',
#  'BiglyBT',
#  'Bitron Video',
#  'BlackBerry',
#  'Bose',
#  'Bose Corporation',
#  'Brickcom Corporation',
#  'BridgeCo AG, Switzerland',
#  'Broadcom Corporation',
#  'Bush',
#  'CANON INC.',
#  'Cabasse',
#  'Cambridge Audio',
#  'Canon',
#  'Champ',
#  'Como Audio',
#  'Connected Object',
#  'CyberLink Corporation',
#  'D-LINK',
#  'D-Link',
#  'D-Link Corporation',
#  'D-Stream',
#  'DENON',
#  'DIRECTV',
#  'DNT',
#  'DSG Retail Ltd',
#  'DUAL',
#  'DVR',
#  'Dell',
#  'Dell Electronics',
#  'Dell Inc.',
#  'Denon',
#  'Devialet',
#  'DivX',
#  'Dual',
#  'ES',
#  'EShare Technology Corporation',
#  'EZVIZ',
#  'Elgato Systems GmbH',
#  'Emby',
#  'Freebox',
#  'Freebox SAS',
#  'Freecom',
#  'Freecom Technologies',
#  'Frontier Silicon Ltd',
#  'Fujitsu Technology Solutions GmbH',
#  'Geniatech Systems GmbH',
#  'Gestetner',
#  'Google Inc.',
#  'Grundig',
#  'HAMA',
#  'HAMA GmbH',
#  'HIKVISION',
#  'HP',
#  'Hama',
#  'Hama GmbH & Co KG',
#  'Harman',
#  'Harman Kardon',
#  'HiWatch',
#  'Hinston Electronics Co., Ltd',
#  'Hisense',
#  'Hisilicon Technologies Co.,Ltd',
#  'Hitachi W100 AllPlay',
#  'INSPUR',
#  'Integra',
#  'Intel Corporation',
#  'Intelbras',
#  'Interlogix',
#  'International Receiver Company',
#  'JBL',
#  'JRiver, Inc.',
#  'Justin Maggard',
#  'Karcher AG',
#  'KuGou-Inc.',
#  'LANIER',
#  'LEBO Foundation',
#  'LENCO',
#  'LG Android TV',
#  'LG Electronics',
#  'LG Electronics Inc.',
#  'LG Electronics.',
#  'LG-Ericsson USA, Inc.',
#  'LYNX TECHNOLOGY',
#  'LaCie',
#  'LaCie S.A.',
#  'Lautsprecher Teufel GmbH',
#  'Lenovo',
#  'Linksys',
#  'Logitech',
#  'Loxone Electronics GmbH',
#  'MEDION AG',
#  'Magnat CS Series',
#  'Marantz',
#  'McIntosh',
#  'Medion International',
#  'Microchip',
#  'Microsoft',
#  'Microsoft Corporation',
#  'Musaic',
#  'NETGEAR',
#  'NETGEAR Inc.',
#  'NOXON',
#  'NRG',
#  'NTGR',
#  'NVIDIA',
#  'Naim Audio Ltd.',
#  'Nero',
#  'Nero AG',
#  'NetworkCamera',
#  'NuVo',
#  'Numericable',
#  'OEM',
#  'ONKYO',
#  'Onkyo & Pioneer Corporation',
#  'Onkyo And Pioneer',
#  'PALONA',
#  'PEAQ',
#  'PHILIPS',
#  'PIONEER CORPORATION',
#  'PMS',
#  'PURE',
#  'PacketVideo',
#  'Palotec',
#  'Panasonic',
#  'Petr Nejedly',
#  'Philips',
#  'Phorus',
#  'Plex, Inc.',
#  'Privacy',
#  'Pro-Ject Audio Systems',
#  'Pure',
#  'QNAP Systems, Inc.',
#  'Qualcomm AllPlay',
#  'REVO',
#  'RICOH',
#  'RVi',
#  'Ralink',
#  'Raumfeld GmbH',
#  'Revo Technologies Ltd',
#  'Revo Technologies Ltd.',
#  'Roberts Radio Limited',
#  'Rockchip',
#  'Roku',
#  'Royal Philips Electronics',
#  'Ruark Audio Ltd',
#  'SAGEM',
#  'SAMSUNG',
#  'SAMSUNG Electronics',
#  'SANGEAN ELECTRONICS INC.',
#  'SAVIN',
#  'Samsung Electronics',
#  'Samsung-Electronics',
#  'Sangean Radio Limited',
#  'Sbox dev',
#  'Scansonic',
#  'Seagate',
#  'Seagate Corporation',
#  'Seagate Technology PLC',
#  'Server-Eye',
#  'Sharp Corporation',
#  'SoftAtHome',
#  'SoftMedia Inc.',
#  'Sonos, Inc.',
#  'Sony',
#  'Sony Corporation',
#  'Soundmaster',
#  'Stéphane Mitermite',
#  'Swisscom',
#  'Synlogy Inc.',
#  'Synology',
#  'Synology Inc',
#  'THECUS',
#  'TP-LINK',
#  'TP-Link',
#  'TRENDnet',
#  'TRENDnet Incorporation',
#  'TTMicro',
#  'TTMicro AS',
#  'TVMOBiLi',
#  'Team XBMC',
#  'TechniSat',
#  'Technisat',
#  'Tencent',
#  'Teufel',
#  'TwonkyVision GmbH',
#  'UPNP',
#  'UTC',
#  'Ubee',
#  'Unknown',
#  'Unmonday',
#  'VAVOO AG',
#  'Ventis Media, Inc.',
#  'WaxRain',
#  'Western Digital Corporation',
#  'Woerlein GmbH ',
#  'XANTE',
#  'XBMC Foundation',
#  'XEROX Corporation',
#  'Xerox',
#  'Xerox Corporation',
#  'Xerox Electronics',
#  'YAMAHA CORPORATION',
#  'Yamaha Corporation',
#  'ZAVIO',
#  'Zavio',
#  'Zona, Inc.',
#  'ZyXEL',
#  'auna',
#  'hikvision',
#  'infotec',
#  'sonoro audio GmbH',
#  'upnp',
#  'wansview',
#  'www.thecus.com',
#  'www.yunos.com_cibn']

# %%
def get_model(upnp):
    return upnp[0]['model_name'] if isinstance(upnp, list) and 'model_name' in upnp[0].keys() else "Unknown"

models = []
for _, row in pd.concat([df_train, df_test], axis=0, sort=False).iterrows():
    m = get_model(row['upnp'])
    if m not in models:
        models.append(m)
#     else:
#         models[m] += 1
models.sort()
print(len(models))
pprint.pprint(models)
# Out:
# 4740
# ['\t',
#  ' ',
#  '     ',
#  '  Dual IR 2A',
#  ' Samsung C406x Series ',
#  ' Samsung CLX-8640 8650 Series ',
#  ' Samsung CLX-9252 9352 Series ',
#  ' Samsung CLX-92x1 93x1 Series ',
#  ' Samsung CLX-981x Series ',
#  ' Samsung K7600 Series ',
#  ' Samsung M408x Series ',
#  ' Samsung M4370 5370 Series ',
#  ' Samsung M458x Series ',
#  ' Samsung M536x Series ',
#  ' Samsung SCX-5835_5935X Series ',
#  ' Samsung SCX-6545X Series ',
#  ' Samsung SCX-6x55X Series ',
#  ' Samsung SCX-8030 8040 Series ',
#  ' Samsung SCX-8230 8240 Series ',
#  ' Samsung X4300 Series ',
#  ' Samsung X7600 Series ',
#  ' Seagate Personal Cloud',
#  ' Seagate Personal Cloud 2 Bay',
#  '*AV7701',
#  '*AV7702',
#  '*AV7702mkII',
#  '*AV8802',
#  '*AVR-1613',
#  '*AVR-1713',
#  '*AVR-1913',
#  '*AVR-2113',
#  '*AVR-2313',
#  '*AVR-3313',
#  '*AVR-4520',
#  '*AVR-E300',
#  '*AVR-E400',
#  '*AVR-S700W',
#  '*AVR-S710W',
#  '*AVR-S720W',
#  '*AVR-S900W',
#  '*AVR-S910W',
#  '*AVR-S920W',
#  '*AVR-X1000',
#  '*AVR-X1100W',
#  '*AVR-X1200W',
#  '*AVR-X1300W',
#  '*AVR-X2000',
#  '*AVR-X2100W',
#  '*AVR-X2200W',
#  '*AVR-X2300W',
#  '*AVR-X3000',
#  '*AVR-X3100W',
#  '*AVR-X3200W',
#  '*AVR-X3300W',
#  '*AVR-X4000',
#  '*AVR-X4100W',
#  '*AVR-X4200W',
#  '*AVR-X5200W',
#  '*AVR-X6200W',
#  '*AVR-X7200W',
#  '*DNP-730',
#  '*DRA-N4',
#  '*M-CR510',
#  '*M-CR511',
#  '*M-CR610',
#  '*M-CR611',
#  '*MX122',
#  '*NA6005',
#  '*NA8005',
#  '*NR1504',
#  '*NR1506',
#  '*NR1603',
#  '*NR1604',
#  '*NR1605',
#  '*NR1606',
#  '*NR1607',
#  '*RCD-N9',
#  '*SR5007',
#  '*SR5009',
#  '*SR5010',
#  '*SR5011',
#  '*SR6007',
#  '*SR6008',
#  '*SR6009',
#  '*SR6010',
#  '*SR6011',
#  '*SR7007',
#  '*SR7009',
#  '*SR7010',
#  '-',
#  '-------',
#  '1.3 MPx Network Compact Camera',
#  '192.168.0.53',
#  '192.168.1.102',
#  '2-Way Audio Surveillance Camera',
#  '2.4GHz Wireless Internet Camera',
#  '2015ALL2',
#  '2015ALL5CD',
#  '2015ALLxx',
#  '2015PMX100',
#  '2016ALLxx',
#  '2016RS75',
#  '2017HC1020',
#  '2017HC1040',
#  '2017PMX152',
#  '22SM3B-BD',
#  '25',
#  '28S305',
#  '2M IR Mini Dome IP Camera, PoE',
#  '2M Mini Dome IP Camera , PoE',
#  '2M Wired IR Cube Camera , PoE',
#  '2M Wireless IR Cube Camera',
#  '2Megapixel D/N Outdoor Motorized Bullet Camera, PoE, w/ audio,\n'
#  'DIDO(2/2), RS485',
#  '32LK540BPTA',
#  '32LK540BPUA',
#  '32LK6100PLB',
#  '32LK610BPLB',
#  '32LK610BPSA',
#  '32LK615BPSB',
#  '32LK6200PLA',
#  '32S301',
#  '32S305',
#  '32S321',
#  '32S327',
#  '4070_FI',
#  '40S305',
#  '40S325',
#  '43LK5700PSC',
#  '43LK5730PVC',
#  '43LK5750PSA',
#  '43LK5760PTA',
#  '43LK5900PLA',
#  '43R80',
#  '43S305',
#  '43S403',
#  '43S405',
#  '43S421',
#  '43S425',
#  '43S515',
#  '43SM5KB-BD',
#  '43UK6090PUA',
#  '43UK6200PDA',
#  '43UK6200PLA',
#  '43UK6200PUA',
#  '43UK6250PUB',
#  '43UK6300BUB',
#  '43UK6300MLB',
#  '43UK6300PDB',
#  '43UK6300PLB',
#  '43UK6300PUE',
#  '43UK6310PSE',
#  '43UK6390PLG',
#  '43UK6400PLF',
#  '43UK6450PLC',
#  '43UK6470PLC',
#  '43UK6500MLA',
#  '43UK6500PLA',
#  '43UK6510PSF',
#  '43UK6540PTD',
#  '43UK6550PUB',
#  '43UK6750PLD',
#  '43UK6950PLB',
#  '4622-BureauJust',
#  '481-PTR31',
#  '49LK5400PLA',
#  '49LK5700PSC',
#  '49LK5700PUA',
#  '49LK5750PSA',
#  '49LK5900PLA',
#  '49S305',
#  '49S325',
#  '49S403',
#  '49S405',
#  '49S405-MX',
#  '49S425-CA',
#  '49SK8000PLB',
#  '49SK8100PLA',
#  '49SK8500PLA',
#  '49SM5C-BF',
#  '49UK6090PUA',
#  '49UK6200PDA',
#  '49UK6200PSA',
#  '49UK6300MLB',
#  '49UK6300PLB',
#  '49UK6300PSB',
#  '49UK6300PUE',
#  '49UK6310PSE',
#  '49UK6320PTE',
#  '49UK6400PLF',
#  '49UK7500PSA',
#  '49UK7500PUA',
#  '50PFL4662/F7',
#  '50R6+',
#  '50R6DM',
#  '50R7+',
#  '50S423',
#  '50UK6090PUA',
#  '50UK6300MLB',
#  '50UK6300PLB',
#  '50UK6300PSB',
#  '50UK6410PLC',
#  '50UK6470PLC',
#  '50UK6500AUA',
#  '50UK6500MLA',
#  '50UK6510PSF',
#  '50UK6520PSA',
#  '50UK6550PLD',
#  '50UK6950PLB',
#  '55P605',
#  '55R6+',
#  '55R6107',
#  '55R80',
#  '55S401',
#  '55S403',
#  '55S405',
#  '55S423',
#  '55S515',
#  '55S517',
#  '55SK8000PCA',
#  '55SK8000PUA',
#  '55SK8100PLA',
#  '55SK8500PLA',
#  '55UK6090PUA',
#  '55UK6200PDA',
#  '55UK6200PLA',
#  '55UK6200PSA',
#  '55UK6250PUB',
#  '55UK6300BUB',
#  '55UK6300MLB',
#  '55UK6300PLB',
#  '55UK6300PUE',
#  '55UK6300PVB',
#  '55UK6340PTF',
#  '55UK6350PSC',
#  '55UK6350PUC',
#  '55UK6360PSF',
#  '55UK6360PTE',
#  '55UK6400PLF',
#  '55UK6450PLC',
#  '55UK6470PLC',
#  '55UK6500AUA',
#  '55UK6500PLA',
#  '55UK6540PSB',
#  '55UK6550PLD',
#  '55UK6550PSB',
#  '55UK6750PLD',
#  '55UK6950PLB',
#  '55UK7550PLA',
#  '60R6+',
#  '60R70',
#  '60UK6090PUA',
#  '60UK6200PLA',
#  '65R6+',
#  '65R6107',
#  '65R615',
#  '65R617',
#  '65R80',
#  '65S4',
#  '65S401',
#  '65S403',
#  '65S405',
#  '65S423',
#  '65S425',
#  '65S513',
#  '65SK8500PLA',
#  '65SK9000PUA',
#  '65UK6300MLB',
#  '65UK6300PLB',
#  '65UK6300PUE',
#  '65UK6400PLF',
#  '65UK6470PLC',
#  '65UK6530PSF',
#  '65UK6540PSB',
#  '65UK6550PSB',
#  '65UK6950PLB',
#  '65UK7550MLA',
#  '65UK7550PLA',
#  '65UK7700AUB',
#  '65UK7700PUD',
#  '70UK6190PUB',
#  '70UK6570PUB',
#  '70UK6950PLA',
#  '75UK6200PLB',
#  '802.11g Pan/Tilt IP Camera',
#  '9040',
#  'ACCUEIL2 xeros ',
#  'AFTA',
#  'AFTB',
#  'AFTM',
#  'AFTMM',
#  'AFTN',
#  'AFTS',
#  'AFTT',
#  'ALA B',
#  'AQUOS \nLC-60EQ10U',
#  'AQUOS \nLC-70SQ15U',
#  'AQUOS LC-40W20',
#  'AQUOS LC-60LE847U',
#  'AQUOS LC-70C8470U',
#  'AQUOS LC-70SQ15U',
#  'AQUOS LC-80LE650UA',
#  'AQUOS LC-U35T',
#  'ASUS Media Streamer DMR',
#  'ASUS Media Streamer DMS',
#  'AUNA KR-1000',
#  'AV Renderer',
#  'AV Renderer Device',
#  'AVR-1912',
#  'AVR-2112',
#  'AVR-2312',
#  'AVR-3310',
#  'AVR-3311',
#  'AVR-3312',
#  'AVR-4310',
#  'AVR-4810',
#  'AVR-A100',
#  'AVR171, AVR1710',
#  'AXIS 206',
#  'AXIS 206 (rev 2)',
#  'AXIS 207',
#  'AXIS 207MW',
#  'AXIS 207W',
#  'AXIS 209FD',
#  'AXIS 209MFD',
#  'AXIS 210',
#  'AXIS 210A',
#  'AXIS 211',
#  'AXIS 211A',
#  'AXIS 211M',
#  'AXIS 211W',
#  'AXIS 212 PTZ',
#  'AXIS 213',
#  'AXIS 214',
#  'AXIS 215 PTZ',
#  'AXIS 216FD',
#  'AXIS 216MFD',
#  'AXIS 221',
#  'AXIS 223M',
#  'AXIS 225FD',
#  'AXIS 231D+',
#  'AXIS 232D+',
#  'AXIS 233D',
#  'AXIS A1001',
#  'AXIS A8004-VE',
#  'AXIS A8105-E',
#  'AXIS Companion Bullet LE',
#  'AXIS Companion Bullet mini LE',
#  'AXIS Companion Cube L',
#  'AXIS Companion Dome V',
#  'AXIS Companion Dome WV',
#  'AXIS Companion Eye L',
#  'AXIS Companion Eye LVE',
#  'AXIS Companion Eye mini L',
#  'AXIS F34',
#  'AXIS F44',
#  'AXIS F44 Dual Audio Input',
#  'AXIS M1004-W',
#  'AXIS M1011',
#  'AXIS M1011-W',
#  'AXIS M1013',
#  'AXIS M1014',
#  'AXIS M1025',
#  'AXIS M1031-W',
#  'AXIS M1033-W',
#  'AXIS M1034-W',
#  'AXIS M1045-LW',
#  'AXIS M1054',
#  'AXIS M1065-L',
#  'AXIS M1065-LW',
#  'AXIS M1103',
#  'AXIS M1104',
#  'AXIS M1113',
#  'AXIS M1114',
#  'AXIS M1124',
#  'AXIS M1125',
#  'AXIS M1144-L',
#  'AXIS M1145',
#  'AXIS M1145-L',
#  'AXIS M2014-E',
#  'AXIS M2025-LE',
#  'AXIS M2026-LE Mk II',
#  'AXIS M3004',
#  'AXIS M3005',
#  'AXIS M3006',
#  'AXIS M3007',
#  'AXIS M3011',
#  'AXIS M3014',
#  'AXIS M3024-L',
#  'AXIS M3025',
#  'AXIS M3026',
#  'AXIS M3027',
#  'AXIS M3037',
#  'AXIS M3044-V',
#  'AXIS M3045-V',
#  'AXIS M3046-V',
#  'AXIS M3046-V 1.8MM',
#  'AXIS M3047-P',
#  'AXIS M3048-P',
#  'AXIS M3104-L',
#  'AXIS M3104-LVE',
#  'AXIS M3105-L',
#  'AXIS M3105-LVE',
#  'AXIS M3106-L Mk II',
#  'AXIS M3106-LVE',
#  'AXIS M3106-LVE Mk II',
#  'AXIS M3113',
#  'AXIS M3114',
#  'AXIS M3203',
#  'AXIS M3204',
#  'AXIS M5013',
#  'AXIS M5014',
#  'AXIS M5014-V',
#  'AXIS M5525-E',
#  'AXIS M7001',
#  'AXIS M7010',
#  'AXIS M7011',
#  'AXIS M7014',
#  'AXIS M7016',
#  'AXIS P12/M20',
#  'AXIS P1204',
#  'AXIS P1214-E',
#  'AXIS P1311',
#  'AXIS P1343',
#  'AXIS P1344',
#  'AXIS P1346',
#  'AXIS P1347',
#  'AXIS P1353',
#  'AXIS P1354',
#  'AXIS P1355',
#  'AXIS P1357',
#  'AXIS P1364',
#  'AXIS P1365',
#  'AXIS P1365 Mk II',
#  'AXIS P1367-E',
#  'AXIS P1405-E',
#  'AXIS P1405-LE',
#  'AXIS P1405-LE Mk II',
#  'AXIS P1425-E',
#  'AXIS P1425-LE',
#  'AXIS P1425-LE Mk II',
#  'AXIS P1427-E',
#  'AXIS P1427-LE',
#  'AXIS P1428-E',
#  'AXIS P1435-LE',
#  'AXIS P1447-LE',
#  'AXIS P3214-V',
#  'AXIS P3214-VE',
#  'AXIS P3215-V',
#  'AXIS P3215-VE',
#  'AXIS P3224-LV Mk II',
#  'AXIS P3224-V Mk II',
#  'AXIS P3225-LV Mk II',
#  'AXIS P3225-LVE',
#  'AXIS P3225-LVE Mk II',
#  'AXIS P3225-V Mk II',
#  'AXIS P3225-VE Mk II',
#  'AXIS P3227-LV',
#  'AXIS P3227-LVE',
#  'AXIS P3228-LV',
#  'AXIS P3228-LVE',
#  'AXIS P3301',
#  'AXIS P3304',
#  'AXIS P3343',
#  'AXIS P3344',
#  'AXIS P3346',
#  'AXIS P3353',
#  'AXIS P3354',
#  'AXIS P3363',
#  'AXIS P3364',
#  'AXIS P3364-L',
#  'AXIS P3365',
#  'AXIS P3367',
#  'AXIS P3374-V',
#  'AXIS P3375-LV',
#  'AXIS P3375-LVE',
#  'AXIS P3375-V',
#  'AXIS P3375-VE',
#  'AXIS P3384-V',
#  'AXIS P3384-VE',
#  'AXIS P3707-PE',
#  'AXIS P3904-R',
#  'AXIS P3905-R',
#  'AXIS P3915-R',
#  'AXIS P5512',
#  'AXIS P5512-E',
#  'AXIS P5514',
#  'AXIS P5514-E',
#  'AXIS P5515',
#  'AXIS P5515-E',
#  'AXIS P5522-E',
#  'AXIS P5532',
#  'AXIS P5532-E',
#  'AXIS P5534',
#  'AXIS P5534-E',
#  'AXIS P5624-E',
#  'AXIS P5624-E Mk II',
#  'AXIS P5624-E MkII',
#  'AXIS P5635-E',
#  'AXIS P5635-E Mk II',
#  'AXIS P7210',
#  'AXIS P7214',
#  'AXIS P7216',
#  'AXIS P7224',
#  'AXIS P7701',
#  'AXIS P8221',
#  'AXIS P8514',
#  'AXIS Q1602',
#  'AXIS Q1604',
#  'AXIS Q1615',
#  'AXIS Q1615 Mk II',
#  'AXIS Q1755',
#  'AXIS Q1765-LE',
#  'AXIS Q1775',
#  'AXIS Q1921',
#  'AXIS Q3505',
#  'AXIS Q3708-PVE',
#  'AXIS Q3709-PVE (Right)',
#  'AXIS Q6032',
#  'AXIS Q6032-E',
#  'AXIS Q6034',
#  'AXIS Q6034-E',
#  'AXIS Q6035-E',
#  'AXIS Q6044-E',
#  'AXIS Q6045-E',
#  'AXIS Q6045-E Mk II',
#  'AXIS Q6054-E',
#  'AXIS Q6054-E Mk III',
#  'AXIS Q6114-E',
#  'AXIS Q6125-LE',
#  'AXIS Q6155-E',
#  'AXIS Q7401',
#  'AXIS Q7404',
#  'AXIS Q7406',
#  'AXIS Q7411',
#  'AXIS Q7414',
#  'AXIS Q7436',
#  'AXiS',
#  'Aficio MP 161',
#  'Aficio MP 171',
#  'Aficio MP 2000',
#  'Aficio MP 201',
#  'Aficio MP 2352',
#  'Aficio MP 2500',
#  'Aficio MP 2510',
#  'Aficio MP 2550',
#  'Aficio MP 2550B',
#  'Aficio MP 2851',
#  'Aficio MP 2852',
#  'Aficio MP 301',
#  'Aficio MP 3350',
#  'Aficio MP 3350B',
#  'Aficio MP 3351',
#  'Aficio MP 3352',
#  'Aficio MP 3500',
#  'Aficio MP 4000',
#  'Aficio MP 4000B',
#  'Aficio MP 4001',
#  'Aficio MP 4002',
#  'Aficio MP 4500',
#  'Aficio MP 5000',
#  'Aficio MP 5001',
#  'Aficio MP 5002',
#  'Aficio MP 6001',
#  'Aficio MP 6002',
#  'Aficio MP 6500',
#  'Aficio MP 7000',
#  'Aficio MP 7001',
#  'Aficio MP 7500',
#  'Aficio MP 7502',
#  'Aficio MP 8000',
#  'Aficio MP 8001',
#  'Aficio MP 9000',
#  'Aficio MP 9002',
#  'Aficio MP C2000',
#  'Aficio MP C2050',
#  'Aficio MP C2051',
#  'Aficio MP C2500',
#  'Aficio MP C2550',
#  'Aficio MP C2551',
#  'Aficio MP C2800',
#  'Aficio MP C300',
#  'Aficio MP C3000',
#  'Aficio MP C3001',
#  'Aficio MP C3002',
#  'Aficio MP C300SR',
#  'Aficio MP C305',
#  'Aficio MP C3300',
#  'Aficio MP C3500',
#  'Aficio MP C3501',
#  'Aficio MP C3502',
#  'Aficio MP C400',
#  'Aficio MP C4000',
#  'Aficio MP C400SR',
#  'Aficio MP C4500',
#  'Aficio MP C4501',
#  'Aficio MP C4501A',
#  'Aficio MP C4502',
#  'Aficio MP C5000',
#  'Aficio MP C5501',
#  'Aficio MP C5502',
#  'Aficio MP W2400',
#  'Aficio SP 4100N',
#  'Aficio SP 4210N',
#  'Aficio SP 4310N',
#  'Aficio SP 5200DN',
#  'Aficio SP 5200S',
#  'Aficio SP 5210DN',
#  'Aficio SP 5210SF',
#  'Aficio SP 5210SR',
#  'Aficio SP 6330N',
#  'Aficio SP 8200DN',
#  'Aficio SP C320DN',
#  'Aficio SP C420DN',
#  'Aficio SP C430DN',
#  'Aficio SP C431DN',
#  'Aficio SP C821DN',
#  'AirBeamTV DLNA DMR',
#  'AirBurn',
#  'AirReceiver',
#  'AirScreen MediaRenderer',
#  'Argon Audio',
#  'AudioMaster',
#  'AutorizaçãoPA',
#  'B-Focus Vari 2 AV7210/10',
#  'B6210 2MP Bullet Camera',
#  'B6220 2MP Bullet Camera',
#  'B6320 3MP Bullet Camera',
#  'B6520 5MP Bullet Camera',
#  'B8220 2MP Bullet Camera',
#  'B8520 5MP Bullet Camera',
#  'B8520V2 5MP Bullet Camera',
#  'BEL-UKR-ACN-XER',
#  'BIP-10Cube',
#  'BL3102 2MP Bullet Camera',
#  'BRAVIA',
#  'BRAVIA 2015',
#  'BRAVIA 2K GB ATV3',
#  'BRAVIA 4K 2015',
#  'BRAVIA 4K GB',
#  'BRAVIA 4K GB ATV3',
#  'BRAVIA 4K UR1',
#  'Banco de Sangue',
#  'BiglyBT Media Server',
#  'BlackArmor NAS 1D',
#  'BlackArmor NAS 2D',
#  'BlackArmor NAS 4D',
#  'BlackBerry 10 Media Server',
#  'Blu-ray Disc Player',
#  'Bose Home Speaker 500',
#  'Bose SoundTouch REST Music Server',
#  'Bose Soundbar 500',
#  'Bose Soundbar 700',
#  'BouygtelTV',
#  'Bridge',
#  'C2670',
#  'C3000-100NAS',
#  'C3700-100NAS',
#  'C460FW Laser',
#  'C6250-100NAS',
#  'C7000-100NAS',
#  'C9130',
#  'CB-100Ae',
#  'CB-101Ap',
#  'CB-102Ap',
#  'CD-N301',
#  'CD-NT670D',
#  'CD6330 3MP Dome Camera',
#  'CENTRAL VEICULO',
#  'CERTIFICACAO',
#  'CGV_DR25i',
#  'CHE-159',
#  'CLP27DN',
#  'CPSPRINTER07',
#  'CR-N765',
#  'CRAS',
#  'CRX-N470D',
#  'CX-A5100',
#  'Chromecast Ultra',
#  'Cinemate',
#  'Cocoon',
#  'Como Audio',
#  'ComoAudio',
#  'Connect 120',
#  'Connect 150',
#  'Connect CD',
#  'Consorcio SU',
#  'Cosmopolit',
#  'CyberLink Media Server',
#  'CyberLink SoftDMA',
#  'Cyberlink BroadCaster',
#  'Cyberlink PowerDVD',
#  'D-Link Audio Extender',
#  'D2 Pro',
#  'D4',
#  'D4211 2MP Mini Dome Camera',
#  'D4320 3MP Dome Camera',
#  'D6210 2MP Dome Camera',
#  'D6320 3MP Dome Camera',
#  'D6330 3MP Dome Camera',
#  'DAB 7000i',
#  'DCS-1100',
#  'DCS-1130',
#  'DCS-1130L',
#  'DCS-2100',
#  'DCS-2102',
#  'DCS-2103',
#  'DCS-2121',
#  'DCS-2130',
#  'DCS-2132L',
#  'DCS-2132LB1',
#  'DCS-2132L_Rev_B',
#  'DCS-2136L',
#  'DCS-2210',
#  'DCS-2210L',
#  'DCS-2230',
#  'DCS-2230L',
#  'DCS-2310L',
#  'DCS-2330L',
#  'DCS-2332L',
#  'DCS-2530L',
#  'DCS-2630L',
#  'DCS-2670L',
#  'DCS-3110',
#  'DCS-3220',
#  'DCS-3411',
#  'DCS-3420',
#  'DCS-3430',
#  'DCS-3710B1',
#  'DCS-3715',
#  'DCS-4201',
#  'DCS-4602EV',
#  'DCS-4603',
#  'DCS-4622',
#  'DCS-4701E',
#  'DCS-4703E',
#  'DCS-4802E',
#  'DCS-5000L',
#  'DCS-5009L',
#  'DCS-5010L',
#  'DCS-5020L',
#  'DCS-5025L',
#  'DCS-5029L',
#  'DCS-5030L',
#  'DCS-5211L',
#  'DCS-5220B1',
#  'DCS-5222L',
#  'DCS-5222LB1',
#  'DCS-5222L_Rev_B',
#  'DCS-5230',
#  'DCS-6004L',
#  'DCS-6005L',
#  'DCS-6010L',
#  'DCS-6045L',
#  'DCS-6111',
#  'DCS-6511',
#  'DCS-6513',
#  'DCS-6517',
#  'DCS-6616',
#  'DCS-7000L',
#  'DCS-7010L',
#  'DCS-7110',
#  'DCS-7110B1',
#  'DCS-7513',
#  'DCS-800L',
#  'DCS-8100LH',
#  'DCS-8200LH',
#  'DCS-820L',
#  'DCS-825L',
#  'DCS-850L',
#  'DCS-855L',
#  'DCS-910',
#  'DCS-920',
#  'DCS-930',
#  'DCS-930L',
#  'DCS-930LB1',
#  'DCS-930L_Rev_B',
#  'DCS-931L',
#  'DCS-932L',
#  'DCS-932LB1',
#  'DCS-932L_Rev_B',
#  'DCS-933L',
#  'DCS-934L',
#  'DCS-935L',
#  'DCS-935LH',
#  'DCS-936L',
#  'DCS-942L',
#  'DCS-942LB1',
#  'DCS-942L_Rev_B',
#  'DCS-950',
#  'DCS-960L',
#  'DCX3200M',
#  'DCX3510M',
#  'DCX3600M',
#  'DDR-62',
#  'DDW36C',
#  'DEL0015991FBA99',
#  'DEL0015992CE16F',
#  'DEL00159944765C',
#  'DEL00159970187E',
#  'DEL0015997509C8',
#  'DEL0015997ED715',
#  'DEL001599880FB1',
#  'DEL0015998A6C68',
#  'DEL0015998B1FED',
#  'DEL0015999A6DDE',
#  'DEL001599A08772',
#  'DEL001599A78799',
#  'DEL001599EE9BED',
#  'DEL30CDA717A556',
#  'DEL30CDA71A2130',
#  'DEL30CDA71C40D3',
#  'DEL30CDA72377B0',
#  'DEL30CDA727A807',
#  'DEL30CDA7A1E9B0',
#  'DEL30CDA7B02BEA',
#  'DEL30CDA7EFA0A3',
#  'DEL30CDA7EFA468',
#  'DEL30CDA7F53AFE',
#  'DEL8425190D86DF',
#  'DEL8425192542FF',
#  'DIR3000 v2',
#  'DIR3010',
#  'DIR3100',
#  'DIR3101MS',
#  'DIR3120LED',
#  'DIR3121M',
#  'DIR3500MCBT',
#  'DIR3505MSCBT',
#  'DIR3600MBT',
#  'DIRECAO',
#  'DIT2000',
#  'DIT2010',
#  'DIT2010MBT',
#  'DIT2100MSBT',
#  'DLNA Media Renderer',
#  'DM3102 2MP Dome Camera',
#  'DM3112 2MP Dome Camera',
#  'DM32D',
#  'DNP-720',
#  'DNP-F109',
#  'DNT',
#  'DRA-N5',
#  'DS-2CD7133-E',
#  'DS-2CD7153-E',
#  'DS-2CD793NFWD-EI',
#  'DS-2CD793PF-E',
#  'DS-2CD853F-E',
#  'DS-2CD863PF-E',
#  'DS-2CD864FWD-E',
#  'DS-2DF1-401H',
#  'DS-6016HGHI-F1',
#  'DS-7104HC-E1',
#  'DS-7104HDT-I',
#  'DS-7104HGHI-E1',
#  'DS-7104HGHI-F1',
#  'DS-7104HGHI-F1/N',
#  'DS-7104HGHI-SH',
#  'DS-7104HQHI-F1',
#  'DS-7104HQHI-F1/N',
#  'DS-7104HQHI-K1',
#  'DS-7104HWI-SH',
#  'DS-7104NI-E1/4P',
#  'DS-7104NI-SN',
#  'DS-7104NI-SN/P',
#  'DS-7108HGHI-E1',
#  'DS-7108HGHI-F1',
#  'DS-7108HGHI-F1/N',
#  'DS-7108HGHI-SH',
#  'DS-7108HQHI-F1',
#  'DS-7108HQHI-F1/N',
#  'DS-7108HQHI-K1',
#  'DS-7108HVI-SH',
#  'DS-7108HWI-SH',
#  'DS-7116HGHI-E1',
#  'DS-7116HGHI-F1',
#  'DS-7116HQHI-F1',
#  'DS-7116HQHI-F1/N',
#  'DS-7116HWI-SH',
#  'DS-7204HGHI-E1',
#  'DS-7204HGHI-E1/A',
#  'DS-7204HGHI-F1',
#  'DS-7204HGHI-SH',
#  'DS-7204HGHI-SH/A',
#  'DS-7204HGHI-SH/S',
#  'DS-7204HGHI-SHA',
#  'DS-7204HI-SL',
#  'DS-7204HQHI-F1/N',
#  'DS-7204HQHI-K1',
#  'DS-7204HQHI-SH',
#  'DS-7204HQHI-SH/A',
#  'DS-7204HUHI-F1/N',
#  'DS-7204HUHI-K1',
#  'DS-7204HVI-SV',
#  'DS-7208HGHI-E1',
#  'DS-7208HGHI-F1',
#  'DS-7208HGHI-F1/N',
#  'DS-7208HGHI-F2',
#  'DS-7208HGHI-SH',
#  'DS-7208HGHI-SH/A',
#  'DS-7208HGHI-SH/S',
#  'DS-7208HGHI-SHST',
#  'DS-7208HQHI-F1/N',
#  'DS-7208HQHI-F2/N/A',
#  'DS-7208HQHI-K1',
#  'DS-7208HQHI-K2/P',
#  'DS-7208HQHI-SH',
#  'DS-7208HUHI-F1/N',
#  'DS-7208HUHI-F2/N',
#  'DS-7208HUHI-F2/S',
#  'DS-7208HUHI-K2',
#  'DS-7208HVI-SV',
#  'DS-7208HWI-E1',
#  'DS-7208HWI-SL',
#  'DS-7216HGHI-E1',
#  'DS-7216HGHI-E2',
#  'DS-7216HGHI-F1',
#  'DS-7216HGHI-F1/N',
#  'DS-7216HGHI-F2',
#  'DS-7216HGHI-SH',
#  'DS-7216HGHI-SH/A',
#  'DS-7216HGHI-SH/S',
#  'DS-7216HGHI-SHSE',
#  'DS-7216HQHI-F1',
#  'DS-7216HQHI-F1/N',
#  'DS-7216HQHI-F2',
#  'DS-7216HQHI-F2/16',
#  'DS-7216HQHI-F2/N',
#  'DS-7216HQHI-F2/N/A',
#  'DS-7216HQHI-K1',
#  'DS-7216HQHI-K2',
#  'DS-7216HQHI-SH',
#  'DS-7216HQI-K2',
#  'DS-7216HUHI-F2/N',
#  'DS-7216HUHI-F2/S',
#  'DS-7216HUHI-K2',
#  'DS-7216HVI-SV',
#  'DS-7216HWI-E1',
#  'DS-7216HWI-E2/A',
#  'DS-7216HWI-SH',
#  'DS-7216HWI-SL',
#  'DS-7224HWI-E2',
#  'DS-7316HGHI-SH',
#  'DS-7316HQHI-SH',
#  'DS-7316HUHI-F4/N',
#  'DS-7324HGHI-SH',
#  'DS-7332HGHI-SH',
#  'DS-7332HQHI-K4',
#  'DS-7604HI-ST',
#  'DS-7604NI-E1/4P',
#  'DS-7604NI-E1/A',
#  'DS-7604NI-EV1/4P',
#  'DS-7604NI-K1/4P',
#  'DS-7608NI-E2/8P',
#  'DS-7608NI-E2/A',
#  'DS-7608NI-I2',
#  'DS-7608NI-I2/8P',
#  'DS-7608NI-K2',
#  'DS-7608NI-K2/8P',
#  'DS-7616HI-ST',
#  'DS-7616HUHI-F2/N',
#  'DS-7616NI-E1',
#  'DS-7616NI-E2',
#  'DS-7616NI-E2/16P',
#  'DS-7616NI-E2/8P',
#  'DS-7616NI-E2/A',
#  'DS-7616NI-I2/16P',
#  'DS-7616NI-K2/16P',
#  'DS-7632NI-E2/A',
#  'DS-7716NI-E4/16P',
#  'DS-7716NI-I4',
#  'DS-7716NI-I4/16P',
#  'DS-7716NI-SP',
#  'DS-7716NI-SP/16',
#  'DS-7716NI-ST',
#  'DS-7732NI-E4',
#  'DS-7732NI-E4/16P',
#  'DS-7732NI-I4/16P',
#  'DS-7732NI-K4',
#  'DS-7804N-K1/C',
#  'DS-7808HQH-F1/N',
#  'DS-7808N-E2',
#  'DS-7808NB-K1/C',
#  'DS-7816NB-K1/C',
#  'DS-7916HE-E4',
#  'DS-7932N-E4',
#  'DS-7932N-K4',
#  'DS-7A16HQHI-K1',
#  'DS-8116HFI-ST',
#  'DS-8632N-K8',
#  'DS-8832N-K8',
#  'DS-9016HQHI-SH',
#  'DS-9632NI-I8',
#  'DS-9632NI-ST',
#  'DS-9664NI-I8',
#  'DS-I114',
#  'DS1010+',
#  'DS1019+',
#  'DS107',
#  'DS107+',
#  'DS109',
#  'DS110j',
#  'DS111',
#  'DS112',
#  'DS112+',
#  'DS112j',
#  'DS115',
#  'DS115j',
#  'DS116',
#  'DS118',
#  'DS119j',
#  'DS1511+',
#  'DS1512+',
#  'DS1513+',
#  'DS1515',
#  'DS1515+',
#  'DS1517',
#  'DS1517+',
#  'DS1618+',
#  'DS1812+',
#  'DS1813+',
#  'DS1815+',
#  'DS1817',
#  'DS1817+',
#  'DS1819+',
#  'DS2015xs',
#  'DS209',
#  'DS209+',
#  'DS209+II',
#  'DS209j',
#  'DS210j',
#  'DS211',
#  'DS211+',
#  'DS211j',
#  'DS212',
#  'DS212+',
#  'DS212j',
#  'DS213',
#  'DS213+',
#  'DS213air',
#  'DS213j',
#  'DS214',
#  'DS214+',
#  'DS214play',
#  'DS214se',
#  'DS215+',
#  'DS215j',
#  'DS216',
#  'DS216+',
#  'DS216+II',
#  'DS216j',
#  'DS216play',
#  'DS216se',
#  'DS218',
#  'DS218+',
#  'DS218j',
#  'DS218play',
#  'DS2411+',
#  'DS2413+',
#  'DS2415+',
#  'DS3615xs',
#  'DS3617xs',
#  'DS409',
#  'DS410j',
#  'DS411',
#  'DS411+',
#  'DS411+II',
#  'DS411j',
#  'DS411slim',
#  'DS412+',
#  'DS413',
#  'DS413j',
#  'DS414',
#  'DS414j',
#  'DS414slim',
#  'DS415+',
#  'DS415play',
#  'DS416',
#  'DS416j',
#  'DS416play',
#  'DS416slim',
#  'DS418',
#  'DS418j',
#  'DS418play',
#  'DS509+',
#  'DS710+',
#  'DS712+',
#  'DS713+',
#  'DS715',
#  'DS716+',
#  'DS716+II',
#  'DS718+',
#  'DS916+',
#  'DS918+',
#  'DSC-6112',
#  'DSC-6113',
#  'DSC-6113B1',
#  'DTR-20.4',
#  'DTR-30.7',
#  'DTR-50.4',
#  'DTR-70.4',
#  'DTR5000',
#  'DVR',
#  'Day/Night Surveillance Camera',
#  'Dell Laser MFP',
#  'Dell TIC',
#  'Denon AVC-X8500H',
#  'Denon AVR-S640H',
#  'Denon AVR-S730H',
#  'Denon AVR-S740H',
#  'Denon AVR-S930H',
#  'Denon AVR-S940H',
#  'Denon AVR-X1400H',
#  'Denon AVR-X1500H',
#  'Denon AVR-X2400H',
#  'Denon AVR-X2500H',
#  'Denon AVR-X3400H',
#  'Denon AVR-X3500H',
#  'Denon AVR-X4300H',
#  'Denon AVR-X4400H',
#  'Denon AVR-X4500H',
#  'Denon AVR-X6300H',
#  'Denon AVR-X6400H',
#  'Denon AVR-X6500H',
#  'Denon AVR-X8500H',
#  'Denon CEOL',
#  'Denon DNP-800NE',
#  'Deskjet 6940 series',
#  'DigitRadio',
#  'DigitRadio 100 IR5',
#  'DigitRadio 110 IR',
#  'DigitRadio 120 IR',
#  'DigitRadio 140',
#  'DigitRadio 500',
#  'DigitRadio 510',
#  'DigitRadio580',
#  'DigitRadio600',
#  'Digital Radio',
#  'DigitalMediaAdapterUPnP',
#  'Dimmer',
#  'DivX Media Server',
#  'E3100 series ',
#  'E4SW5017RKU',
#  'E4SW5518RKU',
#  'ENVY 110 series',
#  'ES File Explorer',
#  'EZVIZ CS-C6H-31WFR',
#  'EZVIZ CS-CV246(A0-3A1WFR)',
#  'Eggy 2 AV7210/11',
#  'Eggy AV7025',
#  'Emby Server',
#  'Envy 100 D410 series',
#  'Eureka Dongle',
#  'Evoke C-F6',
#  'Evoke F3 with Bluetooth',
#  'EyeConnect',
#  'F1105 Wired Compact IP Camera',
#  'FB-100Ae',
#  'FD-100Ae',
#  'FD-130Ap',
#  'Fixed CMOS Camera (Two way audio)',
#  'Fixed CMOS Camera (Two way audio) Wireless',
#  'Fixed CMOS Network Camera (Two way audio)',
#  'FreeMi UPnP Media Server',
#  'Freebox',
#  'Freebox Server',
#  'Freecom MusicPal',
#  'Frontier Media Server',
#  'GE-030-CB',
#  'GQ55Q6FNG',
#  'GQ55Q8CNG',
#  'GQ55Q8DNG',
#  'GQ65Q6FNG',
#  'GQ65Q7FNG',
#  'GQ65Q8DNG',
#  'GQ65Q9FNG',
#  'Globe STREAMWATCH',
#  'Go-KS-Xerox3225',
#  'Google Home Hub',
#  'GrundigDTR6000',
#  'H.264 1.3Megapixel IR Dome Camera,I/O (1/1),PoE',
#  'H.264 1.3Megapixel Outdoor IR Dome Camera,I/O(1/1),PoE',
#  'H.264 1080P Wired D/N Indoor Dome, I/O(2/2), PoE',
#  'H.264 1080P Wired D/N Outdoor Dome, I/O(2/2), PoE',
#  'H.264 1080P Wired IR-Bullet Camera, PoE',
#  'H.264 2-Megapixel D/N Bullet Camera w/ audio, I/O(2/2), PoE',
#  'H.264 720P Wired D/N Indoor Dome, I/O(2/2), PoE',
#  'H.264 720P Wired D/N Indoor Dome, I/O, PoE',
#  'H.264 720P Wired D/N Pan/Tilt , I/O(1/1), PoE',
#  'H.264 720P Wired IR Cube Camera , PoE',
#  'H.264 720P Wired IR Cube Camera, PoE',
#  'H.264 720P Wired IR-Bullet Camera, PoE',
#  'H.264 720P Wireless D/N Pan/Tilt , I/O(1/1)',
#  'H.264 720P Wireless IR Cube Camera',
#  'H.264 Mega IR Pan/Tilt Camera w/ audio, I/O(1/1)',
#  'H.264 Mega Outdoor IR Camera w/audio, I/O(1/1),PoE',
#  'H.264 Megapixel Fixed COMS Camera w/audio',
#  'H.264 Surveillance Camera',
#  'H.264+Megapixel Surveillance Camera',
#  'HAP-S1',
#  'HAP-Z1ES',
#  'HEOS 1',
#  'HEOS 3',
#  'HEOS 5',
#  'HEOS 7',
#  'HEOS Amp',
#  'HEOS Bar',
#  'HEOS Drive',
#  'HEOS HomeCinema',
#  'HEOS Link',
#  'HEOS Subwoofer',
#  'HG32EA590',
#  'HG40ED690',
#  'HG55AE690',
#  'HIKVISION DFI6217',
#  'HIKVISION DS-2CD1001-I',
#  'HIKVISION DS-2CD1010-I',
#  'HIKVISION DS-2CD1021-I',
#  'HIKVISION DS-2CD1021FD-IW1',
#  'HIKVISION DS-2CD1023G0-I',
#  'HIKVISION DS-2CD1031-I',
#  'HIKVISION DS-2CD1041-I',
#  'HIKVISION DS-2CD1101-I',
#  'HIKVISION DS-2CD1121-I',
#  'HIKVISION DS-2CD1123G0-I',
#  'HIKVISION DS-2CD1131-I',
#  'HIKVISION DS-2CD1141-I',
#  'HIKVISION DS-2CD1201-I3',
#  'HIKVISION DS-2CD1201-I5',
#  'HIKVISION DS-2CD1201D-I3',
#  'HIKVISION DS-2CD1202-I3',
#  'HIKVISION DS-2CD1203D-I3',
#  'HIKVISION DS-2CD1211D-I3',
#  'HIKVISION DS-2CD1221-I3',
#  'HIKVISION DS-2CD1221D-I3',
#  'HIKVISION DS-2CD1221D-I5',
#  'HIKVISION DS-2CD122P-I3',
#  'HIKVISION DS-2CD1301-I',
#  'HIKVISION DS-2CD1301D-I',
#  'HIKVISION DS-2CD1302D-I',
#  'HIKVISION DS-2CD1303D-I',
#  'HIKVISION DS-2CD130P-I',
#  'HIKVISION DS-2CD1321-I',
#  'HIKVISION DS-2CD1321D-I',
#  'HIKVISION DS-2CD132P-I',
#  'HIKVISION DS-2CD1331-I',
#  'HIKVISION DS-2CD1341-I',
#  'HIKVISION DS-2CD1410F-IW',
#  'HIKVISION DS-2CD1621FWD-I',
#  'HIKVISION DS-2CD1621FWD-IZ',
#  'HIKVISION DS-2CD1641FWD-I',
#  'HIKVISION DS-2CD1721FWD-I',
#  'HIKVISION DS-2CD1721FWD-IZ',
#  'HIKVISION DS-2CD1740F-IZ',
#  'HIKVISION DS-2CD1741FWD-I',
#  'HIKVISION DS-2CD2010-I',
#  'HIKVISION DS-2CD2010F-I',
#  'HIKVISION DS-2CD2010F-IW',
#  'HIKVISION DS-2CD2010F-IWNS',
#  'HIKVISION DS-2CD2012-I',
#  'HIKVISION DS-2CD2012F-I',
#  'HIKVISION DS-2CD2020-I',
#  'HIKVISION DS-2CD2020F-I',
#  'HIKVISION DS-2CD2020F-IW',
#  'HIKVISION DS-2CD2022F-I',
#  'HIKVISION DS-2CD2022F-IW',
#  'HIKVISION DS-2CD2022WD-I',
#  'HIKVISION DS-2CD2025FHWD-I',
#  'HIKVISION DS-2CD202PF-I',
#  'HIKVISION DS-2CD202PF-IW',
#  'HIKVISION DS-2CD202RF-I',
#  'HIKVISION DS-2CD2032-I',
#  'HIKVISION DS-2CD2032F-I',
#  'HIKVISION DS-2CD2035-I',
#  'HIKVISION DS-2CD2035FWD-I',
#  'HIKVISION DS-2CD2042WD-I',
#  'HIKVISION DS-2CD2052-I',
#  'HIKVISION DS-2CD2055FWD-I',
#  'HIKVISION DS-2CD2085FWD-I',
#  'HIKVISION DS-2CD2110F-I',
#  'HIKVISION DS-2CD2110F-IW',
#  'HIKVISION DS-2CD2112-I',
#  'HIKVISION DS-2CD2112F-I',
#  'HIKVISION DS-2CD2112F-IWS',
#  'HIKVISION DS-2CD2120-I',
#  'HIKVISION DS-2CD2120F-I',
#  'HIKVISION DS-2CD2120F-IS',
#  'HIKVISION DS-2CD2120F-IW',
#  'HIKVISION DS-2CD2120F-IWS',
#  'HIKVISION DS-2CD2121G0-I',
#  'HIKVISION DS-2CD2122F-I',
#  'HIKVISION DS-2CD2122F-IS',
#  'HIKVISION DS-2CD2122FWD-I',
#  'HIKVISION DS-2CD2122FWD-IS',
#  'HIKVISION DS-2CD2122FWD-IWS',
#  'HIKVISION DS-2CD2125FHWD-I',
#  'HIKVISION DS-2CD2125FWD-I',
#  'HIKVISION DS-2CD2125FWD-IS',
#  'HIKVISION DS-2CD212PF-I',
#  'HIKVISION DS-2CD212RF-I',
#  'HIKVISION DS-2CD2132-I',
#  'HIKVISION DS-2CD2132F-I',
#  'HIKVISION DS-2CD2132F-IS',
#  'HIKVISION DS-2CD2132F-IWS',
#  'HIKVISION DS-2CD2135F-IS',
#  'HIKVISION DS-2CD2135FWD-I',
#  'HIKVISION DS-2CD2135FWD-IS',
#  'HIKVISION DS-2CD2142FWD-I',
#  'HIKVISION DS-2CD2142FWD-IS',
#  'HIKVISION DS-2CD2142FWD-IW',
#  'HIKVISION DS-2CD2142FWD-IWS',
#  'HIKVISION DS-2CD2145F-IS',
#  'HIKVISION DS-2CD2152F-IS',
#  'HIKVISION DS-2CD2155F-IWS',
#  'HIKVISION DS-2CD2155FWD-I',
#  'HIKVISION DS-2CD2185FWD-I',
#  'HIKVISION DS-2CD2185FWD-IS',
#  'HIKVISION DS-2CD2212-I5',
#  'HIKVISION DS-2CD2232-I5',
#  'HIKVISION DS-2CD2310F-I',
#  'HIKVISION DS-2CD2312-I',
#  'HIKVISION DS-2CD2320F-I',
#  'HIKVISION DS-2CD2322WD-I',
#  'HIKVISION DS-2CD2325FWD-I',
#  'HIKVISION DS-2CD2332-I',
#  'HIKVISION DS-2CD2335-I',
#  'HIKVISION DS-2CD2335FWD-I',
#  'HIKVISION DS-2CD2342WD-I',
#  'HIKVISION DS-2CD2352-I',
#  'HIKVISION DS-2CD2355FWD-I',
#  'HIKVISION DS-2CD2385FWD-I',
#  'HIKVISION DS-2CD2410F-I',
#  'HIKVISION DS-2CD2410F-IW',
#  'HIKVISION DS-2CD2412F-I',
#  'HIKVISION DS-2CD2412F-IW',
#  'HIKVISION DS-2CD2420F-I',
#  'HIKVISION DS-2CD2420F-IW',
#  'HIKVISION DS-2CD2422FWD-IW',
#  'HIKVISION DS-2CD2432F-I',
#  'HIKVISION DS-2CD2432F-IW',
#  'HIKVISION DS-2CD2442FWD-IW',
#  'HIKVISION DS-2CD2452F-IW',
#  'HIKVISION DS-2CD2520F',
#  'HIKVISION DS-2CD2522FWD-IS',
#  'HIKVISION DS-2CD2522FWD-ISB',
#  'HIKVISION DS-2CD2532F-I',
#  'HIKVISION DS-2CD2532F-IS',
#  'HIKVISION DS-2CD2532F-IW',
#  'HIKVISION DS-2CD2532F-IWS',
#  'HIKVISION DS-2CD2542FWD-I',
#  'HIKVISION DS-2CD2542FWD-IS',
#  'HIKVISION DS-2CD2542FWD-IWS',
#  'HIKVISION DS-2CD2552F-IS',
#  'HIKVISION DS-2CD2555FWD-IS',
#  'HIKVISION DS-2CD2612F-I',
#  'HIKVISION DS-2CD2612F-INS',
#  'HIKVISION DS-2CD2620F-I',
#  'HIKVISION DS-2CD2620F-IZ',
#  'HIKVISION DS-2CD2620F-IZS',
#  'HIKVISION DS-2CD2622FWD-I',
#  'HIKVISION DS-2CD2622FWD-IZS',
#  'HIKVISION DS-2CD2632F-I',
#  'HIKVISION DS-2CD2632F-IS',
#  'HIKVISION DS-2CD2642FWD-I',
#  'HIKVISION DS-2CD2642FWD-IS',
#  'HIKVISION DS-2CD2642FWD-IZ',
#  'HIKVISION DS-2CD2642FWD-IZS',
#  'HIKVISION DS-2CD2710F-I',
#  'HIKVISION DS-2CD2712F-I',
#  'HIKVISION DS-2CD2720F-I',
#  'HIKVISION DS-2CD2720F-IZ',
#  'HIKVISION DS-2CD2722FWD-IZS',
#  'HIKVISION DS-2CD2725FWD-IZS',
#  'HIKVISION DS-2CD2732F-I',
#  'HIKVISION DS-2CD2732F-IS',
#  'HIKVISION DS-2CD2742FWD-I',
#  'HIKVISION DS-2CD2742FWD-IS',
#  'HIKVISION DS-2CD2742FWD-IZ',
#  'HIKVISION DS-2CD2742FWD-IZS',
#  'HIKVISION DS-2CD2752F-IZS',
#  'HIKVISION DS-2CD2820F-IR',
#  'HIKVISION DS-2CD2820FWD',
#  'HIKVISION DS-2CD2822F-IR',
#  'HIKVISION DS-2CD2942F',
#  'HIKVISION DS-2CD2942F-IS',
#  'HIKVISION DS-2CD2955FWD-I',
#  'HIKVISION DS-2CD2955FWD-IS',
#  'HIKVISION DS-2CD2D14WD/M',
#  'HIKVISION DS-2CD2E20F',
#  'HIKVISION DS-2CD2E20F-W',
#  'HIKVISION DS-2CD2F42FWD-IWS',
#  'HIKVISION DS-2CD2Q10FD-IW',
#  'HIKVISION DS-2CD2T12-I5',
#  'HIKVISION DS-2CD2T20-I3',
#  'HIKVISION DS-2CD2T20-I5',
#  'HIKVISION DS-2CD2T20D-I3',
#  'HIKVISION DS-2CD2T20F-I5',
#  'HIKVISION DS-2CD2T22-I3',
#  'HIKVISION DS-2CD2T22-I5',
#  'HIKVISION DS-2CD2T22-I8',
#  'HIKVISION DS-2CD2T22WD-I3',
#  'HIKVISION DS-2CD2T22WD-I5',
#  'HIKVISION DS-2CD2T22WD-I8',
#  'HIKVISION DS-2CD2T32-I3',
#  'HIKVISION DS-2CD2T32-I5',
#  'HIKVISION DS-2CD2T32-I8',
#  'HIKVISION DS-2CD2T42WD-I3',
#  'HIKVISION DS-2CD2T42WD-I5',
#  'HIKVISION DS-2CD2T42WD-I8',
#  'HIKVISION DS-2CD2T52-I5',
#  'HIKVISION DS-2CD2T55FWD-I8',
#  'HIKVISION DS-2CD3042WDN-I/B',
#  'HIKVISION DS-2CD3132-I',
#  'HIKVISION DS-2CD3132F-I',
#  'HIKVISION DS-2CD3135F-I',
#  'HIKVISION DS-2CD3135F-IWS',
#  'HIKVISION DS-2CD3142FWDN-IS/B',
#  'HIKVISION DS-2CD3145F-I',
#  'HIKVISION DS-2CD3210-I3',
#  'HIKVISION DS-2CD3210-I5',
#  'HIKVISION DS-2CD3210D-I3',
#  'HIKVISION DS-2CD3210D-I5',
#  'HIKVISION DS-2CD3220D-I5',
#  'HIKVISION DS-2CD3310-I',
#  'HIKVISION DS-2CD3310D-I',
#  'HIKVISION DS-2CD3320D-I',
#  'HIKVISION DS-2CD3332-I',
#  'HIKVISION DS-2CD3345-I',
#  'HIKVISION DS-2CD3410FD-IW',
#  'HIKVISION DS-2CD3T10D-I3',
#  'HIKVISION DS-2CD3T10D-I5',
#  'HIKVISION DS-2CD3T20-I5',
#  'HIKVISION DS-2CD3T20D-I3',
#  'HIKVISION DS-2CD3T20D-I5',
#  'HIKVISION DS-2CD3T25D-I3',
#  'HIKVISION DS-2CD3T25D-I5',
#  'HIKVISION DS-2CD3T35D-I3',
#  'HIKVISION DS-2CD3T45-I5',
#  'HIKVISION DS-2CD3T45D-I5',
#  'HIKVISION DS-2CD4124F-IZ',
#  'HIKVISION DS-2CD4125FWD-IZ',
#  'HIKVISION DS-2CD4132FWD-I',
#  'HIKVISION DS-2CD4135FWD-IZ',
#  'HIKVISION DS-2CD4332FWD-IZHS',
#  'HIKVISION DS-2CD4332FWD-IZS',
#  'HIKVISION DS-2CD4565F-IZH',
#  'HIKVISION DS-2CD4A26FWD-IZ/P',
#  'HIKVISION DS-2CD4A26FWD-IZHS',
#  'HIKVISION DS-2CD4A26FWD-IZHS/P',
#  'HIKVISION DS-2CD4A26FWD-IZS',
#  'HIKVISION DS-2CD4A26FWD-IZS/P',
#  'HIKVISION DS-2CD4AC5F-IZ',
#  'HIKVISION DS-2CD4D26FWD-IZS',
#  'HIKVISION DS-2CD6332FWD-I',
#  'HIKVISION DS-2CD6332FWD-IVS',
#  'HIKVISION DS-2CD6362F-IS',
#  'HIKVISION DS-2CD6362F-IV',
#  'HIKVISION DS-2CD6362F-IVS',
#  'HIKVISION DS-2CD63C2F-IVS',
#  'HIKVISION DS-2CD6412FWD-C1',
#  'HIKVISION DS-2CD7153-E',
#  'HIKVISION DS-2CD7164-E',
#  'HIKVISION DS-2CD733F-EI',
#  'HIKVISION DS-2CD753F-E',
#  'HIKVISION DS-2CD793PF-E',
#  'HIKVISION DS-2CD8153F-E',
#  'HIKVISION DS-2CD853F-E',
#  'HIKVISION DS-2CD883F-E',
#  'HIKVISION DS-2CD893PF-E',
#  'HIKVISION DS-2CD893PFWD-E',
#  'HIKVISION DS-2CDAC03D-ILY',
#  'HIKVISION DS-2CV2Q01EFD-IW',
#  'HIKVISION DS-2CV2Q01FD-IW',
#  'HIKVISION DS-2CV2Q21FD-IW',
#  'HIKVISION DS-2CV2U01EFD-IW',
#  'HIKVISION DS-2CV2U01FD-IW',
#  'HIKVISION DS-2CV2U21FD-IW',
#  'HIKVISION DS-2DC2202I-DE3/W',
#  'HIKVISION DS-2DE2202-DE3/W',
#  'HIKVISION DS-2DE2204IW-DE3/W',
#  'HIKVISION DS-2DE3204W-DE',
#  'HIKVISION DS-2DE3304W-DE',
#  'HIKVISION DS-2DE4215IW-DE',
#  'HIKVISION DS-2DE4220-AE',
#  'HIKVISION DS-2DE4220-AE3',
#  'HIKVISION DS-2DE4220IW-D',
#  'HIKVISION DS-2DE4220IW-DE',
#  'HIKVISION DS-2DE5184-AE',
#  'HIKVISION DS-2DE5220IW-AE',
#  'HIKVISION DS-2DE5230W-AE',
#  'HIKVISION DS-2DE7174-AE',
#  'HIKVISION DS-2DE7184-AE',
#  'HIKVISION DS-2DE7220IW-AE',
#  'HIKVISION DS-2DE7230IW-AE',
#  'HIKVISION DS-2DF7274-A',
#  'HIKVISION DS-2DF7284-A',
#  'HIKVISION DS-2DF7286-AEL',
#  'HIKVISION DS-2DF8223I-AEL',
#  'HIKVISION DS-2DF8236I-AEL',
#  'HIKVISION DS-2TD2136-15',
#  'HIKVISION DS-2TD4136-25',
#  'HIKVISION DX-2CV2Q01FD-IW/16G',
#  'HIKVISION HIK-IP6020F-I',
#  'HIKVISION HJC-6110F-I',
#  'HIKVISION HWC-P120-D/W',
#  'HIKVISION IPC-B100',
#  'HIKVISION IPC-B120',
#  'HIKVISION IPC-D120',
#  'HIKVISION IPC-T121',
#  'HIKVISION TV-IP310PI',
#  'HIKVISION TV-IP311PI',
#  'HK AVR 151',
#  'HK AVR 151S',
#  'HK AVR 161',
#  'HK AVR 161S',
#  'HK AVR 171S',
#  'HK AVR 270/2700',
#  'HK AVR 370',
#  'HK AVR 370/3700',
#  'HK AVR170',
#  'HK AVR1700',
#  'HK OMNI 10+',
#  'HS-251',
#  'HS-251+',
#  'HT-CT790',
#  'HT-CT800',
#  'HT-MT500/501',
#  'HT-NT3',
#  'HT-NT5',
#  'HT-R693',
#  'HT-RC660',
#  'HT-RT5',
#  'HT-ST5000',
#  'HT-ST9',
#  'HT-XT2',
#  'HT-XT3',
#  'HT-Z9F',
#  'HT-ZF9',
#  'HTR-4066',
#  'HTR-4067',
#  'HTR-4068',
#  'HTR-4069',
#  'HTR-4071',
#  'HUM',
#  'HW-H750',
#  'HW-J650',
#  'HW-J6500',
#  'HW-J6500R',
#  'HW-J7500',
#  'HW-J7500R',
#  'HW-J8500',
#  'HW-J8500R',
#  'HW-K650',
#  'HW-K850',
#  'HW-K950',
#  'HW-N950',
#  'Haier 43E4500R',
#  'Haier 49E4500R',
#  'Heritage P1',
#  'Hisense 32H4+',
#  'Hisense 32H4C+',
#  'Hisense 40H4*',
#  'Hisense 40H4C+',
#  'Hisense 40H4CA+',
#  'Hisense 40H4CM+',
#  'Hisense 50H4+',
#  'Hisense 50H4CA+',
#  'Hisense SmartTV',
#  'Hisilicon HiMultiScreen',
#  'Hitachi 32R20',
#  'Hitachi 43R5',
#  'Hitachi 50R5',
#  'Hitachi 50R8',
#  'ICU100',
#  'IHD92',
#  'IKR1224WTD',
#  'IMAGEM - LAUDOS',
#  'IMP-M-AMBIENTE',
#  'IMPRESSIA',
#  'IMPRESSORA',
#  'IMPSEGUROS',
#  'INSIGNIA NS-24ER310NA17',
#  'INSIGNIA NS-32DR310NA17',
#  'INSIGNIA NS-32DR420NA16',
#  'INSIGNIA NS-39DR510NA17',
#  'INSIGNIA NS-40DR420NA16',
#  'INSIGNIA NS-48DR420NA16',
#  'INSIGNIA NS-55DR420NA16',
#  'IP815',
#  'IPC1100',
#  'IPC1100P2',
#  'IPC4100',
#  'IPCA32500',
#  'IPCA62500',
#  'IPCA63500 - 8C11CB09705C',
#  'IPCA63500 - 8C11CB09CEF1',
#  'IPCA66500 - 8C11CB09DCE8',
#  'IPCA66500 - 8C11CB09DCF0',
#  'IPCA73500 - 8C11CB0B0953',
#  'IPCA76500 - 8C11CB095E20',
#  'IPCB42500 - 8C11CB094B73',
#  'IPCB42500 - 8C11CB096026',
#  'IPCB42500 - 8C11CB096099',
#  'IPCB42501 - 8C11CB0997C5',
#  'IPCB42501 - 8C11CB099E58',
#  'IPCB42501 - 8C11CB09CB09',
#  'IPCB42501 - 8C11CB0B0E30',
#  'IPCB42501 - 8C11CB0B0E8A',
#  'IPCB42501 - 8C11CB0B2F9D',
#  'IPCB42550 - 8C11CB095EFF',
#  'IPCB42551 - 8C11CB099550',
#  'IPCB62510B - 8C11CB0B70A3',
#  'IPCB72501 - 8C11CB09A1C1',
#  'IPCS82520 - 8C11CB09B525',
#  'IPCS82520 - 8C11CB0B3541',
#  'IPSiO SP 8300M',
#  'IPSiO SP C720',
#  'IPSiO SP C721',
#  'IR 1080p Network Dome Camera',
#  'IR 1080p Network Outdoor Dome Camera',
#  'IR 3Megapixel D/N Outdoor Dome, PoE',
#  'IR 5Megapixel D/N Outdoor Bullet, PoE',
#  'IR 6S PLUS ',
#  'IR 7S',
#  'IR HD 720p Network Dome Camera',
#  'IR HD 720p Network Outdoor Dome Camera',
#  'IR HD 720p WLAN Network Dome Camera',
#  'IR HD 720p WLAN Network Outdoor Dome Camera',
#  'IR HD Network Dome Camera',
#  'IR Pan/Tilt 1080p Network Camera',
#  'IR Pan/Tilt 720p Network Camera',
#  'IR Pan/Tilt 720p Network Camera WLAN',
#  'IR110',
#  'IR120MS',
#  'IR320',
#  'IR350',
#  'IR3A',
#  'IR4400',
#  'IR6',
#  'IR8S',
#  'IRD30',
#  'IWR 251',
#  'IWR 261',
#  'IWR271',
#  'IWR282',
#  'Imp_BKP_RUE2',
#  'Imp_U.T.I',
#  'Insight',
#  'Insignia NS-49DR420NA18',
#  'Insignia NS-50DR710CA17',
#  'Insignia NS-50DR710NA17',
#  'Insignia NS-55DR710NA17',
#  'Intel DLNA DMR',
#  'Interlogix RS-3250',
#  'Interlogix TVW-1105',
#  'Internet TV Box NSZ-GT1',
#  'Internet TV NSX-GT1',
#  'JBL OnBeat Air',
#  'JBL SoundFly Air',
#  'JOJO',
#  'Jupiter',
#  'K2',
#  'KD-43X7500E',
#  'KD-43X8000E',
#  'KD-43X8305C',
#  'KD-43X8309C',
#  'KD-43XD8099',
#  'KD-43XD8305',
#  'KD-43XE8004',
#  'KD-43XE8005',
#  'KD-43XE8077',
#  'KD-43XE8096',
#  'KD-43XE8396',
#  'KD-43XF7596',
#  'KD-43XF8096',
#  'KD-43XF8505',
#  'KD-49X7000D',
#  'KD-49X7005D',
#  'KD-49X7500F',
#  'KD-49X8000D',
#  'KD-49X8000E',
#  'KD-49X8300C',
#  'KD-49X8305C',
#  'KD-49X8307C',
#  'KD-49X8308C',
#  'KD-49X8309C',
#  'KD-49X8505B',
#  'KD-49X9000E',
#  'KD-49XD7005',
#  'KD-49XD8005',
#  'KD-49XD8077',
#  'KD-49XD8099',
#  'KD-49XD8305',
#  'KD-49XE8004',
#  'KD-49XE8005',
#  'KD-49XE8077',
#  'KD-49XE8096',
#  'KD-49XE8396',
#  'KD-49XE9005',
#  'KD-49XF7596',
#  'KD-49XF8096',
#  'KD-49XF8505',
#  'KD-49XF8596',
#  'KD-49XF8599',
#  'KD-49XF9005',
#  'KD-55A1',
#  'KD-55AF8',
#  'KD-55S8005C',
#  'KD-55X7000D',
#  'KD-55X7005D',
#  'KD-55X757F',
#  'KD-55X8000E',
#  'KD-55X8005C',
#  'KD-55X8500C',
#  'KD-55X8500D',
#  'KD-55X8500E',
#  'KD-55X8500F',
#  'KD-55X8501C',
#  'KD-55X8505B',
#  'KD-55X8505C',
#  'KD-55X8507C',
#  'KD-55X8508C',
#  'KD-55X8509C',
#  'KD-55X9005A',
#  'KD-55X9005C',
#  'KD-55X9300D',
#  'KD-55XD7005',
#  'KD-55XD8005',
#  'KD-55XD8505',
#  'KD-55XD8577',
#  'KD-55XD8599',
#  'KD-55XD9305',
#  'KD-55XE8096',
#  'KD-55XE8505',
#  'KD-55XE8577',
#  'KD-55XE8588',
#  'KD-55XE8596',
#  'KD-55XE9005',
#  'KD-55XE9305',
#  'KD-55XF7596',
#  'KD-55XF8096',
#  'KD-55XF8505',
#  'KD-55XF8596',
#  'KD-55XF9005',
#  'KD-60XF8305',
#  'KD-65A1',
#  'KD-65AF8',
#  'KD-65S8505C',
#  'KD-65S9005B',
#  'KD-65X7505D',
#  'KD-65X755F',
#  'KD-65X8500E',
#  'KD-65X8505A',
#  'KD-65X8505B',
#  'KD-65X8505C',
#  'KD-65X9005B',
#  'KD-65XD7505',
#  'KD-65XD9305',
#  'KD-65XE8505',
#  'KD-65XE8588',
#  'KD-65XE8596',
#  'KD-65XE9005',
#  'KD-65XF8505',
#  'KD-65XF8599',
#  'KD-65XF9005',
#  'KD-75X9400E',
#  'KD-75XD8505',
#  'KD-85X8500F',
#  'KDL-22E5300     ',
#  'KDL-22EX320',
#  'KDL-22EX420',
#  'KDL-22EX555',
#  'KDL-24W600A',
#  'KDL-24W605A',
#  'KDL-26EX320',
#  'KDL-26EX550',
#  'KDL-26EX553',
#  'KDL-26J1',
#  'KDL-32CX400',
#  'KDL-32EX300/B',
#  'KDL-32EX500',
#  'KDL-32EX521',
#  'KDL-32EX525',
#  'KDL-32EX555',
#  'KDL-32EX557',
#  'KDL-32EX650',
#  'KDL-32EX655',
#  'KDL-32EX700',
#  'KDL-32EX720',
#  'KDL-32EX721',
#  'KDL-32EX728',
#  'KDL-32HX750',
#  'KDL-32HX755',
#  'KDL-32NX655',
#  'KDL-32W500A',
#  'KDL-32W503A',
#  'KDL-32W600A',
#  'KDL-32W605A',
#  'KDL-32W607A',
#  'KDL-32W650A',
#  'KDL-32W653A',
#  'KDL-32W654A',
#  'KDL-32W655A',
#  'KDL-32W670A',
#  'KDL-32W700B',
#  'KDL-32W705B',
#  'KDL-32W705C',
#  'KDL-32W706B',
#  'KDL-37EX723',
#  'KDL-37EX725',
#  'KDL-40CX520',
#  'KDL-40CX523',
#  'KDL-40EX500',
#  'KDL-40EX521',
#  'KDL-40EX525',
#  'KDL-40EX600',
#  'KDL-40EX650',
#  'KDL-40EX653',
#  'KDL-40EX655',
#  'KDL-40EX710',
#  'KDL-40EX720',
#  'KDL-40EX721',
#  'KDL-40EX725',
#  'KDL-40EX727',
#  'KDL-40EX728',
#  'KDL-40EX729',
#  'KDL-40HX720',
#  'KDL-40HX750',
#  'KDL-40HX753',
#  'KDL-40HX755',
#  'KDL-40HX756',
#  'KDL-40HX800',
#  'KDL-40LX900',
#  'KDL-40NX700',
#  'KDL-40NX711',
#  'KDL-40NX713',
#  'KDL-40NX715',
#  'KDL-40NX720',
#  'KDL-40NX725',
#  'KDL-40V5',
#  'KDL-40W5500     ',
#  'KDL-40W580B',
#  'KDL-40W600B',
#  'KDL-40W605B',
#  'KDL-40W607B',
#  'KDL-40W700C',
#  'KDL-40W705C',
#  'KDL-40W905A',
#  'KDL-40Z5800     ',
#  'KDL-42W650A',
#  'KDL-42W653A',
#  'KDL-42W654A',
#  'KDL-42W655A',
#  'KDL-42W656A',
#  'KDL-42W657A',
#  'KDL-42W674A',
#  'KDL-42W700B',
#  'KDL-42W705B',
#  'KDL-42W706B',
#  'KDL-42W800B',
#  'KDL-42W805A',
#  'KDL-42W805B',
#  'KDL-42W807A',
#  'KDL-42W808A',
#  'KDL-42W815B',
#  'KDL-42W817B',
#  'KDL-42W828B',
#  'KDL-42W829B',
#  'KDL-43W755C',
#  'KDL-43W756C',
#  'KDL-43W780C',
#  'KDL-43W800C',
#  'KDL-43W800D',
#  'KDL-43W800F',
#  'KDL-43W805C',
#  'KDL-43W807C',
#  'KDL-43W808C',
#  'KDL-43W809C',
#  'KDL-43W950D',
#  'KDL-46EX500',
#  'KDL-46EX521',
#  'KDL-46EX523',
#  'KDL-46EX620',
#  'KDL-46EX621',
#  'KDL-46EX650',
#  'KDL-46EX653',
#  'KDL-46EX655',
#  'KDL-46EX720',
#  'KDL-46EX721',
#  'KDL-46EX723',
#  'KDL-46EX724',
#  'KDL-46EX728',
#  'KDL-46EX729',
#  'KDL-46HX720',
#  'KDL-46HX729',
#  'KDL-46HX750',
#  'KDL-46HX755',
#  'KDL-46HX758',
#  'KDL-46HX75G',
#  'KDL-46HX800',
#  'KDL-46HX850',
#  'KDL-46HX853',
#  'KDL-46HX855',
#  'KDL-46HX857',
#  'KDL-46HX920',
#  'KDL-46LX900',
#  'KDL-46NX700',
#  'KDL-46NX715',
#  'KDL-46NX720',
#  'KDL-46NX725',
#  'KDL-46NX800',
#  'KDL-46V5',
#  'KDL-46W904A',
#  'KDL-46W905A',
#  'KDL-46W950A',
#  'KDL-46W955A',
#  'KDL-47W800A',
#  'KDL-47W805A',
#  'KDL-47W807A',
#  'KDL-48W580B',
#  'KDL-48W585B',
#  'KDL-48W600B',
#  'KDL-48W605B',
#  'KDL-48W609B',
#  'KDL-48W700C',
#  'KDL-48W705C',
#  'KDL-49W800F',
#  'KDL-50FA97C',
#  'KDL-50W650A',
#  'KDL-50W655A',
#  'KDL-50W656A',
#  'KDL-50W685A',
#  'KDL-50W700A',
#  'KDL-50W700B',
#  'KDL-50W704A',
#  'KDL-50W705B',
#  'KDL-50W706B',
#  'KDL-50W755C',
#  'KDL-50W756C',
#  'KDL-50W790B',
#  'KDL-50W800B',
#  'KDL-50W800C',
#  'KDL-50W805B',
#  'KDL-50W805C',
#  'KDL-50W807B',
#  'KDL-50W807C',
#  'KDL-50W808C',
#  'KDL-50W809C',
#  'KDL-50W815B',
#  'KDL-50W828B',
#  'KDL-50W829B',
#  'KDL-50W900B',
#  'KDL-52LX905',
#  'KDL-52W5500     ',
#  'KDL-55EX505',
#  'KDL-55EX710',
#  'KDL-55EX720',
#  'KDL-55EX723',
#  'KDL-55EX725',
#  'KDL-55HX729',
#  'KDL-55HX750',
#  'KDL-55HX755',
#  'KDL-55HX820',
#  'KDL-55HX850',
#  'KDL-55HX853',
#  'KDL-55HX920',
#  'KDL-55NX720',
#  'KDL-55NX725',
#  'KDL-55NX810',
#  'KDL-55W700B',
#  'KDL-55W755C',
#  'KDL-55W756C',
#  'KDL-55W790B',
#  'KDL-55W800B',
#  'KDL-55W800C',
#  'KDL-55W802A',
#  'KDL-55W805A',
#  'KDL-55W805B',
#  'KDL-55W805C',
#  'KDL-55W807A',
#  'KDL-55W808A',
#  'KDL-55W808C',
#  'KDL-55W809C',
#  'KDL-55W815B',
#  'KDL-55W817B',
#  'KDL-55W828B',
#  'KDL-55W829B',
#  'KDL-55W900A',
#  'KDL-55W905A',
#  'KDL-55W920A',
#  'KDL-55W950B',
#  'KDL-55W955A',
#  'KDL-55W955B',
#  'KDL-60EX700',
#  'KDL-60EX725',
#  'KDL-60NX720',
#  'KDL-60W605B',
#  'KDL-60W610B',
#  'KDL-60W630B',
#  'KDL-60W850B',
#  'KDL-60W855B',
#  'KDL-65S990A',
#  'KDL-65W850A',
#  'KDL-65W850C',
#  'KDL-65W855A',
#  'KDL-65W855C',
#  'KDL-65W859C',
#  'KDL-65W955B',
#  'KDL-70W850B',
#  'KDL-75W850C',
#  'KDL-75W855C',
#  'KR-200',
#  'Kamera-Stodl-720p',
#  'Kamera2',
#  'Kies Sync Server',
#  'Kodi',
#  'Kugou Media Render Device',
#  'Kwesé Play',
#  'LASER COMPTA',
#  'LC-24LB601U',
#  'LC-32LB601C',
#  'LC-32LB601U',
#  'LC-40LB601U',
#  'LC-43LB601U',
#  'LC-43LBU591C',
#  'LC-43LBU591U',
#  'LC-50LB601C',
#  'LC-50LB601U',
#  'LC-50LBU591C',
#  'LC-50LBU591U',
#  'LC-55LBU591C',
#  'LC-55LBU591U',
#  'LC-58Q73+',
#  'LC-60R6003U',
#  'LC-65LBU591U',
#  'LC-65Q73+',
#  'LCAD03FLN',
#  'LCAD03VLNOD',
#  'LD 625C',
#  'LE40D550',
#  'LG 55LF5700-UA',
#  'LG Android TV',
#  'LG Music Flow',
#  'LG SST Device',
#  'LG Smart TV',
#  'LG TV',
#  'LG-Ericsson Wireless AP Router',
#  'LGE Wireless Gigabit Router',
#  'LGPC Admin (LAPTOPRODRIGO)',
#  'LH40RMDT',
#  'LISA',
#  'LN40D550',
#  'LT27D390S',
#  'LT32E390S',
#  'LV24F39S',
#  'LaCie NAS',
#  'LaCie Open Space',
#  'Lab233',
#  'Laboratory_prin',
#  'Lebo',
#  'Legrand Digital',
#  'Lenco Concerto',
#  'Lifestyle',
#  'LightSwitch',
#  'LnvCon1.0',
#  'Logitech Alert(tm) 700e',
#  'Logitech Alert(tm) 700i',
#  'Logitech Alert(tm) 700n',
#  'Logitech Media Server 7.7.0 r33614',
#  'Logitech Media Server 7.7.41415167000',
#  'Logitech Media Server 7.7.61452060463',
#  'Loxone Miniserver',
#  'M4070 JURIDICO',
#  'MA02IMP_GMCBC01',
#  'MEDION',
#  'MEISTERSTUECK',
#  'MELPRINTER',
#  'MG2900 series ',
#  'MG3000 series ',
#  'MG3600 series ',
#  'MG5400 series ',
#  'MG5600 series ',
#  'MG5700 series ',
#  'MG6300 series ',
#  'MG6400 series ',
#  'MG6500 series ',
#  'MG6600 series ',
#  'MG6700 series ',
#  'MG6800 series ',
#  'MG6900 series ',
#  'MG7100 series ',
#  'MG7500 series ',
#  'MG7700 series ',
#  'MHC-V77DW',
#  'MHC-V77W',
#  'MHC-V90DW',
#  'ML2675_Emelet',
#  'MP 2001',
#  'MP 201/LD 220',
#  'MP 2352',
#  'MP 2501',
#  'MP 2550',
#  'MP 2550B/LD425B',
#  'MP 2553',
#  'MP 2554',
#  'MP 2555',
#  'MP 301',
#  'MP 305+',
#  'MP 3054',
#  'MP 3055',
#  'MP 3353',
#  'MP 3554',
#  'MP 4000/LD040',
#  'MP 402SPF',
#  'MP 4054',
#  'MP 4055',
#  'MP 501',
#  'MP 5054',
#  'MP 5055',
#  'MP 6002',
#  'MP 6054',
#  'MP 6055',
#  'MP 6503',
#  'MP 7502',
#  'MP 8001',
#  'MP C2003',
#  'MP C2004',
#  'MP C2004ex',
#  'MP C2011',
#  'MP C2051',
#  'MP C2503',
#  'MP C2504',
#  'MP C2504ex',
#  'MP C3003',
#  'MP C3003 JPN',
#  'MP C3004',
#  'MP C3004 JPN',
#  'MP C3004ex',
#  'MP C306Z',
#  'MP C307',
#  'MP C3503',
#  'MP C3503 JPN',
#  'MP C3504',
#  'MP C3504 JPN',
#  'MP C3504ex',
#  'MP C4000/LD540C',
#  'MP C400SR',
#  'MP C401',
#  'MP C401SR',
#  'MP C406Z',
#  'MP C407',
#  'MP C4503',
#  'MP C4503 JPN',
#  'MP C4504',
#  'MP C4504 JPN',
#  'MP C4504ex',
#  'MP C5503',
#  'MP C5504',
#  'MP C5504 JPN',
#  'MP C6004ex',
#  'MP C6502',
#  'MP C6503',
#  'MP C8003',
#  'MP5',
#  'MSBOX',
#  'MUNET PMN300',
#  'MUNET PMN400',
#  'MX520 series ',
#  'MX720 series ',
#  'MX920 series ',
#  'Magnat_40',
#  'Maker',
#  'Marantz AV7703',
#  'Marantz AV7704',
#  'Marantz AV7705',
#  'Marantz AV8805',
#  'Marantz NA6006',
#  'Marantz ND8006',
#  'Marantz NR1508',
#  'Marantz NR1509',
#  'Marantz NR1608',
#  'Marantz NR1609',
#  'Marantz SR5012',
#  'Marantz SR5013',
#  'Marantz SR6012',
#  'Marantz SR6013',
#  'Marantz SR7011',
#  'Marantz SR7012',
#  'Marantz SR7013',
#  'Marantz SR8012',
#  'Media Center',
#  'MediaMonkey Sync Server',
#  'MediaRenderer',
#  'Medion',
#  'Menuett',
#  'MiniHD',
#  'Minx Xi',
#  'Mu-so',
#  'Mu-so Qb',
#  'My Book Live',
#  'My Book World Edition',
#  'MyBookLive',
#  'MyBookLiveDuo',
#  'MyCloud',
#  'MyCloudEX2Ultra',
#  'MyCloudPR2100',
#  'N2310',
#  'N2350',
#  'N2810',
#  'N3200PRO',
#  'N3LBRCM01-PRT',
#  'N4310',
#  'N4350',
#  'N4560',
#  'N5810PRO',
#  'N600DB',
#  'N7710',
#  'NAC-N 172XS',
#  'NAC-N 272',
#  'NAS326',
#  'NAS520',
#  'NAS540',
#  'NASBOX2',
#  'NBC30-IR Outdoor Night-Vision Network Camera (MPEG4\n+ Motion-J',
#  'ND5XS',
#  'NDS',
#  'NE-3241-T20',
#  'NE-6146-R10',
#  'NE-6146T11',
#  'NFC30 Network Camera (MPEG4 + Motion-JPEG Dual\nMode, PoE, Audi',
#  'NFC30-IR Night-Vision Network Camera (MPEG4 +\nMotion-JPEG Dual',
#  'NFC30-IRWG Night-Vision Network Camera (MPEG4\n+ Motion-JPEG Du',
#  'NFC31 Megapixel Network Camera',
#  'NFLC SDK v1.5',
#  'NMR',
#  'NOVA M',
#  'NOXON A110+',
#  'NOXON A120+',
#  'NOXON NOVA',
#  'NOXON NOVA S',
#  'NP',
#  'NP-S303',
#  'NP30',
#  'NS-24DR220CA18',
#  'NS-24DR220NA18',
#  'NS-32DR310CA17',
#  'NS-32DR310NA17',
#  'NS-39DR510NA17',
#  'NS-43DR620NA18',
#  'NS-50DR620NA18',
#  'NS-55DR620NA18',
#  'NSC15-WG Network Camera (Motion-JPEG + MPEG4,\nDay/Night, Audio',
#  'NSC16-WG Megapixel Network Camera',
#  'NUMAN ONE',
#  'NUMAN One',
#  'NVR216',
#  'NWB6210F 2MP Bullet Camera',
#  'NaimUniti',
#  'Nero MediaHome',
#  'NetCam',
#  'NetCamHDv1',
#  'NetCamHDv2',
#  'NetOne Printer',
#  'Network Camera',
#  'Network Drive XS',
#  'Netzwerkdrucker',
#  'None',
#  'Now TV',
#  'NuVo Player',
#  'Numericable Media Server',
#  'OBRAS - M4070FR',
#  'OLED55B8PLA',
#  'OLED55B8PUA',
#  'OLED55B8SLC',
#  'OLED55B8SSC',
#  'OLED55C8GNA',
#  'OLED55C8LLA',
#  'OLED55C8PLA',
#  'OLED55C8PUA',
#  'OLED55E8LLA',
#  'OLED55E8PUA',
#  'OLED65B8PLA',
#  'OLED65B8YVA',
#  'OLED65C8PUA',
#  'OLED65E8PLA',
#  'OLED65G8PLA',
#  'OM46D',
#  'Onkyo TX-8270',
#  'Onkyo TX-NR555',
#  'Onkyo TX-NR575',
#  'Onkyo TX-NR575E',
#  'Onkyo TX-NR656',
#  'Onkyo TX-NR676',
#  'Onkyo TX-NR676E',
#  'Onkyo TX-NR686',
#  'Onkyo TX-NR757',
#  'Onkyo TX-NR777',
#  'Onkyo TX-RZ710',
#  'Onkyo TX-RZ720',
#  'Onkyo TX-RZ820',
#  'P6210 2MP Pan/Tilt Camera',
#  'P8220 2MP Speed Dome Camera',
#  'PATRIM-542748RE',
#  'PC',
#  'PCT-1331-P01',
#  'PDR260-B',
#  'PDR360BT-B',
#  'PHASER3250',
#  'PLAYLINK',
#  'PMS',
#  'PN51D8000',
#  'PRESTIGE',
#  'PRT-CONTAB',
#  'PS51D550',
#  'PTEC Castor',
#  'Pan/Tilt 1.3 MPx Network Camera',
#  'Pan/Tilt Day/Night IP Camera with Two-way Audio',
#  'Pan/Tilt IP Camera',
#  'Pan/Tilt VGA Network Camera',
#  'Panasonic VIErA',
#  'Personal Cloud',
#  'Phantom Reactor 900',
#  'Philips Multiroom WiFi Speaker',
#  'Philips TV DMR',
#  'Philips TV Server',
#  'Philips hue bridge 2012',
#  'Philips hue bridge 2015',
#  'Phorus-Renderer',
#  'Photosmart 6510 series',
#  'Photosmart 6520 series',
#  'Photosmart 7510 series',
#  'Photosmart 7520 series',
#  'Photosmart C6100 series',
#  'Photosmart C6300 series',
#  'Photosmart C7200 series',
#  'Photosmart Plus B209a-m',
#  'Photosmart Plus B210 series',
#  'Photosmart Prem C310 series',
#  'PiXiS RX ',
#  'Pilatus',
#  'Pinell Supersound',
#  'Plex Media Server',
#  'Point OL96HZ',
#  'Primo',
#  'Print-Colatina',
#  'Printer',
#  'Pro 1357EX',
#  'Pro 8120S',
#  'Q700',
#  'Q800',
#  'Q802',
#  'QA55Q7CAM',
#  'QE49Q6FNA',
#  'QE49Q7FAM',
#  'QE55Q6FNA',
#  'QE55Q7FAM',
#  'QE55Q7FNA',
#  'QE55Q8FNA',
#  'QE65Q6FNA',
#  'QE65Q7FAM',
#  'QE65Q7FGM',
#  'QE65Q8FAM',
#  'QE65Q8FNA',
#  'QE705',
#  'QE707',
#  'QE75Q7FAM',
#  'QM152E',
#  'QM163E',
#  'QM164E',
#  'QN49Q6FNA',
#  'QN55Q6FAM',
#  'QN55Q6FNA',
#  'QN55Q7CAM',
#  'QN55Q7FAM',
#  'QN65Q6FNA',
#  'QN65Q7CDM',
#  'QN65Q7FNA',
#  'QN65Q8CAM',
#  'QN75Q75FM',
#  'QN82Q6FNA',
#  'QQ音乐2015',
#  'QV151E',
#  'R-N301',
#  'R-N303D',
#  'R-N402D',
#  'R-N500',
#  'R-N602',
#  'R-N803D',
#  'R1',
#  'R100',
#  'R2',
#  'R4',
#  'RCD-N7',
#  'RCD-N8',
#  'RD1363DAB',
#  'RELAX',
#  'RMERDIWO(H)15E ',
#  'RNDUDIW(B)15E',
#  'RNSVDI(B)(W)15E',
#  'RS212',
#  'RS214',
#  'RS217',
#  'RS2414+',
#  'RS2416+',
#  'RS2416RP+',
#  'RS2418+',
#  'RS2418RP+',
#  'RS3412xs',
#  'RS3617RPxs',
#  'RS3617xs',
#  'RS3618xs',
#  'RS411',
#  'RS812',
#  'RS812+',
#  'RS812RP+',
#  'RS814',
#  'RS814+',
#  'RS815',
#  'RS815+',
#  'RS815RP+',
#  'RS816',
#  'RS818+',
#  'RS818RP+',
#  'RT2600ac',
#  'RTR3260-B-US',
#  'RTR3260-US',
#  'RTR3261-CA',
#  'RTR4060-B-US',
#  'RTR5061-CA',
#  'RTRU5028-CA',
#  'RTRU5528-CA',
#  'RTRU6528-CA',
#  'RVi IP-camera, 1.3 MP, H.264, two way audio',
#  'RX-A1040',
#  'RX-A1050',
#  'RX-A1060',
#  'RX-A1070',
#  'RX-A2030',
#  'RX-A2040',
#  'RX-A2050',
#  'RX-A2060',
#  'RX-A2070',
#  'RX-A2080',
#  'RX-A3030',
#  'RX-A3050',
#  'RX-A3060',
#  'RX-A3070',
#  'RX-A3080',
#  'RX-A550',
#  'RX-A660',
#  'RX-A670',
#  'RX-A680',
#  'RX-A730',
#  'RX-A750',
#  'RX-A760',
#  'RX-A770',
#  'RX-A780',
#  'RX-A830',
#  'RX-A850',
#  'RX-A860',
#  'RX-A870',
#  'RX-A880',
#  'RX-AS710D',
#  'RX-D485',
#  'RX-S600',
#  'RX-S601',
#  'RX-S601D',
#  'RX-S602',
#  'RX-V1077',
#  'RX-V1079',
#  'RX-V1085',
#  'RX-V475',
#  'RX-V477',
#  'RX-V479',
#  'RX-V481',
#  'RX-V481D',
#  'RX-V483',
#  'RX-V485',
#  'RX-V500D',
#  'RX-V575',
#  'RX-V577',
#  'RX-V579',
#  'RX-V581',
#  'RX-V583',
#  'RX-V585',
#  'RX-V675',
#  'RX-V677',
#  'RX-V679',
#  'RX-V681',
#  'RX-V683',
#  'RX-V685',
#  'RX-V775',
#  'RX-V777',
#  'RX-V779',
#  'RX-V781',
#  'Ralink UPnP Media Server',
#  'Raumfeld Connector',
#  'Raumfeld One M',
#  'Raumfeld One S',
#  'Raumfeld Soundbar',
#  'Raumfeld Sounddeck',
#  'Raumfeld Stereo Cubes',
#  'Raumfeld Stereo L',
#  'Raumfeld Stereo M',
#  'ReadyNAS',
#  'Renderer',
#  'Revival_iStream_3',
#  'Revo',
#  'Roberts S1',
#  'Roberts S2',
#  'Roberts Stream 217',
#  'Roberts Stream 218',
#  'Roberts Stream 93i',
#  'Roberts Stream 94i',
#  'Rockchip Media Renderer',
#  'Roku 1',
#  'Roku 2',
#  'Roku 2 (UK)',
#  'Roku 2 HD',
#  'Roku 2 XD',
#  'Roku 2 XS',
#  'Roku 3',
#  'Roku 4',
#  'Roku Express',
#  'Roku Express+',
#  'Roku HD',
#  'Roku LT',
#  'Roku Premiere',
#  'Roku Premiere+',
#  'Roku SoundBridge M1001',
#  'Roku Stick',
#  'Roku Streaming Player 2000C',
#  'Roku Streaming Player 2050X',
#  'Roku Streaming Player N1100',
#  'Roku Streaming Player N1101',
#  'Roku Streaming Stick',
#  'Roku Streaming Stick+',
#  'Roku Ultra',
#  'RusSPb5-415',
#  'S300',
#  'SAMSUNG File Share',
#  'SAMSUNG_BW',
#  'SANGEAN WFR',
#  'SANGEAN WFR28',
#  'SANGEAN WFR28D',
#  'SANGEAN WFT',
#  'SAOPSH25',
#  'SBMP_JURIDIC',
#  'SBX-B70D',
#  'SC-91/CUXJ',
#  'SC-95/CUXJ',
#  'SC-97/CUXJ',
#  'SC-C70',
#  'SC-LX59/SYXJ8',
#  'SC-LX89/SYXJ8',
#  'SEC001599077715',
#  'SEC001599080D1F',
#  'SEC0015990820EA',
#  'SEC0015990D2457',
#  'SEC0015990DAEFA',
#  'SEC0015990DCC13',
#  'SEC0015990EBF4F',
#  'SEC0015991034FB',
#  'SEC001599106718',
#  'SEC001599108221',
#  'SEC00159910EFFA',
#  'SEC0015991E11B8',
#  'SEC0015991E5959',
#  'SEC0015992459E1',
#  'SEC001599272CE0',
#  'SEC0015993450BC',
#  'SEC0015993580C6',
#  'SEC00159935A6EE',
#  'SEC001599381D84',
#  'SEC00159942C5F8',
#  'SEC001599473389',
#  'SEC00159948AB7C',
#  'SEC00159948CC6E',
#  'SEC0015994931DF',
#  'SEC0015994A9C02',
#  'SEC001599622AC2',
#  'SEC001599636840',
#  'SEC001599655137',
#  'SEC00159965B4AF',
#  'SEC00159969F41F',
#  'SEC0015996B1C9C',
#  'SEC0015996D652C',
#  'SEC0015996F0169',
#  'SEC00159970DEB4',
#  'SEC00159973FE94',
#  'SEC00159974F5A0',
#  'SEC0015997513A0',
#  'SEC0015997597B6',
#  'SEC00159975CB32',
#  'SEC00159976C91E',
#  'SEC0015997DBD9B',
# ...
#  'UE40MU6400',
#  'UE40MU6405',
#  'UE40MU6452',
#  'UE40MU6479',
#  'UE40N5300',
#  'UE40NU7100',
#  'UE40NU7122',
#  'UE40NU7190',
#  'UE40NU7199',
#  'UE42F5300',
#  'UE42F5500',
#  'UE43J5500',
#  'UE43KU6000',
#  'UE43KU6079',
#  'UE43KU6402',
#  'UE43KU6500',
#  'UE43KU6670',
#  'UE43M5500',
#  'UE43M5520',
#  'UE43M5570',
#  'UE43M5572',
#  'UE43MU6100',
#  'UE43MU6102',
#  'UE43MU6105',
#  'UE43MU6172',
#  'UE43MU6179',
#  'UE43MU7000',
#  'UE43N5500',
#  'UE43NU7025',
#  'UE43NU7099',
#  'UE43NU7100',
#  'UE43NU7120',
#  'UE43NU7122',
#  'UE43NU7170',
#  'UE43NU7199',
#  'UE43NU7400',
#  'UE43NU7405',
#  'UE43NU7452',
#  'UE43NU7470',
#  'UE46D5700',
#  'UE46D6000',
#  'UE46D6500',
#  'UE46D7000',
#  'UE46D8000',
#  'UE46EH6030',
#  'UE46ES5500',
#  'UE46ES5700',
#  'UE46ES6100',
#  'UE46ES6300',
#  'UE46ES6560',
#  'UE46ES6800',
#  'UE46ES6890',
#  'UE46ES7000',
#  'UE46ES7090',
#  'UE46ES8090',
#  'UE46F5300',
#  'UE46F5500',
#  'UE46F6200',
#  'UE46F6320',
#  'UE46F6400',
#  'UE46F6500',
#  'UE46F6510',
#  'UE46F6600',
#  'UE46F6700',
#  'UE46F7000',
#  'UE46F8000',
#  'UE46H6203',
#  'UE46H7000',
#  'UE48H5103',
#  'UE48H5500',
#  'UE48H6200',
#  'UE48H6300',
#  'UE48H6400',
#  'UE48H6410',
#  'UE48H6500',
#  'UE48H6600',
#  'UE48H6800',
#  'UE48H6850',
#  'UE48H8000',
#  'UE48HU7500',
#  'UE48J5248',
#  'UE48J5500',
#  'UE48J5510',
#  'UE48J6200',
#  'UE48J6300',
#  'UE48JS8500',
#  'UE48JS9000',
#  'UE48JU6000',
#  'UE48JU6400',
#  'UE48JU6410',
#  'UE48JU6500',
#  'UE48JU6510',
#  'UE48JU6740',
#  'UE48JU7000',
#  'UE48JU7500',
#  'UE49J5278',
#  'UE49K5502',
#  'UE49K5510',
#  'UE49K5572',
#  'UE49K5579',
#  'UE49K5600',
#  'UE49K6300',
#  'UE49K6372',
#  'UE49KS7000',
#  'UE49KS7500',
#  'UE49KS7590',
#  'UE49KU6100',
#  'UE49KU6172',
#  'UE49KU6400',
#  'UE49KU6470',
#  'UE49KU6510',
#  'UE49KU6650',
#  'UE49KU6670',
#  'UE49M5500',
#  'UE49M5520',
#  'UE49MU6179',
#  'UE49MU6205',
#  'UE49MU6220',
#  'UE49MU6400',
#  'UE49MU6402',
#  'UE49MU6405',
#  'UE49MU6452',
#  'UE49MU6470',
#  'UE49MU6475',
#  'UE49MU6505',
#  'UE49NU7100',
#  'UE49NU7102',
#  'UE49NU7105',
#  'UE49NU7172',
#  'UE49NU7175',
#  'UE49NU7179',
#  'UE49NU7300',
#  'UE49NU7302',
#  'UE49NU7305',
#  'UE49NU7670',
#  'UE49NU8000',
#  'UE49NU8009',
#  'UE49NU8075',
#  'UE50ES6900',
#  'UE50H5500',
#  'UE50H6200',
#  'UE50H6400',
#  'UE50HU6900',
#  'UE50J5500',
#  'UE50J6240',
#  'UE50JU6400',
#  'UE50JU6900',
#  'UE50KU6000',
#  'UE50KU6070',
#  'UE50KU6072',
#  'UE50KU6079',
#  'UE50MU6102',
#  'UE50MU6120',
#  'UE50MU6125',
#  'UE50MU6179',
#  'UE50MU6192',
#  'UE50MU6409',
#  'UE50NU7025',
#  'UE50NU7092',
#  'UE50NU7099',
#  'UE50NU7440',
#  'UE50NU7472',
#  'UE55D6500',
#  'UE55D7000',
#  'UE55D8000',
#  'UE55ES6300',
#  'UE55ES6540',
#  'UE55ES7000',
#  'UE55ES7080',
#  'UE55ES8000',
#  'UE55ES8090',
#  'UE55F6320',
#  'UE55F6400',
#  'UE55F6500',
#  'UE55F6600',
#  'UE55F8000',
#  'UE55F9000',
#  'UE55H6200',
#  'UE55H6400',
#  'UE55H6410',
#  'UE55H6500',
#  'UE55H6600',
#  'UE55H6800',
#  'UE55H6850',
#  'UE55HU6900',
#  'UE55HU7100',
#  'UE55HU7200',
#  'UE55HU8500',
#  'UE55J6200',
#  'UE55J6240',
#  'UE55J6300',
#  'UE55JS9000',
#  'UE55JU6000',
#  'UE55JU6400',
#  'UE55JU6410',
#  'UE55JU6500',
#  'UE55JU6900',
#  'UE55JU7000',
#  'UE55JU7500',
#  'UE55K5500',
#  'UE55K5510',
#  'UE55K5579',
#  'UE55K5607',
#  'UE55K5679',
#  'UE55K6300',
#  'UE55K6372',
#  'UE55KS7000',
#  'UE55KS7500',
#  'UE55KS7590',
#  'UE55KS9090',
#  'UE55KU6000',
#  'UE55KU6070',
#  'UE55KU6075',
#  'UE55KU6079',
#  'UE55KU6099',
#  'UE55KU6100',
#  'UE55KU6172',
#  'UE55KU6400',
#  'UE55KU6459',
#  'UE55KU6470',
#  'UE55KU6650',
#  'UE55KU6670',
#  'UE55M6399',
#  'UE55MU6100',
#  'UE55MU6102',
#  'UE55MU6105',
#  'UE55MU6120',
#  'UE55MU6125',
#  'UE55MU6172',
#  'UE55MU6175',
#  'UE55MU6179',
#  'UE55MU6199',
#  'UE55MU6200',
#  'UE55MU6205',
#  'UE55MU6220',
#  'UE55MU6272',
#  'UE55MU6279',
#  'UE55MU6300',
#  'UE55MU6400',
#  'UE55MU6409',
#  'UE55MU6442',
#  'UE55MU6500',
#  'UE55MU6645',
#  'UE55MU6655',
#  'UE55MU7000',
#  'UE55MU7002',
#  'UE55MU7005',
#  'UE55MU7009',
#  'UE55MU7042',
#  'UE55MU7045',
#  'UE55MU7070',
#  'UE55NU6035',
#  'UE55NU7021',
#  'UE55NU7025',
#  'UE55NU7026',
#  'UE55NU7093',
#  'UE55NU7100',
#  'UE55NU7172',
#  'UE55NU7175',
#  'UE55NU7179',
#  'UE55NU7305',
#  'UE55NU7405',
#  'UE55NU7452',
#  'UE55NU7472',
#  'UE55NU7475',
#  'UE55NU7479',
#  'UE55NU8002',
#  'UE55NU8005',
#  'UE55NU8072',
#  'UE58J5200',
#  'UE58MU6125',
#  'UE58MU6199',
#  'UE60F6300',
#  'UE60H6200',
#  'UE60J6200',
#  'UE60JU6900',
#  'UE60KU6000',
#  'UE60KU6072',
#  'UE65HU8200',
#  'UE65HU8500',
#  'UE65J6240',
#  'UE65JS9500',
#  'UE65JU6000',
#  'UE65JU6500',
#  'UE65JU7000',
#  'UE65JU7500',
#  'UE65KU6000',
#  'UE65KU6179',
#  'UE65LS003',
#  'UE65MU6175',
#  'UE65MU6179',
#  'UE65MU6199',
#  'UE65MU6200',
#  'UE65MU6205',
#  'UE65MU7002',
#  'UE65MU7075',
#  'UE65MU7400',
#  'UE65MU8009',
#  'UE65MU9000',
#  'UE65NU7025',
#  'UE65NU7172',
#  'UE65NU7175',
#  'UE65NU8000',
#  'UE65NU8009',
#  'UE70KU6000',
#  'UE75H6400',
#  'UE75JU7000',
#  'UE75MU7005',
#  'UE75NU8005',
#  'UHD86',
#  'UHD87',
#  'UN00NU7100',
#  'UN24M4500',
#  'UN32D5500',
#  'UN32EH5300',
#  'UN32F4300',
#  'UN32F5500',
#  'UN32H4303',
#  'UN32H5203',
#  'UN32H5500',
#  'UN32H6350',
#  'UN32J4290',
#  'UN32J4303',
#  'UN32J4700',
#  'UN32J5303',
#  'UN32J5500',
#  'UN32M4500',
#  'UN32M5300',
#  'UN32N5300',
#  'UN40D5500',
#  'UN40D6050',
#  'UN40EH5300',
#  'UN40EH6030',
#  'UN40ES6100',
#  'UN40ES6500',
#  'UN40ES7000',
#  'UN40F5500',
#  'UN40F6300',
#  'UN40F6400',
#  'UN40FH5303',
#  'UN40FH6203',
#  'UN40H4203',
#  'UN40H5103',
#  'UN40H5203',
#  'UN40H5303',
#  'UN40H5500',
#  'UN40H6350',
#  'UN40H6400',
#  'UN40HU7000',
#  'UN40J5200',
#  'UN40J5290',
#  'UN40J5300',
#  'UN40J5500',
#  'UN40J6203',
#  'UN40J6400',
#  'UN40JU6100',
#  'UN40K5300',
#  'UN40K6500',
#  'UN40KU6000',
#  'UN40KU6300',
#  'UN40M5300',
#  'UN40M530D',
#  'UN40MU6100',
#  'UN40MU6290',
#  'UN40MU6300',
#  'UN40NU7100',
#  'UN43J5200',
#  'UN43J5290',
#  'UN43KU7500',
#  'UN43M5300',
#  'UN43MU6100',
#  'UN43MU6290',
#  'UN43MU6300',
#  'UN43MU630D',
#  'UN43NU6900',
#  'UN43NU6950',
#  'UN43NU7090',
#  'UN43NU7100',
#  'UN46D6000',
#  'UN46D6050',
#  'UN46D6300',
#  'UN46D6450',
#  'UN46D6900',
#  'UN46EH5300',
#  'UN46ES5300',
#  'UN46ES6100',
#  'UN46ES6150',
#  'UN46ES6500',
#  'UN46ES7000',
#  'UN46F5500',
#  'UN46F6300',
#  'UN46F6350',
#  'UN46F6400',
#  'UN46F6800',
#  'UN46F7500',
#  'UN46F8000',
#  'UN46FH5303',
#  'UN46FH6203',
#  'UN46H5203',
#  'UN46H5303',
#  'UN48H4203',
#  'UN48H5500',
#  'UN48H6400',
#  'UN48H6800',
#  'UN48J5200',
#  'UN48J5201',
#  'UN48J5300',
#  'UN48J5500',
#  'UN48J6200',
#  'UN48J6300',
#  'UN48J6400',
#  'UN48JU6100',
#  'UN48JU6400',
#  'UN48JU6700',
#  'UN49J5200',
#  'UN49J5290',
#  'UN49K5300',
#  'UN49K5500',
#  'UN49K6250',
#  'UN49K6500',
#  'UN49KS7000',
#  'UN49KS8000',
#  'UN49KU6300',
#  'UN49KU6400',
#  'UN49KU6450',
#  'UN49M5300',
#  'UN49MU6100',
#  'UN49MU6120',
#  'UN49MU6300',
#  'UN49MU6500',
#  'UN49MU7000',
#  'UN49MU8000',
#  'UN49NU7100',
#  'UN50EH5300',
#  'UN50ES6150',
#  'UN50ES6900',
#  'UN50F5500',
#  'UN50H5203',
#  'UN50H6400',
#  'UN50HU7000',
#  'UN50J5200',
#  'UN50J5300',
#  'UN50J5500',
#  'UN50JU6400',
#  'UN50JU650D',
#  'UN50KU6000',
#  'UN50KU630D',
#  'UN50M5300',
#  'UN50M530D',
#  'UN50MU6070',
#  'UN50MU6100',
#  'UN50MU6103',
#  'UN50MU6300',
#  'UN50MU630D',
#  'UN50NU6900',
#  'UN50NU7100',
#  'UN50NU7400',
#  'UN55D6000',
#  'UN55D6050',
#  'UN55D6420',
#  'UN55D7000',
#  'UN55D8000',
#  'UN55ES6820',
#  'UN55ES8000',
#  'UN55F6300',
#  'UN55F6350',
#  'UN55F6400',
#  'UN55F8000',
#  'UN55F9000',
#  'UN55FH6030',
#  'UN55FH6200',
#  'UN55H6103',
#  'UN55H6203',
#  'UN55H6300',
#  'UN55H6350',
#  'UN55H7100',
#  'UN55H8000',
#  'UN55HU6830',
#  'UN55HU7000',
#  'UN55HU7200',
#  'UN55HU7250',
#  'UN55HU9000',
#  'UN55J5300',
#  'UN55J5500',
#  'UN55J6200',
#  'UN55J6203',
#  'UN55JS6900',
#  'UN55JS700D',
#  'UN55JS8000',
#  'UN55JU6000',
#  'UN55JU6400',
#  'UN55JU6700',
#  'UN55JU670D',
#  'UN55K5300',
#  'UN55K6250',
#  'UN55K6500',
#  'UN55KS7500',
#  'UN55KS8000',
#  'UN55KS9500',
#  'UN55KU6000',
#  'UN55KU6290',
#  'UN55KU6300',
#  'UN55KU630D',
#  'UN55KU6400',
#  'UN55KU6500',
#  'UN55KU7000',
#  'UN55KU7500',
#  'UN55MU6100',
#  'UN55MU6103',
#  'UN55MU6290',
#  'UN55MU6300',
#  'UN55MU6303',
#  'UN55MU6400',
#  'UN55MU6490',
#  'UN55MU6500',
#  'UN55MU7000',
#  'UN55MU7500',
#  'UN55MU8000',
#  'UN55NU6900',
#  'UN55NU6950',
#  'UN55NU7100',
#  'UN55NU7300',
#  'UN55NU8000',
#  'UN55NU8500',
#  'UN58H5203',
#  'UN58J5190',
#  'UN58MU6070',
#  'UN58MU6100',
#  'UN58MU6120',
#  'UN58NU7100',
#  'UN60ES7100',
#  'UN60F6300',
#  'UN60F6400',
#  'UN60F7100',
#  'UN60H6103',
#  'UN60H6203',
#  'UN60H6300',
#  'UN60H6350',
#  'UN60H7100',
#  'UN60J6203',
#  'UN60JS6900',
#  'UN60JS700D',
#  'UN60JU6400',
#  'UN60KS8000',
#  'UN60KU6000',
#  'UN60KU6300',
#  'UN65F6350',
#  'UN65F6400',
#  'UN65F7100',
#  'UN65H6203',
#  'UN65H6350',
#  'UN65HU7200',
#  'UN65HU7250',
#  'UN65J6203',
#  'UN65JS8000',
#  'UN65JU6100',
#  'UN65JU6400',
#  'UN65JU6700',
#  'UN65JU7000',
#  'UN65KS8000',
#  'UN65KS800D',
#  'UN65KS8500',
#  'UN65KU6290',
#  'UN65KU6490',
#  'UN65KU6500',
#  'UN65KU650D',
#  'UN65KU7000',
#  'UN65KU7500',
#  'UN65LS03N',
#  'UN65MU6070',
#  'UN65MU6100',
#  'UN65MU6103',
#  'UN65MU6300',
#  'UN65MU630D',
#  'UN65MU6500',
#  'UN65MU7000',
#  'UN65MU8000',
#  'UN65MU800D',
#  'UN65MU850D',
#  'UN65NU6070',
#  'UN65NU6950',
#  'UN65NU7100',
#  'UN65NU710D',
#  'UN65NU8000',
#  'UN65NU800D',
#  'UN75JU7000',
#  'UN75MU6070',
#  'UN75MU6100',
#  'UN75MU9000',
#  'UN75NU7100',
#  'UN82MU8000',
#  'UNNOH6203',
#  'UPNP  ',
#  'UPNP 0E-40BF40WDR',
#  'UPNP 0E-40DF28WDR',
#  'UPNP 1.3MP-Mini Dome',
#  'UPNP A-14',
#  'UPNP A-15',
#  'UPNP A-28-F',
#  'UPNP A-34',
#  'UPNP A-34W',
#  'UPNP A-35',
#  'UPNP A-37-FW',
#  'UPNP A-38-F',
#  'UPNP A-47',
#  'UPNP A-54-OD',
#  'UPNP A-55',
#  'UPNP A-64',
#  'UPNP A-65',
#  'UPNP ALI-NS7012R',
#  'UPNP CBI-4030-2',
#  'UPNP CD-2230 DOME IP',
#  'UPNP CD-2230 IP',
#  'UPNP CHD-1030 IP',
#  'UPNP CHD-2030 Dome IP',
#  'UPNP CHD-2030 IP',
#  'UPNP CMIP7362W-28M',
#  'UPNP CVP-B2DB50-ODIW',
#  'UPNP D100-SW',
#  'UPNP D200-SP',
#  'UPNP D200-SW',
#  'UPNP DB1',
#  'UPNP DP-12CD1T42WD-I5',
#  'UPNP DP-12CD2T35FWD-I8',
#  'UPNP DS-2CD1621FWD-I',
#  'UPNP DS-2CD2020F-I',
#  'UPNP DS-2CD2420F-IW',
#  'UPNP DS-2CD2620F-I',
#  'UPNP DS-2CD2955FWD-IS',
#  'UPNP DS-2CV2Q21FD-IW',
#  'UPNP DS-I110',
#  'UPNP DS-I114',
#  'UPNP DS-I114W',
#  'UPNP DS-I126',
#  'UPNP DS-I200',
#  'UPNP DS-I203',
#  'UPNP DS-I214W',
#  'UPNP DS-I220',
#  'UPNP DS-I230',
#  'UPNP DS-KB6003-WIP',
#  'UPNP DX-2CD2020F-I',
#  'UPNP ENS3225-20R',
#  'UPNP EXIP-2620/BIR',
#  'UPNP FIC320',
#  'UPNP FIW320H',
#  'UPNP FIW321M',
#  'UPNP FNB-52CD1021',
#  'UPNP FU IP 2222A',
#  'UPNP FU IPC DMIR 3130-I',
#  'UPNP HDI-B101',
#  'UPNP HDI-D101',
#  'UPNP HDS-2010IRP3',
#  'UPNP HDS-2020IRP',
#  'UPNP HDS-2110IRP',
#  'UPNP HDS-2120IRP',
#  'UPNP HNC303-TD',
#  'UPNP HNC303-XD',
#  'UPNP HNC312-TD',
#  'UPNP HQ-MP2028BD-E-IR',
#  'UPNP HQ-MP2028GBD-IR',
#  'UPNP HYU-304',
#  'UPNP I21AE',
#  'UPNP I21AF',
#  'UPNP I61DQ',
#  'UPNP I61DR',
#  'UPNP IDH-21IR',
#  'UPNP IP-2CD2132-I',
#  'UPNP IP-NC312-XD-2.8',
#  'UPNP IPC-2MPVD28W',
#  'UPNP IPC-D140',
#  'UPNP IPC-SC-7001H',
#  'UPNP IWH-42IRL',
#  'UPNP LTK6128W-WIFI',
#  'UPNP LV-PB912F4C',
#  'UPNP LV-PB932F4',
#  'UPNP LV-PD51208C',
#  'UPNP LV-PDB1520F1',
#  'UPNP LV-PW65382',
#  'UPNP LV-PWR302',
#  'UPNP MVID-02IR-E',
#  'UPNP NAIP40D08VF-Z',
#  'UPNP NC29WP',
#  'UPNP NC303-VD',
#  'UPNP NC312-TD',
#  'UPNP NC49WP',
#  'UPNP NHD-850CAM',
#  'UPNP NHD-880CAM',
#  'UPNP NIT D4032-W28',
#  'UPNP NSC-DB1',
#  'UPNP NTH-IP3D',
#  'UPNP NTH-IP4D',
#  'UPNP NTH-IP4T',
#  'UPNP NV312F',
#  'UPNP NV4A25FWD-IZ',
#  'UPNP NV841F-SIR',
#  'UPNP RBOF4-1',
#  'UPNP RDOF3-1',
#  'UPNP RDOF4-1',
#  'UPNP RVi-IPC11SW',
#  'UPNP RVi-IPC11SW (2.8)',
#  'UPNP SC-304-XD',
#  'UPNP SEM-3411VR-EY2',
#  'UPNP SF-IPCV024W-4',
#  'UPNP SF-IPCV789ZW-2',
#  'UPNP SF-IPDM934-2W',
#  'UPNP TV-IP310PI',
#  'UPNP TV-IP311PI',
#  'UPNP TV-IP312PI',
#  'UPNP TV-IP314PI',
#  'UPNP TV-IP315PI',
#  'UPNP TV-IP320PI',
#  'UPNP TV-IP321PI',
#  'UPNP TV-IP322WI',
#  'UPNP TV-IP420P',
#  'UPNP TV-IP440PI',
#  'UPNP V-109HD',
#  'UPNP VB7675',
#  'UPNP WBXID206VRT',
#  'UPNP WND-2122-WI',
#  'UPNP WND-2312-I',
#  'UPNP WND-2342-WI',
#  'UPNP WND-2720-I',
#  'UPNP WNF-2955-I',
#  'UPNP WNO-2620-I',
#  'UPNP XB4MWX',
#  'UPNP XB5MDWX',
#  'UPNP XC-2032FI',
#  'UPNP XD2MDL',
#  'UPNP XD2MVWSD',
#  'UPNP XD2MWF',
#  'UTC settop box',
#  'UnitiLite',
#  'UnitiQute',
#  'Unknown',
#  'Unmonday',
#  'VA_3128@rockchip',
#  'VGA Network Compact Camera',
#  'VIP CB1M',
#  'VMS1100',
#  'VS-2004Pro',
#  'VS-2008Pro',
#  'VS-2104L',
#  'VS-2204 Pro+',
#  'VS-2212 Pro+',
#  'VS-4016Pro',
#  'VS-4108UPro+',
#  'VS-4116Pro+',
#  'VS-4116UPro+',
#  'VSX-1130/CUXESM',
#  'VSX-1130/SYXEV8',
#  'VSX-45/CUXE',
#  'VSX-830/CUXESM',
#  'VSX-830/SYXEV8',
#  'VSX-90/CUXE',
#  'VSX-930/SYXEV8',
#  'Verizon Media Server',
#  'VirtualRemoteControl',
#  'Vuze Media Server',
#  'W100',
#  'WCB-100Ae',
#  'WD ShareSpace',
#  'WDMyCloud',
#  'WDMyCloudDL2100',
#  'WDMyCloudEX2',
#  'WDMyCloudEX2100',
#  'WDMyCloudEX4',
#  'WDMyCloudEX4100',
#  'WDMyCloudMirror',
#  'WEBOS3',
#  'WFB-100Ap',
#  'WHD81',
#  'WHD93',
#  'WKR 9000',
#  'WNDR4300',
#  'WPS',
#  'WR-220W',
#  'WR100-D',
#  'WS-Printer',
#  'WSMCNH_ADMIN',
#  'WX-010',
#  'WX-021',
#  'WX-030',
#  'WX-051',
#  'WXA-50',
#  'WXAD-10',
#  'WXC-50',
#  'Wave SoundTouch',
#  'WaxRainPlayer',
#  'Wi-Fi Protected Setup Router',
#  'WiFi SCX-3400',
#  'Windows DIAL server',
#  'Windows Media Connect',
#  'Windows Media Connect Compatible (WiDMS)',
#  'Windows Media Connect compatible (MiniDLNA)',
#  'Windows Media Connect compatible (ReadyDLNA)',
#  'Windows Media Connect compatible (ReadyNAS)',
#  'Windows Media Player',
#  'Windows Media Player Sharing',
#  'Windows Server',
#  'Wired Network Camera',
#  'Wireless 2-Way Audio Surveillance Camera',
#  'Wireless Day/Night Surveillance Camera',
#  'Wireless N H.264 Surveillance Camera',
#  'Wireless N Network Camera',
#  'Wireless Network Camera',
#  'Wireless Pan/Tilt Day/Night IP Camera with Two-way\nAudio',
#  'Worldwide CD',
#  'XBMC Media Center',
#  'XBR-43X800D',
#  'XBR-43X800E',
#  'XBR-43X830C',
#  'XBR-49X700D',
#  'XBR-49X800D',
#  'XBR-49X800E',
#  'XBR-49X805E',
#  'XBR-49X807E',
#  'XBR-49X830C',
#  'XBR-49X900E',
#  'XBR-49X900F',
#  'XBR-55A8F',
#  'XBR-55X700D',
#  'XBR-55X705D',
#  'XBR-55X800E',
#  'XBR-55X805E',
#  'XBR-55X810C',
#  'XBR-55X850C',
#  'XBR-55X850D',
#  'XBR-55X855D',
#  'XBR-55X900C',
#  'XBR-55X900E',
#  'XBR-55X900F',
#  'XBR-55X905E',
#  'XBR-55X905F',
#  'XBR-65X805C',
#  'XBR-65X810C',
#  'XBR-65X850C',
#  'XBR-65X850D',
#  'XBR-65X850E',
#  'XBR-65X900E',
#  'XBR-65X900F',
#  'XBR-65X905E',
#  'XBR-65X905F',
#  'XBR-65X930D',
#  'XBR-65Z9D',
#  'XBR-75X850D',
#  'XBR-75X850E',
#  'XBR-75X850F',
#  'XBR-75X855D',
#  'XBR-75X900E',
#  'XBR-75X900F',
#  'XBR-75X905E',
#  'XBR-75X940C',
#  'XBR-85X850D',
#  'XDA-QS5400',
#  'XEROX_SEGURANCA',
#  'XRX0000AA97BCEB',
#  'XRX0000AA97F811',
#  'XRX0000AAB9DCC0',
#  'XRX0000AABC5A2C',
#  'XRX0000AABD7C63',
#  'XRX0000AABEDFD6',
#  'XRX0000AABF5788',
#  'XRX0000AAC07E03',
#  'XRX0000AAC95DB7',
#  'XRX0000AAC964B1',
#  'XRX0000AACD7033',
#  'XRX0000AACD88C1',
#  'XRX0000AACEE912',
#  'XRX0000AAD8E2CF',
#  'XRX0000AAD8EA0E',
#  'XRX0000AAD95507',
#  'XRX0000AADB9DDD',
#  'XRX0000AADBC750',
#  'XRX0000AADBC995',
#  'XRX0000AADBE2C5',
#  'XRX0000AADE327B',
#  'XRX0000AAF2A444',
#  'XRX3315-979',
#  'XRX9C934E08414C',
#  'XRX9C934E088031',
#  'XRX9C934E08AE4D',
#  'XRX9C934E08EB1E',
#  'XRX9C934E093F8B',
#  'XRX9C934E09B732',
#  'XRX9C934E09D4FD',
#  'XRX9C934E0A6D22',
#  'XRX9C934E17B655',
#  'XRX9C934E1801BB',
#  'XRX9C934E189A48',
#  'XRX9C934E212145',
#  'XRX9C934E21AAED',
#  'XRX9C934E228D76',
#  'XRX9C934E2341B3',
#  'XRX9C934E2A074E',
#  'XRX9C934E33DF7F',
#  'XRX9C934E380167',
#  'XRX9C934E3BF290',
#  'XRX9C934E3C417E',
#  'XRX9C934E3EC930',
#  'XRX9C934E3ECB93',
#  'XRX9C934E3EE4D8',
#  'XRX9C934E3FA905',
#  'XRX9C934E3FF59A',
#  'XRX9C934E4017F2',
#  'XRX9C934E402876',
#  'XRX9C934E42A96D',
#  'XRX9C934E44513D',
#  'XRX9C934E4494E7',
#  'XRX9C934E4547CD',
#  'XRX9C934E457DA2',
#  'XRX9C934E45A850',
#  'XRX9C934E45BC4B',
#  'XRX9C934E45C2C4',
#  'XRX9C934E45D02E',
#  'XRX9C934E45EC38',
#  'XRX9C934E464D12',
#  'XRX9C934E515EE4',
#  'XRX9C934E518DBF',
#  'XRX9C934E52FE2A',
#  'XRX9C934E5677AE',
#  'XRX9C934E56B39F',
#  'XRX9C934E61B386',
#  'XRX9C934E63255C',
#  'XRX9C934E63817F',
#  'XRX9C934E70CE74',
#  'XRX9C934E70F9E6',
#  'XRX9C934E73B9A7',
#  'XRX9C934E77F992',
#  'XRX9C934E78135E',
#  'XRX9C934E78910E',
#  'XRX9C934E78CA62',
#  'XRX9C934E78F4F5',
#  'XRX9C934E79212B',
#  'XRX9C934E79983F',
#  'XRX9C934E79C637',
#  'Xbox 360',
#  'Xbox One',
#  'Xerox_Photocopi',
#  'YAS-306',
#  'YAS-408',
#  'YMS-4080',
#  'YSP-1600',
#  'YSP-2700',
#  'YSP-5600',
#  'ZDDPBQAHB0020DB',
#  'ZX-1680',
#  'Zona Media Server',
#  'aastralink',
#  'contab',
#  'csaanxlas03',
#  'diaconos',
#  'eedomus',
#  'esc-gabprefeito',
#  'hello',
#  'iP110 series ',
#  'iP8700 series ',
#  'iRadio 310',
#  'iRadio 410',
#  'iStream 2',
#  'iTuner 320',
#  'imagio MP 3352',
#  'imagio MP C2800',
#  'imagio MP C3302',
#  'imagio MP C3500',
#  'imp-estacioname',
#  'interve',
#  'plena02',
#  'posto12_par',
#  'posto1_par',
#  'rascunho',
#  'reitoria-spdi',
#  'samsung8128',
#  'samtreinamento',
#  'sonoroSTREAM',
#  'soundmaster IR2023',
#  'soundmaster IR3200',
#  'supersound2',
#  'xerox3550',
#  'xerox3635',
#  'xseries']

# %%
def get_premodel(upnp):
    return upnp[0]['model_name'].split(' ')[0] if isinstance(upnp, list) and 'model_name' in upnp[0].keys() else "Unknown"

premodels = []
for _, row in pd.concat([df_train, df_test], axis=0, sort=False).iterrows():
    m = get_premodel(row['upnp'])
    if m not in premodels:
        premodels.append(m)
#     else:
#         premodels[m] += 1
premodels.sort()
print(len(premodels))
pprint.pprint(premodels)
# Out:
# 3524
# ['',
#  '\t',
#  '*AV7701',
#  '*AV7702',
#  '*AV7702mkII',
#  '*AV8802',
#  '*AVR-1613',
#  '*AVR-1713',
#  '*AVR-1913',
#  '*AVR-2113',
#  '*AVR-2313',
#  '*AVR-3313',
#  '*AVR-4520',
#  '*AVR-E300',
#  '*AVR-E400',
#  '*AVR-S700W',
#  '*AVR-S710W',
#  '*AVR-S720W',
#  '*AVR-S900W',
#  '*AVR-S910W',
#  '*AVR-S920W',
#  '*AVR-X1000',
#  '*AVR-X1100W',
#  '*AVR-X1200W',
#  '*AVR-X1300W',
#  '*AVR-X2000',
#  '*AVR-X2100W',
#  '*AVR-X2200W',
#  '*AVR-X2300W',
#  '*AVR-X3000',
#  '*AVR-X3100W',
#  '*AVR-X3200W',
#  '*AVR-X3300W',
#  '*AVR-X4000',
#  '*AVR-X4100W',
#  '*AVR-X4200W',
#  '*AVR-X5200W',
#  '*AVR-X6200W',
#  '*AVR-X7200W',
#  '*DNP-730',
#  '*DRA-N4',
#  '*M-CR510',
#  '*M-CR511',
#  '*M-CR610',
#  '*M-CR611',
#  '*MX122',
#  '*NA6005',
#  '*NA8005',
#  '*NR1504',
#  '*NR1506',
#  '*NR1603',
#  '*NR1604',
#  '*NR1605',
#  '*NR1606',
#  '*NR1607',
#  '*RCD-N9',
#  '*SR5007',
#  '*SR5009',
#  '*SR5010',
#  '*SR5011',
#  '*SR6007',
#  '*SR6008',
#  '*SR6009',
#  '*SR6010',
#  '*SR6011',
#  '*SR7007',
#  '*SR7009',
#  '*SR7010',
#  '-',
#  '-------',
#  '1.3',
#  '192.168.0.53',
#  '192.168.1.102',
#  '2-Way',
#  '2.4GHz',
#  '2015ALL2',
#  '2015ALL5CD',
#  '2015ALLxx',
#  '2015PMX100',
#  '2016ALLxx',
#  '2016RS75',
#  '2017HC1020',
#  '2017HC1040',
#  '2017PMX152',
#  '22SM3B-BD',
#  '25',
#  '28S305',
#  '2M',
#  '2Megapixel',
#  '32LK540BPTA',
#  '32LK540BPUA',
#  '32LK6100PLB',
#  '32LK610BPLB',
#  '32LK610BPSA',
#  '32LK615BPSB',
#  '32LK6200PLA',
#  '32S301',
#  '32S305',
#  '32S321',
#  '32S327',
#  '4070_FI',
#  '40S305',
#  '40S325',
#  '43LK5700PSC',
#  '43LK5730PVC',
#  '43LK5750PSA',
#  '43LK5760PTA',
#  '43LK5900PLA',
#  '43R80',
#  '43S305',
#  '43S403',
#  '43S405',
#  '43S421',
#  '43S425',
#  '43S515',
#  '43SM5KB-BD',
#  '43UK6090PUA',
#  '43UK6200PDA',
#  '43UK6200PLA',
#  '43UK6200PUA',
#  '43UK6250PUB',
#  '43UK6300BUB',
#  '43UK6300MLB',
#  '43UK6300PDB',
#  '43UK6300PLB',
#  '43UK6300PUE',
#  '43UK6310PSE',
#  '43UK6390PLG',
#  '43UK6400PLF',
#  '43UK6450PLC',
#  '43UK6470PLC',
#  '43UK6500MLA',
#  '43UK6500PLA',
#  '43UK6510PSF',
#  '43UK6540PTD',
#  '43UK6550PUB',
#  '43UK6750PLD',
#  '43UK6950PLB',
#  '4622-BureauJust',
#  '481-PTR31',
#  '49LK5400PLA',
#  '49LK5700PSC',
#  '49LK5700PUA',
#  '49LK5750PSA',
#  '49LK5900PLA',
#  '49S305',
#  '49S325',
#  '49S403',
#  '49S405',
#  '49S405-MX',
#  '49S425-CA',
#  '49SK8000PLB',
#  '49SK8100PLA',
#  '49SK8500PLA',
#  '49SM5C-BF',
#  '49UK6090PUA',
#  '49UK6200PDA',
#  '49UK6200PSA',
#  '49UK6300MLB',
#  '49UK6300PLB',
#  '49UK6300PSB',
#  '49UK6300PUE',
#  '49UK6310PSE',
#  '49UK6320PTE',
#  '49UK6400PLF',
#  '49UK7500PSA',
#  '49UK7500PUA',
#  '50PFL4662/F7',
#  '50R6+',
#  '50R6DM',
#  '50R7+',
#  '50S423',
#  '50UK6090PUA',
#  '50UK6300MLB',
#  '50UK6300PLB',
#  '50UK6300PSB',
#  '50UK6410PLC',
#  '50UK6470PLC',
#  '50UK6500AUA',
#  '50UK6500MLA',
#  '50UK6510PSF',
#  '50UK6520PSA',
#  '50UK6550PLD',
#  '50UK6950PLB',
#  '55P605',
#  '55R6+',
#  '55R6107',
#  '55R80',
#  '55S401',
#  '55S403',
#  '55S405',
#  '55S423',
#  '55S515',
#  '55S517',
#  '55SK8000PCA',
#  '55SK8000PUA',
#  '55SK8100PLA',
#  '55SK8500PLA',
#  '55UK6090PUA',
#  '55UK6200PDA',
#  '55UK6200PLA',
#  '55UK6200PSA',
#  '55UK6250PUB',
#  '55UK6300BUB',
#  '55UK6300MLB',
#  '55UK6300PLB',
#  '55UK6300PUE',
#  '55UK6300PVB',
#  '55UK6340PTF',
#  '55UK6350PSC',
#  '55UK6350PUC',
#  '55UK6360PSF',
#  '55UK6360PTE',
#  '55UK6400PLF',
#  '55UK6450PLC',
#  '55UK6470PLC',
#  '55UK6500AUA',
#  '55UK6500PLA',
#  '55UK6540PSB',
#  '55UK6550PLD',
#  '55UK6550PSB',
#  '55UK6750PLD',
#  '55UK6950PLB',
#  '55UK7550PLA',
#  '60R6+',
#  '60R70',
#  '60UK6090PUA',
#  '60UK6200PLA',
#  '65R6+',
#  '65R6107',
#  '65R615',
#  '65R617',
#  '65R80',
#  '65S4',
#  '65S401',
#  '65S403',
#  '65S405',
#  '65S423',
#  '65S425',
#  '65S513',
#  '65SK8500PLA',
#  '65SK9000PUA',
#  '65UK6300MLB',
#  '65UK6300PLB',
#  '65UK6300PUE',
#  '65UK6400PLF',
#  '65UK6470PLC',
#  '65UK6530PSF',
#  '65UK6540PSB',
#  '65UK6550PSB',
#  '65UK6950PLB',
#  '65UK7550MLA',
#  '65UK7550PLA',
#  '65UK7700AUB',
#  '65UK7700PUD',
#  '70UK6190PUB',
#  '70UK6570PUB',
#  '70UK6950PLA',
#  '75UK6200PLB',
#  '802.11g',
#  '9040',
#  'ACCUEIL2',
#  'AFTA',
#  'AFTB',
#  'AFTM',
#  'AFTMM',
#  'AFTN',
#  'AFTS',
#  'AFTT',
#  'ALA',
#  'AQUOS',
#  'ASUS',
#  'AUNA',
#  'AV',
#  'AVR-1912',
#  'AVR-2112',
#  'AVR-2312',
#  'AVR-3310',
#  'AVR-3311',
#  'AVR-3312',
#  'AVR-4310',
#  'AVR-4810',
#  'AVR-A100',
#  'AVR171,',
#  'AXIS',
#  'AXiS',
#  'Aficio',
#  'AirBeamTV',
#  'AirBurn',
#  'AirReceiver',
#  'AirScreen',
#  'Argon',
#  'AudioMaster',
#  'AutorizaçãoPA',
#  'B-Focus',
#  'B6210',
#  'B6220',
#  'B6320',
#  'B6520',
#  'B8220',
#  'B8520',
#  'B8520V2',
#  'BEL-UKR-ACN-XER',
#  'BIP-10Cube',
#  'BL3102',
#  'BRAVIA',
#  'Banco',
#  'BiglyBT',
#  'BlackArmor',
#  'BlackBerry',
#  'Blu-ray',
#  'Bose',
#  'BouygtelTV',
#  'Bridge',
#  'C2670',
#  'C3000-100NAS',
#  'C3700-100NAS',
#  'C460FW',
#  'C6250-100NAS',
#  'C7000-100NAS',
#  'C9130',
#  'CB-100Ae',
#  'CB-101Ap',
#  'CB-102Ap',
#  'CD-N301',
#  'CD-NT670D',
#  'CD6330',
#  'CENTRAL',
#  'CERTIFICACAO',
#  'CGV_DR25i',
#  'CHE-159',
#  'CLP27DN',
#  'CPSPRINTER07',
#  'CR-N765',
#  'CRAS',
#  'CRX-N470D',
#  'CX-A5100',
#  'Chromecast',
#  'Cinemate',
#  'Cocoon',
#  'Como',
#  'ComoAudio',
#  'Connect',
#  'Consorcio',
#  'Cosmopolit',
#  'CyberLink',
#  'Cyberlink',
#  'D-Link',
#  'D2',
#  'D4',
#  'D4211',
#  'D4320',
#  'D6210',
#  'D6320',
#  'D6330',
#  'DAB',
#  'DCS-1100',
#  'DCS-1130',
#  'DCS-1130L',
#  'DCS-2100',
#  'DCS-2102',
#  'DCS-2103',
#  'DCS-2121',
#  'DCS-2130',
#  'DCS-2132L',
#  'DCS-2132LB1',
#  'DCS-2132L_Rev_B',
#  'DCS-2136L',
#  'DCS-2210',
#  'DCS-2210L',
#  'DCS-2230',
#  'DCS-2230L',
#  'DCS-2310L',
#  'DCS-2330L',
#  'DCS-2332L',
#  'DCS-2530L',
#  'DCS-2630L',
#  'DCS-2670L',
#  'DCS-3110',
#  'DCS-3220',
#  'DCS-3411',
#  'DCS-3420',
#  'DCS-3430',
#  'DCS-3710B1',
#  'DCS-3715',
#  'DCS-4201',
#  'DCS-4602EV',
#  'DCS-4603',
#  'DCS-4622',
#  'DCS-4701E',
#  'DCS-4703E',
#  'DCS-4802E',
#  'DCS-5000L',
#  'DCS-5009L',
#  'DCS-5010L',
#  'DCS-5020L',
#  'DCS-5025L',
#  'DCS-5029L',
#  'DCS-5030L',
#  'DCS-5211L',
#  'DCS-5220B1',
#  'DCS-5222L',
#  'DCS-5222LB1',
#  'DCS-5222L_Rev_B',
#  'DCS-5230',
#  'DCS-6004L',
#  'DCS-6005L',
#  'DCS-6010L',
#  'DCS-6045L',
#  'DCS-6111',
#  'DCS-6511',
#  'DCS-6513',
#  'DCS-6517',
#  'DCS-6616',
#  'DCS-7000L',
#  'DCS-7010L',
#  'DCS-7110',
#  'DCS-7110B1',
#  'DCS-7513',
#  'DCS-800L',
#  'DCS-8100LH',
#  'DCS-8200LH',
#  'DCS-820L',
#  'DCS-825L',
#  'DCS-850L',
#  'DCS-855L',
#  'DCS-910',
#  'DCS-920',
#  'DCS-930',
#  'DCS-930L',
#  'DCS-930LB1',
#  'DCS-930L_Rev_B',
#  'DCS-931L',
#  'DCS-932L',
#  'DCS-932LB1',
#  'DCS-932L_Rev_B',
#  'DCS-933L',
#  'DCS-934L',
#  'DCS-935L',
#  'DCS-935LH',
#  'DCS-936L',
#  'DCS-942L',
#  'DCS-942LB1',
#  'DCS-942L_Rev_B',
#  'DCS-950',
#  'DCS-960L',
#  'DCX3200M',
#  'DCX3510M',
#  'DCX3600M',
#  'DDR-62',
#  'DDW36C',
#  'DEL0015991FBA99',
#  'DEL0015992CE16F',
#  'DEL00159944765C',
#  'DEL00159970187E',
#  'DEL0015997509C8',
#  'DEL0015997ED715',
#  'DEL001599880FB1',
#  'DEL0015998A6C68',
#  'DEL0015998B1FED',
#  'DEL0015999A6DDE',
#  'DEL001599A08772',
#  'DEL001599A78799',
#  'DEL001599EE9BED',
#  'DEL30CDA717A556',
#  'DEL30CDA71A2130',
#  'DEL30CDA71C40D3',
#  'DEL30CDA72377B0',
#  'DEL30CDA727A807',
#  'DEL30CDA7A1E9B0',
#  'DEL30CDA7B02BEA',
#  'DEL30CDA7EFA0A3',
#  'DEL30CDA7EFA468',
#  'DEL30CDA7F53AFE',
#  'DEL8425190D86DF',
#  'DEL8425192542FF',
#  'DIR3000',
#  'DIR3010',
#  'DIR3100',
#  'DIR3101MS',
#  'DIR3120LED',
#  'DIR3121M',
#  'DIR3500MCBT',
#  'DIR3505MSCBT',
#  'DIR3600MBT',
#  'DIRECAO',
#  'DIT2000',
#  'DIT2010',
#  'DIT2010MBT',
#  'DIT2100MSBT',
#  'DLNA',
#  'DM3102',
#  'DM3112',
#  'DM32D',
#  'DNP-720',
#  'DNP-F109',
#  'DNT',
#  'DRA-N5',
#  'DS-2CD7133-E',
#  'DS-2CD7153-E',
#  'DS-2CD793NFWD-EI',
#  'DS-2CD793PF-E',
#  'DS-2CD853F-E',
#  'DS-2CD863PF-E',
#  'DS-2CD864FWD-E',
#  'DS-2DF1-401H',
#  'DS-6016HGHI-F1',
#  'DS-7104HC-E1',
#  'DS-7104HDT-I',
#  'DS-7104HGHI-E1',
#  'DS-7104HGHI-F1',
#  'DS-7104HGHI-F1/N',
#  'DS-7104HGHI-SH',
#  'DS-7104HQHI-F1',
#  'DS-7104HQHI-F1/N',
#  'DS-7104HQHI-K1',
#  'DS-7104HWI-SH',
#  'DS-7104NI-E1/4P',
#  'DS-7104NI-SN',
#  'DS-7104NI-SN/P',
#  'DS-7108HGHI-E1',
#  'DS-7108HGHI-F1',
#  'DS-7108HGHI-F1/N',
#  'DS-7108HGHI-SH',
#  'DS-7108HQHI-F1',
#  'DS-7108HQHI-F1/N',
#  'DS-7108HQHI-K1',
#  'DS-7108HVI-SH',
#  'DS-7108HWI-SH',
#  'DS-7116HGHI-E1',
#  'DS-7116HGHI-F1',
#  'DS-7116HQHI-F1',
#  'DS-7116HQHI-F1/N',
#  'DS-7116HWI-SH',
#  'DS-7204HGHI-E1',
#  'DS-7204HGHI-E1/A',
#  'DS-7204HGHI-F1',
#  'DS-7204HGHI-SH',
#  'DS-7204HGHI-SH/A',
#  'DS-7204HGHI-SH/S',
#  'DS-7204HGHI-SHA',
#  'DS-7204HI-SL',
#  'DS-7204HQHI-F1/N',
#  'DS-7204HQHI-K1',
#  'DS-7204HQHI-SH',
#  'DS-7204HQHI-SH/A',
#  'DS-7204HUHI-F1/N',
#  'DS-7204HUHI-K1',
#  'DS-7204HVI-SV',
#  'DS-7208HGHI-E1',
#  'DS-7208HGHI-F1',
#  'DS-7208HGHI-F1/N',
#  'DS-7208HGHI-F2',
#  'DS-7208HGHI-SH',
#  'DS-7208HGHI-SH/A',
#  'DS-7208HGHI-SH/S',
#  'DS-7208HGHI-SHST',
#  'DS-7208HQHI-F1/N',
#  'DS-7208HQHI-F2/N/A',
#  'DS-7208HQHI-K1',
#  'DS-7208HQHI-K2/P',
#  'DS-7208HQHI-SH',
#  'DS-7208HUHI-F1/N',
#  'DS-7208HUHI-F2/N',
#  'DS-7208HUHI-F2/S',
#  'DS-7208HUHI-K2',
#  'DS-7208HVI-SV',
#  'DS-7208HWI-E1',
#  'DS-7208HWI-SL',
#  'DS-7216HGHI-E1',
#  'DS-7216HGHI-E2',
#  'DS-7216HGHI-F1',
#  'DS-7216HGHI-F1/N',
#  'DS-7216HGHI-F2',
#  'DS-7216HGHI-SH',
#  'DS-7216HGHI-SH/A',
#  'DS-7216HGHI-SH/S',
#  'DS-7216HGHI-SHSE',
#  'DS-7216HQHI-F1',
#  'DS-7216HQHI-F1/N',
#  'DS-7216HQHI-F2',
#  'DS-7216HQHI-F2/16',
#  'DS-7216HQHI-F2/N',
#  'DS-7216HQHI-F2/N/A',
#  'DS-7216HQHI-K1',
#  'DS-7216HQHI-K2',
#  'DS-7216HQHI-SH',
#  'DS-7216HQI-K2',
#  'DS-7216HUHI-F2/N',
#  'DS-7216HUHI-F2/S',
#  'DS-7216HUHI-K2',
#  'DS-7216HVI-SV',
#  'DS-7216HWI-E1',
#  'DS-7216HWI-E2/A',
#  'DS-7216HWI-SH',
#  'DS-7216HWI-SL',
#  'DS-7224HWI-E2',
#  'DS-7316HGHI-SH',
#  'DS-7316HQHI-SH',
#  'DS-7316HUHI-F4/N',
#  'DS-7324HGHI-SH',
#  'DS-7332HGHI-SH',
#  'DS-7332HQHI-K4',
#  'DS-7604HI-ST',
#  'DS-7604NI-E1/4P',
#  'DS-7604NI-E1/A',
#  'DS-7604NI-EV1/4P',
#  'DS-7604NI-K1/4P',
#  'DS-7608NI-E2/8P',
#  'DS-7608NI-E2/A',
#  'DS-7608NI-I2',
#  'DS-7608NI-I2/8P',
#  'DS-7608NI-K2',
#  'DS-7608NI-K2/8P',
#  'DS-7616HI-ST',
#  'DS-7616HUHI-F2/N',
#  'DS-7616NI-E1',
#  'DS-7616NI-E2',
#  'DS-7616NI-E2/16P',
#  'DS-7616NI-E2/8P',
#  'DS-7616NI-E2/A',
#  'DS-7616NI-I2/16P',
#  'DS-7616NI-K2/16P',
#  'DS-7632NI-E2/A',
#  'DS-7716NI-E4/16P',
#  'DS-7716NI-I4',
#  'DS-7716NI-I4/16P',
#  'DS-7716NI-SP',
#  'DS-7716NI-SP/16',
#  'DS-7716NI-ST',
#  'DS-7732NI-E4',
#  'DS-7732NI-E4/16P',
#  'DS-7732NI-I4/16P',
#  'DS-7732NI-K4',
#  'DS-7804N-K1/C',
#  'DS-7808HQH-F1/N',
#  'DS-7808N-E2',
#  'DS-7808NB-K1/C',
#  'DS-7816NB-K1/C',
#  'DS-7916HE-E4',
#  'DS-7932N-E4',
#  'DS-7932N-K4',
#  'DS-7A16HQHI-K1',
#  'DS-8116HFI-ST',
#  'DS-8632N-K8',
#  'DS-8832N-K8',
#  'DS-9016HQHI-SH',
#  'DS-9632NI-I8',
#  'DS-9632NI-ST',
#  'DS-9664NI-I8',
#  'DS-I114',
#  'DS1010+',
#  'DS1019+',
#  'DS107',
#  'DS107+',
#  'DS109',
#  'DS110j',
#  'DS111',
#  'DS112',
#  'DS112+',
#  'DS112j',
#  'DS115',
#  'DS115j',
#  'DS116',
#  'DS118',
#  'DS119j',
#  'DS1511+',
#  'DS1512+',
#  'DS1513+',
#  'DS1515',
#  'DS1515+',
#  'DS1517',
#  'DS1517+',
#  'DS1618+',
#  'DS1812+',
#  'DS1813+',
#  'DS1815+',
#  'DS1817',
#  'DS1817+',
#  'DS1819+',
#  'DS2015xs',
#  'DS209',
#  'DS209+',
#  'DS209+II',
#  'DS209j',
#  'DS210j',
#  'DS211',
#  'DS211+',
#  'DS211j',
#  'DS212',
#  'DS212+',
#  'DS212j',
#  'DS213',
#  'DS213+',
#  'DS213air',
#  'DS213j',
#  'DS214',
#  'DS214+',
#  'DS214play',
#  'DS214se',
#  'DS215+',
#  'DS215j',
#  'DS216',
#  'DS216+',
#  'DS216+II',
#  'DS216j',
#  'DS216play',
#  'DS216se',
#  'DS218',
#  'DS218+',
#  'DS218j',
#  'DS218play',
#  'DS2411+',
#  'DS2413+',
#  'DS2415+',
#  'DS3615xs',
#  'DS3617xs',
#  'DS409',
#  'DS410j',
#  'DS411',
#  'DS411+',
#  'DS411+II',
#  'DS411j',
#  'DS411slim',
#  'DS412+',
#  'DS413',
#  'DS413j',
#  'DS414',
#  'DS414j',
#  'DS414slim',
#  'DS415+',
#  'DS415play',
#  'DS416',
#  'DS416j',
#  'DS416play',
#  'DS416slim',
#  'DS418',
#  'DS418j',
#  'DS418play',
#  'DS509+',
#  'DS710+',
#  'DS712+',
#  'DS713+',
#  'DS715',
#  'DS716+',
#  'DS716+II',
#  'DS718+',
#  'DS916+',
#  'DS918+',
#  'DSC-6112',
#  'DSC-6113',
#  'DSC-6113B1',
#  'DTR-20.4',
#  'DTR-30.7',
#  'DTR-50.4',
#  'DTR-70.4',
#  'DTR5000',
#  'DVR',
#  'Day/Night',
#  'Dell',
#  'Denon',
#  'Deskjet',
#  'DigitRadio',
#  'DigitRadio580',
#  'DigitRadio600',
#  'Digital',
#  'DigitalMediaAdapterUPnP',
#  'Dimmer',
#  'DivX',
#  'E3100',
#  'E4SW5017RKU',
#  'E4SW5518RKU',
#  'ENVY',
#  'ES',
#  'EZVIZ',
#  'Eggy',
#  'Emby',
#  'Envy',
#  'Eureka',
#  'Evoke',
#  'EyeConnect',
#  'F1105',
#  'FB-100Ae',
#  'FD-100Ae',
#  'FD-130Ap',
#  'Fixed',
#  'FreeMi',
#  'Freebox',
#  'Freecom',
#  'Frontier',
#  'GE-030-CB',
#  'GQ55Q6FNG',
#  'GQ55Q8CNG',
#  'GQ55Q8DNG',
#  'GQ65Q6FNG',
#  'GQ65Q7FNG',
#  'GQ65Q8DNG',
#  'GQ65Q9FNG',
#  'Globe',
#  'Go-KS-Xerox3225',
#  'Google',
#  'GrundigDTR6000',
#  'H.264',
#  'H.264+Megapixel',
#  'HAP-S1',
#  'HAP-Z1ES',
#  'HEOS',
#  'HG32EA590',
#  'HG40ED690',
#  'HG55AE690',
#  'HIKVISION',
#  'HK',
#  'HS-251',
#  'HS-251+',
#  'HT-CT790',
#  'HT-CT800',
#  'HT-MT500/501',
#  'HT-NT3',
#  'HT-NT5',
#  'HT-R693',
#  'HT-RC660',
#  'HT-RT5',
#  'HT-ST5000',
#  'HT-ST9',
#  'HT-XT2',
#  'HT-XT3',
#  'HT-Z9F',
#  'HT-ZF9',
#  'HTR-4066',
#  'HTR-4067',
#  'HTR-4068',
#  'HTR-4069',
#  'HTR-4071',
#  'HUM',
#  'HW-H750',
#  'HW-J650',
#  'HW-J6500',
#  'HW-J6500R',
#  'HW-J7500',
#  'HW-J7500R',
#  'HW-J8500',
#  'HW-J8500R',
#  'HW-K650',
#  'HW-K850',
#  'HW-K950',
#  'HW-N950',
#  'Haier',
#  'Heritage',
#  'Hisense',
#  'Hisilicon',
#  'Hitachi',
#  'ICU100',
#  'IHD92',
#  'IKR1224WTD',
#  'IMAGEM',
#  'IMP-M-AMBIENTE',
#  'IMPRESSIA',
#  'IMPRESSORA',
#  'IMPSEGUROS',
#  'INSIGNIA',
#  'IP815',
#  'IPC1100',
#  'IPC1100P2',
#  'IPC4100',
#  'IPCA32500',
#  'IPCA62500',
#  'IPCA63500',
#  'IPCA66500',
#  'IPCA73500',
#  'IPCA76500',
#  'IPCB42500',
#  'IPCB42501',
#  'IPCB42550',
#  'IPCB42551',
#  'IPCB62510B',
#  'IPCB72501',
#  'IPCS82520',
#  'IPSiO',
#  'IR',
#  'IR110',
#  'IR120MS',
#  'IR320',
#  'IR350',
#  'IR3A',
#  'IR4400',
#  'IR6',
#  'IR8S',
#  'IRD30',
#  'IWR',
#  'IWR271',
#  'IWR282',
#  'Imp_BKP_RUE2',
#  'Imp_U.T.I',
#  'Insight',
#  'Insignia',
#  'Intel',
#  'Interlogix',
#  'Internet',
#  'JBL',
#  'JOJO',
#  'Jupiter',
#  'K2',
#  'KD-43X7500E',
#  'KD-43X8000E',
#  'KD-43X8305C',
#  'KD-43X8309C',
#  'KD-43XD8099',
#  'KD-43XD8305',
#  'KD-43XE8004',
#  'KD-43XE8005',
#  'KD-43XE8077',
#  'KD-43XE8096',
#  'KD-43XE8396',
#  'KD-43XF7596',
#  'KD-43XF8096',
#  'KD-43XF8505',
#  'KD-49X7000D',
#  'KD-49X7005D',
#  'KD-49X7500F',
#  'KD-49X8000D',
#  'KD-49X8000E',
#  'KD-49X8300C',
#  'KD-49X8305C',
#  'KD-49X8307C',
#  'KD-49X8308C',
#  'KD-49X8309C',
#  'KD-49X8505B',
#  'KD-49X9000E',
#  'KD-49XD7005',
#  'KD-49XD8005',
#  'KD-49XD8077',
#  'KD-49XD8099',
#  'KD-49XD8305',
#  'KD-49XE8004',
#  'KD-49XE8005',
#  'KD-49XE8077',
#  'KD-49XE8096',
#  'KD-49XE8396',
#  'KD-49XE9005',
#  'KD-49XF7596',
#  'KD-49XF8096',
#  'KD-49XF8505',
#  'KD-49XF8596',
#  'KD-49XF8599',
#  'KD-49XF9005',
#  'KD-55A1',
#  'KD-55AF8',
#  'KD-55S8005C',
#  'KD-55X7000D',
#  'KD-55X7005D',
#  'KD-55X757F',
#  'KD-55X8000E',
#  'KD-55X8005C',
#  'KD-55X8500C',
#  'KD-55X8500D',
#  'KD-55X8500E',
#  'KD-55X8500F',
#  'KD-55X8501C',
#  'KD-55X8505B',
#  'KD-55X8505C',
#  'KD-55X8507C',
#  'KD-55X8508C',
#  'KD-55X8509C',
#  'KD-55X9005A',
#  'KD-55X9005C',
#  'KD-55X9300D',
#  'KD-55XD7005',
#  'KD-55XD8005',
#  'KD-55XD8505',
#  'KD-55XD8577',
#  'KD-55XD8599',
#  'KD-55XD9305',
#  'KD-55XE8096',
#  'KD-55XE8505',
#  'KD-55XE8577',
#  'KD-55XE8588',
#  'KD-55XE8596',
#  'KD-55XE9005',
#  'KD-55XE9305',
#  'KD-55XF7596',
#  'KD-55XF8096',
#  'KD-55XF8505',
#  'KD-55XF8596',
#  'KD-55XF9005',
#  'KD-60XF8305',
#  'KD-65A1',
#  'KD-65AF8',
#  'KD-65S8505C',
#  'KD-65S9005B',
#  'KD-65X7505D',
#  'KD-65X755F',
#  'KD-65X8500E',
#  'KD-65X8505A',
#  'KD-65X8505B',
#  'KD-65X8505C',
#  'KD-65X9005B',
#  'KD-65XD7505',
#  'KD-65XD9305',
#  'KD-65XE8505',
#  'KD-65XE8588',
#  'KD-65XE8596',
#  'KD-65XE9005',
#  'KD-65XF8505',
#  'KD-65XF8599',
#  'KD-65XF9005',
#  'KD-75X9400E',
#  'KD-75XD8505',
#  'KD-85X8500F',
#  'KDL-22E5300',
#  'KDL-22EX320',
#  'KDL-22EX420',
#  'KDL-22EX555',
#  'KDL-24W600A',
#  'KDL-24W605A',
#  'KDL-26EX320',
#  'KDL-26EX550',
#  'KDL-26EX553',
#  'KDL-26J1',
#  'KDL-32CX400',
#  'KDL-32EX300/B',
#  'KDL-32EX500',
#  'KDL-32EX521',
#  'KDL-32EX525',
#  'KDL-32EX555',
#  'KDL-32EX557',
#  'KDL-32EX650',
#  'KDL-32EX655',
#  'KDL-32EX700',
#  'KDL-32EX720',
#  'KDL-32EX721',
#  'KDL-32EX728',
#  'KDL-32HX750',
#  'KDL-32HX755',
#  'KDL-32NX655',
#  'KDL-32W500A',
#  'KDL-32W503A',
#  'KDL-32W600A',
#  'KDL-32W605A',
#  'KDL-32W607A',
#  'KDL-32W650A',
#  'KDL-32W653A',
#  'KDL-32W654A',
#  'KDL-32W655A',
#  'KDL-32W670A',
#  'KDL-32W700B',
#  'KDL-32W705B',
#  'KDL-32W705C',
#  'KDL-32W706B',
#  'KDL-37EX723',
#  'KDL-37EX725',
#  'KDL-40CX520',
#  'KDL-40CX523',
#  'KDL-40EX500',
#  'KDL-40EX521',
#  'KDL-40EX525',
#  'KDL-40EX600',
#  'KDL-40EX650',
#  'KDL-40EX653',
#  'KDL-40EX655',
#  'KDL-40EX710',
#  'KDL-40EX720',
#  'KDL-40EX721',
#  'KDL-40EX725',
#  'KDL-40EX727',
#  'KDL-40EX728',
#  'KDL-40EX729',
#  'KDL-40HX720',
#  'KDL-40HX750',
#  'KDL-40HX753',
#  'KDL-40HX755',
#  'KDL-40HX756',
#  'KDL-40HX800',
#  'KDL-40LX900',
#  'KDL-40NX700',
#  'KDL-40NX711',
#  'KDL-40NX713',
#  'KDL-40NX715',
#  'KDL-40NX720',
#  'KDL-40NX725',
#  'KDL-40V5',
#  'KDL-40W5500',
#  'KDL-40W580B',
#  'KDL-40W600B',
#  'KDL-40W605B',
#  'KDL-40W607B',
#  'KDL-40W700C',
#  'KDL-40W705C',
#  'KDL-40W905A',
#  'KDL-40Z5800',
#  'KDL-42W650A',
#  'KDL-42W653A',
#  'KDL-42W654A',
#  'KDL-42W655A',
#  'KDL-42W656A',
#  'KDL-42W657A',
#  'KDL-42W674A',
#  'KDL-42W700B',
#  'KDL-42W705B',
#  'KDL-42W706B',
#  'KDL-42W800B',
#  'KDL-42W805A',
#  'KDL-42W805B',
#  'KDL-42W807A',
#  'KDL-42W808A',
#  'KDL-42W815B',
#  'KDL-42W817B',
#  'KDL-42W828B',
#  'KDL-42W829B',
#  'KDL-43W755C',
#  'KDL-43W756C',
#  'KDL-43W780C',
#  'KDL-43W800C',
#  'KDL-43W800D',
#  'KDL-43W800F',
#  'KDL-43W805C',
#  'KDL-43W807C',
#  'KDL-43W808C',
#  'KDL-43W809C',
#  'KDL-43W950D',
#  'KDL-46EX500',
#  'KDL-46EX521',
#  'KDL-46EX523',
#  'KDL-46EX620',
#  'KDL-46EX621',
#  'KDL-46EX650',
#  'KDL-46EX653',
#  'KDL-46EX655',
#  'KDL-46EX720',
#  'KDL-46EX721',
#  'KDL-46EX723',
#  'KDL-46EX724',
#  'KDL-46EX728',
#  'KDL-46EX729',
#  'KDL-46HX720',
#  'KDL-46HX729',
#  'KDL-46HX750',
#  'KDL-46HX755',
#  'KDL-46HX758',
#  'KDL-46HX75G',
#  'KDL-46HX800',
#  'KDL-46HX850',
#  'KDL-46HX853',
#  'KDL-46HX855',
#  'KDL-46HX857',
#  'KDL-46HX920',
#  'KDL-46LX900',
#  'KDL-46NX700',
#  'KDL-46NX715',
#  'KDL-46NX720',
#  'KDL-46NX725',
#  'KDL-46NX800',
#  'KDL-46V5',
#  'KDL-46W904A',
#  'KDL-46W905A',
#  'KDL-46W950A',
#  'KDL-46W955A',
#  'KDL-47W800A',
#  'KDL-47W805A',
#  'KDL-47W807A',
#  'KDL-48W580B',
#  'KDL-48W585B',
#  'KDL-48W600B',
#  'KDL-48W605B',
#  'KDL-48W609B',
#  'KDL-48W700C',
#  'KDL-48W705C',
#  'KDL-49W800F',
#  'KDL-50FA97C',
#  'KDL-50W650A',
#  'KDL-50W655A',
#  'KDL-50W656A',
#  'KDL-50W685A',
#  'KDL-50W700A',
#  'KDL-50W700B',
#  'KDL-50W704A',
#  'KDL-50W705B',
#  'KDL-50W706B',
#  'KDL-50W755C',
#  'KDL-50W756C',
#  'KDL-50W790B',
#  'KDL-50W800B',
#  'KDL-50W800C',
#  'KDL-50W805B',
#  'KDL-50W805C',
#  'KDL-50W807B',
#  'KDL-50W807C',
#  'KDL-50W808C',
#  'KDL-50W809C',
#  'KDL-50W815B',
#  'KDL-50W828B',
#  'KDL-50W829B',
#  'KDL-50W900B',
#  'KDL-52LX905',
#  'KDL-52W5500',
#  'KDL-55EX505',
#  'KDL-55EX710',
#  'KDL-55EX720',
#  'KDL-55EX723',
#  'KDL-55EX725',
#  'KDL-55HX729',
#  'KDL-55HX750',
#  'KDL-55HX755',
#  'KDL-55HX820',
#  'KDL-55HX850',
#  'KDL-55HX853',
#  'KDL-55HX920',
#  'KDL-55NX720',
#  'KDL-55NX725',
#  'KDL-55NX810',
#  'KDL-55W700B',
#  'KDL-55W755C',
#  'KDL-55W756C',
#  'KDL-55W790B',
#  'KDL-55W800B',
#  'KDL-55W800C',
#  'KDL-55W802A',
#  'KDL-55W805A',
#  'KDL-55W805B',
#  'KDL-55W805C',
#  'KDL-55W807A',
#  'KDL-55W808A',
#  'KDL-55W808C',
#  'KDL-55W809C',
#  'KDL-55W815B',
#  'KDL-55W817B',
#  'KDL-55W828B',
#  'KDL-55W829B',
#  'KDL-55W900A',
#  'KDL-55W905A',
#  'KDL-55W920A',
#  'KDL-55W950B',
#  'KDL-55W955A',
#  'KDL-55W955B',
#  'KDL-60EX700',
#  'KDL-60EX725',
#  'KDL-60NX720',
#  'KDL-60W605B',
#  'KDL-60W610B',
#  'KDL-60W630B',
#  'KDL-60W850B',
#  'KDL-60W855B',
#  'KDL-65S990A',
#  'KDL-65W850A',
#  'KDL-65W850C',
#  'KDL-65W855A',
#  'KDL-65W855C',
#  'KDL-65W859C',
#  'KDL-65W955B',
#  'KDL-70W850B',
#  'KDL-75W850C',
#  'KDL-75W855C',
#  'KR-200',
#  'Kamera-Stodl-720p',
#  'Kamera2',
#  'Kies',
#  'Kodi',
#  'Kugou',
#  'Kwesé',
#  'LASER',
#  'LC-24LB601U',
#  'LC-32LB601C',
#  'LC-32LB601U',
#  'LC-40LB601U',
#  'LC-43LB601U',
#  'LC-43LBU591C',
#  'LC-43LBU591U',
#  'LC-50LB601C',
#  'LC-50LB601U',
#  'LC-50LBU591C',
#  'LC-50LBU591U',
#  'LC-55LBU591C',
#  'LC-55LBU591U',
#  'LC-58Q73+',
#  'LC-60R6003U',
#  'LC-65LBU591U',
#  'LC-65Q73+',
#  'LCAD03FLN',
#  'LCAD03VLNOD',
#  'LD',
#  'LE40D550',
#  'LG',
#  'LG-Ericsson',
#  'LGE',
#  'LGPC',
#  'LH40RMDT',
#  'LISA',
#  'LN40D550',
#  'LT27D390S',
#  'LT32E390S',
#  'LV24F39S',
#  'LaCie',
#  'Lab233',
#  'Laboratory_prin',
#  'Lebo',
#  'Legrand',
#  'Lenco',
#  'Lifestyle',
#  'LightSwitch',
#  'LnvCon1.0',
#  'Logitech',
#  'Loxone',
#  'M4070',
#  'MA02IMP_GMCBC01',
#  'MEDION',
#  'MEISTERSTUECK',
#  'MELPRINTER',
#  'MG2900',
#  'MG3000',
#  'MG3600',
#  'MG5400',
#  'MG5600',
#  'MG5700',
#  'MG6300',
#  'MG6400',
#  'MG6500',
#  'MG6600',
#  'MG6700',
#  'MG6800',
#  'MG6900',
#  'MG7100',
#  'MG7500',
#  'MG7700',
#  'MHC-V77DW',
#  'MHC-V77W',
#  'MHC-V90DW',
#  'ML2675_Emelet',
#  'MP',
#  'MP5',
#  'MSBOX',
#  'MUNET',
#  'MX520',
#  'MX720',
#  'MX920',
#  'Magnat_40',
#  'Maker',
#  'Marantz',
#  'Media',
#  'MediaMonkey',
#  'MediaRenderer',
#  'Medion',
#  'Menuett',
#  'MiniHD',
#  'Minx',
#  'Mu-so',
#  'My',
#  'MyBookLive',
#  'MyBookLiveDuo',
#  'MyCloud',
#  'MyCloudEX2Ultra',
#  'MyCloudPR2100',
#  'N2310',
#  'N2350',
#  'N2810',
#  'N3200PRO',
#  'N3LBRCM01-PRT',
#  'N4310',
#  'N4350',
#  'N4560',
#  'N5810PRO',
#  'N600DB',
#  'N7710',
#  'NAC-N',
#  'NAS326',
#  'NAS520',
#  'NAS540',
#  'NASBOX2',
#  'NBC30-IR',
#  'ND5XS',
#  'NDS',
#  'NE-3241-T20',
#  'NE-6146-R10',
#  'NE-6146T11',
#  'NFC30',
#  'NFC30-IR',
#  'NFC30-IRWG',
#  'NFC31',
#  'NFLC',
#  'NMR',
#  'NOVA',
#  'NOXON',
#  'NP',
#  'NP-S303',
#  'NP30',
#  'NS-24DR220CA18',
#  'NS-24DR220NA18',
#  'NS-32DR310CA17',
#  'NS-32DR310NA17',
#  'NS-39DR510NA17',
#  'NS-43DR620NA18',
#  'NS-50DR620NA18',
#  'NS-55DR620NA18',
#  'NSC15-WG',
#  'NSC16-WG',
#  'NUMAN',
#  'NVR216',
#  'NWB6210F',
#  'NaimUniti',
#  'Nero',
#  'NetCam',
#  'NetCamHDv1',
#  'NetCamHDv2',
#  'NetOne',
#  'Network',
#  'Netzwerkdrucker',
#  'None',
#  'Now',
#  'NuVo',
#  'Numericable',
#  'OBRAS',
#  'OLED55B8PLA',
#  'OLED55B8PUA',
#  'OLED55B8SLC',
#  'OLED55B8SSC',
#  'OLED55C8GNA',
#  'OLED55C8LLA',
#  'OLED55C8PLA',
#  'OLED55C8PUA',
#  'OLED55E8LLA',
#  'OLED55E8PUA',
#  'OLED65B8PLA',
#  'OLED65B8YVA',
#  'OLED65C8PUA',
#  'OLED65E8PLA',
#  'OLED65G8PLA',
#  'OM46D',
#  'Onkyo',
#  'P6210',
#  'P8220',
#  'PATRIM-542748RE',
#  'PC',
#  'PCT-1331-P01',
#  'PDR260-B',
#  'PDR360BT-B',
#  'PHASER3250',
#  'PLAYLINK',
#  'PMS',
#  'PN51D8000',
#  'PRESTIGE',
#  'PRT-CONTAB',
#  'PS51D550',
#  'PTEC',
#  'Pan/Tilt',
#  'Panasonic',
#  'Personal',
#  'Phantom',
#  'Philips',
#  'Phorus-Renderer',
#  'Photosmart',
#  'PiXiS',
#  'Pilatus',
#  'Pinell',
#  'Plex',
#  'Point',
#  'Primo',
#  'Print-Colatina',
#  'Printer',
#  'Pro',
#  'Q700',
#  'Q800',
#  'Q802',
#  'QA55Q7CAM',
#  'QE49Q6FNA',
#  'QE49Q7FAM',
#  'QE55Q6FNA',
#  'QE55Q7FAM',
#  'QE55Q7FNA',
#  'QE55Q8FNA',
#  'QE65Q6FNA',
#  'QE65Q7FAM',
#  'QE65Q7FGM',
#  'QE65Q8FAM',
#  'QE65Q8FNA',
#  'QE705',
#  'QE707',
#  'QE75Q7FAM',
#  'QM152E',
#  'QM163E',
#  'QM164E',
#  'QN49Q6FNA',
#  'QN55Q6FAM',
#  'QN55Q6FNA',
#  'QN55Q7CAM',
#  'QN55Q7FAM',
#  'QN65Q6FNA',
#  'QN65Q7CDM',
#  'QN65Q7FNA',
#  'QN65Q8CAM',
#  'QN75Q75FM',
#  'QN82Q6FNA',
#  'QQ音乐2015',
#  'QV151E',
#  'R-N301',
#  'R-N303D',
#  'R-N402D',
#  'R-N500',
#  'R-N602',
#  'R-N803D',
#  'R1',
#  'R100',
#  'R2',
#  'R4',
#  'RCD-N7',
#  'RCD-N8',
#  'RD1363DAB',
#  'RELAX',
#  'RMERDIWO(H)15E',
#  'RNDUDIW(B)15E',
#  'RNSVDI(B)(W)15E',
#  'RS212',
#  'RS214',
#  'RS217',
#  'RS2414+',
#  'RS2416+',
#  'RS2416RP+',
#  'RS2418+',
#  'RS2418RP+',
#  'RS3412xs',
#  'RS3617RPxs',
#  'RS3617xs',
#  'RS3618xs',
#  'RS411',
#  'RS812',
#  'RS812+',
#  'RS812RP+',
#  'RS814',
#  'RS814+',
#  'RS815',
#  'RS815+',
#  'RS815RP+',
#  'RS816',
#  'RS818+',
#  'RS818RP+',
#  'RT2600ac',
#  'RTR3260-B-US',
#  'RTR3260-US',
#  'RTR3261-CA',
#  'RTR4060-B-US',
#  'RTR5061-CA',
#  'RTRU5028-CA',
#  'RTRU5528-CA',
#  'RTRU6528-CA',
#  'RVi',
#  'RX-A1040',
#  'RX-A1050',
#  'RX-A1060',
#  'RX-A1070',
#  'RX-A2030',
#  'RX-A2040',
#  'RX-A2050',
#  'RX-A2060',
#  'RX-A2070',
#  'RX-A2080',
#  'RX-A3030',
#  'RX-A3050',
#  'RX-A3060',
#  'RX-A3070',
#  'RX-A3080',
#  'RX-A550',
#  'RX-A660',
#  'RX-A670',
#  'RX-A680',
#  'RX-A730',
#  'RX-A750',
#  'RX-A760',
#  'RX-A770',
#  'RX-A780',
#  'RX-A830',
#  'RX-A850',
#  'RX-A860',
#  'RX-A870',
#  'RX-A880',
#  'RX-AS710D',
#  'RX-D485',
#  'RX-S600',
#  'RX-S601',
#  'RX-S601D',
#  'RX-S602',
#  'RX-V1077',
#  'RX-V1079',
#  'RX-V1085',
#  'RX-V475',
#  'RX-V477',
#  'RX-V479',
#  'RX-V481',
#  'RX-V481D',
#  'RX-V483',
#  'RX-V485',
#  'RX-V500D',
#  'RX-V575',
#  'RX-V577',
#  'RX-V579',
#  'RX-V581',
#  'RX-V583',
#  'RX-V585',
#  'RX-V675',
#  'RX-V677',
#  'RX-V679',
#  'RX-V681',
#  'RX-V683',
#  'RX-V685',
#  'RX-V775',
#  'RX-V777',
#  'RX-V779',
#  'RX-V781',
#  'Ralink',
#  'Raumfeld',
#  'ReadyNAS',
#  'Renderer',
#  'Revival_iStream_3',
#  'Revo',
#  'Roberts',
#  'Rockchip',
#  'Roku',
#  'RusSPb5-415',
#  'S300',
#  'SAMSUNG',
#  'SAMSUNG_BW',
#  'SANGEAN',
#  'SAOPSH25',
#  'SBMP_JURIDIC',
#  'SBX-B70D',
#  'SC-91/CUXJ',
#  'SC-95/CUXJ',
#  'SC-97/CUXJ',
#  'SC-C70',
#  'SC-LX59/SYXJ8',
#  'SC-LX89/SYXJ8',
#  'SEC001599077715',
#  'SEC001599080D1F',
#  'SEC0015990820EA',
#  'SEC0015990D2457',
#  'SEC0015990DAEFA',
#  'SEC0015990DCC13',
#  'SEC0015990EBF4F',
#  'SEC0015991034FB',
#  'SEC001599106718',
#  'SEC001599108221',
#  'SEC00159910EFFA',
#  'SEC0015991E11B8',
#  'SEC0015991E5959',
#  'SEC0015992459E1',
#  'SEC001599272CE0',
#  'SEC0015993450BC',
#  'SEC0015993580C6',
#  'SEC00159935A6EE',
#  'SEC001599381D84',
#  'SEC00159942C5F8',
#  'SEC001599473389',
#  'SEC00159948AB7C',
#  'SEC00159948CC6E',
#  'SEC0015994931DF',
#  'SEC0015994A9C02',
#  'SEC001599622AC2',
#  'SEC001599636840',
#  'SEC001599655137',
#  'SEC00159965B4AF',
#  'SEC00159969F41F',
#  'SEC0015996B1C9C',
#  'SEC0015996D652C',
#  'SEC0015996F0169',
#  'SEC00159970DEB4',
#  'SEC00159973FE94',
#  'SEC00159974F5A0',
#  'SEC0015997513A0',
#  'SEC0015997597B6',
#  'SEC00159975CB32',
#  'SEC00159976C91E',
#  'SEC0015997DBD9B',
#  'SEC0015997E0C9C',
#  'SEC0015997FC497',
#  'SEC001599808CDD',
#  'SEC00159981F8F4',
#  'SEC0015998229C5',
#  'SEC00159982F399',
#  'SEC0015998465EC',
#  'SEC00159987407E',
#  'SEC00159987C695',
#  'SEC0015998949E9',
#  'SEC0015998A0E35',
#  'SEC0015998A82DC',
#  'SEC0015998AABCB',
#  'SEC0015998AAC1B',
#  'SEC0015998ACB00',
#  'SEC0015998FB9E0',
#  'SEC001599913A0A',
#  'SEC001599937528',
#  'SEC00159994C8DE',
#  'SEC001599951966',
#  'SEC00159995B20F',
#  'SEC0015999793FA',
#  'SEC001599980897',
#  'SEC001599989CFD',
#  'SEC001599989D44',
#  'SEC00159998B1AE',
#  'SEC0015999A133C',
#  'SEC0015999C694D',
#  'SEC0015999C9460',
#  'SEC0015999DE4EB',
#  'SEC0015999DE551',
#  'SEC0015999E9F91',
#  'SEC0015999EBDC0',
#  'SEC0015999FFDA6',
#  'SEC001599A01009',
#  'SEC001599A16607',
#  'SEC001599A36C8B',
#  'SEC001599A4651E',
#  'SEC001599A5045F',
#  'SEC001599A6174C',
#  'SEC001599A6AE2F',
#  'SEC001599A7222A',
#  'SEC001599A74324',
#  'SEC001599A93E6A',
#  'SEC001599A9B2DB',
#  'SEC001599AA5848',
#  'SEC001599AAFA27',
#  'SEC001599AB8B35',
#  'SEC001599ABA7EC',
#  'SEC001599AC4383',
#  'SEC001599AC9FD5',
#  'SEC001599AD6443',
#  'SEC001599AE05A1',
#  'SEC001599AFAF8E',
#  'SEC001599AFB81E',
#  'SEC001599B071E9',
#  'SEC001599B0D079',
#  'SEC001599B12791',
#  'SEC001599B1A551',
#  'SEC001599B3AEB5',
#  'SEC001599B3AEF1',
#  'SEC001599B47B77',
#  'SEC001599C88E11',
#  'SEC001599C8B0D3',
#  'SEC001599C8_FL4',
#  'SEC001599CA1D82',
#  'SEC001599CB2F4E',
#  'SEC001599CC4DFE',
#  'SEC001599CD9C4D',
#  'SEC001599CDCDA8',
#  'SEC001599CEE9EA',
#  'SEC001599CEFCB2',
#  'SEC001599CF0D69',
#  'SEC001599CF7322',
#  'SEC001599CF7A7F',
#  'SEC001599CF7F40',
#  'SEC001599CFECE3',
#  'SEC001599CFF71D',
#  'SEC001599D01825',
#  'SEC001599D01A9F',
#  'SEC001599D045FB',
#  'SEC001599D05A0B',
#  'SEC001599D077D2',
#  'SEC001599D07CE1',
#  'SEC001599D081F2',
#  'SEC001599D08AC1',
#  'SEC001599D0A0FB',
#  'SEC001599D0B2D6',
#  'SEC001599D0B3CC',
#  'SEC001599D0B680',
#  'SEC001599D0B6D9',
#  'SEC001599D0BDDF',
#  'SEC001599D0FC33',
#  'SEC001599D11026',
#  'SEC001599D224DA',
#  'SEC001599D29FD3',
#  'SEC001599D2FBF6',
#  'SEC001599D3BE72',
#  'SEC001599D513E9',
#  'SEC001599D53D3F',
#  'SEC001599D5CEAC',
#  'SEC001599D65AB1',
#  'SEC001599D7A3CE',
#  'SEC001599D7F9F8',
#  'SEC001599D83DED',
#  'SEC001599D8BF33',
#  'SEC001599D936BF',
#  'SEC001599D9EB79',
#  'SEC001599DA2053',
#  'SEC001599DA89DA',
#  'SEC001599DB77F4',
#  'SEC001599DEBC5C',
#  'SEC001599DF96BD',
#  'SEC001599E03C8B',
#  'SEC001599E0CE56',
#  'SEC001599E2E70B',
#  'SEC001599E3740F',
#  'SEC001599E4A933',
#  'SEC001599E4F396',
#  'SEC001599E5F2F7',
#  'SEC001599E7DF3D',
#  'SEC001599EA83E0',
#  'SEC001599EBACF8',
#  'SEC001599EDAC70',
#  'SEC001599EDBFA6',
#  'SEC001599EDFAF8',
#  'SEC30CDA711BBD4',
#  'SEC30CDA712AE60',
#  'SEC30CDA71412C1',
#  'SEC30CDA71578DF',
#  'SEC30CDA7166B60',
#  'SEC30CDA7170A39',
#  'SEC30CDA7181EC2',
#  'SEC30CDA71825EC',
#  'SEC30CDA71867E0',
#  'SEC30CDA7195E1E',
#  'SEC30CDA71AD5E5',
#  'SEC30CDA71B3ABA',
#  'SEC30CDA71C70D9',
#  'SEC30CDA71DA43D',
#  'SEC30CDA71E92E2',
#  'SEC30CDA7204CF3',
#  'SEC30CDA720FB77',
#  'SEC30CDA722744F',
#  'SEC30CDA722E1B8',
#  'SEC30CDA725C3E5',
#  'SEC30CDA726513D',
#  'SEC30CDA7269A56',
#  'SEC30CDA726A9BD',
#  'SEC30CDA726BC86',
#  'SEC30CDA726FE91',
#  'SEC30CDA7279695',
#  'SEC30CDA7285535',
#  'SEC30CDA7289140',
#  'SEC30CDA72A90A0',
#  'SEC30CDA72C1DF3',
#  'SEC30CDA72C7371',
#  'SEC30CDA72CE199',
#  'SEC30CDA72E9D96',
#  'SEC30CDA72F760C',
#  'SEC30CDA72F892B',
#  'SEC30CDA730476B',
#  'SEC30CDA7314CE0',
#  'SEC30CDA731B54D',
#  'SEC30CDA73238E8',
#  'SEC30CDA73256F6',
#  'SEC30CDA733B665',
#  'SEC30CDA733FED1',
#  'SEC30CDA734F32C',
#  'SEC30CDA7362A69',
#  'SEC30CDA7364A9D',
#  'SEC30CDA736A4E2',
#  'SEC30CDA736E5EB',
#  'SEC30CDA736F88A',
#  'SEC30CDA737D6D1',
#  'SEC30CDA738208D',
#  'SEC30CDA738912D',
#  'SEC30CDA738D743',
#  'SEC30CDA738E7B1',
#  'SEC30CDA739231D',
#  'SEC30CDA73934A4',
#  'SEC30CDA73A6129',
#  'SEC30CDA73B2DBE',
#  'SEC30CDA73B845C',
#  'SEC30CDA73C1FF3',
#  'SEC30CDA73C623C',
#  'SEC30CDA73CEBA7',
#  'SEC30CDA73D4B96',
#  'SEC30CDA73DAE3F',
#  'SEC30CDA73DCD90',
#  'SEC30CDA75D2DAC',
#  'SEC30CDA75D437B',
#  'SEC30CDA75D4BBF',
#  'SEC30CDA75D548E',
#  'SEC30CDA75D6E3C',
#  'SEC30CDA75D8D4C',
#  'SEC30CDA75D93FC',
#  'SEC30CDA75D9950',
#  'SEC30CDA75DED91',
#  'SEC30CDA75E11EE',
#  'SEC30CDA75E1FC4',
#  'SEC30CDA75E4107',
#  'SEC30CDA75E84D4',
#  'SEC30CDA75EBCB2',
#  'SEC30CDA75ED239',
#  'SEC30CDA763BE68',
#  'SEC30CDA76489B3',
#  'SEC30CDA764949D',
#  'SEC30CDA764BBD0',
#  'SEC30CDA764CC56',
#  'SEC30CDA764F65A',
#  'SEC30CDA76503B9',
#  'SEC30CDA7651E07',
#  'SEC30CDA7652073',
#  'SEC30CDA76539BF',
#  'SEC30CDA7653C57',
#  'SEC30CDA765533E',
#  'SEC30CDA7657884',
#  'SEC30CDA7658793',
#  'SEC30CDA76590F4',
#  'SEC30CDA78CC11B',
#  'SEC30CDA78FF094',
#  'SEC30CDA7912951',
#  'SEC30CDA792DD9A',
#  'SEC30CDA793FA19',
#  'SEC30CDA7943922',
#  'SEC30CDA794E105',
#  'SEC30CDA794F465',
#  'SEC30CDA7951E60',
#  'SEC30CDA795315B',
#  'SEC30CDA7956D69',
#  'SEC30CDA7965373',
#  'SEC30CDA796E4AE',
#  'SEC30CDA7974F6B',
#  'SEC30CDA7976EE4',
#  'SEC30CDA79871B2',
#  'SEC30CDA7995953',
#  'SEC30CDA79C3114',
#  'SEC30CDA79C41D7',
#  'SEC30CDA79D63C9',
#  'SEC30CDA79E2F75',
#  'SEC30CDA79ED0E8',
#  'SEC30CDA79EF376',
#  'SEC30CDA7A06808',
#  'SEC30CDA7A0E8E2',
#  'SEC30CDA7A16F36',
#  'SEC30CDA7A2D5E1',
#  'SEC30CDA7A31AAB',
#  'SEC30CDA7A330B2',
#  'SEC30CDA7A4DF3E',
#  'SEC30CDA7A4EA4C',
#  'SEC30CDA7A63C6D',
#  'SEC30CDA7A742E6',
#  'SEC30CDA7A76329',
#  'SEC30CDA7A76467',
#  'SEC30CDA7A80941',
#  'SEC30CDA7A89A4B',
#  'SEC30CDA7AC92FC',
#  'SEC30CDA7ACE7DE',
#  'SEC30CDA7AD2520',
#  'SEC30CDA7AD7DE8',
#  'SEC30CDA7ADEE36',
#  'SEC30CDA7AE059C',
#  'SEC30CDA7AF382F',
#  'SEC30CDA7AF3DB8',
#  'SEC30CDA7AF47DA',
#  'SEC30CDA7B03663',
#  'SEC30CDA7B0B786',
#  'SEC30CDA7B13BC3',
#  'SEC30CDA7B16271',
#  'SEC30CDA7B24105',
#  'SEC30CDA7B25887',
#  'SEC30CDA7B3395A',
#  'SEC30CDA7B4307A',
#  'SEC30CDA7B5B8D2',
#  'SEC30CDA7B5D20C',
#  'SEC30CDA7B61B44',
#  'SEC30CDA7B63E08',
#  'SEC30CDA7B80745',
#  'SEC30CDA7B97F40',
#  'SEC30CDA7BAA2CE',
#  'SEC30CDA7BB8666',
#  'SEC30CDA7BC82B0',
#  'SEC30CDA7BDB7C4',
#  'SEC30CDA7BE1FA9',
#  'SEC30CDA7BEFFAA',
#  'SEC30CDA7BF41EA',
#  'SEC30CDA7BFFDC5',
#  'SEC30CDA7C06B2B',
#  'SEC30CDA7C1347C',
#  'SEC30CDA7C15936',
#  'SEC30CDA7C22195',
#  'SEC30CDA7C2D60B',
#  'SEC30CDA7C3B2BF',
#  'SEC30CDA7C3B9E5',
#  'SEC30CDA7C3EED2',
#  'SEC30CDA7C46491',
#  'SEC30CDA7C4AC69',
#  'SEC30CDA7C4D328',
#  'SEC30CDA7C5097A',
#  'SEC30CDA7C72E14',
#  'SEC30CDA7C82299',
#  'SEC30CDA7C8E5A0',
#  'SEC30CDA7C8E7C6',
#  'SEC30CDA7C96DA0',
#  'SEC30CDA7C9AF48',
#  'SEC30CDA7C9C6CB',
#  'SEC30CDA7C9D3FD',
#  'SEC30CDA7C9FD4B',
#  'SEC30CDA7CA0947',
#  'SEC30CDA7CA140C',
#  'SEC30CDA7CA37AC',
#  'SEC30CDA7CA37B4',
#  'SEC30CDA7CA9702',
#  'SEC30CDA7CA978D',
#  'SEC30CDA7CAC9A9',
#  'SEC30CDA7CACB9F',
#  'SEC30CDA7CACBA4',
#  'SEC30CDA7CB0E25',
#  'SEC30CDA7CB2721',
#  'SEC30CDA7CB7068',
#  'SEC30CDA7CB81BA',
#  'SEC30CDA7CBA217',
#  'SEC30CDA7CBA736',
#  'SEC30CDA7CBBADD',
#  'SEC30CDA7CBD6B0',
#  'SEC30CDA7CBF75D',
#  'SEC30CDA7CC0E8F',
#  'SEC30CDA7CC12CD',
#  'SEC30CDA7CC17BD',
#  'SEC30CDA7CC1809',
#  'SEC30CDA7CC1813',
#  'SEC30CDA7CC25CA',
#  'SEC30CDA7EB48CA',
#  'SEC30CDA7EB4EDC',
#  'SEC30CDA7EB944B',
#  'SEC30CDA7EC1F40',
#  'SEC30CDA7EC7EBC',
#  'SEC30CDA7EC921B',
#  'SEC30CDA7ECD5F5',
#  'SEC30CDA7ED53AD',
#  'SEC30CDA7ED563B',
#  'SEC30CDA7EDBBBE',
#  'SEC30CDA7EFCA96',
#  'SEC30CDA7F0A3C1',
#  'SEC30CDA7F16FD2',
#  'SEC30CDA7F1CBFD',
#  'SEC30CDA7F1DAE1',
#  'SEC30CDA7F2585E',
#  'SEC30CDA7F25C7C',
#  'SEC30CDA7F3AF36',
#  'SEC30CDA7F3EA3D',
#  'SEC30CDA7F3F122',
#  'SEC30CDA7F58A64',
#  'SEC30CDA7F5E5CA',
#  'SEC30CDA7FB055C',
#  'SEC30CDA7FB8575',
#  'SEC30CDA7FC2F39',
#  'SEC30CDA7FDB893',
#  'SEC30CDA7FF470E',
#  'SEC30CDA7FF4C5D',
#  'SEC30CDA7FF4C8A',
#  'SEC30CDA7FF52DC',
#  'SEC30CDA7FF53EE',
#  'SEC30CDA7FF5E29',
#  'SEC30CDA7FFB67D',
#  'SEC30CDA7FFFB36',
#  'SEC84251900928F',
#  'SEC842519011B9D',
#  'SEC842519011C02',
#  'SEC842519017610',
#  'SEC84251901D2B6',
#  'SEC84251901E16F',
#  'SEC8425190370E7',
#  'SEC842519046C16',
#  'SEC84251904BC9C',
#  'SEC84251904DF72',
#  'SEC84251904F4F1',
#  'SEC842519059EC8',
#  'SEC842519070A2C',
#  'SEC8425190A6332',
#  'SEC8425190A679E',
#  'SEC8425190B0956',
#  'SEC8425190B095D',
#  'SEC8425190B0FE2',
#  'SEC8425190C2AB6',
#  'SEC8425190CD29F',
#  'SEC8425190CD7F8',
#  'SEC8425190D0A11',
#  'SEC8425190FC09B',
#  'SEC8425190FC235',
#  'SEC84251910B3F0',
#  'SEC842519110795',
#  'SEC842519117D46',
#  'SEC84251911FD6F',
#  'SEC84251912CC2C',
#  'SEC84251913263A',
#  'SEC842519142C26',
#  'SEC842519145F09',
#  'SEC84251914A5D2',
#  'SEC8425191547B5',
#  'SEC84251915DEF2',
#  'SEC84251916B881',
#  'SEC84251916D5C3',
#  'SEC8425191B3079',
#  'SEC8425191B49CD',
#  'SEC8425191B8272',
#  'SEC8425191B8D34',
#  'SEC8425191B9220',
#  'SEC8425191B9F2A',
#  'SEC8425191CBC27',
#  'SEC8425191CC9A6',
#  'SEC8425191CD306',
#  'SEC8425191CDD3A',
#  'SEC8425191CF432',
#  'SEC8425191D0D8E',
#  'SEC8425191D0F98',
#  'SEC8425191D1425',
#  'SEC8425191D3B4E',
#  'SEC8425191D447A',
#  'SEC8425191D57EF',
#  'SEC8425191D5A70',
#  'SEC8425191D5F23',
#  'SEC8425191D764D',
#  'SEC8425191D832B',
#  'SEC8425191D96C4',
#  'SEC8425191DAFF7',
#  'SEC8425191DB997',
#  'SEC8425191DBC5B',
#  'SEC8425191DBE3D',
#  'SEC8425191DC0A6',
#  'SEC8425191DD013',
#  'SEC8425191DD118',
#  'SEC8425191DD634',
#  'SEC8425191DDC82',
#  'SEC8425191DF838',
#  'SEC8425191DFB5A',
#  'SEC8425191E0FF3',
#  'SEC8425191E16A4',
#  'SEC842519224959',
#  'SEC84251922B2FA',
#  'SEC842519232E39',
#  'SEC84251924C7A7',
#  'SEC84251924F380',
#  'SEC84251925C1B5',
#  'SEC84251925E954',
#  'SEC84251925F98B',
#  'SEC84251925FEE4',
#  'SEC842519263692',
#  'SEC842519273BD1',
#  'SEC8425192895AE',
#  'SEC84251929794E',
#  'SEC842519299D2A',
#  'SEC84251929B1D1',
#  'SEC8425192A8635',
#  'SEC8425192B320A',
#  'SEC8425192BA914',
#  'SEC8425192C5230',
#  'SEC8425192D05C2',
#  'SEC8425192E35C0',
#  'SEC8425193138BA',
#  'SEC842519322764',
#  'SEC842519329C3E',
#  'SEC84251932DD8F',
#  'SEC84251934C46E',
#  'SEC842519357860',
#  'SEC84251935950A',
#  'SEC842519365C3F',
#  'SEC84251936BACD',
#  'SEC84251954B6B4',
#  'SEC842519559F8C',
#  'SEC84251955B880',
#  'SEC842519566004',
#  'SEC8425195693E8',
#  'SEC84251956CF02',
#  'SEC842519573FDF',
#  'SEC84251957882E',
#  'SEC842519586B43',
#  'SEC8425195A8A53',
#  'SEC8425195B1EED',
#  'SEC8425195B2E73',
#  'SEC8425195BD9DB',
#  'SEC8425195C55CC',
#  'SEC8425195CCDF5',
#  'SEC8425195F0927',
#  'SEC842519608C00',
#  'SEC84251960D839',
#  'SEC84251961DABE',
#  'SEC84251965A230',
#  'SEC842519684128',
#  'SEC8425196A3567',
#  'SEC8425196A7A59',
#  'SEC8425196B1E72',
#  'SEC8425196B1F3C',
#  'SEC8425196B4F0C',
#  'SEC8425196B8886',
#  'SEC84251972906C',
#  'SEC8425197293D6',
#  'SEC84251976DD53',
#  'SECRET.DPEC',
#  'SELB-4440',
#  'SELB-6195',
#  'SELPHY',
#  'SHIELD',
#  'SIRD14C1',
#  'SIRD14C2',
#  'SIRD14C3',
#  'SIRD14C4',
#  'SIRD14D1',
#  'SL-IBTB(C)18',
#  'SMRA5.0A1',
#  'SMRB40A1',
#  'SMRS18A1',
#  'SMRS30A1',
#  'SMRS35A1',
#  'SP',
#  'SPK-WAM1400',
#  'SPK-WAM1500',
#  'SPK-WAM270',
#  'SPK-WAM350',
#  'SPK-WAM3500',
#  'SPK-WAM550',
#  'SPK-WAM5500',
#  'SPK-WAM6500',
#  'SPK-WAM750',
#  'SPK-WAM7500',
#  'SRS-HG1',
#  'SRS-HG10',
#  'SRS-HG2',
#  'SRS-X77',
#  'SRS-X88',
#  'SRS-X99',
#  'SRS-ZR5',
#  'SRS-ZR7',
#  'SS-439',
#  'SS-839',
#  'SSM267x',
#  'STR',
#  'STR-DN1050',
#  'STR-DN1060',
#  'STR-DN1070',
#  'STR-DN1080',
#  'STR-DN850',
#  'STR-DN860',
#  'STR-ZA810ES',
#  'SUPRIMENT-6545N',
#  'SX-N30',
#  'Samsung',
#  'Samsung-4195FN',
#  'SamsungCLX-6220',
#  'Samsung_ML-2850',
#  'Scansonic',
#  'Seagate',
#  'Sensor',
#  'Sensorhub',
#  'Sentry',
#  'Serveur',
#  'Serviio',
#  'Sharp',
#  'SilverStore',
#  'SimpleDMS',
#  'Sky',
#  'SmartShare(DMR)',
#  'Socket',
#  'SoftAtHome',
#  'Sonoclock',
#  'Sonos',
#  'Sony',
#  'SoundTouch',
#  'Squeezebox',
#  'Stream',
#  'SuperConnect',
#  'SuperUniti',
#  'Surveillance',
#  'Swisscom',
#  'TCL',
#  'TES-1885U',
#  'TL-IPC223(KP)-2.8',
#  'TL-IPC223K(P)-2.8',
#  'TL-IPC325(KP)-6',
#  'TL-IPC423(P)-4',
#  'TL-IPC443(P)-2.8',
#  'TL-IPC525C(P)-4',
#  'TL-IPC525K(P)-4',
#  'TL-IPC525K(P)-8',
#  'TL-IPC535K(P)-4',
#  'TL-SC3230',
#  'TL-SC3230N',
#  'TMS',
#  'TPM171E',
#  'TR7500',
#  'TR8500',
#  'TRENDnet',
#  'TS-1079',
#  'TS-110',
#  'TS-112',
#  'TS-119',
#  'TS-119P',
#  'TS-119P+',
#  'TS-121',
#  'TS-1231XU-RP',
#  'TS-1253U-RP',
#  'TS-1270U-RP',
#  'TS-1273U',
#  'TS-1277XU-RP',
#  'TS-1279U-RP',
#  'TS-128',
#  'TS-128A',
#  'TS-131',
#  'TS-131P',
#  'TS-1685',
#  'TS-210',
#  'TS-212',
#  'TS-212P',
#  'TS-219',
#  'TS-219P',
#  'TS-219P+',
#  'TS-220',
#  'TS-221',
#  'TS-228',
#  'TS-228A',
#  'TS-231',
#  'TS-231+',
#  'TS-231P',
#  'TS-231P2',
#  'TS-239',
#  'TS-239PROII',
#  'TS-239PROII+',
#  'TS-251',
#  'TS-251+',
#  'TS-251A',
#  'TS-251B',
#  'TS-251C',
#  'TS-253',
#  'TS-253A',
#  'TS-253B',
#  'TS-253Be',
#  'TS-259',
#  'TS-269',
#  'TS-269L',
#  'TS-328',
#  'TS-410',
#  'TS-412',
#  'TS-419P',
#  'TS-419P+',
#  'TS-419U',
#  'TS-420',
#  'TS-420U',
#  'TS-421',
#  'TS-421U',
#  'TS-431',
#  'TS-431+',
#  'TS-431P',
#  'TS-431P2',
#  'TS-431U',
#  'TS-431X',
#  'TS-431X2',
#  'TS-431XU',
#  'TS-431XU-RP',
#  'TS-431XeU',
#  'TS-439',
#  'TS-439U',
#  'TS-451',
#  'TS-451+',
#  'TS-451A',
#  'TS-451U',
#  'TS-453',
#  'TS-453A',
#  'TS-453B',
#  'TS-453BU',
#  'TS-453BU-RP',
#  'TS-453Be',
#  'TS-453Bmini',
#  'TS-453S',
#  'TS-453U-RP',
#  'TS-453mini',
#  'TS-459',
#  'TS-459U',
#  'TS-459U+',
#  'TS-463U',
#  'TS-463U-RP',
#  'TS-469',
#  'TS-469L',
#  'TS-469U',
#  'TS-470',
#  'TS-473',
#  'TS-509',
#  'TS-531P',
#  'TS-531X',
#  'TS-559',
#  'TS-563',
#  'TS-569',
#  'TS-569L',
#  'TS-639',
#  'TS-651',
#  'TS-653',
#  'TS-653A',
#  'TS-653B',
#  'TS-659',
#  'TS-669',
#  'TS-669L',
#  'TS-670',
#  'TS-673',
#  'TS-809',
#  'TS-809U',
#  'TS-831X',
#  'TS-831XU-RP',
#  'TS-832XU',
#  'TS-851',
#  'TS-853',
#  'TS-853A',
#  'TS-853BU',
#  'TS-853U',
#  'TS-853U-RP',
#  'TS-859',
#  'TS-859U',
#  'TS-859U+',
#  'TS-863U',
#  'TS-863U-RP',
#  'TS-869',
#  'TS-869U-RP',
#  'TS-870',
#  'TS-870U-RP',
#  'TS-873',
#  'TS-873U-RP',
#  'TS-877',
#  'TS-879',
#  'TS-963X',
#  'TS-EC1280U',
#  'TS-EC1679U-RP',
#  'TS-EC2480U',
#  'TS-EC879U-RP',
#  'TS-EC880',
#  'TS-EC880U',
#  'TS-X53-G',
#  'TS-X71',
#  'TS3100',
#  'TS5000',
#  'TS5100',
#  'TS6000',
#  'TS6100',
#  'TS6200',
#  'TS8000',
#  'TS8100',
#  'TS8130',
#  'TS8200',
#  'TS9000',
#  'TS9100',
#  'TS9500',
#  'TSR-5790',
#  'TSR-5810',
#  'TSR-5830',
#  'TSR-7790',
#  'TSR-7810',
#  'TSR-7850',
#  'TUNER',
#  'TV-IP110WN',
#  'TV-IP262PI',
#  'TV2012HE',
#  'TV2013HE',
#  'TVIP31501',
#  'TVIP41560',
#  'TVIP42560',
#  'TVIP61560',
#  'TVIP62560',
#  'TVIP71551',
#  'TVIP92300',
#  'TVMOBiLi',
#  'TVS-1271U-RP',
#  'TVS-1282',
#  'TVS-1282T3',
#  'TVS-463',
#  'TVS-471',
#  'TVS-471U',
#  'TVS-473',
#  'TVS-663',
#  'TVS-671',
#  'TVS-682T',
#  'TVS-863',
#  'TVS-871',
#  'TVS-871U-RP',
#  'TVS-873',
#  'TVS-882',
#  'TVS-882BR',
#  'TVS-882T',
#  'TVS-EC1080+',
#  'TVS-EC880',
#  'TVolution',
#  'TX-8050',
#  'TX-8140',
#  'TX-8150',
#  'TX-8160',
#  'TX-8270',
#  'TX-L20D',
#  'TX-NR1008',
#  'TX-NR1009',
#  'TX-NR3007',
#  'TX-NR3008',
#  'TX-NR3030',
#  'TX-NR414',
#  'TX-NR474',
#  'TX-NR5010',
#  'TX-NR509',
#  'TX-NR515',
#  'TX-NR525',
#  'TX-NR535',
#  'TX-NR545',
#  'TX-NR555',
#  'TX-NR575',
#  'TX-NR575E',
#  'TX-NR579',
#  'TX-NR585',
#  'TX-NR609',
#  'TX-NR616',
#  'TX-NR626',
#  'TX-NR636',
#  'TX-NR646',
#  'TX-NR656',
#  'TX-NR676',
#  'TX-NR676E',
#  'TX-NR686',
#  'TX-NR708',
#  'TX-NR709',
#  'TX-NR717',
#  'TX-NR727',
#  'TX-NR737',
#  'TX-NR747',
#  'TX-NR757',
#  'TX-NR777',
#  'TX-NR787',
#  'TX-NR807',
#  'TX-NR808',
#  'TX-NR809',
#  'TX-NR818',
#  'TX-NR828',
#  'TX-NR838',
#  'TX-NR929',
#  'TX-RZ610',
#  'TX-RZ630',
#  'TX-RZ710',
#  'TX-RZ720',
#  'TX-RZ730',
#  'TX-RZ800',
#  'TX-RZ810',
#  'TX-RZ820',
#  'TX-RZ830',
#  'TX-RZ900',
#  'TechniSat',
#  'TechniSound',
#  'Telstra',
#  'Teufel',
#  'The_Pearl',
#  'Tisk-kryt',
#  'Twonky',
#  'TwonkyMedia',
#  'TwonkyProxy',
#  'TwonkyServer',
#  'UA32F4500',
#  'UA32F6400',
#  'UA32J4300',
#  'UA32J4700',
#  'UA32K5300',
#  'UA32M5500',
#  'UA32M5570',
#  'UA32N4300',
#  'UA40ES5500',
#  'UA40ES6200',
#  'UA40F5500',
#  'UA40H6400',
#  'UA40J5200',
#  'UA40JU6000',
#  'UA40JU6400',
#  'UA40K5500',
#  'UA40N5300',
#  'UA43J5278',
#  'UA43J5500',
#  'UA43K5500',
#  'UA43M6000',
#  'UA43MU6103',
#  'UA43NU7100',
#  'UA46EH5300',
#  'UA48H6300',
#  'UA48J6300',
#  'UA49J5200',
#  'UA49MU6103',
#  'UA49MU6300',
#  'UA49MU7350',
#  'UA50F5500',
#  'UA50F6400',
#  'UA50MU7000',
#  'UA55F8000',
#  'UA55H6400',
#  'UA55H8000',
#  'UA55HU9000',
#  'UA55J6200',
#  'UA55JU7500',
#  'UA55K6500',
#  'UA55MU6100',
#  'UA55MU7000',
#  'UA55MU7350',
#  'UA55NU7090',
#  'UA55NU7100',
#  'UA55NU8000',
#  'UA55NU8500',
#  'UA60J6200',
#  'UA65KU7000',
#  'UA65MU6100',
#  'UA65MU7000',
#  'UA78JU7500',
#  'UBD-M7500',
#  'UBD-M8500',
#  'UE22H5600',
#  'UE32D5500',
#  'UE32D6100',
#  'UE32D6500',
#  'UE32EH5300',
#  'UE32EH5307',
#  'UE32ES5500',
#  'UE32ES6100',
#  'UE32ES6300',
#  'UE32ES6307',
#  'UE32ES6500',
#  'UE32ES6580',
#  'UE32ES6710',
#  'UE32F4500',
#  'UE32F5300',
#  'UE32F5500',
#  'UE32F6330',
#  'UE32F6400',
#  'UE32F6510',
#  'UE32H4500',
#  'UE32H5303',
#  'UE32H5500',
#  'UE32H6200',
#  'UE32H6410',
#  'UE32J4500',
#  'UE32J4570',
#  'UE32J5200',
#  'UE32J5500',
#  'UE32K5500',
#  'UE32K5572',
#  'UE32M5500',
#  'UE32M5503',
#  'UE32M5505',
#  'UE32M5520',
#  'UE32M5522',
#  'UE32M5550',
#  'UE32M5590',
#  'UE32M5602',
#  'UE32M5672',
#  'UE37ES5500',
#  'UE37ES6300',
#  'UE37ES6307',
#  'UE39F5500',
#  'UE40D5000',
#  'UE40D5500',
#  'UE40D5700',
#  'UE40D6100',
#  'UE40D6500',
#  'UE40D7000',
#  'UE40D8000',
#  'UE40EH5300',
#  'UE40ES5500',
#  'UE40ES5507',
#  'UE40ES5537',
#  'UE40ES5700',
#  'UE40ES6100',
#  'UE40ES6200',
#  'UE40ES6300',
#  'UE40ES6307',
#  'UE40ES6557',
#  'UE40ES6560',
#  'UE40ES6710',
#  'UE40ES6715',
#  'UE40ES8000',
#  'UE40F5300',
#  'UE40F5500',
#  'UE40F6200',
#  'UE40F6320',
#  'UE40F6330',
#  'UE40F6400',
#  'UE40F6500',
#  'UE40F6600',
#  'UE40F7000',
#  'UE40H4203',
#  'UE40H5303',
#  'UE40H5500',
#  'UE40H5510',
#  'UE40H6200',
#  'UE40H6400',
#  'UE40H6600',
#  'UE40H6700',
#  'UE40HU6900',
#  'UE40J5248',
#  'UE40J5278',
#  'UE40J5500',
#  'UE40J5510',
#  'UE40J6200',
#  'UE40J6240',
#  'UE40J6300',
#  'UE40JU6000',
#  'UE40JU6400',
#  'UE40JU6410',
#  'UE40JU6500',
#  'UE40JU6700',
#  'UE40K5500',
#  'UE40K5572',
#  'UE40K5600',
#  'UE40K5607',
#  'UE40K6300',
#  'UE40K6372',
#  'UE40K6500',
#  'UE40KU6000',
#  'UE40KU6020',
#  'UE40KU6070',
#  'UE40KU6072',
#  'UE40KU6100',
#  'UE40KU6172',
#  'UE40KU6179',
#  'UE40KU6400',
#  'UE40KU6402',
#  'UE40KU6470',
#  'UE40KU6479',
#  'UE40MU6102',
#  'UE40MU6105',
#  'UE40MU6120',
#  'UE40MU6122',
#  'UE40MU6125',
#  'UE40MU6170',
#  'UE40MU6172',
#  'UE40MU6175',
#  'UE40MU6199',
#  'UE40MU6400',
#  'UE40MU6405',
#  'UE40MU6452',
#  'UE40MU6479',
#  'UE40N5300',
#  'UE40NU7100',
#  'UE40NU7122',
#  'UE40NU7190',
#  'UE40NU7199',
#  'UE42F5300',
#  'UE42F5500',
#  'UE43J5500',
#  'UE43KU6000',
#  'UE43KU6079',
#  'UE43KU6402',
#  'UE43KU6500',
#  'UE43KU6670',
#  'UE43M5500',
#  'UE43M5520',
#  'UE43M5570',
#  'UE43M5572',
#  'UE43MU6100',
#  'UE43MU6102',
#  'UE43MU6105',
#  'UE43MU6172',
#  'UE43MU6179',
#  'UE43MU7000',
#  'UE43N5500',
#  'UE43NU7025',
#  'UE43NU7099',
#  'UE43NU7100',
#  'UE43NU7120',
#  'UE43NU7122',
#  'UE43NU7170',
#  'UE43NU7199',
#  'UE43NU7400',
#  'UE43NU7405',
#  'UE43NU7452',
#  'UE43NU7470',
#  'UE46D5700',
#  'UE46D6000',
#  'UE46D6500',
#  'UE46D7000',
#  'UE46D8000',
#  'UE46EH6030',
#  'UE46ES5500',
#  'UE46ES5700',
#  'UE46ES6100',
#  'UE46ES6300',
#  'UE46ES6560',
#  'UE46ES6800',
#  'UE46ES6890',
#  'UE46ES7000',
#  'UE46ES7090',
#  'UE46ES8090',
#  'UE46F5300',
#  'UE46F5500',
#  'UE46F6200',
#  'UE46F6320',
#  'UE46F6400',
#  'UE46F6500',
#  'UE46F6510',
#  'UE46F6600',
#  'UE46F6700',
#  'UE46F7000',
#  'UE46F8000',
#  'UE46H6203',
#  'UE46H7000',
#  'UE48H5103',
#  'UE48H5500',
#  'UE48H6200',
#  'UE48H6300',
#  'UE48H6400',
#  'UE48H6410',
#  'UE48H6500',
#  'UE48H6600',
#  'UE48H6800',
#  'UE48H6850',
#  'UE48H8000',
#  'UE48HU7500',
#  'UE48J5248',
#  'UE48J5500',
#  'UE48J5510',
#  'UE48J6200',
#  'UE48J6300',
#  'UE48JS8500',
#  'UE48JS9000',
#  'UE48JU6000',
#  'UE48JU6400',
#  'UE48JU6410',
#  'UE48JU6500',
#  'UE48JU6510',
#  'UE48JU6740',
#  'UE48JU7000',
#  'UE48JU7500',
#  'UE49J5278',
#  'UE49K5502',
#  'UE49K5510',
#  'UE49K5572',
#  'UE49K5579',
#  'UE49K5600',
#  'UE49K6300',
#  'UE49K6372',
#  'UE49KS7000',
#  'UE49KS7500',
#  'UE49KS7590',
#  'UE49KU6100',
#  'UE49KU6172',
#  'UE49KU6400',
#  'UE49KU6470',
#  'UE49KU6510',
#  'UE49KU6650',
#  'UE49KU6670',
#  'UE49M5500',
#  'UE49M5520',
#  'UE49MU6179',
#  'UE49MU6205',
#  'UE49MU6220',
#  'UE49MU6400',
#  'UE49MU6402',
#  'UE49MU6405',
#  'UE49MU6452',
#  'UE49MU6470',
#  'UE49MU6475',
#  'UE49MU6505',
#  'UE49NU7100',
#  'UE49NU7102',
#  'UE49NU7105',
#  'UE49NU7172',
#  'UE49NU7175',
#  'UE49NU7179',
#  'UE49NU7300',
#  'UE49NU7302',
#  'UE49NU7305',
#  'UE49NU7670',
#  'UE49NU8000',
#  'UE49NU8009',
#  'UE49NU8075',
#  'UE50ES6900',
#  'UE50H5500',
#  'UE50H6200',
#  'UE50H6400',
#  'UE50HU6900',
#  'UE50J5500',
#  'UE50J6240',
#  'UE50JU6400',
#  'UE50JU6900',
#  'UE50KU6000',
#  'UE50KU6070',
#  'UE50KU6072',
#  'UE50KU6079',
#  'UE50MU6102',
#  'UE50MU6120',
#  'UE50MU6125',
#  'UE50MU6179',
#  'UE50MU6192',
#  'UE50MU6409',
#  'UE50NU7025',
#  'UE50NU7092',
#  'UE50NU7099',
#  'UE50NU7440',
#  'UE50NU7472',
#  'UE55D6500',
#  'UE55D7000',
#  'UE55D8000',
#  'UE55ES6300',
#  'UE55ES6540',
#  'UE55ES7000',
#  'UE55ES7080',
#  'UE55ES8000',
#  'UE55ES8090',
#  'UE55F6320',
#  'UE55F6400',
#  'UE55F6500',
#  'UE55F6600',
#  'UE55F8000',
#  'UE55F9000',
#  'UE55H6200',
#  'UE55H6400',
#  'UE55H6410',
#  'UE55H6500',
#  'UE55H6600',
#  'UE55H6800',
#  'UE55H6850',
#  'UE55HU6900',
#  'UE55HU7100',
#  'UE55HU7200',
#  'UE55HU8500',
#  'UE55J6200',
#  'UE55J6240',
#  'UE55J6300',
#  'UE55JS9000',
#  'UE55JU6000',
#  'UE55JU6400',
#  'UE55JU6410',
#  'UE55JU6500',
#  'UE55JU6900',
#  'UE55JU7000',
#  'UE55JU7500',
#  'UE55K5500',
#  'UE55K5510',
#  'UE55K5579',
#  'UE55K5607',
#  'UE55K5679',
#  'UE55K6300',
#  'UE55K6372',
#  'UE55KS7000',
#  'UE55KS7500',
#  'UE55KS7590',
#  'UE55KS9090',
#  'UE55KU6000',
#  'UE55KU6070',
#  'UE55KU6075',
#  'UE55KU6079',
#  'UE55KU6099',
#  'UE55KU6100',
#  'UE55KU6172',
#  'UE55KU6400',
#  'UE55KU6459',
#  'UE55KU6470',
#  'UE55KU6650',
#  'UE55KU6670',
#  'UE55M6399',
#  'UE55MU6100',
#  'UE55MU6102',
#  'UE55MU6105',
#  'UE55MU6120',
#  'UE55MU6125',
#  'UE55MU6172',
#  'UE55MU6175',
#  'UE55MU6179',
#  'UE55MU6199',
#  'UE55MU6200',
#  'UE55MU6205',
#  'UE55MU6220',
#  'UE55MU6272',
#  'UE55MU6279',
#  'UE55MU6300',
#  'UE55MU6400',
#  'UE55MU6409',
#  'UE55MU6442',
#  'UE55MU6500',
#  'UE55MU6645',
#  'UE55MU6655',
#  'UE55MU7000',
#  'UE55MU7002',
#  'UE55MU7005',
#  'UE55MU7009',
#  'UE55MU7042',
#  'UE55MU7045',
#  'UE55MU7070',
#  'UE55NU6035',
#  'UE55NU7021',
#  'UE55NU7025',
#  'UE55NU7026',
#  'UE55NU7093',
#  'UE55NU7100',
#  'UE55NU7172',
#  'UE55NU7175',
#  'UE55NU7179',
#  'UE55NU7305',
#  'UE55NU7405',
#  'UE55NU7452',
#  'UE55NU7472',
#  'UE55NU7475',
#  'UE55NU7479',
#  'UE55NU8002',
#  'UE55NU8005',
#  'UE55NU8072',
#  'UE58J5200',
#  'UE58MU6125',
#  'UE58MU6199',
#  'UE60F6300',
#  'UE60H6200',
#  'UE60J6200',
#  'UE60JU6900',
#  'UE60KU6000',
#  'UE60KU6072',
#  'UE65HU8200',
#  'UE65HU8500',
#  'UE65J6240',
#  'UE65JS9500',
#  'UE65JU6000',
#  'UE65JU6500',
#  'UE65JU7000',
#  'UE65JU7500',
#  'UE65KU6000',
#  'UE65KU6179',
#  'UE65LS003',
#  'UE65MU6175',
#  'UE65MU6179',
#  'UE65MU6199',
#  'UE65MU6200',
#  'UE65MU6205',
#  'UE65MU7002',
#  'UE65MU7075',
#  'UE65MU7400',
#  'UE65MU8009',
#  'UE65MU9000',
#  'UE65NU7025',
#  'UE65NU7172',
#  'UE65NU7175',
#  'UE65NU8000',
#  'UE65NU8009',
#  'UE70KU6000',
#  'UE75H6400',
#  'UE75JU7000',
#  'UE75MU7005',
#  'UE75NU8005',
#  'UHD86',
#  'UHD87',
#  'UN00NU7100',
#  'UN24M4500',
#  'UN32D5500',
#  'UN32EH5300',
#  'UN32F4300',
#  'UN32F5500',
#  'UN32H4303',
#  'UN32H5203',
#  'UN32H5500',
#  'UN32H6350',
#  'UN32J4290',
#  'UN32J4303',
#  'UN32J4700',
#  'UN32J5303',
#  'UN32J5500',
#  'UN32M4500',
#  'UN32M5300',
#  'UN32N5300',
#  'UN40D5500',
#  'UN40D6050',
#  'UN40EH5300',
#  'UN40EH6030',
#  'UN40ES6100',
#  'UN40ES6500',
#  'UN40ES7000',
#  'UN40F5500',
#  'UN40F6300',
#  'UN40F6400',
#  'UN40FH5303',
#  'UN40FH6203',
#  'UN40H4203',
#  'UN40H5103',
#  'UN40H5203',
#  'UN40H5303',
#  'UN40H5500',
#  'UN40H6350',
#  'UN40H6400',
#  'UN40HU7000',
#  'UN40J5200',
#  'UN40J5290',
#  'UN40J5300',
#  'UN40J5500',
#  'UN40J6203',
#  'UN40J6400',
#  'UN40JU6100',
#  'UN40K5300',
#  'UN40K6500',
#  'UN40KU6000',
#  'UN40KU6300',
#  'UN40M5300',
#  'UN40M530D',
#  'UN40MU6100',
#  'UN40MU6290',
#  'UN40MU6300',
#  'UN40NU7100',
#  'UN43J5200',
#  'UN43J5290',
#  'UN43KU7500',
#  'UN43M5300',
#  'UN43MU6100',
#  'UN43MU6290',
#  'UN43MU6300',
#  'UN43MU630D',
#  'UN43NU6900',
#  'UN43NU6950',
#  'UN43NU7090',
#  'UN43NU7100',
#  'UN46D6000',
#  'UN46D6050',
#  'UN46D6300',
#  'UN46D6450',
#  'UN46D6900',
#  'UN46EH5300',
#  'UN46ES5300',
#  'UN46ES6100',
#  'UN46ES6150',
#  'UN46ES6500',
#  'UN46ES7000',
#  'UN46F5500',
#  'UN46F6300',
#  'UN46F6350',
#  'UN46F6400',
#  'UN46F6800',
#  'UN46F7500',
#  'UN46F8000',
#  'UN46FH5303',
#  'UN46FH6203',
#  'UN46H5203',
#  'UN46H5303',
#  'UN48H4203',
#  'UN48H5500',
#  'UN48H6400',
#  'UN48H6800',
#  'UN48J5200',
#  'UN48J5201',
#  'UN48J5300',
#  'UN48J5500',
#  'UN48J6200',
#  'UN48J6300',
#  'UN48J6400',
#  'UN48JU6100',
#  'UN48JU6400',
#  'UN48JU6700',
#  'UN49J5200',
#  'UN49J5290',
#  'UN49K5300',
#  'UN49K5500',
#  'UN49K6250',
#  'UN49K6500',
#  'UN49KS7000',
#  'UN49KS8000',
#  'UN49KU6300',
#  'UN49KU6400',
#  'UN49KU6450',
#  'UN49M5300',
#  'UN49MU6100',
#  'UN49MU6120',
#  'UN49MU6300',
#  'UN49MU6500',
#  'UN49MU7000',
#  'UN49MU8000',
#  'UN49NU7100',
#  'UN50EH5300',
#  'UN50ES6150',
#  'UN50ES6900',
#  'UN50F5500',
#  'UN50H5203',
#  'UN50H6400',
#  'UN50HU7000',
#  'UN50J5200',
#  'UN50J5300',
#  'UN50J5500',
#  'UN50JU6400',
#  'UN50JU650D',
#  'UN50KU6000',
#  'UN50KU630D',
#  'UN50M5300',
#  'UN50M530D',
#  'UN50MU6070',
#  'UN50MU6100',
#  'UN50MU6103',
#  'UN50MU6300',
#  'UN50MU630D',
#  'UN50NU6900',
#  'UN50NU7100',
#  'UN50NU7400',
#  'UN55D6000',
#  'UN55D6050',
#  'UN55D6420',
#  'UN55D7000',
#  'UN55D8000',
#  'UN55ES6820',
#  'UN55ES8000',
#  'UN55F6300',
#  'UN55F6350',
#  'UN55F6400',
#  'UN55F8000',
#  'UN55F9000',
#  'UN55FH6030',
#  'UN55FH6200',
#  'UN55H6103',
#  'UN55H6203',
#  'UN55H6300',
#  'UN55H6350',
#  'UN55H7100',
#  'UN55H8000',
#  'UN55HU6830',
#  'UN55HU7000',
#  'UN55HU7200',
#  'UN55HU7250',
#  'UN55HU9000',
#  'UN55J5300',
#  'UN55J5500',
#  'UN55J6200',
#  'UN55J6203',
#  'UN55JS6900',
#  'UN55JS700D',
#  'UN55JS8000',
#  'UN55JU6000',
#  'UN55JU6400',
#  'UN55JU6700',
#  'UN55JU670D',
#  'UN55K5300',
#  'UN55K6250',
#  'UN55K6500',
#  'UN55KS7500',
#  'UN55KS8000',
#  'UN55KS9500',
#  'UN55KU6000',
#  'UN55KU6290',
#  'UN55KU6300',
#  'UN55KU630D',
#  'UN55KU6400',
#  'UN55KU6500',
#  'UN55KU7000',
#  'UN55KU7500',
#  'UN55MU6100',
#  'UN55MU6103',
#  'UN55MU6290',
#  'UN55MU6300',
#  'UN55MU6303',
#  'UN55MU6400',
#  'UN55MU6490',
#  'UN55MU6500',
#  'UN55MU7000',
#  'UN55MU7500',
#  'UN55MU8000',
#  'UN55NU6900',
#  'UN55NU6950',
#  'UN55NU7100',
#  'UN55NU7300',
#  'UN55NU8000',
#  'UN55NU8500',
#  'UN58H5203',
#  'UN58J5190',
#  'UN58MU6070',
#  'UN58MU6100',
#  'UN58MU6120',
#  'UN58NU7100',
#  'UN60ES7100',
#  'UN60F6300',
#  'UN60F6400',
#  'UN60F7100',
#  'UN60H6103',
#  'UN60H6203',
#  'UN60H6300',
#  'UN60H6350',
#  'UN60H7100',
#  'UN60J6203',
#  'UN60JS6900',
#  'UN60JS700D',
#  'UN60JU6400',
#  'UN60KS8000',
#  'UN60KU6000',
#  'UN60KU6300',
#  'UN65F6350',
#  'UN65F6400',
#  'UN65F7100',
#  'UN65H6203',
#  'UN65H6350',
#  'UN65HU7200',
#  'UN65HU7250',
#  'UN65J6203',
#  'UN65JS8000',
#  'UN65JU6100',
#  'UN65JU6400',
#  'UN65JU6700',
#  'UN65JU7000',
#  'UN65KS8000',
#  'UN65KS800D',
#  'UN65KS8500',
#  'UN65KU6290',
#  'UN65KU6490',
#  'UN65KU6500',
#  'UN65KU650D',
#  'UN65KU7000',
#  'UN65KU7500',
#  'UN65LS03N',
#  'UN65MU6070',
#  'UN65MU6100',
#  'UN65MU6103',
#  'UN65MU6300',
#  'UN65MU630D',
#  'UN65MU6500',
#  'UN65MU7000',
#  'UN65MU8000',
#  'UN65MU800D',
#  'UN65MU850D',
#  'UN65NU6070',
#  'UN65NU6950',
#  'UN65NU7100',
#  'UN65NU710D',
#  'UN65NU8000',
#  'UN65NU800D',
#  'UN75JU7000',
#  'UN75MU6070',
#  'UN75MU6100',
#  'UN75MU9000',
#  'UN75NU7100',
#  'UN82MU8000',
#  'UNNOH6203',
#  'UPNP',
#  'UTC',
#  'UnitiLite',
#  'UnitiQute',
#  'Unknown',
#  'Unmonday',
#  'VA_3128@rockchip',
#  'VGA',
#  'VIP',
#  'VMS1100',
#  'VS-2004Pro',
#  'VS-2008Pro',
#  'VS-2104L',
#  'VS-2204',
#  'VS-2212',
#  'VS-4016Pro',
#  'VS-4108UPro+',
#  'VS-4116Pro+',
#  'VS-4116UPro+',
#  'VSX-1130/CUXESM',
#  'VSX-1130/SYXEV8',
#  'VSX-45/CUXE',
#  'VSX-830/CUXESM',
#  'VSX-830/SYXEV8',
#  'VSX-90/CUXE',
#  'VSX-930/SYXEV8',
#  'Verizon',
#  'VirtualRemoteControl',
#  'Vuze',
#  'W100',
#  'WCB-100Ae',
#  'WD',
#  'WDMyCloud',
#  'WDMyCloudDL2100',
#  'WDMyCloudEX2',
#  'WDMyCloudEX2100',
#  'WDMyCloudEX4',
#  'WDMyCloudEX4100',
#  'WDMyCloudMirror',
#  'WEBOS3',
#  'WFB-100Ap',
#  'WHD81',
#  'WHD93',
#  'WKR',
#  'WNDR4300',
#  'WPS',
#  'WR-220W',
#  'WR100-D',
#  'WS-Printer',
#  'WSMCNH_ADMIN',
#  'WX-010',
#  'WX-021',
#  'WX-030',
#  'WX-051',
#  'WXA-50',
#  'WXAD-10',
#  'WXC-50',
#  'Wave',
#  'WaxRainPlayer',
#  'Wi-Fi',
#  'WiFi',
#  'Windows',
#  'Wired',
#  'Wireless',
#  'Worldwide',
#  'XBMC',
#  'XBR-43X800D',
#  'XBR-43X800E',
#  'XBR-43X830C',
#  'XBR-49X700D',
#  'XBR-49X800D',
#  'XBR-49X800E',
#  'XBR-49X805E',
#  'XBR-49X807E',
#  'XBR-49X830C',
#  'XBR-49X900E',
#  'XBR-49X900F',
#  'XBR-55A8F',
#  'XBR-55X700D',
#  'XBR-55X705D',
#  'XBR-55X800E',
#  'XBR-55X805E',
#  'XBR-55X810C',
#  'XBR-55X850C',
#  'XBR-55X850D',
#  'XBR-55X855D',
#  'XBR-55X900C',
#  'XBR-55X900E',
#  'XBR-55X900F',
#  'XBR-55X905E',
#  'XBR-55X905F',
#  'XBR-65X805C',
#  'XBR-65X810C',
#  'XBR-65X850C',
#  'XBR-65X850D',
#  'XBR-65X850E',
#  'XBR-65X900E',
#  'XBR-65X900F',
#  'XBR-65X905E',
#  'XBR-65X905F',
#  'XBR-65X930D',
#  'XBR-65Z9D',
#  'XBR-75X850D',
#  'XBR-75X850E',
#  'XBR-75X850F',
#  'XBR-75X855D',
#  'XBR-75X900E',
#  'XBR-75X900F',
#  'XBR-75X905E',
#  'XBR-75X940C',
#  'XBR-85X850D',
#  'XDA-QS5400',
#  'XEROX_SEGURANCA',
#  'XRX0000AA97BCEB',
#  'XRX0000AA97F811',
#  'XRX0000AAB9DCC0',
#  'XRX0000AABC5A2C',
#  'XRX0000AABD7C63',
#  'XRX0000AABEDFD6',
#  'XRX0000AABF5788',
#  'XRX0000AAC07E03',
#  'XRX0000AAC95DB7',
#  'XRX0000AAC964B1',
#  'XRX0000AACD7033',
#  'XRX0000AACD88C1',
#  'XRX0000AACEE912',
#  'XRX0000AAD8E2CF',
#  'XRX0000AAD8EA0E',
#  'XRX0000AAD95507',
#  'XRX0000AADB9DDD',
#  'XRX0000AADBC750',
#  'XRX0000AADBC995',
#  'XRX0000AADBE2C5',
#  'XRX0000AADE327B',
#  'XRX0000AAF2A444',
#  'XRX3315-979',
#  'XRX9C934E08414C',
#  'XRX9C934E088031',
#  'XRX9C934E08AE4D',
#  'XRX9C934E08EB1E',
#  'XRX9C934E093F8B',
#  'XRX9C934E09B732',
#  'XRX9C934E09D4FD',
#  'XRX9C934E0A6D22',
#  'XRX9C934E17B655',
#  'XRX9C934E1801BB',
#  'XRX9C934E189A48',
#  'XRX9C934E212145',
#  'XRX9C934E21AAED',
#  'XRX9C934E228D76',
#  'XRX9C934E2341B3',
#  'XRX9C934E2A074E',
#  'XRX9C934E33DF7F',
#  'XRX9C934E380167',
#  'XRX9C934E3BF290',
#  'XRX9C934E3C417E',
#  'XRX9C934E3EC930',
#  'XRX9C934E3ECB93',
#  'XRX9C934E3EE4D8',
#  'XRX9C934E3FA905',
#  'XRX9C934E3FF59A',
#  'XRX9C934E4017F2',
#  'XRX9C934E402876',
#  'XRX9C934E42A96D',
#  'XRX9C934E44513D',
#  'XRX9C934E4494E7',
#  'XRX9C934E4547CD',
#  'XRX9C934E457DA2',
#  'XRX9C934E45A850',
#  'XRX9C934E45BC4B',
#  'XRX9C934E45C2C4',
#  'XRX9C934E45D02E',
#  'XRX9C934E45EC38',
#  'XRX9C934E464D12',
#  'XRX9C934E515EE4',
#  'XRX9C934E518DBF',
#  'XRX9C934E52FE2A',
#  'XRX9C934E5677AE',
#  'XRX9C934E56B39F',
#  'XRX9C934E61B386',
#  'XRX9C934E63255C',
#  'XRX9C934E63817F',
#  'XRX9C934E70CE74',
#  'XRX9C934E70F9E6',
#  'XRX9C934E73B9A7',
#  'XRX9C934E77F992',
#  'XRX9C934E78135E',
#  'XRX9C934E78910E',
#  'XRX9C934E78CA62',
#  'XRX9C934E78F4F5',
#  'XRX9C934E79212B',
#  'XRX9C934E79983F',
#  'XRX9C934E79C637',
#  'Xbox',
#  'Xerox_Photocopi',
#  'YAS-306',
#  'YAS-408',
#  'YMS-4080',
#  'YSP-1600',
#  'YSP-2700',
#  'YSP-5600',
#  'ZDDPBQAHB0020DB',
#  'ZX-1680',
#  'Zona',
#  'aastralink',
#  'contab',
#  'csaanxlas03',
#  'diaconos',
#  'eedomus',
#  'esc-gabprefeito',
#  'hello',
#  'iP110',
#  'iP8700',
#  'iRadio',
#  'iStream',
#  'iTuner',
#  'imagio',
#  'imp-estacioname',
#  'interve',
#  'plena02',
#  'posto12_par',
#  'posto1_par',
#  'rascunho',
#  'reitoria-spdi',
#  'samsung8128',
#  'samtreinamento',
#  'sonoroSTREAM',
#  'soundmaster',
#  'supersound2',
#  'xerox3550',
#  'xerox3635',
#  'xseries']

# %%
def get_upnp_services(upnp):
    if isinstance(upnp, list) and 'services' in upnp[0].keys():
        ss = []
        for d in upnp:
            ss += [x.split(':')[-1] for x in d['services']] 
        return list(filter(lambda x: not x.isdigit(), ss))
    return ["Unknown"]

upnp_services = []
for _, row in pd.concat([df_train, df_test], axis=0, sort=False).iterrows():
    xs = get_upnp_services(row['upnp'])
    for x in xs:
        if x not in upnp_services:
            upnp_services.append(x)
#             upnp_services[x] = 1
#         else:
#             upnp_services[x] += 1
upnp_services.sort()
print(len(upnp_services))
pprint.pprint(upnp_services)
# Out:
# 148
# ['',
#  '(null)',
#  'ABControl',
#  'ACT',
#  'AVTransport',
#  'AccessControlServer',
#  'AlarmClock',
#  'AudioIn',
#  'BasicManagement',
#  'BasicServiceId',
#  'CDS_0-99',
#  'CMGR_0-99',
#  'ConfigService',
#  'ConfigurationManagement',
#  'ConnectionManager',
#  'ConnectionManager1',
#  'ConnectionManager_E114A616-9B1B-4904-B2D4-A1DA02E4C439',
#  'ContentDirectory',
#  'ContentDirectory1',
#  'DPSConnectionManager',
#  'DeviceProperties',
#  'DeviceProtection',
#  'DigitalSecurityCameraSettings',
#  'DigitalSecurityCameraStillImage',
#  'DiscoveryService',
#  'EmbeddedNetDeviceControl',
#  'EmptyService',
#  'ErrorHandler',
#  'EventLogService',
#  'FileTransfer',
#  'Group',
#  'GroupControl',
#  'GroupManagement',
#  'GroupRenderingControl',
#  'GsensorControlServer',
#  'HTControl',
#  'HisenseLanControl',
#  'INETTV',
#  'IPChange',
#  'IPControlService',
#  'IRCC',
#  'L3Forwarding1',
#  'LG_SIGNAGE',
#  'LibraryServer',
#  'LnvConnectService1.0',
#  'Log',
#  'MainTVAgent2',
#  'MediaControl1',
#  'MirrorControlServer',
#  'Monitor',
#  'MultiChannel',
#  'MultiScreenService',
#  'MusicConnect',
#  'MusicServices',
#  'NAS',
#  'NULL',
#  'Nascontrol1',
#  'Nastorage1',
#  'NetCamService1',
#  'NetworkManagement',
#  'PanasonicSession',
#  'PlaylistExtension',
#  'PlaylistManager',
#  'PrivateServer',
#  'ProbeProvider',
#  'QPlay',
#  'Queue',
#  'RTSPGateway',
#  'RaumfeldGenerator',
#  'RemoteAppControlServer',
#  'RemoteControl',
#  'RemoteUIServer',
#  'RenderingControl',
#  'RenderingControl_F027767B-FA10-4e98-97C6-D80E6EA4B419',
#  'RootNull',
#  'SBoxControlService1',
#  'SMSearch',
#  'ScalarWebAPI',
#  'ScheduledRecording',
#  'ScreenSharingService',
#  'SecurityDeviceControl',
#  'SessionManagement',
#  'SetupService',
#  'SpeakerManagement',
#  'StreamBookmark',
#  'StreamMagic6',
#  'StreamSplicing',
#  'SyncControl',
#  'SyncManager',
#  'SystemProperties',
#  'TestRCRService',
#  'UTCInHome1',
#  'UTCLCDIAPI1',
#  'UTCRCEmulation1',
#  'Unknown',
#  'UuVolControl',
#  'UuVolSimpleRemote',
#  'VIMEControlServer',
#  'VinputControlServer',
#  'VirtualLineIn',
#  'VirtualRemoteControl',
#  'WANCommonIFC1',
#  'WANIPConn1',
#  'WFAWLANConfig1',
#  'WiAutoConfig.1',
#  'WiFiSetup1',
#  'X_CIS',
#  'X_HtmlPage',
#  'X_IPcontrol',
#  'X_LG_WFDisplay',
#  'X_MS_MediaReceiverRegistrar',
#  'X_OrangeSTBRemoteControl',
#  'X_ServiceManager',
#  'X_TVersity_Metadata',
#  'X_Tandem',
#  'ZoneControl',
#  'ZoneGroupTopology',
#  'ZoneService',
#  'basicevent1',
#  'bridge1',
#  'cam_set',
#  'crockpotevent1',
#  'deviceevent1',
#  'deviceinfo1',
#  'dial',
#  'dial1-0',
#  'dummy1',
#  'ecp1-0',
#  'firmwareupdate1',
#  'insight1',
#  'ipccontrol1',
#  'jardenevent1',
#  'manufacture1',
#  'metainfo1',
#  'nascontrol1',
#  'p00NetworkControl',
#  'p00ProAVControlService',
#  'p01NetCamService1',
#  'print-1',
#  'remoteaccess1',
#  'rules1',
#  'smartsetup1',
#  'tidal',
#  'timesync1',
#  'tvcontrol1',
#  'tvpicture1',
#  'virtualSvc-0000-0001',
#  'webos-second-screen-3000-3001']

# %% [markdown]
# ## mdns_services col

# %%
services = []
for _, row in pd.concat([df_train, df_test], axis=0, sort=False).iterrows():
    if not isinstance(row['mdns_services'], list): continue
    for s in row['mdns_services']:
        if s not in services:
            services.append(s)
services.sort()
print(len(services))
pprint.pprint(services)
# Out:
# 445
# ['.',
#  '_13230._tcp.local.',
#  '_176562606B454C0._tcp.local.',
#  '_1password4._tcp.local.',
#  '_501SVC02VC0TPJ1GN._tcp.local.',
#  '_501SVC07SH21CG1HW._tcp.local.',
#  '_AcctsCfgSrvc._tcp.local.',
#  '_Astropad._tcp.local.',
#  '_CGI._tcp.local.',
#  '_DistantRouter_asy._tcp.local.',
#  '_ExtensisSN4._tcp.local.',
#  '_FullControlServer._tcp.local.',
#  '_HippoRemote._tcp.local.',
#  '_JB2XiOSApp._tcp.local.',
#  '_JBRemoteServer._tcp.local.',
#  '_JUDO-dp._tcp.local.',
#  '_JeppFDRouteXfr._tcp.local.',
#  '_KeynoteControl._tcp.local.',
#  '_LifeLineDevice._tcp.local.',
#  '_MacRCServer._tcp.local.',
#  '_Naim-Updater._tcp.local.',
#  '_OZOmniFocus2._udp.local.',
#  '_OZOmniFocus3._udp.local.',
#  '_PRO17MP2W._tcp.local.',
#  '_SSC02VC0TPJ1GN._tcp.local.',
#  '_SSC07SH21CG1HW._tcp.local.',
#  '_STVADevSettings._tcp.local.',
#  '_SVC02VC0TPJ1GN._tcp.local.',
#  '_SVC07SH21CG1HW._tcp.local.',
#  '_WECB_AEI._tcp.local.',
#  '_aastra-cfg._tcp.local.',
#  '_acdseems._tcp.local.',
#  '_acer._tcp.local.',
#  '_acestreamcast._tcp.local.',
#  '_aci._tcp.local.',
#  '_acp-sync._tcp.local.',
#  '_acrobatSRV._tcp.local.',
#  '_adb._tcp.local.',
#  '_adisk._tcp.local.',
#  '_adobe-vc._tcp.local.',
#  '_aether-chrono._udp.local.',
#  '_aether._tcp.local.',
#  '_afpovertcp._tcp.1062242935.members.btmm.icloud.com.',
#  '_afpovertcp._tcp.1098945996.members.btmm.icloud.com.',
#  '_afpovertcp._tcp.1317945497.members.btmm.icloud.com.',
#  '_afpovertcp._tcp.local.',
#  '_air-keynote._tcp.local.',
#  '_airdrop._tcp.local.',
#  '_airkan._tcp.local.',
#  '_airplay._tcp.local.',
#  '_airport._tcp.local.',
#  '_alljoyn._tcp.local.',
#  '_alljoyn._udp.local.',
#  '_amzn-wplay._tcp.local.',
#  '_androidtvremote._tcp.local.',
#  '_anymote._tcp.local.',
#  '_apple-demohub._tcp.local.',
#  '_apple-lgremote._tcp.local.',
#  '_apple-midi._udp.local.',
#  '_apple-mobdev._tcp.local.',
#  '_apple-mobdev2._tcp.local.',
#  '_apple-pairable._tcp.local.',
#  '_apple-sasl._tcp.local.',
#  '_appletv-v2._tcp.local.',
#  '_aptoide-rmtinst._tcp.local.',
#  '_arduino._tcp.local.',
#  '_arxcontrol._tcp.local.',
#  '_atc._tcp.1444892592.members.btmm.icloud.com.',
#  '_atc._tcp.609838663.members.btmm.icloud.com.',
#  '_atc._tcp.8043913666.members.btmm.icloud.com.',
#  '_atc._tcp.local.',
#  '_atualizador._tcp.local.',
#  '_audiobus._udp.local.',
#  '_automap3._tcp.local.',
#  '_awox-api._tcp.local.',
#  '_awox-zone._tcp.local.',
#  '_axis-nvr._tcp.local.',
#  '_axis-video._tcp.local.',
#  '_bittorrent-play._tcp.local.',
#  '_blackarmor1dconfig._tcp.local.',
#  '_blackarmor1dinfo._udp.local.',
#  '_blackarmor2dconfig._tcp.local.',
#  '_blackarmor2dinfo._udp.local.',
#  '_blackarmor4dconfig._tcp.local.',
#  '_blackarmor4dinfo._udp.local.',
#  '_blizzard._udp.local.',
#  '_boom2._tcp.local.',
#  '_boom3._tcp.local.',
#  '_bose-passport._tcp.local.',
#  '_bp2p._tcp.local.',
#  '_brocelgdb2._tcp.local.',
#  '_bttremote._tcp.local.',
#  '_c02lw6v_503._tcp.local.',
#  '_camera._tcp.local.',
#  '_canon-bjnp1._tcp.local.',
#  '_canon-chmp._tcp.local.',
#  '_canon-cpp-disc._udp.local.',
#  '_carplay-ctrl._tcp.local.',
#  '_channels_dvr._tcp.local.',
#  '_classroom._tcp.local.',
#  '_coap._udp.local.',
#  '_cogilog._tcp.local.',
#  '_communicator._tcp.local.',
#  '_companion-link._tcp.local.',
#  '_continuity._tcp.local.',
#  '_coremediamgr._tcp.local.',
#  '_coupon_printer._tcp.local.',
#  '_cros_p2p._tcp.local.',
#  '_csco-api._tcp.local.',
#  '_csco-sb._tcp.local.',
#  '_daap._tcp.local.',
#  '_dacp._tcp.local.',
#  '_dcamera._tcp.local.',
#  '_dcp._tcp.local.',
#  '_dedicarz-rest._tcp.local.',
#  '_dedicarz-rpc._tcp.local.',
#  '_dedicarz-ws._tcp.local.',
#  '_deploystudio._tcp.local.',
#  '_device-info._tcp.local.',
#  '_dhnap._tcp.local.',
#  '_digido._tcp.local.',
#  '_display._tcp.local.',
#  '_dlagent._tcp.local.',
#  '_e2esoft_ivcam._tcp.local.',
#  '_e2stream._tcp.local.',
#  '_easymigrate._tcp.local.',
#  '_echo._tcp.local.',
#  '_echo._udp.local.',
#  '_edcp._udp.local.',
#  '_enphase-envoy._tcp.local.',
#  '_eoscompanion._tcp.local.',
#  '_epoccam._tcp.local.',
#  '_eppc._tcp.local.',
#  '_esp_920569._tcp.local.',
#  '_esphomelib._tcp.local.',
#  '_ethbus._tcp.local.',
#  '_ethbus._udp.local.',
#  '_fax-ipp._tcp.local.',
#  '_fb._tcp.local.',
#  '_fbx-api._tcp.local.',
#  '_fbx-devel._tcp.local.',
#  '_firmware._tcp.local.',
#  '_fm-sfp-3008._tcp.local.',
#  '_fmpro-rcfmp12._tcp.local.',
#  '_frameo._tcp.local.',
#  '_freenas._tcp.local.',
#  '_ftm._tcp.local.',
#  '_ftp._tcp.local.',
#  '_fwcld._tcp.local.',
#  '_gamecenter._tcp.local.',
#  '_gasetup._udp.local.',
#  '_glyphs-eye._tcp.local.',
#  '_googlecast._tcp.local.',
#  '_googlerpc._tcp.local.',
#  '_googlezone._tcp.local.',
#  '_gva._tcp.local.',
#  '_hap._tcp.local.',
#  '_harman_002._tcp.local.',
#  '_hc._tcp.local.',
#  '_hearing._tcp.local.',
#  '_hekr._udp.local.',
#  '_hid._udp.local.',
#  '_holegamev140._tcp.local.',
#  '_home-sharing._tcp.local.',
#  '_home-wpp._tcp.local.',
#  '_homekit._tcp.local.',
#  '_hs-off._tcp.local.',
#  '_hs-vlcstream._tcp.local.',
#  '_http-alt._tcp.local.',
#  '_http._tcp.',
#  '_http._tcp.local.',
#  '_https._tcp.local.',
#  '_hudson._tcp.local.',
#  '_hue._tcp.local.',
#  '_iSyncr._tcp.local.',
#  '_ica-networking._tcp.local.',
#  '_icc-service._tcp.local.',
#  '_ieee1588._udp.local.',
#  '_impressremote._tcp.local.',
#  '_instantshare._tcp.local.',
#  '_iphone_photo._tcp.local.',
#  '_ipp-tls._tcp.local.',
#  '_ipp._tcp.1502567871.members.btmm.icloud.com.',
#  '_ipp._tcp.local.',
#  '_ipps._tcp.1502567871.members.btmm.icloud.com.',
#  '_ipps._tcp.local.',
#  '_ipro-paskal._tcp.local.',
#  '_ips_beacon._tcp.local.',
#  '_iri._tcp.local.',
#  '_istatserv._tcp.local.',
#  '_istatserver._tcp.local.',
#  '_iuuml3qu1uslan._udp.local.',
#  '_jargon._tcp.local.',
#  '_jenkins._tcp.local.',
#  '_keepalive._dns-sd._udp.local.',
#  '_ktcp-remote._tcp.local.',
#  '_lanrevagent._tcp.local.',
#  '_lap._tcp.local.',
#  '_ldap._tcp.local.',
#  '_leap._tcp.local.',
#  '_leboremote._tcp.local.',
#  '_lg_bd_remote._tcp.local.',
#  '_lg_dtv_wifirc._tcp.local.',
#  '_link411._udp.local.',
#  '_livestream._tcp.local.',
#  '_lutron._tcp.local.',
#  '_makerbot-jsonrpc._tcp.local.',
#  '_mamp._tcp.local.',
#  '_mdns._udp.local.',
#  '_mediaremotetv._tcp.local.',
#  '_mfi-config._tcp.local.',
#  '_middleware._tcp.local.',
#  '_migo._tcp.local.',
#  '_miio._udp.local.',
#  '_modo7sp3lansrv._tcp.local.',
#  '_mosaicremote._tcp.local.',
#  '_mpd._tcp.local.',
#  '_mqtt._tcp.local.',
#  '_musc._tcp.local.',
#  '_mwg-cc._tcp.local.',
#  '_mycanal._tcp.local.',
#  '_myq._tcp.local.',
#  '_mywifiext._tcp.local.',
#  '_naim-updater._tcp.local.',
#  '_nanoleafapi._tcp.local.',
#  '_nanoleafms._tcp.local.',
#  '_nd14._tcp.local.',
#  '_ndi._tcp.local.',
#  '_net-assistant._udp.1098945996.members.btmm.icloud.com.',
#  '_net-assistant._udp.8142242044.members.btmm.icloud.com.',
#  '_net-assistant._udp.local.',
#  '_netaudio-arc._udp.local.',
#  '_netaudio-chan._udp.local.',
#  '_netaudio-cmc._udp.local.',
#  '_netaudio-dbc._udp.local.',
#  '_netbios-ns._tcp.local.',
#  '_nfs._tcp.local.',
#  '_ni-logos._tcp.local.',
#  '_nipca._tcp.local.',
#  '_nokia-home._tcp.local.',
#  '_nssocketport._tcp.local.',
#  '_nut._tcp.local.',
#  '_nuvomaster._tcp.local.',
#  '_nuvoplayer._tcp.local.',
#  '_nv_shield_remote._tcp.local.',
#  '_nvstream._tcp.local.',
#  '_nvstream_dbd._tcp.local.',
#  '_nvstream_nv._tcp.local.',
#  '_oculusmedia._tcp.local.',
#  '_od-master._tcp.local.',
#  '_odisk._tcp.local.',
#  '_odproxy._tcp.local.',
#  '_omnistate._tcp.local.',
#  '_omsg._tcp.local.',
#  '_onsongapp._tcp.local.',
#  '_opcua-tcp._tcp.local.',
#  '_openhab-server-ssl._tcp.local.',
#  '_openhab-server._tcp.local.',
#  '_osc._udp.local.',
#  '_osxsvr._tcp.local.',
#  '_panopto_upload._tcp.local.',
#  '_parentcontrol._tcp.local.',
#  '_pblipc._tcp.local.',
#  '_pdl-datastream._tcp.local.',
#  '_philipstv_rpc._tcp.local.',
#  '_philipstv_s_rpc._tcp.local.',
#  '_photoshopserver._tcp.local.',
#  '_planet-video._tcp.local.',
#  '_playmate._tcp.local.',
#  '_plexmediasvr._tcp.local.',
#  '_powerview._tcp.local.',
#  '_pres_sdo._tcp.local.',
#  '_presence._tcp.local.',
#  '_print-caps._tcp.local.',
#  '_printer._tcp.local.',
#  '_privet._tcp.local.',
#  '_pro4_sd._tcp.local.',
#  '_pro6masterctl._tcp.local.',
#  '_pro6proremote._tcp.local.',
#  '_pro6slidexml._tcp.local.',
#  '_pro6stagedsply._tcp.local.',
#  '_propresenter6._tcp.local.',
#  '_psia._tcp.local.',
#  '_ptService._tcp.local.',
#  '_ptax._tcp.local.',
#  '_ptp-init._tcp.local.',
#  '_qboxcluster._tcp.local.',
#  '_qdiscover._tcp.local.',
#  '_qlab._tcp.local.',
#  '_qlab._udp.local.',
#  '_qmobile._tcp.local.',
#  '_qmp4._tcp.local.',
#  '_r1873A3FD67B3._tcp.local.',
#  '_raop._tcp.local.',
#  '_rc._tcp.local.',
#  '_rdhandoff0DDCB9EE-65CC-468C-87DB-87AE40A892D0._tcp.local.',
#  '_rdhandoff126DD885-2C18-4D66-B1C1-95B674C2587A._tcp.local.',
#  '_rdhandoff18BAC05C-A4F9-4AF2-896D-21CFC06874AB._tcp.local.',
#  '_rdhandoff198B6527-43EE-4C4C-9607-1889334A577F._tcp.local.',
#  '_rdhandoff2085E310-D05D-4886-9864-AD330E9D1A0E._tcp.local.',
#  '_rdhandoff3674D2DB-CD9F-4CEB-96B7-CE936293DFF6._tcp.local.',
#  '_rdhandoff496F2C75-1EEC-4CCA-B45A-4910E230895C._tcp.local.',
#  '_rdhandoff65AE8DB8-DF3C-4723-8FE7-073C3C351165._tcp.local.',
#  '_rdhandoff67F2E5E4-275D-4593-A4D4-EA979D274993._tcp.local.',
#  '_rdhandoff6A8C8AA8-610F-4269-813A-A676272C36A6._tcp.local.',
#  '_rdhandoff79B7E065-C936-478B-840E-E18747AFCC2C._tcp.local.',
#  '_rdhandoffAC8EFDDE-A8BF-42C8-9646-5C6BBC1D6D9D._tcp.local.',
#  '_rdhandoffC5F7502E-1068-4118-B8C6-FD1871EABE3E._tcp.local.',
#  '_rdhandoffC748091C-6975-4013-B6F8-0E92CD1C81F0._tcp.local.',
#  '_rdhandoffD25D0511-BB23-4804-97A2-CBA96EDC45FB._tcp.local.',
#  '_rdhandoffD81EDA71-743E-4390-B736-E90C47E1D6DC._tcp.local.',
#  '_rdhandoffE4F4E3C2-DCC4-415A-8745-7994394AC92C._tcp.local.',
#  '_rdhandoffE73B3704-45BA-48E4-B5A8-22D3EBDBCD3C._tcp.local.',
#  '_rdlink._tcp.local.',
#  '_rdprint._tcp.local.',
#  '_readydr._tcp.local.',
#  '_readynas._tcp.local.',
#  '_readynasphotos._tcp.local.',
#  '_rfb._tcp.1098945996.members.btmm.icloud.com.',
#  '_rfb._tcp.1317945497.members.btmm.icloud.com.',
#  '_rfb._tcp.1954166988.members.btmm.icloud.com.',
#  '_rfb._tcp.445862625.members.btmm.icloud.com.',
#  '_rfb._tcp.8142242044.members.btmm.icloud.com.',
#  '_rfb._tcp.local.',
#  '_roku-rcp._tcp.local.',
#  '_ros-master._tcp.local.',
#  '_rowmote._tcp.local.',
#  '_rp-hsd._tcp.local.',
#  '_rp-media._tcp.local.',
#  '_rpmRsync_Maiost_sdo._tcp.local.',
#  '_rpmRsync_Scotem_sdo._tcp.local.',
#  '_rsp._tcp.local.',
#  '_rsync._tcp.local.',
#  '_rtsp._tcp.local.',
#  '_rubisyscenter._tcp.local.',
#  '_ruckus-unleashed._tcp.local.',
#  '_ruckus-zd._tcp.local.',
#  '_runestone._udp.local.',
#  '_rvpro6ap._tcp.local.',
#  '_samsungmsf._tcp.local.',
#  '_satellite_info._tcp.local.',
#  '_scan-target._tcp.1305028907.members.btmm.icloud.com.',
#  '_scan-target._tcp.local.',
#  '_scanner._tcp.local.',
#  '_secure_aci._tcp.local.',
#  '_secure_firmware._tcp.local.',
#  '_secure_hc._tcp.local.',
#  '_servermgr._tcp.local.',
#  '_sftp-ssh._tcp.1098945996.members.btmm.icloud.com.',
#  '_sftp-ssh._tcp.local.',
#  '_sftp._tcp.local.',
#  '_silhouettelink._tcp.local.',
#  '_sip._udp.local.',
#  '_sironaxray._tcp.local.',
#  '_sleep-proxy._udp.local.',
#  '_sleepcycle_ald._tcp.local.',
#  '_slipstreamrem._tcp.local.',
#  '_smart._tcp.local.',
#  '_smb._tcp.1062242935.members.btmm.icloud.com.',
#  '_smb._tcp.1317945497.members.btmm.icloud.com.',
#  '_smb._tcp.8142242044.members.btmm.icloud.com.',
#  '_smb._tcp.local.',
#  '_snosirix._tcp.local.',
#  '_snsf_Maiost_ssp._udp.local.',
#  '_snsf_Scotem_ssp._udp.local.',
#  '_soundhound._tcp.local.',
#  '_soundtouch._tcp.local.',
#  '_sovi-mfg._tcp.local.',
#  '_spotify-connect._tcp.local.',
#  '_ssh._tcp.1098945996.members.btmm.icloud.com.',
#  '_ssh._tcp.local.',
#  '_ssr_Maiost_ssp._udp.local.',
#  '_ssr_Scotem_ssp._udp.local.',
#  '_ssw._tcp.local.',
#  '_stNT_Maiost_ssp._udp.local.',
#  '_stNT_Scotem_ssp._udp.local.',
#  '_stmg_Maiost_ssp._udp.local.',
#  '_stmg_Scotem_ssp._udp.local.',
#  '_stream-magic._tcp.local.',
#  '_sub._apple-mobdev2._tcp.local.',
#  '_sueGrouping._tcp.local.',
#  '_sueS800Device._tcp.local.',
#  '_suegrouping._tcp.local.',
#  '_supersync._tcp.local.',
#  '_svnp._tcp.local.',
#  '_syncmate._tcp.local.',
#  '_tdrsservice._tcp.local.',
#  '_tdrsservices._tcp.local.',
#  '_teamviewer._tcp.local.',
#  '_tellybean-launch._tcp.local.',
#  '_telnet._tcp.local.',
#  '_terA_Maiost_asy._tcp.local.',
#  '_terA_Scotem_asy._tcp.local.',
#  '_tftp._udp.local.',
#  '_tivo-device._tcp.local.',
#  '_tivo-mindrpc._tcp.local.',
#  '_tivo-music._tcp.local.',
#  '_tivo-photos._tcp.local.',
#  '_tivo-remote._tcp.local.',
#  '_tivo-videos._tcp.local.',
#  '_tivo-videostream._tcp.local.',
#  '_tivo-xcode._tcp.local.',
#  '_tivo_servemedia._tcp.local.',
#  '_tnp-hub._tcp.local.',
#  '_touch-able._tcp.local.',
#  '_touch-remote._tcp.local.',
#  '_transmissionserver._tcp.local.',
#  '_tunnel._tcp.local.',
#  '_tw-multipeer._tcp.local.',
#  '_uamixer._tcp.local.',
#  '_udisks-ssh._tcp.local.',
#  '_uis_Maiost_ssp._udp.local.',
#  '_uis_Scotem_ssp._udp.local.',
#  '_undok._tcp.local.',
#  '_upnp._tcp.local.',
#  '_uscan._tcp.local.',
#  '_uscans._tcp.local.',
#  '_vhusb._tcp.local.',
#  '_video._tcp.local.',
#  '_vigreen._tcp.local.',
#  '_viziocast._tcp.local.',
#  '_voucher_com_udemy_tv-auth._tcp.local.',
#  '_wcwds._tcp.local.',
#  '_wd-2go._tcp.local.',
#  '_wd-tv-webremote._tcp.local.',
#  '_wdtv-webremote._tcp.local.',
#  '_webdav._tcp.local.',
#  '_webdavs._tcp.local.',
#  '_whatsup._tcp.local.',
#  '_wifisend._tcp.local.',
#  '_withings-aura-bridge._tcp.local.',
#  '_withings-aura._tcp.local.',
#  '_withings-home._tcp.local.',
#  '_withings-sbm._tcp.local.',
#  '_workstation._tcp.local.',
#  '_ws._tcp.local.',
#  '_xbmc-events._udp.local.',
#  '_xbmc-jsonrpc-h._tcp.local.',
#  '_xbmc-jsonrpc._tcp.local.',
#  '_xboxcol._tcp.local.',
#  '_xmind._tcp.local.',
#  '_xrdovertcp._tcp.local.',
#  '_yv-bridge._tcp.local.',
#  '_zound._tcp.local.',
#  'local.']

# %% [markdown]
# We will need to put similar name companies into one.

# %% [markdown]
# ## dhcp col

# %%
dhcps = []
for _, row in pd.concat([df_train, df_test], axis=0, sort=False).iterrows():
    if not isinstance(row['dhcp'], list) or 'paramlist' not in row['dhcp'][0]: continue
    for p in row['dhcp']:
        for n in p['paramlist'].split(','):
            if n not in dhcps:
                dhcps.append(n)
dhcps = list(map(lambda x: 'p' + x, dhcps))
dhcps.sort()
print(len(dhcps))
pprint.pprint(dhcps)
# Out:
# 108
# ['p1',
#  'p10',
#  'p100',
#  'p101',
#  'p11',
#  'p119',
#  'p12',
#  'p120',
#  'p121',
#  'p125',
#  'p128',
#  'p129',
#  'p13',
#  'p130',
#  'p131',
#  'p132',
#  'p133',
#  'p134',
#  'p135',
#  'p14',
#  'p142',
#  'p143',
#  'p144',
#  'p15',
#  'p150',
#  'p151',
#  'p153',
#  'p154',
#  'p156',
#  'p157',
#  'p159',
#  'p16',
#  'p160',
#  'p161',
#  'p17',
#  'p170',
#  'p18',
#  'p19',
#  'p190',
#  'p191',
#  'p2',
#  'p20',
#  'p204',
#  'p21',
#  'p22',
#  'p23',
#  'p24',
#  'p244',
#  'p245',
#  'p249',
#  'p25',
#  'p252',
#  'p255',
#  'p26',
#  'p27',
#  'p28',
#  'p29',
#  'p3',
#  'p30',
#  'p31',
#  'p32',
#  'p33',
#  'p34',
#  'p35',
#  'p36',
#  'p37',
#  'p38',
#  'p39',
#  'p4',
#  'p40',
#  'p41',
#  'p42',
#  'p43',
#  'p44',
#  'p45',
#  'p46',
#  'p47',
#  'p48',
#  'p49',
#  'p5',
#  'p50',
#  'p51',
#  'p52',
#  'p53',
#  'p54',
#  'p55',
#  'p56',
#  'p57',
#  'p58',
#  'p59',
#  'p6',
#  'p60',
#  'p61',
#  'p66',
#  'p67',
#  'p69',
#  'p7',
#  'p70',
#  'p72',
#  'p78',
#  'p79',
#  'p8',
#  'p81',
#  'p88',
#  'p9',
#  'p95',
#  'p97',
#  'p99']

# %% [markdown]
# ## First half of MAC (HW manufacturer)

# %%
def get_mac(mac):
    return mac[:8]

macs = []
for _, row in pd.concat([df_train, df_test], axis=0, sort=False).iterrows():
    m = get_mac(row['mac'])
    if m not in macs:
        macs.append(m)
macs.sort()
print(len(macs))
pprint.pprint(macs)
# Out:
# 2890
# ['00:00:00',
#  '00:00:48',
#  '00:00:74',
#  '00:00:85',
#  '00:00:aa',
#  '00:00:c0',
#  '00:00:f0',
#  '00:01:db',
#  '00:01:e6',
#  '00:02:9b',
#  '00:02:fd',
#  '00:04:00',
#  '00:04:4b',
#  '00:04:f2',
#  '00:05:cd',
#  '00:06:78',
#  '00:07:25',
#  '00:08:02',
#  '00:08:5d',
#  '00:08:9b',
#  '00:09:b0',
#  '00:09:df',
#  '00:0a:eb',
#  '00:0c:76',
#  '00:0c:8a',
#  '00:0d:4b',
#  '00:0d:88',
#  '00:0e:2e',
#  '00:0e:58',
#  '00:0e:7f',
#  '00:0f:ea',
#  '00:10:19',
#  '00:10:75',
#  '00:10:c6',
#  '00:11:09',
#  '00:11:0a',
#  '00:11:24',
#  '00:11:2f',
#  '00:11:32',
#  '00:11:43',
#  '00:11:5b',
#  '00:11:a9',
#  '00:11:f6',
#  '00:12:3f',
#  '00:12:ab',
#  '00:12:fb',
#  '00:13:02',
#  '00:13:20',
#  '00:13:21',
#  '00:13:46',
#  '00:13:72',
#  '00:13:77',
#  '00:13:8f',
#  '00:13:d3',
#  '00:13:e8',
#  '00:14:22',
#  '00:14:2a',
#  '00:14:38',
#  '00:14:51',
#  '00:14:78',
#  '00:14:85',
#  '00:14:c2',
#  '00:14:d1',
#  '00:14:ee',
#  '00:14:fd',
#  '00:15:00',
#  '00:15:0d',
#  '00:15:17',
#  '00:15:5d',
#  '00:15:60',
#  '00:15:65',
#  '00:15:94',
#  '00:15:99',
#  '00:15:af',
#  '00:15:c5',
#  '00:15:f2',
#  '00:16:17',
#  '00:16:41',
#  '00:16:6f',
#  '00:16:76',
#  '00:16:cb',
#  '00:16:ce',
#  '00:16:cf',
#  '00:16:e6',
#  '00:16:ea',
#  '00:16:eb',
#  '00:16:ec',
#  '00:17:08',
#  '00:17:31',
#  '00:17:88',
#  '00:17:a4',
#  '00:17:c8',
#  '00:17:f2',
#  '00:18:4d',
#  '00:18:71',
#  '00:18:8b',
#  '00:18:de',
#  '00:18:f3',
#  '00:18:fe',
#  '00:19:1d',
#  '00:19:21',
#  '00:19:66',
#  '00:19:7d',
#  '00:19:7e',
#  '00:19:99',
#  '00:19:b9',
#  '00:19:bb',
#  '00:19:c5',
#  '00:19:d1',
#  '00:19:d2',
#  '00:19:db',
#  '00:19:e0',
#  '00:1a:4b',
#  '00:1a:4d',
#  '00:1a:6b',
#  '00:1a:92',
#  '00:1a:a0',
#  '00:1b:21',
#  '00:1b:38',
#  '00:1b:63',
#  '00:1b:77',
#  '00:1b:78',
#  '00:1b:9e',
#  '00:1b:a9',
#  '00:1b:b9',
#  '00:1b:ea',
#  '00:1b:fc',
#  '00:1b:fe',
#  '00:1c:23',
#  '00:1c:25',
#  '00:1c:26',
#  '00:1c:be',
#  '00:1c:bf',
#  '00:1c:c0',
#  '00:1c:c4',
#  '00:1c:ee',
#  '00:1c:f0',
#  '00:1d:09',
#  '00:1d:0d',
#  '00:1d:0f',
#  '00:1d:4f',
#  '00:1d:60',
#  '00:1d:72',
#  '00:1d:7d',
#  '00:1d:92',
#  '00:1d:ba',
#  '00:1d:d8',
#  '00:1d:d9',
#  '00:1d:e0',
#  '00:1e:0b',
#  '00:1e:2a',
#  '00:1e:35',
#  '00:1e:37',
#  '00:1e:4f',
#  '00:1e:58',
#  '00:1e:64',
#  '00:1e:65',
#  '00:1e:67',
#  '00:1e:8c',
#  '00:1e:8f',
#  '00:1e:90',
#  '00:1e:b2',
#  '00:1e:c2',
#  '00:1e:c9',
#  '00:1e:ec',
#  '00:1f:16',
#  '00:1f:1f',
#  '00:1f:29',
#  '00:1f:32',
#  '00:1f:33',
#  '00:1f:3a',
#  '00:1f:3b',
#  '00:1f:3c',
#  '00:1f:5b',
#  '00:1f:a7',
#  '00:1f:c5',
#  '00:1f:c6',
#  '00:1f:d0',
#  '00:1f:e1',
#  '00:1f:e2',
#  '00:1f:f0',
#  '00:20:00',
#  '00:20:6b',
#  '00:21:19',
#  '00:21:27',
#  '00:21:47',
#  '00:21:5a',
#  '00:21:5c',
#  '00:21:5d',
#  '00:21:63',
#  '00:21:6a',
#  '00:21:6b',
#  '00:21:70',
#  '00:21:85',
#  '00:21:86',
#  '00:21:91',
#  '00:21:97',
#  '00:21:9b',
#  '00:21:b7',
#  '00:21:bd',
#  '00:21:c7',
#  '00:22:15',
#  '00:22:19',
#  '00:22:3f',
#  '00:22:41',
#  '00:22:43',
#  '00:22:48',
#  '00:22:4c',
#  '00:22:58',
#  '00:22:5f',
#  '00:22:61',
#  '00:22:64',
#  '00:22:68',
#  '00:22:69',
#  '00:22:75',
#  '00:22:aa',
#  '00:22:b0',
#  '00:22:c0',
#  '00:22:d7',
#  '00:22:f3',
#  '00:22:fa',
#  '00:22:fb',
#  '00:23:14',
#  '00:23:15',
#  '00:23:31',
#  '00:23:32',
#  '00:23:48',
#  '00:23:4d',
#  '00:23:4e',
#  '00:23:54',
#  '00:23:5a',
#  '00:23:6c',
#  '00:23:7d',
#  '00:23:ae',
#  '00:23:cd',
#  '00:23:df',
#  '00:24:1d',
#  '00:24:1e',
#  '00:24:21',
#  '00:24:23',
#  '00:24:2b',
#  '00:24:2c',
#  '00:24:36',
#  '00:24:44',
#  '00:24:54',
#  '00:24:7e',
#  '00:24:81',
#  '00:24:8c',
#  '00:24:8d',
#  '00:24:b2',
#  '00:24:be',
#  '00:24:d2',
#  '00:24:d4',
#  '00:24:d6',
#  '00:24:d7',
#  '00:24:e4',
#  '00:24:e8',
#  '00:24:f3',
#  '00:25:00',
#  '00:25:11',
#  '00:25:22',
#  '00:25:36',
#  '00:25:4b',
#  '00:25:56',
#  '00:25:64',
#  '00:25:69',
#  '00:25:86',
#  '00:25:ab',
#  '00:25:ae',
#  '00:25:b3',
#  '00:25:d3',
#  '00:25:ed',
#  '00:26:08',
#  '00:26:18',
#  '00:26:22',
#  '00:26:2d',
#  '00:26:4a',
#  '00:26:55',
#  '00:26:59',
#  '00:26:5a',
#  '00:26:5e',
#  '00:26:73',
#  '00:26:82',
#  '00:26:91',
#  '00:26:ab',
#  '00:26:b0',
#  '00:26:b6',
#  '00:26:b9',
#  '00:26:bb',
#  '00:26:c6',
#  '00:26:c7',
#  '00:26:f2',
#  '00:27:09',
#  '00:27:0e',
#  '00:27:10',
#  '00:27:13',
#  '00:27:19',
#  '00:28:f8',
#  '00:30:67',
#  '00:34:da',
#  '00:37:b7',
#  '00:3d:e8',
#  '00:3e:e1',
#  '00:40:48',
#  '00:40:8c',
#  '00:50:aa',
#  '00:51:ed',
#  '00:55:da',
#  '00:56:cd',
#  '00:57:c1',
#  '00:5a:13',
#  '00:60:6e',
#  '00:6d:52',
#  '00:71:47',
#  '00:71:c2',
#  '00:71:cc',
#  '00:78:9e',
#  '00:7e:56',
#  '00:80:77',
#  '00:80:91',
#  '00:80:f0',
#  '00:87:01',
#  '00:88:65',
#  '00:90:a9',
#  '00:95:69',
#  '00:9a:d2',
#  '00:9c:02',
#  '00:9d:6b',
#  '00:a0:96',
#  '00:a0:de',
#  '00:a2:89',
#  '00:ae:fa',
#  '00:b3:62',
#  '00:b5:d0',
#  '00:bb:3a',
#  '00:bb:60',
#  '00:bb:c1',
#  '00:be:3b',
#  '00:c0:ee',
#  '00:c2:c6',
#  '00:c3:f4',
#  '00:cc:fc',
#  '00:cd:fe',
#  '00:d0:2d',
#  '00:d0:4b',
#  '00:d8:61',
#  '00:d9:d1',
#  '00:da:55',
#  '00:db:70',
#  '00:db:df',
#  '00:e0:4c',
#  '00:e0:91',
#  '00:e1:8c',
#  '00:e3:b2',
#  '00:ec:0a',
#  '00:f4:8d',
#  '00:f7:6f',
#  '00:f8:1c',
#  '00:fc:8b',
#  '02:0f:b5',
#  '02:25:00',
#  '02:26:bb',
#  '04:02:1f',
#  '04:03:d6',
#  '04:0c:ce',
#  '04:15:52',
#  '04:1b:6d',
#  '04:1e:64',
#  '04:20:9a',
#  '04:4e:5a',
#  '04:4e:af',
#  '04:4f:4c',
#  '04:52:c7',
#  '04:52:f3',
#  '04:54:53',
#  '04:5d:4b',
#  '04:69:f8',
#  '04:79:70',
#  '04:92:26',
#  '04:a1:51',
#  '04:b1:67',
#  '04:d1:3a',
#  '04:d3:b0',
#  '04:d4:c4',
#  '04:d6:aa',
#  '04:db:56',
#  '04:e5:36',
#  '04:f7:e4',
#  '06:d6:aa',
#  '08:00:37',
#  '08:02:8e',
#  '08:05:81',
#  '08:11:96',
#  '08:21:ef',
#  '08:23:b2',
#  '08:2e:5f',
#  '08:3e:5d',
#  '08:3e:8e',
#  '08:57:00',
#  '08:60:6e',
#  '08:62:66',
#  '08:6d:41',
#  '08:74:02',
#  '08:78:08',
#  '08:86:3b',
#  '08:9e:08',
#  '08:ba:5f',
#  '08:bd:43',
#  '08:c5:e1',
#  '08:d0:b7',
#  '08:d4:0c',
#  '08:d4:6a',
#  '08:d5:9d',
#  '08:d8:33',
#  '08:df:1f',
#  '08:e6:89',
#  '08:ea:40',
#  '08:ec:a9',
#  '08:ed:b9',
#  '08:f6:9c',
#  '0a:c5:e1',
#  '0c:1d:af',
#  '0c:2c:54',
#  '0c:3e:9f',
#  '0c:47:c9',
#  '0c:48:85',
#  '0c:4b:54',
#  '0c:4d:e9',
#  '0c:51:01',
#  '0c:54:15',
#  '0c:54:a5',
#  '0c:60:76',
#  '0c:62:a6',
#  '0c:70:4a',
#  '0c:77:1a',
#  '0c:80:63',
#  '0c:82:68',
#  '0c:84:dc',
#  '0c:89:10',
#  '0c:8b:fd',
#  '0c:8c:24',
#  '0c:8f:ff',
#  '0c:98:38',
#  '0c:9d:92',
#  '0c:a8:a7',
#  '0c:b3:19',
#  '0c:b6:d2',
#  '0c:cb:85',
#  '0c:d2:92',
#  '0c:d6:bd',
#  '0c:d7:46',
#  '0c:e0:dc',
#  '0c:ee:e6',
#  '0c:f3:46',
#  '0c:fe:45',
#  '0e:80:63',
#  '10:02:b5',
#  '10:05:01',
#  '10:05:b1',
#  '10:07:b6',
#  '10:08:b1',
#  '10:0b:a9',
#  '10:0d:7f',
#  '10:1c:0c',
#  '10:1f:74',
#  '10:2a:b3',
#  '10:40:f3',
#  '10:44:00',
#  '10:4a:7d',
#  '10:4f:a8',
#  '10:60:4b',
#  '10:62:e5',
#  '10:62:eb',
#  '10:65:30',
#  '10:77:b1',
#  '10:78:d2',
#  '10:7b:44',
#  '10:7d:1a',
#  '10:8e:e0',
#  '10:92:66',
#  '10:93:e9',
#  '10:94:bb',
#  '10:98:36',
#  '10:98:c3',
#  '10:9a:dd',
#  '10:a4:be',
#  '10:ae:60',
#  '10:b1:f8',
#  '10:bd:18',
#  '10:be:f5',
#  '10:bf:48',
#  '10:c3:7b',
#  '10:d3:8a',
#  '10:da:43',
#  '10:dd:b1',
#  '10:e7:c6',
#  '10:f0:05',
#  '10:f1:f2',
#  '10:fe:ed',
#  '14:0c:76',
#  '14:10:9f',
#  '14:18:77',
#  '14:1f:78',
#  '14:20:5e',
#  '14:2d:27',
#  '14:2f:fd',
#  '14:32:d1',
#  '14:49:e0',
#  '14:4f:8a',
#  '14:56:8e',
#  '14:58:d0',
#  '14:59:c0',
#  '14:5f:94',
#  '14:6b:9c',
#  '14:91:82',
#  '14:96:e5',
#  '14:99:e2',
#  '14:9d:09',
#  '14:9f:3c',
#  '14:a3:64',
#  '14:a5:1a',
#  '14:ab:c5',
#  '14:b3:1f',
#  '14:bb:6e',
#  '14:c2:13',
#  '14:c6:97',
#  '14:c9:13',
#  '14:cc:20',
#  '14:d1:1f',
#  '14:d1:69',
#  '14:d6:4d',
#  '14:da:e9',
#  '14:dd:a9',
#  '14:fe:b5',
#  '16:91:82',
#  '16:cc:20',
#  '18:03:73',
#  '18:0c:ac',
#  '18:0f:76',
#  '18:1d:ea',
#  '18:1e:78',
#  '18:20:32',
#  '18:21:95',
#  '18:2a:7b',
#  '18:31:bf',
#  '18:3a:2d',
#  '18:3d:a2',
#  '18:4f:32',
#  '18:56:80',
#  '18:5e:0f',
#  '18:60:24',
#  '18:62:2c',
#  '18:65:90',
#  '18:66:da',
#  '18:67:b0',
#  '18:68:cb',
#  '18:74:2e',
#  '18:81:0e',
#  '18:83:bf',
#  '18:89:5b',
#  '18:8b:45',
#  '18:8e:d5',
#  '18:90:d8',
#  '18:9c:27',
#  '18:a6:f7',
#  '18:a9:05',
#  '18:a9:9b',
#  '18:b8:1f',
#  '18:cf:5e',
#  '18:d2:76',
#  '18:d6:c7',
#  '18:d7:17',
#  '18:db:f2',
#  '18:e2:9f',
#  '18:ee:69',
#  '18:f0:e4',
#  '18:f1:d8',
#  '18:f4:6a',
#  '18:f6:43',
#  '18:fb:7b',
#  '18:fe:34',
#  '1a:83:bf',
#  '1a:a6:f7',
#  '1a:d6:c7',
#  '1a:f1:d8',
#  '1c:12:b0',
#  '1c:15:1f',
#  '1c:1b:0d',
#  '1c:1b:68',
#  '1c:1b:b5',
#  '1c:1e:e3',
#  '1c:23:2c',
#  '1c:36:bb',
#  '1c:39:47',
#  '1c:3e:84',
#  '1c:42:7d',
#  '1c:4b:d6',
#  '1c:4d:70',
#  '1c:5a:3e',
#  '1c:5a:6b',
#  '1c:5f:2b',
#  '1c:65:9d',
#  '1c:66:6d',
#  '1c:67:58',
#  '1c:6f:65',
#  '1c:74:0d',
#  '1c:75:08',
#  '1c:7b:23',
#  '1c:7e:e5',
#  '1c:87:2c',
#  '1c:91:48',
#  '1c:9e:46',
#  '1c:a5:32',
#  '1c:ab:a7',
#  '1c:af:f7',
#  '1c:b7:2c',
#  '1c:bd:b9',
#  '1c:c1:de',
#  '1c:c6:3c',
#  '1c:da:27',
#  '1c:df:0f',
#  '1c:e6:2b',
#  '1c:f2:9a',
#  '20:04:0f',
#  '20:0c:c8',
#  '20:10:7a',
#  '20:16:b9',
#  '20:16:d8',
#  '20:1a:06',
#  '20:25:64',
#  '20:2d:07',
#  '20:3c:ae',
#  '20:3d:66',
#  '20:3d:bd',
#  '20:47:47',
#  '20:47:da',
#  '20:4e:7f',
#  '20:54:fa',
#  '20:55:31',
#  '20:5e:f7',
#  '20:68:9d',
#  '20:78:f0',
#  '20:79:18',
#  '20:7d:74',
#  '20:82:c0',
#  '20:89:84',
#  '20:a6:0c',
#  '20:ab:37',
#  '20:c6:eb',
#  '20:c9:d0',
#  '20:cf:30',
#  '20:df:b9',
#  '20:e5:2a',
#  '20:e5:64',
#  '20:ee:28',
#  '20:f1:9e',
#  '20:f4:1b',
#  '20:f5:43',
#  '20:f7:7c',
#  '22:3c:ae',
#  '22:78:f0',
#  '22:a2:e4',
#  '22:df:b9',
#  '22:ee:28',
#  '22:f7:7c',
#  '24:00:ba',
#  '24:0a:64',
#  '24:0a:c4',
#  '24:18:1d',
#  '24:1b:7a',
#  '24:20:c7',
#  '24:24:0e',
#  '24:26:42',
#  '24:2e:02',
#  '24:31:84',
#  '24:4b:03',
#  '24:4b:81',
#  '24:4c:e3',
#  '24:5b:a7',
#  '24:5e:be',
#  '24:69:a5',
#  '24:77:03',
#  '24:7f:20',
#  '24:92:0e',
#  '24:a0:74',
#  '24:a2:e1',
#  '24:b6:fd',
#  '24:be:05',
#  '24:df:6a',
#  '24:ec:99',
#  '24:f0:94',
#  '24:f5:a2',
#  '24:f5:aa',
#  '24:f6:77',
#  '24:fd:52',
#  '26:1b:7a',
#  '26:a2:e1',
#  '26:ab:81',
#  '26:da:9b',
#  '26:f0:94',
#  '26:f5:a2',
#  '28:0d:fc',
#  '28:10:7b',
#  '28:11:a5',
#  '28:16:a8',
#  '28:16:ad',
#  '28:18:78',
#  '28:24:ff',
#  '28:27:bf',
#  '28:31:66',
#  '28:37:37',
#  '28:39:5e',
#  '28:3b:82',
#  '28:56:5a',
#  '28:57:be',
#  '28:5a:eb',
#  '28:66:e3',
#  '28:6a:ba',
#  '28:6d:97',
#  '28:80:23',
#  '28:83:35',
#  '28:84:fa',
#  '28:92:4a',
#  '28:9e:fc',
#  '28:a0:2b',
#  '28:ad:3e',
#  '28:b2:bd',
#  '28:c1:3c',
#  '28:c2:dd',
#  '28:c6:3f',
#  '28:c6:8e',
#  '28:cf:da',
#  '28:cf:e9',
#  '28:e3:47',
#  '28:ed:6a',
#  '28:f0:76',
#  '28:f1:0e',
#  '28:f3:66',
#  '28:fa:a0',
#  '28:ff:3c',
#  '2a:10:7b',
#  '2a:a0:2b',
#  '2a:ed:6a',
#  '2a:f0:76',
#  '2a:ff:3c',
#  '2c:0e:3d',
#  '2c:10:c1',
#  '2c:1d:b8',
#  '2c:1f:23',
#  '2c:27:d7',
#  '2c:2b:f9',
#  '2c:30:33',
#  '2c:33:61',
#  '2c:33:7a',
#  '2c:39:96',
#  '2c:3a:e8',
#  '2c:41:38',
#  '2c:44:fd',
#  '2c:4d:54',
#  '2c:54:91',
#  '2c:54:cf',
#  '2c:56:dc',
#  '2c:58:4f',
#  '2c:59:8a',
#  '2c:59:e5',
#  '2c:61:f6',
#  '2c:6e:85',
#  '2c:6f:c9',
#  '2c:76:8a',
#  '2c:7e:81',
#  '2c:86:d2',
#  '2c:95:69',
#  '2c:9e:fc',
#  '2c:a9:f0',
#  '2c:ae:2b',
#  '2c:b0:5d',
#  '2c:be:08',
#  '2c:cc:44',
#  '2c:d0:5a',
#  '2c:d9:74',
#  '2c:e4:12',
#  '2c:f0:a2',
#  '2c:f0:ee',
#  '2c:fd:a1',
#  '2e:20:0b',
#  '2e:33:61',
#  '2e:61:f6',
#  '2e:b4:3a',
#  '2e:f0:a2',
#  '2e:f0:ee',
#  '30:05:5c',
#  '30:07:4d',
#  '30:0e:d5',
#  '30:10:b3',
#  '30:10:e4',
#  '30:14:4a',
#  '30:19:66',
#  '30:23:03',
#  '30:24:32',
#  '30:35:ad',
#  '30:3a:64',
#  '30:45:96',
#  '30:46:9a',
#  '30:4b:07',
#  '30:52:cb',
#  '30:58:90',
#  '30:59:b7',
#  '30:5a:3a',
#  '30:60:23',
#  '30:63:6b',
#  '30:6a:85',
#  '30:74:96',
#  '30:85:a9',
#  '30:8d:99',
#  '30:96:fb',
#  '30:9c:23',
#  '30:a1:fa',
#  '30:a9:de',
#  '30:ae:a4',
#  '30:b4:9e',
#  '30:b5:c2',
#  '30:c7:ae',
#  '30:cb:f8',
#  '30:cd:a7',
#  '30:d1:6b',
#  '30:d9:d9',
#  '30:e1:71',
#  '30:e3:7a',
#  '30:e4:db',
#  '30:f7:72',
#  '30:f9:ed',
#  '30:fd:38',
#  '32:07:4d',
#  '32:24:32',
#  '32:35:ad',
#  '32:52:cb',
#  '32:63:6b',
#  '32:b5:c2',
#  '32:d9:d9',
#  '34:02:86',
#  '34:08:bc',
#  '34:12:98',
#  '34:12:f9',
#  '34:13:e8',
#  '34:14:5f',
#  '34:15:9e',
#  '34:17:eb',
#  '34:1a:4c',
#  '34:1f:e4',
#  '34:23:87',
#  '34:23:ba',
#  '34:27:92',
#  '34:29:12',
#  '34:2d:0d',
#  '34:2e:b6',
#  '34:36:3b',
#  '34:41:5d',
#  '34:4d:f7',
#  '34:51:c9',
#  '34:5a:06',
#  '34:64:a9',
#  '34:68:95',
#  '34:6b:46',
#  '34:79:16',
#  '34:7c:25',
#  '34:7e:5c',
#  '34:80:b3',
#  '34:8a:7b',
#  '34:96:72',
#  '34:97:f6',
#  '34:a3:95',
#  '34:ab:37',
#  '34:af:2c',
#  '34:c0:59',
#  '34:d2:70',
#  '34:db:fd',
#  '34:de:1a',
#  '34:e1:2d',
#  '34:e2:fd',
#  '34:e6:ad',
#  '34:e6:d7',
#  '34:e9:11',
#  '34:f3:9a',
#  '34:f6:2d',
#  '34:f6:4b',
#  '34:fc:ef',
#  '36:08:bc',
#  '36:7c:25',
#  '36:a3:95',
#  '36:ab:37',
#  '36:af:2c',
#  '36:e2:fd',
#  '38:01:95',
#  '38:0f:4a',
#  '38:1c:1a',
#  '38:2c:4a',
#  '38:2d:d1',
#  '38:2d:e8',
#  '38:30:f9',
#  '38:37:8b',
#  '38:48:4c',
#  '38:53:9c',
#  '38:59:f9',
#  '38:60:77',
#  '38:63:bb',
#  '38:6b:bb',
#  '38:71:de',
#  '38:89:2c',
#  '38:8b:59',
#  '38:8c:50',
#  '38:94:96',
#  '38:9a:f6',
#  '38:9d:92',
#  '38:a2:8c',
#  '38:a4:ed',
#  '38:b1:db',
#  '38:ba:f8',
#  '38:c9:86',
#  '38:ca:da',
#  '38:d4:0b',
#  '38:d5:47',
#  '38:de:ad',
#  '38:e6:0a',
#  '38:ea:a7',
#  '38:f7:3d',
#  '38:f9:d3',
#  '3a:0f:4a',
#  '3a:53:9c',
#  '3a:71:de',
#  '3a:8b:59',
#  '3a:ca:da',
#  '3c:05:18',
#  '3c:07:54',
#  '3c:07:71',
#  '3c:15:c2',
#  '3c:17:10',
#  '3c:18:9f',
#  '3c:1e:04',
#  '3c:2a:f4',
#  '3c:2c:30',
#  '3c:2e:ff',
#  '3c:33:00',
#  '3c:36:e4',
#  '3c:37:86',
#  '3c:47:11',
#  '3c:4a:92',
#  '3c:52:82',
#  '3c:57:6c',
#  '3c:5c:c4',
#  '3c:6a:a7',
#  '3c:70:59',
#  '3c:71:bf',
#  '3c:77:e6',
#  '3c:8c:f8',
#  '3c:8d:20',
#  '3c:95:09',
#  '3c:a0:67',
#  '3c:a1:0d',
#  '3c:a6:16',
#  '3c:a8:2a',
#  '3c:a9:f4',
#  '3c:ab:8e',
#  '3c:b6:b7',
#  '3c:bb:fd',
#  '3c:bd:d8',
#  '3c:cd:5d',
#  '3c:cd:93',
#  '3c:ce:73',
#  '3c:d9:2b',
#  '3c:dc:bc',
#  '3c:df:a9',
#  '3c:e0:72',
#  '3c:f7:a4',
#  '3c:f8:62',
#  '3c:fa:43',
#  '3e:2e:f9',
#  '3e:2e:ff',
#  '3e:ab:8e',
#  '3e:e0:72',
#  '40:16:3b',
#  '40:16:7e',
#  '40:25:c2',
#  '40:26:19',
#  '40:2c:f4',
#  '40:30:04',
#  '40:33:1a',
#  '40:3c:fc',
#  '40:49:0f',
#  '40:5d:82',
#  '40:61:86',
#  '40:65:a3',
#  '40:6c:8f',
#  '40:6f:2a',
#  '40:83:1d',
#  '40:8d:5c',
#  '40:98:ad',
#  '40:99:22',
#  '40:9b:cd',
#  '40:9c:28',
#  '40:9f:38',
#  '40:a3:cc',
#  '40:a5:ef',
#  '40:a8:f0',
#  '40:b0:34',
#  '40:b3:95',
#  '40:b4:cd',
#  '40:b8:9a',
#  '40:bc:60',
#  '40:c7:29',
#  '40:cb:c0',
#  '40:cd:7a',
#  '40:d2:8a',
#  '40:d3:ae',
#  '40:e2:30',
#  '40:f0:2f',
#  '40:f4:07',
#  '42:cb:c0',
#  '44:00:10',
#  '44:00:49',
#  '44:03:2c',
#  '44:07:0b',
#  '44:19:b6',
#  '44:1c:a8',
#  '44:1e:a1',
#  '44:2a:60',
#  '44:37:e6',
#  '44:39:c4',
#  '44:47:cc',
#  '44:61:32',
#  '44:65:0d',
#  '44:66:fc',
#  '44:6d:57',
#  '44:6e:e5',
#  '44:78:3e',
#  '44:85:00',
#  '44:87:fc',
#  '44:8a:5b',
#  '44:91:60',
#  '44:94:fc',
#  '44:a8:42',
#  '44:c3:46',
#  '44:d2:44',
#  '44:d3:ca',
#  '44:e1:37',
#  '44:fe:3b',
#  '48:0f:cf',
#  '48:13:7e',
#  '48:27:ea',
#  '48:2c:a0',
#  '48:3b:38',
#  '48:3c:0c',
#  '48:43:7c',
#  '48:44:f7',
#  '48:45:20',
#  '48:49:c7',
#  '48:4b:aa',
#  '48:4d:7e',
#  '48:51:b7',
#  '48:59:29',
#  '48:5a:b6',
#  '48:5b:39',
#  '48:5d:60',
#  '48:60:5f',
#  '48:60:bc',
#  '48:6d:bb',
#  '48:7d:2e',
#  '48:8d:36',
#  '48:9d:24',
#  '48:a1:95',
#  '48:a4:72',
#  '48:a9:1c',
#  '48:a9:d2',
#  '48:ba:4e',
#  '48:bf:6b',
#  '48:c7:96',
#  '48:d2:24',
#  '48:d6:d5',
#  '48:d7:05',
#  '48:db:50',
#  '48:e2:44',
#  '48:e9:f1',
#  '4a:60:5f',
#  '4a:d6:d5',
#  '4a:ee:0c',
#  '4c:09:d4',
#  '4c:0b:be',
#  '4c:0f:6e',
#  '4c:12:65',
#  '4c:17:eb',
#  '4c:1a:3d',
#  '4c:1b:86',
#  '4c:32:75',
#  '4c:34:88',
#  '4c:49:e3',
#  '4c:52:62',
#  '4c:56:9d',
#  '4c:57:ca',
#  '4c:60:de',
#  '4c:66:41',
#  '4c:72:b9',
#  '4c:74:bf',
#  '4c:80:93',
#  '4c:8d:79',
#  '4c:b1:99',
#  '4c:bb:58',
#  '4c:bd:8f',
#  '4c:cc:6a',
#  '4c:d1:a1',
#  '4c:dd:31',
#  '4c:eb:42',
#  '4c:ed:de',
#  '4c:ed:fb',
#  '4c:ef:c0',
#  '4c:fb:45',
#  '50:01:d9',
#  '50:04:b8',
#  '50:1a:c5',
#  '50:1e:2d',
#  '50:29:f5',
#  '50:32:37',
#  '50:3a:a0',
#  '50:3e:aa',
#  '50:46:5d',
#  '50:4f:94',
#  '50:55:27',
#  '50:56:bf',
#  '50:5b:c2',
#  '50:65:83',
#  '50:65:f3',
#  '50:67:ae',
#  '50:6a:03',
#  '50:76:af',
#  '50:77:05',
#  '50:7a:55',
#  '50:7e:5d',
#  '50:85:69',
#  '50:8c:b1',
#  '50:8f:4c',
#  '50:92:b9',
#  '50:95:51',
#  '50:9a:4c',
#  '50:9e:a7',
#  '50:a6:7f',
#  '50:a7:2b',
#  '50:af:73',
#  '50:b7:c3',
#  '50:bc:96',
#  '50:c7:bf',
#  '50:dc:e7',
#  '50:e5:49',
#  '50:f0:d3',
#  '50:f5:da',
#  '52:c7:bf',
#  '54:04:a6',
#  '54:13:79',
#  '54:25:ea',
#  '54:26:96',
#  '54:27:1e',
#  '54:33:cb',
#  '54:35:30',
#  '54:40:ad',
#  '54:42:49',
#  '54:48:10',
#  '54:4e:90',
#  '54:53:ed',
#  '54:5a:a6',
#  '54:60:09',
#  '54:64:d9',
#  '54:78:1a',
#  '54:7c:69',
#  '54:88:0e',
#  '54:8c:a0',
#  '54:99:63',
#  '54:a0:50',
#  '54:ae:27',
#  '54:b1:21',
#  '54:b8:02',
#  '54:b8:0a',
#  '54:bd:79',
#  '54:be:f7',
#  '54:bf:64',
#  '54:c4:15',
#  '54:e4:3a',
#  '54:e6:fc',
#  '54:f2:01',
#  '54:fc:f0',
#  '56:99:63',
#  '58:00:e3',
#  '58:03:fb',
#  '58:0a:20',
#  '58:19:f8',
#  '58:1f:28',
#  '58:1f:aa',
#  '58:20:b1',
#  '58:2a:f7',
#  '58:2f:40',
#  '58:38:79',
#  '58:3f:54',
#  '58:40:4e',
#  '58:55:ca',
#  '58:56:e8',
#  '58:67:1a',
#  '58:7f:57',
#  '58:82:a8',
#  '58:8a:5a',
#  '58:8b:f3',
#  '58:90:43',
#  '58:91:cf',
#  '58:94:6b',
#  '58:b0:35',
#  '58:b1:0f',
#  '58:b3:fc',
#  '58:bd:a3',
#  '58:bf:ea',
#  '58:c5:cb',
#  '58:d5:6e',
#  '58:e2:8f',
#  '58:e6:ba',
#  '58:ef:68',
#  '58:fb:84',
#  '5a:ef:68',
#  '5c:03:39',
#  '5c:09:47',
#  '5c:1d:d9',
#  '5c:26:0a',
#  '5c:2e:59',
#  '5c:41:5a',
#  '5c:49:7d',
#  '5c:51:4f',
#  '5c:51:81',
#  '5c:52:1e',
#  '5c:5f:67',
#  '5c:6a:80',
#  '5c:70:a3',
#  '5c:93:a2',
#  '5c:96:56',
#  '5c:96:9d',
#  '5c:97:f3',
#  '5c:99:60',
#  '5c:a3:9d',
#  '5c:a8:6a',
#  '5c:aa:fd',
#  '5c:ac:4c',
#  '5c:ad:cf',
#  '5c:af:06',
#  '5c:b0:66',
#  '5c:b9:01',
#  '5c:c3:07',
#  '5c:c5:d4',
#  '5c:c9:d3',
#  '5c:cf:7f',
#  '5c:dc:96',
#  '5c:e0:c5',
#  '5c:e2:8c',
#  '5c:ea:1d',
#  '5c:f4:ab',
#  '5c:f5:da',
#  '5c:f6:dc',
#  '5c:f7:e6',
#  '5c:f9:38',
#  '5c:f9:dd',
#  '60:01:94',
#  '60:02:92',
#  '60:02:b4',
#  '60:03:08',
#  '60:12:8b',
#  '60:30:d4',
#  '60:31:97',
#  '60:36:dd',
#  '60:38:e0',
#  '60:45:bd',
#  '60:45:cb',
#  '60:57:18',
#  '60:5b:b4',
#  '60:64:05',
#  '60:67:20',
#  '60:69:44',
#  '60:6b:bd',
#  '60:6b:ff',
#  '60:6c:66',
#  '60:6d:c7',
#  '60:8c:4a',
#  '60:8e:08',
#  '60:92:17',
#  '60:a4:4c',
#  '60:a4:d0',
#  '60:af:6d',
#  '60:b6:06',
#  '60:c5:47',
#  '60:c5:ad',
#  '60:d8:19',
#  '60:d9:c7',
#  '60:e3:27',
#  '60:e3:ac',
#  '60:f1:89',
#  '60:f4:45',
#  '60:f4:94',
#  '60:f6:77',
#  '60:f8:1d',
#  '60:fb:42',
#  '60:fe:c5',
#  '62:03:08',
#  '62:30:d4',
#  '62:38:e0',
#  '62:8c:4a',
#  '62:92:17',
#  '62:a3:7d',
#  '62:f4:45',
#  '62:f8:1d',
#  '64:00:6a',
#  '64:16:7f',
#  '64:1c:67',
#  '64:1c:ae',
#  '64:1c:b0',
#  '64:20:0c',
#  '64:27:37',
#  '64:31:50',
#  '64:32:a8',
#  '64:51:06',
#  '64:55:b1',
#  '64:5a:04',
#  '64:5a:ed',
#  '64:5d:86',
#  '64:66:b3',
#  '64:6c:b2',
#  '64:6e:69',
#  '64:70:02',
#  '64:70:33',
#  '64:76:ba',
#  '64:77:91',
#  '64:80:99',
#  '64:89:9a',
#  '64:9a:be',
#  '64:9e:f3',
#  '64:a2:f9',
#  '64:a3:cb',
#  '64:a5:c3',
#  '64:b5:c6',
#  '64:b9:e8',
#  '64:bc:0c',
#  '64:c6:67',
#  '64:cc:2e',
#  '64:db:8b',
#  '64:e6:82',
#  '64:eb:8c',
#  '66:5a:ed',
#  '66:70:33',
#  '66:9a:be',
#  '66:a3:cb',
#  '66:b0:a6',
#  '66:b9:e8',
#  '68:05:ca',
#  '68:07:15',
#  '68:09:27',
#  '68:14:01',
#  '68:15:90',
#  '68:17:29',
#  '68:27:37',
#  '68:37:e9',
#  '68:54:fd',
#  '68:5a:cf',
#  '68:5b:35',
#  '68:5d:43',
#  '68:79:ed',
#  '68:94:23',
#  '68:9a:87',
#  '68:9c:70',
#  '68:a3:78',
#  '68:a3:c4',
#  '68:a8:6d',
#  '68:ab:1e',
#  '68:b5:99',
#  '68:c4:4d',
#  '68:c6:3a',
#  '68:d9:3c',
#  '68:db:ca',
#  '68:e7:c2',
#  '68:ec:c5',
#  '68:fb:7e',
#  '68:fe:f7',
#  '6a:ab:1e',
#  '6a:ae:20',
#  '6a:db:ca',
#  '6a:ef:43',
#  '6a:fb:7e',
#  '6a:fe:f7',
#  '6c:0b:84',
#  '6c:19:8f',
#  '6c:19:c0',
#  '6c:29:95',
#  '6c:2b:59',
#  '6c:2e:85',
#  '6c:2f:2c',
#  '6c:3b:e5',
#  '6c:40:08',
#  '6c:4b:90',
#  '6c:4d:73',
#  '6c:56:97',
#  '6c:62:6d',
#  '6c:70:9f',
#  '6c:71:d9',
#  '6c:72:20',
#  '6c:72:e7',
#  '6c:88:14',
#  '6c:94:f8',
#  '6c:96:cf',
#  '6c:ab:31',
#  '6c:ad:f8',
#  '6c:b0:ce',
#  '6c:b7:49',
#  '6c:c2:17',
#  '6c:c7:ec',
#  '6c:ca:08',
#  '6c:f0:49',
#  '6e:19:c0',
#  '6e:40:08',
#  '6e:4d:73',
#  '6e:72:e7',
#  '6e:8d:c1',
#  '6e:96:cf',
#  '6e:ab:31',
#  '6e:e8:5c',
#  '70:0b:01',
#  '70:10:6f',
#  '70:11:24',
#  '70:18:8b',
#  '70:1a:04',
#  '70:1c:e7',
#  '70:20:84',
#  '70:26:05',
#  '70:28:8b',
#  '70:2a:d5',
#  '70:3a:51',
#  '70:3e:ac',
#  '70:48:0f',
#  '70:4d:7b',
#  '70:4f:57',
#  '70:4f:b8',
#  '70:54:b4',
#  '70:54:d2',
#  '70:56:81',
#  '70:5a:0f',
#  '70:5a:ac',
#  '70:5a:b6',
#  '70:62:b8',
#  '70:70:0d',
#  '70:71:bc',
#  '70:72:3c',
#  '70:77:81',
#  '70:78:8b',
#  '70:81:05',
#  '70:81:eb',
#  '70:85:c2',
#  '70:8a:09',
#  '70:8b:cd',
#  '70:9e:29',
#  '70:a2:b3',
#  '70:af:24',
#  '70:b7:aa',
#  '70:bb:e9',
#  '70:c9:4e',
#  '70:ca:9b',
#  '70:cd:60',
#  '70:de:e2',
#  '70:e7:2c',
#  '70:ec:e4',
#  '70:ee:50',
#  '70:ef:00',
#  '70:f0:87',
#  '70:f1:a1',
#  '70:f3:95',
#  '70:fd:46',
#  '72:14:a6',
#  '72:3e:ac',
#  '72:70:0d',
#  '72:81:eb',
#  '72:ee:50',
#  '72:ef:00',
#  '72:f0:87',
#  '74:23:44',
#  '74:27:ea',
#  '74:29:af',
#  '74:2f:68',
#  '74:40:bb',
#  '74:46:a0',
#  '74:5e:1c',
#  '74:6f:f7',
#  '74:70:fd',
#  '74:75:48',
#  '74:81:14',
#  '74:85:2a',
#  '74:86:7a',
#  '74:8d:08',
#  '74:9e:af',
#  '74:b5:87',
#  '74:bf:c0',
#  '74:c1:4f',
#  '74:c2:46',
#  '74:c6:3b',
#  '74:d0:2b',
#  '74:d2:1d',
#  '74:d4:35',
#  '74:da:38',
#  '74:de:2b',
#  '74:df:bf',
#  '74:e1:b6',
#  '74:e5:0b',
#  '74:e5:43',
#  '74:e5:f9',
#  '74:e6:e2',
#  '74:ea:3a',
#  '74:ea:e8',
#  '74:eb:80',
#  '74:f0:6d',
#  '76:1b:b2',
#  '76:81:14',
#  '76:8d:08',
#  '76:9e:af',
#  '76:b5:87',
#  '76:bf:c0',
#  '78:00:9e',
#  '78:02:f8',
#  '78:0c:b8',
#  '78:1c:5a',
#  '78:23:ae',
#  '78:24:af',
#  '78:28:ca',
#  '78:29:ed',
#  '78:2b:cb',
#  '78:31:c1',
#  '78:32:1b',
#  '78:36:cc',
#  '78:3a:84',
#  '78:40:e4',
#  '78:45:c4',
#  '78:4f:43',
#  '78:54:2e',
#  '78:5d:c8',
#  '78:62:56',
#  '78:67:d7',
#  '78:7b:8a',
#  '78:7e:61',
#  '78:84:3c',
#  '78:88:6d',
#  '78:92:9c',
#  '78:96:84',
#  '78:9f:70',
#  '78:a1:83',
#  '78:a2:a0',
#  '78:a3:51',
#  '78:ab:bb',
#  '78:ac:c0',
#  '78:bd:bc',
#  '78:ca:39',
#  '78:d2:94',
#  '78:dd:08',
#  '78:dd:12',
#  '78:e1:03',
#  '78:e3:b5',
#  '78:e4:00',
#  '78:e7:d1',
#  '78:f2:9e',
#  '78:f7:be',
#  '78:f8:82',
#  '78:fd:94',
#  '7a:31:c1',
#  '7a:32:1b',
#  '7a:4f:43',
#  '7a:67:d7',
#  '7a:7b:8a',
#  '7a:88:6d',
#  '7a:fd:94',
#  '7c:03:4c',
#  '7c:03:ab',
#  '7c:03:d8',
#  '7c:04:d0',
#  '7c:05:07',
#  '7c:0b:c6',
#  '7c:11:be',
#  '7c:11:cb',
#  '7c:1c:4e',
#  '7c:1c:68',
#  '7c:1e:52',
#  '7c:26:64',
#  '7c:2a:31',
#  '7c:2e:bd',
#  '7c:2e:dd',
#  '7c:50:49',
#  '7c:5c:f8',
#  '7c:64:56',
#  '7c:67:a2',
#  '7c:6b:9c',
#  '7c:6d:62',
#  '7c:76:35',
#  '7c:76:68',
#  '7c:7a:91',
#  '7c:7d:3d',
#  '7c:8b:ca',
#  '7c:91:22',
#  '7c:a1:77',
#  '7c:b0:c2',
#  '7c:bb:8a',
#  '7c:c3:a1',
#  '7c:c7:09',
#  '7c:d1:c3',
#  '7c:dd:90',
#  '7c:e9:d3',
#  '7c:ed:8d',
#  '7c:f9:0e',
#  '7e:01:91',
#  '7e:1d:d9',
#  '7e:46:85',
#  '7e:50:49',
#  '80:00:0b',
#  '80:13:82',
#  '80:18:44',
#  '80:18:a7',
#  '80:19:34',
#  '80:1f:02',
#  '80:2b:f9',
#  '80:35:c1',
#  '80:37:73',
#  '80:38:96',
#  '80:4e:70',
#  '80:4e:81',
#  '80:56:f2',
#  '80:5a:04',
#  '80:5e:c0',
#  '80:65:6d',
#  '80:7d:3a',
#  '80:82:23',
#  '80:86:f2',
#  '80:9b:20',
#  '80:a5:89',
#  '80:ad:16',
#  '80:b0:3d',
#  '80:be:05',
#  '80:c1:6e',
#  '80:c5:f2',
#  '80:c7:55',
#  '80:ce:62',
#  '80:ce:b9',
#  '80:d2:1d',
#  '80:d6:05',
#  '80:e6:50',
#  '80:ea:23',
#  '80:ea:96',
#  '84:00:2d',
#  '84:0d:8e',
#  '84:11:9e',
#  '84:16:f9',
#  '84:1b:5e',
#  '84:20:96',
#  '84:25:19',
#  '84:29:99',
#  '84:2b:2b',
#  '84:2e:27',
#  '84:34:97',
#  '84:38:35',
#  '84:39:be',
#  '84:3a:4b',
#  '84:41:67',
#  '84:4b:f5',
#  '84:61:a0',
#  '84:78:8b',
#  '84:7b:eb',
#  '84:80:2d',
#  '84:85:06',
#  '84:89:ad',
#  '84:8e:0c',
#  '84:8f:69',
#  '84:98:66',
#  '84:9c:a6',
#  '84:9f:b5',
#  '84:a1:34',
#  '84:a1:d1',
#  '84:a4:66',
#  '84:a6:c8',
#  '84:a9:3e',
#  '84:b5:41',
#  '84:ba:3b',
#  '84:be:52',
#  '84:c0:ef',
#  '84:c9:b2',
#  '84:d6:d0',
#  '84:ef:18',
#  '84:f3:eb',
#  '84:fc:ac',
#  '86:16:f9',
#  '86:4b:f5',
#  '88:03:55',
#  '88:07:4b',
#  '88:11:96',
#  '88:19:08',
#  '88:1f:a1',
#  '88:28:b3',
#  '88:30:8a',
#  '88:36:5f',
#  '88:3d:24',
#  '88:43:e1',
#  '88:44:77',
#  '88:51:fb',
#  '88:53:2e',
#  '88:53:95',
#  '88:63:df',
#  '88:66:a5',
#  '88:6b:6e',
#  '88:71:b1',
#  '88:71:e5',
#  '88:75:98',
#  '88:78:73',
#  '88:79:7e',
#  '88:82:79',
#  '88:83:22',
#  '88:87:17',
#  '88:9f:6f',
#  '88:9f:fa',
#  '88:ad:d2',
#  '88:ae:07',
#  '88:ae:1d',
#  '88:b1:11',
#  '88:b4:a6',
#  '88:bd:45',
#  '88:c9:d0',
#  '88:cb:87',
#  '88:d5:0c',
#  '88:d7:f6',
#  '88:de:a9',
#  '88:e8:7f',
#  '88:e9:fe',
#  '88:f7:bf',
#  '8a:19:08',
#  '8c:0d:76',
#  '8c:0f:6f',
#  '8c:10:d4',
#  '8c:11:cb',
#  '8c:18:d9',
#  '8c:1a:bf',
#  '8c:25:05',
#  '8c:29:37',
#  '8c:2d:aa',
#  '8c:3b:ad',
#  '8c:45:00',
#  '8c:57:9b',
#  '8c:59:73',
#  '8c:61:a3',
#  '8c:70:5a',
#  '8c:7c:92',
#  '8c:7f:3b',
#  '8c:83:e1',
#  '8c:85:90',
#  '8c:89:a5',
#  '8c:8e:f2',
#  '8c:9f:3b',
#  '8c:a9:82',
#  '8c:be:be',
#  '8c:bf:a6',
#  '8c:c1:21',
#  '8c:c8:cd',
#  '8c:cd:e8',
#  '8c:dc:d4',
#  '8c:eb:c6',
#  '8c:ec:4b',
#  '8c:f5:a3',
#  '8c:fa:ba',
#  '8c:fe:57',
#  '8e:f5:a3',
#  '90:00:4e',
#  '90:06:28',
#  '90:18:7c',
#  '90:1b:0e',
#  '90:2b:34',
#  '90:2b:d2',
#  '90:2e:1c',
#  '90:32:4b',
#  '90:34:fc',
#  '90:48:9a',
#  '90:4c:e5',
#  '90:61:ae',
#  '90:8d:6c',
#  '90:8d:78',
#  '90:94:97',
#  '90:94:e4',
#  '90:97:d5',
#  '90:97:f3',
#  '90:9d:7d',
#  '90:b1:1c',
#  '90:b2:1f',
#  '90:b6:86',
#  '90:b9:31',
#  '90:c5:4a',
#  '90:cd:b6',
#  '90:e6:ba',
#  '90:f1:aa',
#  '90:f6:52',
#  '90:fb:a6',
#  '90:fd:61',
#  '92:68:c3',
#  '92:8d:78',
#  '92:b9:31',
#  '94:0c:6d',
#  '94:0e:6b',
#  '94:10:3e',
#  '94:14:7a',
#  '94:18:82',
#  '94:35:0a',
#  '94:39:e5',
#  '94:44:44',
#  '94:44:52',
#  '94:53:30',
#  '94:57:a5',
#  '94:58:cb',
#  '94:62:69',
#  '94:65:2d',
#  '94:65:9c',
#  '94:6a:b0',
#  '94:76:b7',
#  '94:7b:e7',
#  '94:87:e0',
#  '94:8b:c1',
#  '94:8f:cf',
#  '94:94:26',
#  '94:9a:a9',
#  '94:9f:3e',
#  '94:b1:0a',
#  '94:b8:6d',
#  '94:bf:2d',
#  '94:c6:91',
#  '94:db:c9',
#  '94:de:80',
#  '94:e1:ac',
#  '94:e9:6a',
#  '94:e9:79',
#  '94:eb:cd',
#  '94:f6:d6',
#  '94:fe:22',
#  '94:fe:f4',
#  '98:01:a7',
#  '98:09:cf',
#  '98:10:e8',
#  '98:22:ef',
#  '98:28:a6',
#  '98:29:a6',
#  '98:39:8e',
#  '98:3b:8f',
#  '98:40:bb',
#  '98:4b:e1',
#  '98:54:1b',
#  '98:5a:eb',
#  '98:5f:d3',
#  '98:83:89',
#  '98:8b:5d',
#  '98:90:96',
#  '98:93:cc',
#  '98:9c:57',
#  '98:9e:63',
#  '98:b6:e9',
#  '98:b8:e3',
#  '98:ca:33',
#  '98:de:d0',
#  '98:e0:d9',
#  '98:e7:f4',
#  '98:e7:f5',
#  '98:f0:ab',
#  '98:f1:70',
#  '98:fe:94',
#  '9a:0c:a5',
#  '9a:de:d0',
#  '9c:04:eb',
#  '9c:0c:df',
#  '9c:2a:70',
#  '9c:2e:a1',
#  '9c:30:5b',
#  '9c:32:ce',
#  '9c:35:eb',
#  '9c:3d:cf',
#  '9c:4e:36',
#  '9c:57:ad',
#  '9c:5a:44',
#  '9c:5c:8e',
#  '9c:64:5e',
#  '9c:80:df',
#  '9c:8b:a0',
#  '9c:8c:6e',
#  '9c:8e:99',
#  '9c:93:4e',
#  '9c:a5:c0',
#  '9c:ad:97',
#  '9c:ae:d3',
#  '9c:b2:b2',
#  '9c:b6:54',
#  '9c:b7:0d',
#  '9c:c1:72',
#  '9c:c7:d1',
#  '9c:d2:1e',
#  '9c:d3:5b',
#  '9c:da:3e',
#  '9c:e0:63',
#  '9c:e3:3f',
#  '9c:e6:35',
#  '9c:e6:5e',
#  '9c:f3:87',
#  '9c:f4:8e',
#  '9c:fc:01',
#  '9e:30:5b',
#  '9e:e3:3f',
#  '9e:e6:5e',
#  'a0:02:dc',
#  'a0:04:60',
#  'a0:0b:ba',
#  'a0:10:81',
#  'a0:18:28',
#  'a0:1d:48',
#  'a0:20:a6',
#  'a0:21:b7',
#  'a0:2b:b8',
#  'a0:36:9f',
#  'a0:39:ee',
#  'a0:39:f7',
#  'a0:3b:e3',
#  'a0:40:a0',
#  'a0:48:1c',
#  'a0:4e:a7',
#  'a0:56:f3',
#  'a0:57:e3',
#  'a0:63:91',
#  'a0:64:8f',
#  'a0:6f:aa',
#  'a0:86:c6',
#  'a0:88:69',
#  'a0:88:b4',
#  'a0:8c:fd',
#  'a0:8e:78',
#  'a0:91:69',
#  'a0:99:9b',
#  'a0:9d:c1',
#  'a0:a8:cd',
#  'a0:af:bd',
#  'a0:b3:cc',
#  'a0:b4:a5',
#  'a0:c5:89',
#  'a0:c9:a0',
#  'a0:cb:fd',
#  'a0:cc:2b',
#  'a0:d3:7a',
#  'a0:d3:c1',
#  'a0:d7:95',
#  'a0:dd:e5',
#  'a0:ed:cd',
#  'a0:f3:c1',
#  'a2:18:28',
#  'a2:3b:e3',
#  'a2:4e:a7',
#  'a2:56:f3',
#  'a2:99:9b',
#  'a2:c9:a0',
#  'a2:d7:95',
#  'a2:ed:cd',
#  'a4:02:b9',
#  'a4:07:b6',
#  'a4:08:ea',
#  'a4:08:f5',
#  'a4:12:32',
#  'a4:14:37',
#  'a4:17:31',
#  'a4:1f:72',
#  'a4:2b:b0',
#  'a4:34:d9',
#  'a4:38:cc',
#  'a4:4c:11',
#  'a4:4c:c8',
#  'a4:4e:31',
#  'a4:50:46',
#  'a4:5c:27',
#  'a4:5d:36',
#  'a4:5e:60',
#  'a4:67:06',
#  'a4:6c:f1',
#  'a4:71:74',
#  'a4:77:33',
#  'a4:77:60',
#  'a4:81:ee',
#  'a4:84:31',
#  'a4:93:3f',
#  'a4:93:4c',
#  'a4:b8:05',
#  'a4:ba:db',
#  'a4:c0:e1',
#  'a4:c4:94',
#  'a4:ca:a0',
#  'a4:d1:8c',
#  'a4:d1:d2',
#  'a4:db:30',
#  'a4:e4:b8',
#  'a4:e9:75',
#  'a4:ee:57',
#  'a4:f1:e8',
#  'a6:2b:b0',
#  'a6:b8:05',
#  'a6:d9:31',
#  'a6:e9:75',
#  'a6:f1:e8',
#  'a8:0c:63',
#  'a8:11:fc',
#  'a8:13:74',
#  'a8:16:d0',
#  'a8:1b:6a',
#  'a8:1d:16',
#  'a8:20:66',
#  'a8:23:fe',
#  'a8:47:4a',
#  'a8:51:5b',
#  'a8:54:b2',
#  'a8:5b:78',
#  'a8:5c:2c',
#  'a8:60:b6',
#  'a8:66:7f',
#  'a8:6b:ad',
#  'a8:7c:01',
#  'a8:7d:12',
#  'a8:81:95',
#  'a8:86:dd',
#  'a8:88:08',
#  'a8:96:75',
#  'a8:96:8a',
#  'a8:9a:93',
#  'a8:9f:ec',
#  'a8:a6:48',
#  'a8:a7:95',
#  'a8:b8:6e',
#  'a8:bb:cf',
#  'a8:be:27',
#  'a8:c8:3a',
#  'a8:d3:f7',
#  'a8:e3:ee',
#  'a8:fa:d8',
#  'aa:5b:78',
#  'aa:5c:2c',
#  'aa:66:7f',
#  'aa:86:dd',
#  'aa:88:08',
#  'aa:8e:24',
#  'aa:be:27',
#  'ac:07:5f',
#  'ac:0d:1b',
#  'ac:16:2d',
#  'ac:18:26',
#  'ac:1f:74',
#  'ac:22:0b',
#  'ac:29:3a',
#  'ac:2b:6e',
#  'ac:3a:7a',
#  'ac:3c:0b',
#  'ac:44:f2',
#  'ac:5f:3e',
#  'ac:63:be',
#  'ac:72:89',
#  'ac:7b:a1',
#  'ac:81:12',
#  'ac:84:c6',
#  'ac:84:c9',
#  'ac:87:a3',
#  'ac:89:95',
#  'ac:92:32',
#  'ac:9b:0a',
#  'ac:9e:17',
#  'ac:a2:13',
#  'ac:ae:19',
#  'ac:af:b9',
#  'ac:b5:7d',
#  'ac:bc:32',
#  'ac:c1:ee',
#  'ac:c3:3a',
#  'ac:cc:8e',
#  'ac:cf:5c',
#  'ac:cf:85',
#  'ac:d0:74',
#  'ac:d1:b8',
#  'ac:de:48',
#  'ac:e0:10',
#  'ac:e2:d3',
#  'ac:e4:b5',
#  'ac:ed:5c',
#  'ac:ee:9e',
#  'ac:fd:ce',
#  'ac:fd:ec',
#  'ae:1f:74',
#  'ae:84:c6',
#  'ae:cf:5c',
#  'ae:e4:b5',
#  'ae:fd:ec',
#  'b0:05:94',
#  'b0:0c:d1',
#  'b0:10:41',
#  'b0:19:c6',
#  'b0:2a:43',
#  'b0:34:95',
#  'b0:35:9f',
#  'b0:39:56',
#  'b0:47:bf',
#  'b0:48:1a',
#  'b0:48:7a',
#  'b0:4e:26',
#  'b0:52:16',
#  'b0:55:08',
#  'b0:5a:da',
#  'b0:65:bd',
#  'b0:6e:bf',
#  'b0:70:2d',
#  'b0:72:bf',
#  'b0:77:ac',
#  'b0:7f:b9',
#  'b0:83:fe',
#  'b0:89:00',
#  'b0:93:5b',
#  'b0:98:2b',
#  'b0:a7:37',
#  'b0:b2:8f',
#  'b0:b9:8a',
#  'b0:be:76',
#  'b0:c0:90',
#  'b0:c5:54',
#  'b0:c5:59',
#  'b0:ca:68',
#  'b0:da:f9',
#  'b0:e1:7e',
#  'b0:e2:35',
#  'b0:e5:ed',
#  'b0:e8:92',
#  'b0:eb:57',
#  'b0:ee:45',
#  'b0:ee:7b',
#  'b0:fc:0d',
#  'b2:19:c6',
#  'b2:34:95',
#  'b2:48:1a',
#  'b2:4e:26',
#  'b2:6e:bf',
#  'b2:70:2d',
#  'b2:9f:ba',
#  'b2:be:76',
#  'b2:c5:54',
#  'b4:07:f9',
#  'b4:0e:dc',
#  'b4:0f:b3',
#  'b4:18:d1',
#  'b4:2e:99',
#  'b4:3a:28',
#  'b4:4b:d2',
#  'b4:69:21',
#  'b4:6b:fc',
#  'b4:6d:83',
#  'b4:74:43',
#  'b4:74:9f',
#  'b4:75:0e',
#  'b4:7c:9c',
#  'b4:82:fe',
#  'b4:86:55',
#  'b4:8b:19',
#  'b4:96:91',
#  'b4:99:ba',
#  'b4:9c:df',
#  'b4:a3:82',
#  'b4:ae:2b',
#  'b4:b5:2f',
#  'b4:b6:76',
#  'b4:b6:86',
#  'b4:bf:f6',
#  'b4:cd:27',
#  'b4:d5:bd',
#  'b4:e6:2a',
#  'b4:e6:2d',
#  'b4:ef:39',
#  'b4:f0:ab',
#  'b4:f1:da',
#  'b4:f6:1c',
#  'b4:f7:a1',
#  'b6:18:d1',
#  'b6:4b:d2',
#  'b6:6b:fc',
#  'b6:8b:19',
#  'b6:9c:df',
#  'b6:f6:1c',
#  'b8:03:05',
#  'b8:08:cf',
#  'b8:08:d7',
#  'b8:09:8a',
#  'b8:1d:aa',
#  'b8:2a:72',
#  'b8:2c:a0',
#  'b8:31:b5',
#  'b8:3e:59',
#  'b8:41:a4',
#  'b8:44:d9',
#  'b8:53:ac',
#  'b8:57:d8',
#  'b8:5e:7b',
#  'b8:63:4d',
#  'b8:70:f4',
#  'b8:76:3f',
#  'b8:78:26',
#  'b8:78:2e',
#  'b8:81:98',
#  'b8:85:84',
#  'b8:86:87',
#  'b8:88:e3',
#  'b8:8a:60',
#  'b8:8a:ec',
#  'b8:8d:12',
#  'b8:94:36',
#  'b8:97:5a',
#  'b8:a1:75',
#  'b8:ac:6f',
#  'b8:ae:6e',
#  'b8:ae:ed',
#  'b8:bb:af',
#  'b8:ca:3a',
#  'b8:d7:af',
#  'b8:d9:4d',
#  'b8:e8:56',
#  'b8:e9:37',
#  'b8:ec:a3',
#  'b8:ee:65',
#  'b8:f6:b1',
#  'b8:f8:83',
#  'b8:ff:61',
#  'ba:08:cf',
#  'ba:09:8a',
#  'ba:41:a4',
#  'ba:53:ac',
#  'ba:c1:11',
#  'bc:14:85',
#  'bc:20:ba',
#  'bc:2e:48',
#  'bc:30:5b',
#  'bc:30:7d',
#  'bc:30:7e',
#  'bc:30:d9',
#  'bc:3b:af',
#  'bc:3d:85',
#  'bc:4c:c4',
#  'bc:51:fe',
#  'bc:54:51',
#  'bc:5f:f4',
#  'bc:60:a7',
#  'bc:64:4b',
#  'bc:67:78',
#  'bc:6c:21',
#  'bc:75:74',
#  'bc:76:5e',
#  'bc:77:37',
#  'bc:83:85',
#  'bc:85:56',
#  'bc:8c:cd',
#  'bc:92:6b',
#  'bc:99:11',
#  'bc:a5:8b',
#  'bc:a8:a6',
#  'bc:a9:20',
#  'bc:ad:28',
#  'bc:ae:c5',
#  'bc:b1:81',
#  'bc:b8:63',
#  'bc:c6:db',
#  'bc:dd:c2',
#  'bc:e1:43',
#  'bc:e2:65',
#  'bc:e6:3f',
#  'bc:ec:23',
#  'bc:ec:5d',
#  'bc:ee:7b',
#  'bc:fe:d9',
#  'be:4c:c4',
#  'be:54:36',
#  'be:6c:21',
#  'be:9f:ef',
#  'be:a9:20',
#  'be:e1:43',
#  'be:fe:d9',
#  'c0:11:73',
#  'c0:14:3d',
#  'c0:17:4d',
#  'c0:18:85',
#  'c0:1a:da',
#  'c0:21:0d',
#  'c0:25:e9',
#  'c0:33:5e',
#  'c0:38:96',
#  'c0:3f:0e',
#  'c0:3f:d5',
#  'c0:41:f6',
#  'c0:48:e6',
#  'c0:4a:00',
#  'c0:56:27',
#  'c0:56:e3',
#  'c0:64:c6',
#  'c0:7c:d1',
#  'c0:87:eb',
#  'c0:97:27',
#  'c0:a0:0d',
#  'c0:b6:58',
#  'c0:b6:f9',
#  'c0:cb:38',
#  'c0:cc:f8',
#  'c0:ce:cd',
#  'c0:d0:12',
#  'c0:d0:44',
#  'c0:d2:f3',
#  'c0:d3:c0',
#  'c0:d9:62',
#  'c0:ee:fb',
#  'c0:f2:fb',
#  'c0:f4:e6',
#  'c0:f8:da',
#  'c0:ff:d4',
#  'c2:25:e9',
#  'c4:04:15',
#  'c4:07:2f',
#  'c4:0b:cb',
#  'c4:12:f5',
#  'c4:17:fe',
#  'c4:2c:03',
#  'c4:2f:90',
#  'c4:34:6b',
#  'c4:36:6c',
#  'c4:3d:c7',
#  'c4:42:02',
#  'c4:46:19',
#  'c4:57:6e',
#  'c4:61:8b',
#  'c4:62:ea',
#  'c4:6e:1f',
#  'c4:71:fe',
#  'c4:72:95',
#  'c4:73:1e',
#  'c4:84:66',
#  'c4:85:08',
#  'c4:86:e9',
#  'c4:8e:8f',
#  'c4:93:d9',
#  'c4:95:00',
#  'c4:98:5c',
#  'c4:9a:02',
#  'c4:9d:ed',
#  'c4:9f:4c',
#  'c4:a8:1d',
#  'c4:ab:b2',
#  'c4:b3:01',
#  'c4:d9:87',
#  'c4:e9:84',
#  'c6:12:f5',
#  'c8:02:10',
#  'c8:08:e9',
#  'c8:14:51',
#  'c8:16:bd',
#  'c8:1f:66',
#  'c8:21:58',
#  'c8:2a:14',
#  'c8:38:70',
#  'c8:3a:6b',
#  'c8:3c:85',
#  'c8:54:4b',
#  'c8:60:00',
#  'c8:63:f1',
#  'c8:69:cd',
#  'c8:85:50',
#  'c8:91:f9',
#  'c8:94:bb',
#  'c8:9c:1d',
#  'c8:9c:dc',
#  'c8:a8:23',
#  'c8:bc:c8',
#  'c8:be:19',
#  'c8:cb:b8',
#  'c8:cd:72',
#  'c8:d0:83',
#  'c8:d3:a3',
#  'c8:d3:ff',
#  'c8:d7:b0',
#  'c8:d9:d2',
#  'c8:e0:eb',
#  'c8:f6:50',
#  'c8:f7:33',
#  'c8:ff:28',
#  'cc:20:e8',
#  'cc:21:19',
#  'cc:25:ef',
#  'cc:29:f5',
#  'cc:2d:8c',
#  'cc:2f:71',
#  'cc:3d:82',
#  'cc:40:d0',
#  'cc:44:63',
#  'cc:50:e3',
#  'cc:52:af',
#  'cc:65:ad',
#  'cc:6d:a0',
#  'cc:6e:a4',
#  'cc:78:5f',
#  'cc:79:cf',
#  'cc:7e:e7',
#  'cc:98:8b',
#  'cc:9e:00',
#  'cc:9e:a2',
#  'cc:af:78',
#  'cc:b0:da',
#  'cc:b1:1a',
#  'cc:b2:55',
#  'cc:c0:79',
#  'cc:c7:60',
#  'cc:d2:9b',
#  'cc:ef:48',
#  'cc:f7:35',
#  'cc:fb:65',
#  'ce:6e:a4',
#  'd0:03:4b',
#  'd0:03:df',
#  'd0:04:01',
#  'd0:05:2a',
#  'd0:13:fd',
#  'd0:16:b4',
#  'd0:17:c2',
#  'd0:22:12',
#  'd0:23:db',
#  'd0:27:88',
#  'd0:2b:20',
#  'd0:31:69',
#  'd0:33:11',
#  'd0:39:b3',
#  'd0:4d:2c',
#  'd0:4f:7e',
#  'd0:50:99',
#  'd0:53:49',
#  'd0:57:7b',
#  'd0:65:ca',
#  'd0:66:7b',
#  'd0:67:26',
#  'd0:67:e5',
#  'd0:73:d5',
#  'd0:76:e7',
#  'd0:7e:35',
#  'd0:7f:a0',
#  'd0:81:7a',
#  'd0:84:b0',
#  'd0:87:e2',
#  'd0:94:66',
#  'd0:b1:28',
#  'd0:bf:9c',
#  'd0:c5:d3',
#  'd0:c5:f3',
#  'd0:d2:b0',
#  'd0:d7:83',
#  'd0:df:9a',
#  'd0:e1:40',
#  'd0:e7:82',
#  'd0:fc:cc',
#  'd0:ff:98',
#  'd2:04:01',
#  'd4:04:cd',
#  'd4:0a:a9',
#  'd4:25:8b',
#  'd4:3d:7e',
#  'd4:40:f0',
#  'd4:4b:5e',
#  'd4:61:2e',
#  'd4:61:9d',
#  'd4:61:da',
#  'd4:63:fe',
#  'd4:67:d3',
#  'd4:6a:6a',
#  'd4:6d:6d',
#  'd4:6e:0e',
#  'd4:7a:e2',
#  'd4:81:d7',
#  'd4:85:64',
#  'd4:90:9c',
#  'd4:9a:20',
#  'd4:a1:48',
#  'd4:a3:3d',
#  'd4:ab:82',
#  'd4:ae:05',
#  'd4:ae:52',
#  'd4:be:d9',
#  'd4:c9:ef',
#  'd4:e6:b7',
#  'd6:63:c6',
#  'd6:6e:0e',
#  'd8:00:4d',
#  'd8:08:31',
#  'd8:0d:17',
#  'd8:0f:99',
#  'd8:1c:79',
#  'd8:30:62',
#  'd8:32:e3',
#  'd8:49:2f',
#  'd8:50:e6',
#  'd8:5b:2a',
#  'd8:5d:4c',
#  'd8:5d:e2',
#  'd8:61:62',
#  'd8:63:75',
#  'd8:68:c3',
#  'd8:6b:f7',
#  'd8:6c:63',
#  'd8:6c:e9',
#  'd8:7d:7f',
#  'd8:8f:76',
#  'd8:96:95',
#  'd8:97:ba',
#  'd8:9c:67',
#  'd8:9d:67',
#  'd8:9e:f3',
#  'd8:a2:5e',
#  'd8:af:f1',
#  'd8:bb:2c',
#  'd8:c4:6a',
#  'd8:c7:71',
#  'd8:cb:8a',
#  'd8:ce:3a',
#  'd8:d3:85',
#  'd8:d4:3c',
#  'd8:e0:e1',
#  'd8:eb:97',
#  'd8:f2:ca',
#  'd8:fc:93',
#  'd8:fe:e3',
#  'da:8f:76',
#  'dc:08:0f',
#  'dc:09:4c',
#  'dc:0b:34',
#  'dc:0c:5c',
#  'dc:0e:a1',
#  'dc:1a:c5',
#  'dc:2b:2a',
#  'dc:37:14',
#  'dc:3a:5e',
#  'dc:44:b6',
#  'dc:4a:3e',
#  'dc:4f:22',
#  'dc:53:60',
#  'dc:56:e7',
#  'dc:66:72',
#  'dc:68:eb',
#  'dc:71:44',
#  'dc:72:9b',
#  'dc:74:a8',
#  'dc:85:de',
#  'dc:86:d8',
#  'dc:8b:28',
#  'dc:a2:66',
#  'dc:a4:ca',
#  'dc:a9:04',
#  'dc:a9:71',
#  'dc:d9:16',
#  'dc:ee:06',
#  'dc:ef:09',
#  'dc:ef:ca',
#  'dc:f1:10',
#  'dc:f5:05',
#  'dc:fe:07',
#  'de:55:83',
#  'de:71:44',
#  'de:a4:ca',
#  'e0:06:e6',
#  'e0:0c:7f',
#  'e0:13:b5',
#  'e0:2a:82',
#  'e0:2f:6d',
#  'e0:33:8e',
#  'e0:37:bf',
#  'e0:3f:49',
#  'e0:46:9a',
#  'e0:4f:43',
#  'e0:51:63',
#  'e0:5f:b9',
#  'e0:62:67',
#  'e0:66:78',
#  'e0:69:95',
#  'e0:91:f5',
#  'e0:94:67',
#  'e0:99:71',
#  'e0:9d:31',
#  'e0:a3:ac',
#  'e0:aa:96',
#  'e0:ac:cb',
#  'e0:b5:2d',
#  'e0:b7:0a',
#  'e0:b9:4d',
#  'e0:b9:a5',
#  'e0:b9:ba',
#  'e0:c7:67',
#  'e0:ca:94',
#  'e0:cb:4e',
#  'e0:cb:ee',
#  'e0:ce:c3',
#  'e0:d5:5e',
#  'e0:db:10',
#  'e0:db:55',
#  'e0:dd:c0',
#  'e0:f5:c6',
#  'e0:f8:47',
#  'e2:33:8e',
#  'e2:5f:45',
#  'e2:66:78',
#  'e2:ac:cb',
#  'e2:b5:2d',
#  'e2:f5:c6',
#  'e4:02:9b',
#  'e4:0e:ee',
#  'e4:11:5b',
#  'e4:23:54',
#  'e4:2b:34',
#  'e4:3e:d7',
#  'e4:42:a6',
#  'e4:46:da',
#  'e4:58:e7',
#  'e4:6f:13',
#  'e4:70:b8',
#  'e4:7c:f9',
#  'e4:7d:bd',
#  'e4:8b:7f',
#  'e4:98:d6',
#  'e4:9a:79',
#  'e4:9a:dc',
#  'e4:9e:12',
#  'e4:a4:71',
#  'e4:a7:a0',
#  'e4:a7:c5',
#  'e4:b2:fb',
#  'e4:b3:18',
#  'e4:c4:83',
#  'e4:ce:8f',
#  'e4:d5:3d',
#  'e4:e0:a6',
#  'e4:e0:c5',
#  'e4:e4:ab',
#  'e4:e7:49',
#  'e4:f0:42',
#  'e4:f4:c6',
#  'e4:f8:9c',
#  'e6:2b:34',
#  'e6:6f:13',
#  'e6:9a:79',
#  'e6:9a:dc',
#  'e6:b2:fb',
#  'e6:e4:ab',
#  'e6:f0:42',
#  'e8:03:9a',
#  'e8:06:88',
#  'e8:11:32',
#  'e8:15:0e',
#  'e8:2a:44',
#  'e8:2a:ea',
#  'e8:33:81',
#  'e8:39:35',
#  'e8:39:df',
#  'e8:3a:12',
#  'e8:40:f2',
#  'e8:4e:ce',
#  'e8:50:8b',
#  'e8:5b:5b',
#  'e8:61:7e',
#  'e8:8d:28',
#  'e8:93:09',
#  'e8:94:f6',
#  'e8:9e:b4',
#  'e8:ab:fa',
#  'e8:b1:fc',
#  'e8:b2:ac',
#  'e8:b4:c8',
#  'e8:b7:48',
#  'e8:c7:4f',
#  'e8:d8:19',
#  'e8:de:27',
#  'e8:e8:b7',
#  'e8:eb:11',
#  'e8:ed:f3',
#  'e8:f2:e2',
#  'e8:fc:af',
#  'ea:36:17',
#  'ea:80:2e',
#  'ea:b2:ac',
#  'ea:cc:18',
#  'ec:08:6b',
#  'ec:0e:c4',
#  'ec:10:7b',
#  'ec:1a:59',
#  'ec:1f:72',
#  'ec:2c:e2',
#  'ec:35:86',
#  'ec:3d:fd',
#  'ec:55:f9',
#  'ec:89:14',
#  'ec:8c:9a',
#  'ec:8e:b5',
#  'ec:9a:74',
#  'ec:9b:f3',
#  'ec:a8:6b',
#  'ec:aa:a0',
#  'ec:ad:b8',
#  'ec:b1:d7',
#  'ec:b5:fa',
#  'ec:c4:0d',
#  'ec:d0:9f',
#  'ec:e0:9b',
#  'ec:e1:a9',
#  'ec:f4:51',
#  'ec:f4:bb',
#  'ec:fa:bc',
#  'ee:08:6b',
#  'f0:03:8c',
#  'f0:0f:ec',
#  'f0:18:98',
#  'f0:1b:6c',
#  'f0:1d:bc',
#  'f0:1f:af',
#  'f0:24:75',
#  'f0:27:2d',
#  'f0:27:65',
#  'f0:2f:a7',
#  'f0:42:1c',
#  'f0:43:47',
#  'f0:4d:a2',
#  'f0:4f:7c',
#  'f0:5b:7b',
#  'f0:6e:0b',
#  'f0:76:1c',
#  'f0:76:6f',
#  'f0:79:59',
#  'f0:79:60',
#  'f0:79:e8',
#  'f0:7b:cb',
#  'f0:7d:68',
#  'f0:81:73',
#  'f0:82:61',
#  'f0:92:1c',
#  'f0:98:9d',
#  'f0:99:b6',
#  'f0:99:bf',
#  'f0:b4:79',
#  'f0:bf:97',
#  'f0:c8:50',
#  'f0:cb:a1',
#  'f0:d1:a9',
#  'f0:d5:bf',
#  'f0:db:e2',
#  'f0:db:f8',
#  'f0:ee:10',
#  'f0:f6:1c',
#  'f2:18:98',
#  'f2:24:75',
#  'f2:6d:78',
#  'f2:79:60',
#  'f2:79:e8',
#  'f2:98:9d',
#  'f2:99:b6',
#  'f2:99:bf',
#  'f2:c1:f1',
#  'f2:db:e2',
#  'f2:f6:1c',
#  'f4:06:16',
#  'f4:06:69',
#  'f4:09:d8',
#  'f4:0e:22',
#  'f4:0e:83',
#  'f4:0f:24',
#  'f4:1b:a1',
#  'f4:30:b9',
#  'f4:39:09',
#  'f4:42:8f',
#  'f4:4d:30',
#  'f4:5c:89',
#  'f4:5e:ab',
#  'f4:60:e2',
#  'f4:63:1f',
#  'f4:6b:ef',
#  'f4:6d:04',
#  'f4:71:90',
#  'f4:7b:5e',
#  'f4:81:39',
#  'f4:8b:32',
#  'f4:8c:50',
#  'f4:8e:38',
#  'f4:93:9f',
#  'f4:96:34',
#  'f4:a9:97',
#  'f4:b5:20',
#  'f4:b7:e2',
#  'f4:bf:80',
#  'f4:c2:48',
#  'f4:ca:e5',
#  'f4:cb:52',
#  'f4:ce:46',
#  'f4:ec:38',
#  'f4:f2:6d',
#  'f4:f5:24',
#  'f4:f5:d8',
#  'f4:f5:db',
#  'f4:f5:e8',
#  'f4:f9:51',
#  'f6:0f:24',
#  'f6:31:c3',
#  'f6:37:b7',
#  'f6:5c:89',
#  'f6:f1:5a',
#  'f6:f2:6d',
#  'f8:04:2e',
#  'f8:0b:be',
#  'f8:0d:60',
#  'f8:16:54',
#  'f8:1a:67',
#  'f8:1e:df',
#  'f8:23:b2',
#  'f8:27:93',
#  'f8:28:19',
#  'f8:2d:7c',
#  'f8:2f:a8',
#  'f8:32:e4',
#  'f8:34:41',
#  'f8:38:80',
#  'f8:3f:51',
#  'f8:46:1c',
#  'f8:4d:fc',
#  'f8:59:71',
#  'f8:62:14',
#  'f8:63:3f',
#  'f8:77:b8',
#  'f8:8b:37',
#  'f8:94:c2',
#  'f8:95:c7',
#  'f8:95:ea',
#  'f8:a0:97',
#  'f8:a2:d6',
#  'f8:a9:63',
#  'f8:a9:d0',
#  'f8:ab:05',
#  'f8:b1:56',
#  'f8:bc:12',
#  'f8:c3:9e',
#  'f8:ca:b8',
#  'f8:d0:27',
#  'f8:d0:ac',
#  'f8:d1:11',
#  'f8:da:0c',
#  'f8:e6:1a',
#  'f8:e9:03',
#  'f8:e9:4e',
#  'f8:f5:32',
#  'fa:2d:7c',
#  'fa:38:80',
#  'fa:95:ea',
#  'fa:e9:4e',
#  'fc:01:7c',
#  'fc:03:9f',
#  'fc:0f:e6',
#  'fc:15:b4',
#  'fc:18:3c',
#  'fc:19:10',
#  'fc:25:3f',
#  'fc:2a:9c',
#  'fc:3f:7c',
#  'fc:3f:db',
#  'fc:42:03',
#  'fc:45:96',
#  'fc:4d:d4',
#  'fc:51:a4',
#  'fc:64:3a',
#  'fc:64:ba',
#  'fc:65:de',
#  'fc:75:16',
#  'fc:77:74',
#  'fc:8f:90',
#  'fc:a1:83',
#  'fc:a6:21',
#  'fc:a6:67',
#  'fc:aa:14',
#  'fc:ae:34',
#  'fc:c2:de',
#  'fc:d8:48',
#  'fc:db:b3',
#  'fc:e9:98',
#  'fc:f1:36',
#  'fc:f1:52',
#  'fc:f8:ae',
#  'fc:fc:48',
#  'fe:18:3c',
#  'fe:2a:9c',
#  'fe:b6:d8',
#  'fe:d8:48',
#  'fe:e9:98']

# %% [markdown]
# ## ssdp col

# %%
ssdp_nts = []
for _, row in pd.concat([df_train, df_test], axis=0, sort=False).iterrows():
    if not isinstance(row['ssdp'], list): continue
    for d in row['ssdp']:
        if 'nt' not in d: continue
        nts = d['nt'].split(':')
        if nts[0] != 'urn' and nts[0] != 'upnp': continue
        for nt in nts:
            if nt.replace('.','',1).isdigit(): continue
            if 's' + nt not in ssdp_nts:
                ssdp_nts.append('s' + nt)
ssdp_nts.sort()
print(len(ssdp_nts))
pprint.pprint(ssdp_nts)
# Out:
# 394
# ['s',
#  'sABControl',
#  'sACT',
#  'sACT-Denon',
#  'sAVTransport',
#  'sAccessControlServer',
#  'sAiosDevice',
#  'sAiosServices',
#  'sAirBorne',
#  'sAlarmClock',
#  'sAlphanetworks',
#  'sAquosIPC',
#  'sAudioIn',
#  'sBANAS',
#  'sBasic',
#  'sBasicManagement',
#  'sBasicService',
#  'sBboxTV',
#  'sBelkin',
#  'sBinaryLight',
#  'sBroadCaster',
#  'sCAService',
#  'sCameraConnectedMobileService',
#  'sChangeIP',
#  'sClientImageManager',
#  'sClientOverride',
#  'sConfigDevice',
#  'sConfigService',
#  'sConfigurationManagement',
#  'sConnectionMalager',
#  'sConnectionManager',
#  'sContentDirectory',
#  'sD-LinkCamera-8100lh',
#  'sDCS-2100',
#  'sDCS-3220',
#  'sDCS-3420',
#  'sDCS-5300',
#  'sDCS-5300G',
#  'sDCS-8200LH',
#  'sDCS-935L',
#  'sDCS-935LH',
#  'sDCS-960L',
#  'sDPSConnectionManager',
#  'sDPSPrinter',
#  'sDVR',
#  'sDeviceProperties',
#  'sDeviceProtection',
#  'sDigitalSecurityCamera',
#  'sDigitalSecurityCameraSettings',
#  'sDigitalSecurityCameraStillImage',
#  'sDiscoveryService',
#  'sEmbeddedNetDevice',
#  'sEmbeddedNetDeviceControl',
#  'sEmptyService',
#  'sEnergyManagement',
#  'sErrorHandler',
#  'sEventDevice',
#  'sEventLogService',
#  'sFileTransferServer',
#  'sFileTransport',
#  'sGateway',
#  'sGatewaySkyControl',
#  'sGatewaySkyPairing',
#  'sGatewaySkyRemote',
#  'sGatewaySkyServe',
#  'sGroup',
#  'sGroupControl',
#  'sGroupManagement',
#  'sGroupRenderingControl',
#  'sGsensorControlServer',
#  'sHSBSServer',
#  'sHTControl',
#  'sHVAC_System',
#  'sHiMultiScreenServerDevice',
#  'sHisenseLanControl',
#  'sINETTV_APPLIANCE_service',
#  'sIPControlServer',
#  'sIPControlService',
#  'sIQIYIMediaRenderer',
#  'sIRCC',
#  'sIntelbrasSecurityCamera',
#  'sInternetGatewayDevice',
#  'sLayer3Forwarding',
#  'sLibraryServer',
#  'sLnvConnectDevice',
#  'sLnvConnectService',
#  'sLog',
#  'sMSContentDirectory',
#  'sMainTVAgent2',
#  'sMainTVServer2',
#  'sMaker',
#  'sManageableDevice',
#  'sMediaCenter',
#  'sMediaControl',
#  'sMediaRenderer',
#  'sMediaServer',
#  'sMessageBoxService',
#  'sMirrorControlServer',
#  'sMonitor',
#  'sMotionControlService',
#  'sMultiChannel',
#  'sMultiScreenService',
#  'sMultiroomSpk',
#  'sMusicConnect',
#  'sMusicServices',
#  'sNAS',
#  'sNASOS',
#  'sNMCQueueHandlerDevice',
#  'sNMCServer',
#  'sNMCServerDevice',
#  'sNULL',
#  'sNascontrol',
#  'sNastorage',
#  'sNetCamSensor',
#  'sNetworkManagement',
#  'sNeufBoxEvent',
#  'sNull',
#  'sOCAP_HOST',
#  'sOSDService',
#  'sOSInfo',
#  'sPRINTER',
#  'sParty',
#  'sPersonalMessageReceiver',
#  'sPlaylistExtension',
#  'sPlaylistManager',
#  'sPrintBasic',
#  'sPrintEnhanced',
#  'sPrinter',
#  'sProbeProvider',
#  'sProxyServer',
#  'sQPlay',
#  'sQueue',
#  'sRTSPGateway',
#  'sRVUServer',
#  'sRaumfeldDevice',
#  'sRaumfeldGenerator',
#  'sRemoteAppControlServer',
#  'sRemoteControl',
#  'sRemoteControlReceiver',
#  'sRemoteUIServer',
#  'sRemoteUIServerDevice',
#  'sRenderingControl',
#  'sRoot',
#  'sSBox',
#  'sSBoxControlService',
#  'sSCNAS',
#  'sSMSearch',
#  'sSSTDevice',
#  'sSatIPServer',
#  'sScalarWebAPI',
#  'sScheduledRecording',
#  'sScreenSharing',
#  'sScreenSharingService',
#  'sSecurity',
#  'sSecurityDevice',
#  'sSecurityDeviceControl',
#  'sSessionManagement',
#  'sSetupService',
#  'sSignageM2M',
#  'sSkyBook',
#  'sSkyBrowse',
#  'sSkyCM',
#  'sSkyPairing',
#  'sSkyPlay',
#  'sSkyRC',
#  'sSkyRemote',
#  'sSmartHomeAlliance-org',
#  'sSmartHomeService',
#  'sSpeakerGroup',
#  'sSpeakerManagement',
#  'sStreamBookmark',
#  'sStreamMagic6',
#  'sStreamSplicing',
#  'sSyncControl',
#  'sSyncManager',
#  'sSyncServer',
#  'sSystemProperties',
#  'sTV-IP110WN',
#  'sTV-IP262PI',
#  'sTVTransport',
#  'sTestRCRService',
#  'sUTC',
#  'sUTCInHome',
#  'sUTCLCDI',
#  'sUTCLCDIAPI',
#  'sUTCRCEmulation',
#  'sUTCTrigger',
#  'sUuVol-com',
#  'sUuVolControl',
#  'sUuVolSimpleRemote',
#  'sVIMEControlServer',
#  'sVinputControlServer',
#  'sVirtualLineIn',
#  'sVirtualRemoteControl',
#  'sWANCommonInterfaceConfig',
#  'sWANConnectionDevice',
#  'sWANDevice',
#  'sWANIPConnection',
#  'sWANPOTSLinkConfig',
#  'sWANPPPConnection',
#  'sWFADevice',
#  'sWFAWLANConfig',
#  'sWLANAccessPointDevice',
#  'sWdNAS',
#  'sWdNAS-AP2NC',
#  'sWdNAS-DEV_0064',
#  'sWdNAS-DEV_0083',
#  'sWdNAS-DEV_0092',
#  'sWdNAS-DEV_0094',
#  'sWdNAS-DEV_0096',
#  'sWdNAS-DEV_009B',
#  'sWdNAS-DEV_0102',
#  'sWdNAS-DEV_0104',
#  'sWdNAS-DEV_030B',
#  'sWdNAS-DEV_0314',
#  'sWdNAS-DEV_0402',
#  'sWebdavServer',
#  'sWholeHomeAudioDevice',
#  'sWiAutoConfig',
#  'sWiFiSetup',
#  'sWiNAS',
#  'sWireless Network Camera',
#  'sWirelessNetworkCamera',
#  'sX-JRiver-Library-Server',
#  'sX_ADB_CerberService',
#  'sX_ADB_RemoteControl',
#  'sX_CIS',
#  'sX_HtmlPageHandler',
#  'sX_IPcontrol',
#  'sX_LG_WFDisplay',
#  'sX_MS_MediaReceiverRegistrar',
#  'sX_OrangeSTBRemoteControl',
#  'sX_ServiceManager',
#  'sX_TVersity_Metadata',
#  'sX_Tandem',
#  'sX_Telepathy',
#  'sX_WholeHomeAudio',
#  'sZone',
#  'sZoneControl',
#  'sZoneGroupTopology',
#  'sZonePlayer',
#  'sacn-com',
#  'sadbglobal.com',
#  'sargon_001',
#  'sav-openhome-org',
#  'saxis-com',
#  'sbasic',
#  'sbasicevent',
#  'sbmlinks',
#  'sbouygues-telecom-com',
#  'sbridge',
#  'scellvision',
#  'scomoaudio_001',
#  'sconnector-service',
#  'scontrollee',
#  'scrockpotevent',
#  'sdevice',
#  'sdeviceevent',
#  'sdeviceinfo',
#  'sdial',
#  'sdial-multiscreen-org',
#  'sdialreceiver',
#  'sdimmer',
#  'sdmc-samsung-com',
#  'sfirmwareupdate',
#  'sfs_invalid',
#  'sfs_reference',
#  'sfsapi',
#  'sfsaudsync',
#  'shama_001',
#  'shy-com',
#  'shyipcdevice',
#  'sinsight',
#  'sinvalid',
#  'sinvalid_id',
#  'sinvalid_string',
#  'sinvalid_vendor',
#  'sipccontrol',
#  'siptunnelling',
#  'sivandong',
#  'sjardenevent',
#  'sjminim-org',
#  'sjriver.com',
#  'slge',
#  'slge-com',
#  'slightswitch',
#  'slocalstreamingserver',
#  'smanufacture',
#  'smdx-netflix-com',
#  'smdxdevice',
#  'smediaroom',
#  'smedion_001',
#  'smetainfo',
#  'smicrosoft',
#  'smicrosoft-com',
#  'smicrosoft.com',
#  'smoonplayer',
#  'sncplus_stb',
#  'snetworkstoragedevice',
#  'sneufbox-org',
#  'snosupport',
#  'snw-dtv-jp',
#  'soccc',
#  'sokidata-com',
#  'sonebox',
#  'sorange.com',
#  'sp00DimoraRemoteControl',
#  'sp00NetworkControl',
#  'sp00PANASONIC_SESSION_service',
#  'sp00ProAVControlService',
#  'sp00ProAVController',
#  'sp00RemoteAccess',
#  'sp00RemoteController',
#  'sp01NetCamService',
#  'spanasonic-com',
#  'sprint',
#  'sprinter',
#  'spure_298',
#  'spure_308',
#  'spv-com',
#  'sremote',
#  'sremoteaccess',
#  'srevo_001',
#  'sroberts_001',
#  'srockchip-com',
#  'srockvr',
#  'srootdevice',
#  'sroot�$�\x06��^\x15�?@t�m~ah\x1b�\x01$g�\t'
#  '�����Q�j���\x10=E\x10��4%$��}\x18!�\x11�3>��5H^�?(��&���\x11\x1f�a�j',
#  'srules',
#  'srvualliance-org',
#  'ssagemcom-stblist-service',
#  'ssamsung.com',
#  'ssangean_001',
#  'ssbox-dev-com',
#  'sscansonic_001',
#  'sschemas-awox-com',
#  'sschemas-bmlinks-jp',
#  'sschemas-canon-com',
#  'sschemas-ce-org',
#  'sschemas-cipa-jp',
#  'sschemas-cyberlink-com',
#  'sschemas-denon-com',
#  'sschemas-directv-com',
#  'sschemas-dm-holdings-com',
#  'sschemas-frontier-silicon-com',
#  'sschemas-ickstream-com',
#  'sschemas-konnected-io',
#  'sschemas-microsoft-com',
#  'sschemas-nds-com',
#  'sschemas-nuvotechnologies-com',
#  'sschemas-opencable-com',
#  'sschemas-orange-com',
#  'sschemas-panasonic-com',
#  'sschemas-pure-com',
#  'sschemas-raumfeld-com',
#  'sschemas-rvualliance-org',
#  'sschemas-server-eye-de',
#  'sschemas-sharp-co-jp',
#  'sschemas-smsc-com',
#  'sschemas-sonos-com',
#  'sschemas-sony-com',
#  'sschemas-tencent-com',
#  'sschemas-upnp-org',
#  'sschemas-wd-com',
#  'sschemas-wifialliance-org',
#  'sschemas-xerox-com',
#  'ssensor',
#  'ssensorhub',
#  'ssensorhub-service',
#  'sservice',
#  'sses-com',
#  'ssmartsetup',
#  'ssmartspeaker-audio',
#  'sspotify',
#  'starga_001',
#  'starga_002',
#  'starget',
#  'stechnisat_001',
#  'stidal',
#  'stimesync',
#  'sttmicro_001',
#  'stv',
#  'stvcontrol',
#  'stvdevice',
#  'stversity.com',
#  'stvpicture',
#  'sundok',
#  'supnp',
#  'supnp-logitech-com',
#  'surn',
#  'svirtualSvc',
#  'swebos-second-screen',
#  'swebservice',
#  'swww-seagate-com']

# %% [markdown]
# # Feature preprocessing
#
# Prepare data for ML

# %%
le = preprocessing.LabelEncoder()
classes = list(set(df_train['device_class']))
encoded_classes = le.fit_transform(classes)
classes_indexes = dict(zip(classes, encoded_classes))
index_classes = dict(zip(encoded_classes, classes))
pprint.pprint(classes_indexes)
# Out:
# {'AUDIO': 0,
#  'GAME_CONSOLE': 1,
#  'GENERIC_IOT': 2,
#  'HOME_AUTOMATION': 3,
#  'IP_PHONE': 4,
#  'MEDIA_BOX': 5,
#  'MOBILE': 6,
#  'NAS': 7,
#  'PC': 8,
#  'PRINTER': 9,
#  'SURVEILLANCE': 10,
#  'TV': 11,
#  'VOICE_ASSISTANT': 12}

# %% [markdown]
# Process input data into df.
#
# ## Data to vectors

# %%
def protocol2index(protocol):
    if protocol == 'tcp': return 1
    elif protocol == 'udp': return 2
    else: return 0

def get_ports(services):
    return list(map(lambda x: (x['port'], protocol2index(x['protocol'])), services)) if isinstance(services, list) else []

# def get_manufacturer()
# def get_model()
# def get_premodel()
# def get_upnp_services()

def get_services(mdns_services):
    return mdns_services if isinstance(mdns_services, list) else []

def get_dhcps(dhcp):
    return list(map(lambda x: 'p' + x, dhcp[0]['paramlist'].split(','))) if isinstance(dhcp, list) and 'paramlist' in dhcp[0] else []

# def get_mac()

def get_ssdp_nt(ssdp):
    if not isinstance(ssdp, list): return []
    ret_nts = []
    for d in ssdp:
        if 'nt' not in d: continue
        nts = d['nt'].split(':')
        if nts[0] != 'urn' and nts[0] != 'upnp': continue
        for nt in nts:
            if nt.replace('.','',1).isdigit(): continue
            if 's' + nt not in ret_nts:
                ret_nts.append('s' + nt)
    return ret_nts

# def get_upnp_services()

mac2index = dict(zip(macs, le.fit_transform(macs)))
manufacturer2index = dict(zip(manufacturers, le.fit_transform(manufacturers)))
model2index = dict(zip(models, le.fit_transform(models)))
premodel2index = dict(zip(premodels, le.fit_transform(premodels)))

# %%
def input2df(input_df, ports, manufacturers, services, macs, dhcps, models, premodels, ssdp_nts, upnp_services, is_train=True):
    t_start = time.time()
    col_names = ports + ['manufacturer'] + services + dhcps + ['mac'] + ['model'] + ['premodel'] + ssdp_nts + upnp_services
#     col_names = ports + services + ['mac'] + ['model'] + ['premodel'] + upnp_services
#     col_names = ports + ['manufacturer'] + services + ['mac'] + ['model'] + ['premodel'] + upnp_services
    if is_train:
        col_names += ['CLASS']
    col2index_dict = dict(zip(col_names, range(len(col_names))))
    in_dict = dict((k, []) for k in col_names)

#     c = 0

    for _, row in input_df.iterrows():
#         if(c == 7000): break
        new_row = np.zeros(len(col_names))

        curr_ports = get_ports(row['services'])
        curr_manufacturer = get_manufacturer(row['upnp'])
        curr_services = get_services(row['mdns_services'])
        curr_mac = get_mac(row['mac'])
        curr_dhcp = get_dhcps(row['dhcp'])
        curr_model = get_model(row['upnp'])
        curr_premodel = get_premodel(row['upnp'])
        curr_ssdp_nts = get_ssdp_nt(row['ssdp'])
        curr_upnp_services = get_upnp_services(row['upnp'])

        for p, val in curr_ports:
            if p in col2index_dict.keys():
                new_row[col2index_dict[p]] = val
        if curr_manufacturer in manufacturer2index.keys():
            new_row[col2index_dict['manufacturer']] = manufacturer2index[curr_manufacturer]
#             new_row[col2index_dict[curr_manufacturer]] = 1
        for s in curr_services:
            if s in col2index_dict.keys():
                new_row[col2index_dict[s]] = 1
        if curr_mac in mac2index.keys():
            new_row[col2index_dict['mac']] = mac2index[curr_mac]
        for p in curr_dhcp:
            if p in col2index_dict.keys():
                new_row[col2index_dict[p]] = 1
        if curr_model in model2index.keys():
            new_row[col2index_dict['model']] = model2index[curr_model]
        if curr_premodel in premodel2index.keys():
            new_row[col2index_dict['premodel']] = premodel2index[curr_premodel]
        for nt in curr_ssdp_nts:
            if nt in col2index_dict.keys():
                new_row[col2index_dict[nt]] = 1
        for us in curr_upnp_services:
            if us in col2index_dict.keys():
                new_row[col2index_dict[us]] = 1
        if is_train:
            new_row[-1] = classes_indexes[row['device_class']]

        for n, k in enumerate(in_dict.keys()):
            in_dict[k].append(new_row[n])

#         c += 1
    
    output = pd.DataFrame(in_dict)
    print("Seconds: {}".format(round(time.time() - t_start)))
    return output

# %%
get_ports(df_train['services'][0])
# Out:
# [(80, 1), (443, 1), (1434, 2), (5060, 1), (5351, 2), (5353, 2), (5683, 2)]

# %%
get_manufacturer(df_train['upnp'][2])
# Out:
# 'Denon'

# %%
get_services(df_train['mdns_services'][2])
# Out:
# ['_airplay._tcp.local.',
#  '_spotify-connect._tcp.local.',
#  '_raop._tcp.local.',
#  '_http._tcp.local.']

# %%
get_mac(df_train['mac'][0])
# Out:
# '80:5e:c0'

# %%
get_dhcps(df_train['dhcp'][4])
# Out:
# ['p1',
#  'p28',
#  'p2',
#  'p3',
#  'p15',
#  'p6',
#  'p119',
#  'p12',
#  'p44',
#  'p47',
#  'p26',
#  'p121',
#  'p42']

# %%
get_ssdp_nt(df_train['ssdp'][1])
# Out:
# ['supnp',
#  'srootdevice',
#  'surn',
#  'sschemas-upnp-org',
#  'sservice',
#  'sBasicManagement',
#  'sdevice',
#  'sManageableDevice',
#  'sDeviceProtection',
#  'sConfigurationManagement',
#  'sMediaServer',
#  'sConnectionManager',
#  'sContentDirectory']

# %%
get_upnp_services(df_train['upnp'][1])
# Out:
# ['ContentDirectory',
#  'ConnectionManager',
#  'BasicManagement',
#  'ConfigurationManagement',
#  'DeviceProtection',
#  'dial']

# %% [markdown]
# ## Splitting data

# %%
df = input2df(df_train, ports, manufacturers, services, macs, dhcps, models, premodels, ssdp_nts, upnp_services)
# Out:
# Seconds: 3638

# %%
# A) Use train data only
# X_train, X_test, y_train, y_test = train_test_split(df.drop('CLASS', axis=1), df['CLASS'], test_size=0.2)

# B) Perform regular ML
X_train = df.drop('CLASS', axis=1)
y_train = df['CLASS']

# %% [markdown]
# # Clasification method
#
# ## Method experiments
#
# (In case A)

# %%
t_start = time.time()
knn = KNeighborsClassifier(n_neighbors=10, n_jobs=4, p=1)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
t_end = time.time()
print("F1-score:", metrics.f1_score(y_test, y_pred, average='micro'))
print("Time:", t_end - t_start)
# Out:
# F1-score: 0.8866666666666667
# Time: 11.554763555526733

# %%
t_start = time.time()
knn = KNeighborsClassifier(n_neighbors=10, n_jobs=4, p=2)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
t_end = time.time()
print("F1-score:", metrics.f1_score(y_test, y_pred, average='micro'))
print("Time:", t_end - t_start)
# Out:
# F1-score: 0.8683333333333333
# Time: 12.049591302871704

# %%
t_start = time.time()
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)
t_end = time.time()
print("F1-score:", metrics.f1_score(y_test, y_pred, average='micro'))
print("Time:", t_end - t_start)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# F1-score: 0.8975
# Time: 2.624030590057373

# %%
t_start = time.time()
svc = SVC()
svc.fit(X_train, y_train)
y_pred = svc.predict(X_test)
t_end = time.time()
print("F1-score:", metrics.f1_score(y_test, y_pred, average='micro'))
print("Time:", t_end - t_start)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# F1-score: 0.24333333333333335
# Time: 411.25162148475647

# %%
t_start = time.time()
gaussian = GaussianNB()
gaussian.fit(X_train, y_train)
y_pred = gaussian.predict(X_test)
t_end = time.time()
print("F1-score:", metrics.f1_score(y_test, y_pred, average='micro'))
print("Time:", t_end - t_start)
# Out:
# F1-score: 0.7716666666666666
# Time: 2.0739998817443848

# %%
t_start = time.time()
random_forest = RandomForestClassifier(n_estimators=100)
random_forest.fit(X_train, y_train)
y_pred = random_forest.predict(X_test)
t_end = time.time()
print("F1-score:", metrics.f1_score(y_test, y_pred, average='micro'))
print("Time:", t_end - t_start)
# Out:
# F1-score: 0.969
# Time: 27.08111023902893

# %%
# for n in range(100, 410, 10):
#     t_start = time.time()
#     random_forest = RandomForestClassifier(n_estimators=n)
#     random_forest.fit(X_train, y_train)
#     y_pred = random_forest.predict(X_test)
#     t_end = time.time()
#     print("n =", n)
#     print("F1-score:", metrics.f1_score(y_test, y_pred, average='micro'))
#     print("Time:", t_end - t_start, "\n")
    
#     t_start = time.time()
#     random_forest = RandomForestClassifier(n_estimators=n, max_features=None)
#     random_forest.fit(X_train, y_train)
#     y_pred = random_forest.predict(X_test)
#     t_end = time.time()
#     print("n =", n)
#     print("F1-score:", metrics.f1_score(y_test, y_pred, average='micro'))
#     print("Time:", t_end - t_start, "\n")

# %% [markdown]
# ## Chosen method application
#
# **(In case B)**

# %%
X_test = input2df(df_test, ports, manufacturers, services, macs, dhcps, models, premodels, ssdp_nts, upnp_services, is_train=False)
# Out:
# Seconds: 5532

# %% [markdown]
# # Train data eval

# %%
classifier = RandomForestClassifier(n_estimators=50, n_jobs=-1)
# classifier = LogisticRegression(n_jobs=-1)
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=-1,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)

# %%
y_pred = classifier.predict(X_test)

# %%
pred = list(map(lambda x: index_classes[x], y_pred))
output_df = pd.DataFrame({'Id': df_test['device_id'], 'Predicted': pred})
output_df
# Out:
#                                          Id        Predicted
# 0      a3529c63-8d5f-4a90-85f0-33a10b9c5ca4           MOBILE
# 1      addb3142-6b4a-4aef-9d00-ce7ab250c05c     GAME_CONSOLE
# 2      939102ad-730b-48e5-8f36-438a68192aa9               TV
# 3      e8b4c2b1-8820-475d-8f75-0f1dda325539               TV
# 4      6e7e5101-9f82-45c8-a0f0-17f58f77d82c  HOME_AUTOMATION
# 5      89197990-6549-4463-89e0-929c3d8c988a               TV
# 6      655699d3-e035-4dcd-b5be-4d55280ac41b               TV
# 7      1cbfb119-74b0-488e-99fe-6f4aac53248a         IP_PHONE
# 8      1a5d561a-2e87-4e0f-8610-b7c39293f169     GAME_CONSOLE
# 9      9e574f6a-8a96-48e8-b3fd-1da1f0c2965c     GAME_CONSOLE
# 10     4a7d5491-1ac4-4b2d-b7c9-f79984401b9c               TV
# 11     eaa1afaa-e0a3-4ccc-80f7-5e85d3567806        MEDIA_BOX
# 12     5cd5447f-f2be-443f-8bf7-9f750a9d0e85  HOME_AUTOMATION
# 13     fe6726d8-77a5-40f7-aeee-1cc233664660     GAME_CONSOLE
# 14     be1ba352-e697-4310-a781-2e4c80f27733        MEDIA_BOX
# 15     b5ba21a8-d5e1-4704-a539-bd988ec18618        MEDIA_BOX
# 16     fd5838f8-c53f-4a1e-8542-b362513ecc02               PC
# 17     79185607-7ce8-4a37-bc71-be697f14146d            AUDIO
# 18     b595aefd-dd49-4a7d-8d06-008a72271c35          PRINTER
# 19     fa13df6b-090b-4210-91cf-8ccba1ade13a        MEDIA_BOX
# 20     d9357155-d77c-4332-a087-2219d3d6894d        MEDIA_BOX
# 21     2cb4bf53-1c70-4a95-959a-09ec4f7260a1     GAME_CONSOLE
# 22     66eae4ee-5443-4075-9f42-7d9301409abb           MOBILE
# 23     c5cc55e9-83d2-4e50-a45a-5090f58b9802               TV
# 24     2aad1186-575c-4c13-b692-4b1106be03e3               TV
# 25     4fb17e41-8111-44d9-9345-ce874ce8bd9b     GAME_CONSOLE
# 26     48f39869-f964-4f7c-9cfe-9fab066b1a3b               PC
# 27     7e4e1c14-3dfe-4e9f-9fac-10a8a395b0ab               PC
# 28     29682cef-547c-4fa0-8714-45b7b604f646     GAME_CONSOLE
# 29     64002d04-a4d5-4e7f-a2d1-3875c46f54d7            AUDIO
# ...                                     ...              ...
# 77747  b8ee7d51-d6c5-4dbb-baa1-3565403f67f7     GAME_CONSOLE
# 77748  79be04fe-0af0-45b2-be46-947af03a5b97               PC
# 77749  f2955c2f-ddd7-44c3-8aa3-56ce283f6480            AUDIO
# 77750  1e8a4bdf-c15b-4c4e-9570-bff4c43ec2e9               PC
# 77751  730191bd-0a20-4214-864a-bfee96f5fb89            AUDIO
# 77752  9ea89f84-f1f8-4c02-bdaa-beaa063f59a7     GAME_CONSOLE
# 77753  b93dc64e-9c76-468f-8786-e6c99bc689bd               TV
# 77754  5e89d214-3ac7-439a-a70e-e26ed92fbb7d               TV
# 77755  5bde04bc-609b-4bfd-a962-47716287e7ed               PC
# 77756  66d6e1c0-712a-4aaa-ad0b-d28b3635e791               TV
# 77757  20c32ad6-fb8e-4c02-b387-7bd891ef0f33              NAS
# 77758  4ca7554f-3f90-4626-a750-4885cb4af239     GAME_CONSOLE
# 77759  f96d86e4-ca99-413f-bca0-e2023d2b3199            AUDIO
# 77760  edc44c51-3933-4b80-82b1-81ae37abf2ac               TV
# 77761  fff5dec1-9c27-456e-8340-04276ec2223f          PRINTER
# 77762  98f9652d-6d1f-4af6-ad42-18694b31c4d6          PRINTER
# 77763  cf986cfc-2631-42ac-873c-d722502a0fa7     GAME_CONSOLE
# 77764  b007b511-c699-4f26-9ee5-6f97939e5c21            AUDIO
# 77765  3cd6e998-5de3-4e8c-b388-e8ae971a1f1e     SURVEILLANCE
# 77766  b33c8526-9c44-412f-8796-8b03458fbdee          PRINTER
# 77767  3ab9afd8-8766-41a2-be87-771a7a1bfe9d     GAME_CONSOLE
# 77768  b3934917-2b91-4826-8aff-4a1c1fe27a43               TV
# 77769  4f29cabe-c282-4b0a-b645-dcecacba53a2              NAS
# 77770  84a775cb-d61b-4266-97aa-61a13eb18b7b     GAME_CONSOLE
# 77771  17a42d25-fa3a-48d9-baaa-07a5f9a3b670        MEDIA_BOX
# 77772  8a1fe622-0eb5-459a-8692-f8054803bf93               TV
# 77773  ddf0ce06-691e-4d3a-8b0b-8e10555bdb67  HOME_AUTOMATION
# 77774  54f91d02-aef5-4c38-9012-662954efab28        MEDIA_BOX
# 77775  6c6c410a-dda3-4703-b6d7-81fee10bd6a9           MOBILE
# 77776  85d6317c-8a38-4910-82e8-46d5c53506b4               TV
#
# [77777 rows x 2 columns]

# %%
output_df.to_csv('submission.csv', sep=',', index=False)
